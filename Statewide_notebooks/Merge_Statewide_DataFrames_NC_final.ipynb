# %% [markdown]
# # Obtain

# %%
## Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt
import plotly.express as px

# %%
## Import functions made specifically for this project
from capstone_functions import *

# %%
## Set options for displaying Pandas DataFrames
pd.options.display.max_columns = 100
pd.options.display.max_rows = 120

# %%
## Define which NC voter registration columns to load in
vreg_cols_to_use = ['voter_status_desc', 'voter_status_reason_desc', 
                    'last_name', 'first_name', 'middle_name', 
                    'res_street_address', 'res_city_desc', 'state_cd',
                    'zip_code', 'race_code', 'ethnic_code', 'party_cd',
                    'gender_code', 'birth_age', 'birth_state', 
                    'drivers_lic', 'registr_dt', 'precinct_abbrv', 
                    'cong_dist_abbrv', 'super_court_abbrv', 
                    'judic_dist_abbrv', 'nc_senate_abbrv', 'nc_house_abbrv',
                    'school_dist_abbrv', 'dist_1_abbrv', 'confidential_ind', 
                    'birth_year', 'ncid', 'vtd_abbrv']

# %%
## Load in voter registration data for NC
nc_vreg = pd.read_table('Data/ncvoter_Statewide.zip', encoding='ISO-8859-1',
                        usecols=vreg_cols_to_use, 
                       dtype={'precinct_abbrv': str, 
                              'super_court_abbrv': str, 
                              'judic_dist_abbrv': str,
                              'school_dist_abbrv': str,
                              'vtd_abbrv': str
                             })
nc_vreg.head()
# Out:
#   voter_status_desc voter_status_reason_desc   last_name first_name  \
# 0            ACTIVE                 VERIFIED       AABEL       RUTH
# 1            ACTIVE                 VERIFIED      AARDEN       JONI
# 2            ACTIVE     VERIFICATION PENDING  AARMSTRONG    TIMOTHY
# 3            ACTIVE                 VERIFIED       AARON  CHRISTINA
# 4            ACTIVE                 VERIFIED       AARON    CLAUDIA
#
#   middle_name                   res_street_address res_city_desc state_cd  \
# 0      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 1      AUTUMN                     117 W CLAY ST           MEBANE       NC
# 2       DUANE               3670  COVINGTON TRL           MEBANE       NC
# 3    CASTAGNA                    421  WHITT AVE       BURLINGTON       NC
# 4      HAYDEN                    1013  EDITH ST       BURLINGTON       NC
#
#    zip_code race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0   27253.0         W          NL      UNA           F         85          NY
# 1   27302.0         W          UN      UNA           F         42          DC
# 2   27302.0         W          UN      REP           M         54          AL
# 3   27215.0         W          UN      UNA           F         44          NC
# 4   27215.0         W          NL      UNA           F         75          VA
#
#   drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           N  10/01/1984            08N             13.0               15A
# 1           Y  02/23/2018            10N             13.0               15A
# 2           N  10/31/2020            103             13.0               15A
# 3           Y  03/26/1996            03S             13.0               15A
# 4           Y  08/15/1989            124             13.0               15A
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 0              15A             24.0            64.0               NaN
# 1              15A             24.0            63.0               NaN
# 2              15A             24.0            63.0               NaN
# 3              15A             24.0            64.0               NaN
# 4              15A             24.0            63.0               NaN
#
#    dist_1_abbrv confidential_ind  birth_year      ncid vtd_abbrv
# 0          17.0                N        1935   AA56273       08N
# 1          17.0                N        1978  AA201627       10N
# 2          17.0                N        1966  AA216996       103
# 3          17.0                N        1976   AA98377       03S
# 4          17.0                N        1945   AA69747       124

# %%
## Define which NC voter history columns to load in
vhis_cols_to_use = ['county_id', 'voter_reg_num', 'election_lbl', 
                    'election_desc', 'voting_method', 'voted_party_cd', 
                    'pct_label', 'ncid', 'voted_county_id', 'vtd_label']

# %%
## Load in voter history data for NC
nc_vhis = pd.read_table('Data/ncvhis_Statewide.zip',
                        usecols=vhis_cols_to_use)
nc_vhis.head()
# Out:
#    county_id  voter_reg_num election_lbl       election_desc  \
# 0          1        9050398   11/08/2016  11/08/2016 GENERAL
# 1          1        9050398   03/03/2020  03/03/2020 PRIMARY
# 2          1        9050398   11/03/2020  11/03/2020 GENERAL
# 3          1        9050405   11/08/2016  11/08/2016 GENERAL
# 4          1        9050405   03/15/2016  03/15/2016 PRIMARY
#
#       voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 0  ABSENTEE ONESTOP            UNA        07  AA100000                1
# 1         IN-PERSON            REP        07  AA100000                1
# 2  ABSENTEE ONESTOP            UNA        07  AA100000                1
# 3  ABSENTEE ONESTOP            REP       09S  AA100006                1
# 4         IN-PERSON            REP       09S  AA100006                1
#
#   vtd_label
# 0        07
# 1        07
# 2        07
# 3       09S
# 4       09S

# %% [markdown]
# # Scrub and Explore

# %%
## Check metadata for voter registration dataframe
nc_vreg.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8309352 entries, 0 to 8309351
# Data columns (total 29 columns):
# voter_status_desc           8309352 non-null object
# voter_status_reason_desc    8309351 non-null object
# last_name                   8309163 non-null object
# first_name                  8309199 non-null object
# middle_name                 7712276 non-null object
# res_street_address          8309352 non-null object
# res_city_desc               7553949 non-null object
# state_cd                    7554189 non-null object
# zip_code                    7553848 non-null float64
# race_code                   8309352 non-null object
# ethnic_code                 8309352 non-null object
# party_cd                    8309352 non-null object
# gender_code                 8309352 non-null object
# birth_age                   8309352 non-null int64
# birth_state                 6688979 non-null object
# drivers_lic                 8309352 non-null object
# registr_dt                  8309352 non-null object
# precinct_abbrv              7414614 non-null object
# cong_dist_abbrv             7414614 non-null float64
# super_court_abbrv           7414614 non-null object
# judic_dist_abbrv            7414614 non-null object
# nc_senate_abbrv             7414614 non-null float64
# nc_house_abbrv              7414614 non-null float64
# school_dist_abbrv           5857959 non-null object
# dist_1_abbrv                7414614 non-null float64
# confidential_ind            8309352 non-null object
# birth_year                  8309352 non-null int64
# ncid                        8309352 non-null object
# vtd_abbrv                   7414614 non-null object
# dtypes: float64(5), int64(2), object(22)
# memory usage: 1.8+ GB

# %%
## Check metadata for voter history dataframe
nc_vhis.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34818053 entries, 0 to 34818052
# Data columns (total 10 columns):
# county_id          34818053 non-null int64
# voter_reg_num      34818053 non-null int64
# election_lbl       34818053 non-null object
# election_desc      34818053 non-null object
# voting_method      34818051 non-null object
# voted_party_cd     34806146 non-null object
# pct_label          34818053 non-null object
# ncid               34818053 non-null object
# voted_county_id    34818053 non-null int64
# vtd_label          34097359 non-null object
# dtypes: int64(3), object(7)
# memory usage: 2.6+ GB

# %% [markdown]
# ## Explore Duplicate Records

# %%
## Check for duplicate entries in voter registration data
nc_vreg.duplicated().sum()
# Out:
# 0

# %%
## Check for duplicate entries in voter history data
nc_vhis.duplicated().sum()
# Out:
# 410

# %%
## Inspect duplicate entries in voter history data
exact_dup_vhis = nc_vhis.loc[nc_vhis.duplicated()]
exact_dup_vhis
# Out:
#           county_id  voter_reg_num election_lbl  \
# 765568            5          39380   07/17/2012
# 765569            5          39380   05/06/2014
# 765571            5          39380   06/07/2016
# 765572            5          39380   03/15/2016
# 765573            5          39380   11/08/2011
# 765575            5          39380   05/08/2012
# 839967            6          23708   05/08/2018
# 869446            6          24491   11/06/2012
# 869464            6          24506   11/06/2012
# 869471            6          24508   11/06/2012
# 883196            6           4744   11/06/2012
# 883197            6           4744   05/08/2012
# 901078            7          11265   11/04/2014
# 901079            7          11265   07/15/2014
# 903612            7          12033   11/06/2012
# 907876            7          13246   07/15/2014
# 910168            7          13912   11/06/2012
# 945041            7          24180   11/06/2012
# 947375            7          24746   05/08/2012
# 947376            7          24746   11/04/2014
# 947377            7          24746   11/06/2012
# 951977            7          26307   11/06/2012
# 973899            7          33974   11/06/2012
# 973900            7          33974   07/17/2012
# 990822            7          76605   05/08/2012
# 990823            7          76605   11/06/2012
# 1032380           7          50189   11/06/2012
# 1050705           7          56646   11/08/2016
# 1060635          48           8828   11/06/2012
# 1070573           7           4591   05/08/2012
# 1090443           7           7708   05/06/2014
# 1090444           7           7708   05/08/2012
# 1090445           7           7708   11/04/2014
# 1090446           7           7708   11/06/2012
# 2350243          11         372852   05/06/2014
# 2350244          11         372852   11/04/2014
# 3106362          16         114021   11/06/2018
# 3349467          90         325228   09/10/2019
# 3349470          90         325228   03/03/2020
# 4138463          16         120735   11/06/2018
# 4189050          16         109529   11/06/2018
# 4205695          16         120734   11/06/2018
# 4207705          16         113179   11/06/2018
# 4243446          67         453877   11/08/2016
# 4254239          67         417166   11/06/2012
# 4258172          16         102747   11/08/2016
# 4626487          18       30089625   11/06/2012
# 5143680          19         153175   11/06/2018
# 5199641          20          51741   11/06/2012
# 5379205          23        1051739   11/08/2016
# 5726301          24          22105   05/08/2012
# 5726302          24          22105   11/06/2012
# 5825343          24          72510   05/06/2014
# 5876762          25         133830   11/06/2012
# 5915222          60     1000365727   05/08/2012
# 5950611          16         120885   11/06/2018
# 6132620          16         110712   05/08/2012
# 6736271          26      166030251   11/08/2016
# 6736273          26      166030251   11/06/2012
# 7232451          27          44653   11/04/2014
# ...             ...            ...          ...
# 29200537         90         155790   11/06/2012
# 29207891         90         157758   11/08/2016
# 29208468         90         157930   11/06/2012
# 29208595         90         157965   11/06/2012
# 29208596         90         157965   03/15/2016
# 29208597         90         157965   11/04/2014
# 29213068         90         159141   11/06/2012
# 29213069         90         159141   11/04/2014
# 29219533         90          10836   05/08/2018
# 29219540         90          10836   11/08/2016
# 29244049         90         338953   11/06/2018
# 29245054         90         167702   05/08/2012
# 29250341         90         271801   11/06/2012
# 29258047         34       30243863   11/06/2012
# 29261425         90         172038   11/06/2012
# 29400009         51       33144031   05/08/2012
# 29400028         51       33142973   05/08/2012
# 29401667         91         132589   11/06/2012
# 29710923         92      100402899   10/08/2013
# 29710925         92      100402899   11/06/2012
# 29710926         92      100402899   05/08/2012
# 29710936         92      100402899   05/06/2014
# 29710939         92      100402899   10/11/2011
# 29865573         92      100577538   11/06/2012
# 29865574         92      100577538   11/04/2014
# 30127288         92      100812686   11/06/2018
# 30354983         92      100331068   05/08/2012
# 30354986         92      100331068   11/06/2012
# 30354991         92      100331068   10/11/2011
# 30354992         92      100331068   07/17/2012
# 30663509         92       10301748   05/08/2012
# 30839138         92      100425883   11/04/2014
# 30839141         92      100425883   05/06/2014
# 31061311         92        7603890   05/08/2012
# 31503804          7          51006   11/06/2012
# 31503806          7          51006   11/04/2014
# 32142320         92      100331080   11/06/2012
# 32142321         92      100331080   05/08/2012
# 32142322         92      100331080   10/11/2011
# 32142323         92      100331080   07/17/2012
# 32510086         92      100366748   11/06/2012
# 32990168         92      100183023   11/06/2018
# 33115203         35          83153   11/08/2016
# 33311449         92      100291427   11/06/2012
# 33472481         93          11351   11/08/2016
# 33476639         93          13371   11/06/2012
# 33492012         93          19663   11/06/2012
# 33492810         93          19943   07/17/2012
# 33492811         93          19943   05/06/2014
# 33492812         93          19943   05/08/2012
# 33500061         93          22779   11/06/2012
# 33507136         93          25891   07/17/2012
# 33508637         42          98241   11/06/2012
# 33509674         93          27042   11/06/2012
# 33510580         93          28101   05/06/2014
# 33525457         93           4534   11/06/2012
# 33565326         94       30006971   11/06/2012
# 34142042         54         452305   03/03/2020
# 34535877         98       57484692   11/08/2016
# 34634357         99          15048   11/06/2018
#
#                              election_desc     voting_method voted_party_cd  \
# 765568           07/17/2012 SECOND PRIMARY         IN-PERSON            REP
# 765569                  05/06/2014 PRIMARY         IN-PERSON            REP
# 765571    06/07/2016 CONGRESSIONAL PRIMARY         IN-PERSON            REP
# 765572                  03/15/2016 PRIMARY         IN-PERSON            REP
# 765573                11/08/2011 MUNICIPAL         IN-PERSON            UNA
# 765575                  05/08/2012 PRIMARY         IN-PERSON            REP
# 839967                  05/08/2018 PRIMARY       PROVISIONAL            REP
# 869446                  11/06/2012 GENERAL       PROVISIONAL            UNA
# 869464                  11/06/2012 GENERAL       PROVISIONAL            UNA
# 869471                  11/06/2012 GENERAL       PROVISIONAL            UNA
# 883196                  11/06/2012 GENERAL         IN-PERSON            DEM
# 883197                  05/08/2012 PRIMARY         IN-PERSON            DEM
# 901078                  11/04/2014 GENERAL         IN-PERSON            REP
# 901079           07/15/2014 SECOND PRIMARY         IN-PERSON            REP
# 903612                  11/06/2012 GENERAL         IN-PERSON            DEM
# 907876           07/15/2014 SECOND PRIMARY  ABSENTEE ONESTOP            DEM
# 910168                  11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
# 945041                  11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
# 947375                  05/08/2012 PRIMARY         IN-PERSON            REP
# 947376                  11/04/2014 GENERAL         IN-PERSON            REP
# 947377                  11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 951977                  11/06/2012 GENERAL         IN-PERSON            REP
# 973899                  11/06/2012 GENERAL         IN-PERSON            UNA
# 973900           07/17/2012 SECOND PRIMARY  ABSENTEE ONESTOP            REP
# 990822                  05/08/2012 PRIMARY         IN-PERSON            DEM
# 990823                  11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
# 1032380                 11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 1050705                 11/08/2016 GENERAL  ABSENTEE ONESTOP            UNA
# 1060635                 11/06/2012 GENERAL       PROVISIONAL            REP
# 1070573                 05/08/2012 PRIMARY         IN-PERSON            DEM
# 1090443                 05/06/2014 PRIMARY         IN-PERSON            DEM
# 1090444                 05/08/2012 PRIMARY         IN-PERSON            DEM
# 1090445                 11/04/2014 GENERAL  ABSENTEE ONESTOP            DEM
# 1090446                 11/06/2012 GENERAL         IN-PERSON            DEM
# 2350243                 05/06/2014 PRIMARY         IN-PERSON            DEM
# 2350244                 11/04/2014 GENERAL         IN-PERSON            DEM
# 3106362                 11/06/2018 GENERAL       PROVISIONAL            REP
# 3349467                 09/10/2019 GENERAL         IN-PERSON            DEM
# 3349470                 03/03/2020 PRIMARY  ABSENTEE ONESTOP            DEM
# 4138463                 11/06/2018 GENERAL       PROVISIONAL            REP
# 4189050                 11/06/2018 GENERAL       PROVISIONAL            UNA
# 4205695                 11/06/2018 GENERAL       PROVISIONAL            REP
# 4207705                 11/06/2018 GENERAL       PROVISIONAL            UNA
# 4243446                 11/08/2016 GENERAL       PROVISIONAL            REP
# 4254239                 11/06/2012 GENERAL       PROVISIONAL            DEM
# 4258172                 11/08/2016 GENERAL       PROVISIONAL            REP
# 4626487                 11/06/2012 GENERAL         IN-PERSON            REP
# 5143680                 11/06/2018 GENERAL  ABSENTEE ONESTOP            DEM
# 5199641                 11/06/2012 GENERAL       PROVISIONAL            UNA
# 5379205                 11/08/2016 GENERAL  ABSENTEE ONESTOP            UNA
# 5726301                 05/08/2012 PRIMARY         IN-PERSON            DEM
# 5726302                 11/06/2012 GENERAL         IN-PERSON            DEM
# 5825343                 05/06/2014 PRIMARY       PROVISIONAL            DEM
# 5876762                 11/06/2012 GENERAL       PROVISIONAL            UNA
# 5915222                 05/08/2012 PRIMARY       PROVISIONAL            DEM
# 5950611                 11/06/2018 GENERAL       PROVISIONAL            REP
# 6132620                 05/08/2012 PRIMARY       PROVISIONAL            REP
# 6736271                 11/08/2016 GENERAL  ABSENTEE ONESTOP            DEM
# 6736273                 11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 7232451                 11/04/2014 GENERAL       PROVISIONAL            NaN
# ...                                    ...               ...            ...
# 29200537                11/06/2012 GENERAL         IN-PERSON            REP
# 29207891                11/08/2016 GENERAL         IN-PERSON            DEM
# 29208468                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 29208595                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 29208596                03/15/2016 PRIMARY         IN-PERSON            DEM
# 29208597                11/04/2014 GENERAL  ABSENTEE ONESTOP            DEM
# 29213068                11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 29213069                11/04/2014 GENERAL         IN-PERSON            REP
# 29219533                05/08/2018 PRIMARY  ABSENTEE ONESTOP            REP
# 29219540                11/08/2016 GENERAL  ABSENTEE ONESTOP            REP
# 29244049                11/06/2018 GENERAL       PROVISIONAL            UNA
# 29245054                05/08/2012 PRIMARY         IN-PERSON            REP
# 29250341                11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 29258047                11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 29261425                11/06/2012 GENERAL         IN-PERSON            UNA
# 29400009                05/08/2012 PRIMARY       PROVISIONAL            DEM
# 29400028                05/08/2012 PRIMARY       PROVISIONAL            DEM
# 29401667                11/06/2012 GENERAL         IN-PERSON            DEM
# 29710923    10/08/2013 RALEIGH CARY SCHOOL         IN-PERSON            DEM
# 29710925                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 29710926                05/08/2012 PRIMARY         IN-PERSON            DEM
# 29710936                05/06/2014 PRIMARY         IN-PERSON            DEM
# 29710939    10/11/2011 RALEIGH CARY SCHOOL         IN-PERSON            DEM
# 29865573                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 29865574                11/04/2014 GENERAL  ABSENTEE ONESTOP            DEM
# 30127288                11/06/2018 GENERAL       PROVISIONAL            UNA
# 30354983                05/08/2012 PRIMARY         IN-PERSON            REP
# 30354986                11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
# 30354991    10/11/2011 RALEIGH CARY SCHOOL         IN-PERSON            UNA
# 30354992         07/17/2012 SECOND PRIMARY         IN-PERSON            REP
# 30663509                05/08/2012 PRIMARY         IN-PERSON            DEM
# 30839138                11/04/2014 GENERAL         IN-PERSON            DEM
# 30839141                05/06/2014 PRIMARY       PROVISIONAL            DEM
# 31061311                05/08/2012 PRIMARY         IN-PERSON            DEM
# 31503804                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 31503806                11/04/2014 GENERAL  ABSENTEE ONESTOP            DEM
# 32142320                11/06/2012 GENERAL         IN-PERSON            UNA
# 32142321                05/08/2012 PRIMARY         IN-PERSON            DEM
# 32142322    10/11/2011 RALEIGH CARY SCHOOL         IN-PERSON            UNA
# 32142323         07/17/2012 SECOND PRIMARY         IN-PERSON            DEM
# 32510086                11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 32990168                11/06/2018 GENERAL       PROVISIONAL            REP
# 33115203                11/08/2016 GENERAL  ABSENTEE ONESTOP            REP
# 33311449                11/06/2012 GENERAL       PROVISIONAL            DEM
# 33472481                11/08/2016 GENERAL  ABSENTEE ONESTOP            DEM
# 33476639                11/06/2012 GENERAL         IN-PERSON            UNA
# 33492012                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 33492810         07/17/2012 SECOND PRIMARY  ABSENTEE ONESTOP            DEM
# 33492811                05/06/2014 PRIMARY         IN-PERSON            DEM
# 33492812                05/08/2012 PRIMARY  ABSENTEE ONESTOP            DEM
# 33500061                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 33507136         07/17/2012 SECOND PRIMARY       PROVISIONAL            DEM
# 33508637                11/06/2012 GENERAL         IN-PERSON            UNA
# 33509674                11/06/2012 GENERAL       PROVISIONAL            UNA
# 33510580                05/06/2014 PRIMARY  ABSENTEE ONESTOP            DEM
# 33525457                11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 33565326                11/06/2012 GENERAL       PROVISIONAL            DEM
# 34142042                03/03/2020 PRIMARY       PROVISIONAL            DEM
# 34535877                11/08/2016 GENERAL         IN-PERSON            DEM
# 34634357                11/06/2018 GENERAL  ABSENTEE ONESTOP            REP
#
#          pct_label       ncid  voted_county_id vtd_label
# 765568          09    AE20677                5        09
# 765569          09    AE20677                5        09
# 765571          09    AE20677                5        09
# 765572          09    AE20677                5        09
# 765573          09    AE20677                5        09
# 765575          09    AE20677                5        09
# 839967          07    AF14599                6        07
# 869446          01    AF25332                6        01
# 869464          18    AF25342                6        18
# 869471          12    AF25344                6        12
# 883196          13     AF6774                6        13
# 883197          13     AF6774                6        13
# 901078       SURBA    AG11613                7     SURBA
# 901079       SURBA    AG11613                7     SURBA
# 903612        NCRK    AG12294                7      NCRK
# 907876       WASH2    AG13342                7     WASH2
# 910168       PANTE    AG13916                7     PANTE
# 945041       BELHV    AG22716                7     BELHV
# 947375       EDWAR    AG23282                7     EDWAR
# 947376       EDWAR    AG23282                7     EDWAR
# 947377       EDWAR    AG23282                7     EDWAR
# 951977       PINET    AG24786                7     PINET
# 973899       BEADM    AG31864                7     BEADM
# 973900       BEADM    AG31864                7     BEADM
# 990822        BLCK    AG36573                7      BLCK
# 990823        BLCK    AG36573                7      BLCK
# 1032380      BELHV    AG46951                7     BELHV
# 1050705      WASH2    AG52044                7     WASH2
# 1060635      AUROR    AG54774                7     AUROR
# 1070573      AUROR     AG5856                7     AUROR
# 1090443       BLCK     AG8536                7      BLCK
# 1090444       BLCK     AG8536                7      BLCK
# 1090445       BLCK     AG8536                7      BLCK
# 1090446       BLCK     AG8536                7      BLCK
# 2350243       01.1   AL266672               11      01.1
# 2350244       01.1   AL266672               11      01.1
# 3106362       WILD    AM96250               16      WILD
# 3349467       020A   AN168178               90      020A
# 3349470       020A   AN168178               90      020A
# 4138463       CCCP    AS51732               16      CCCP
# 4189050       WILD    AS65641               16      WILD
# 4205695       WILD    AS69933               16      WILD
# 4207705       MHD1    AS70460               16      MHD1
# 4243446       BOGU    AS81341               16      BOGU
# 4254239       MHD2    AS84428               16      MHD2
# 4258172       OTBE    AS85965               16      OTST
# 4626487         33   AW192777               18        33
# 5143680         75    AX76840               19        75
# 5199641       ANSW    AY26597               20      ANSW
# 5379205     SHANGI   BB106684               23    SHANGI
# 5726301        P24    BC18809               24       P24
# 5726302        P24    BC18809               24       P24
# 5825343        P18    BC62260               24       P18
# 5876762         19   BD110449               25        19
# 5915222         07   BD124313               25        07
# 5950611       MHD1   BD138017               16      MHD1
# 6132620         22    BD72862               25        22
# 6736271     G11A-2   BE308810               26       G11
# 6736273     G11A-2   BE308810               26       G11
# 7232451         GW    BF16481               27        GW
# ...            ...        ...              ...       ...
# 29200537       001    EF79578               90       001
# 29207891      029B    EF81468               90      029B
# 29208468       026    EF81637               90       026
# 29208595       001    EF81671               90       001
# 29208596       001    EF81671               90       001
# 29208597       001    EF81671               90       001
# 29213068       021    EF82803               90       021
# 29213069       021    EF82803               90       021
# 29219533       024     EF8430               90       024
# 29219540       024     EF8430               90       024
# 29244049       012    EF90843               90       012
# 29245054       036    EF91060               90       036
# 29250341       042    EF92439               90       042
# 29258047       034    EF94456               90       034
# 29261425       013    EF95396               90       013
# 29400009      MIDD    EG52731               91      MIDD
# 29400028      MIDD    EG52733               91      MIDD
# 29401667       SH1    EG53391               91       SH1
# 29710923     07-13   EH109184               92     07-13
# 29710925     07-13   EH109184               92     07-13
# 29710926     07-13   EH109184               92     07-13
# 29710936     07-13   EH109184               92     07-13
# 29710939     07-13   EH109184               92     07-13
# 29865573     01-40  EH1156167               92     01-40
# 29865574     01-40  EH1156167               92     01-40
# 30127288     16-11  EH1313002               92     16-08
# 30354983     20-05   EH185796               92     20-05
# 30354986     20-05   EH185796               92     20-05
# 30354991     20-05   EH185796               92     20-05
# 30354992     20-05   EH185796               92     20-05
# 30663509     08-08   EH266816               92     08-08
# 30839138     15-03   EH317018               92     15-03
# 30839141     15-03   EH317018               92     15-03
# 31061311     16-03    EH38438               92     16-03
# 31503804     PSJW3   EH504034                7     PSJW3
# 31503806     PSJW3   EH504034                7     PSJW3
# 32142320     11-02    EH65775               92     11-02
# 32142321     11-02    EH65775               92     11-02
# 32142322     11-01    EH65775               92     11-01
# 32142323     11-02    EH65775               92     11-02
# 32510086     12-05   EH747345               92     12-05
# 32990168     13-06   EH870863               92     13-06
# 33115203        15   EH901751               35        15
# 33311449     17-07   EH954051               92     17-07
# 33472481       010    EJ13005               93       010
# 33476639       003    EJ15001               93       003
# 33492012       009    EJ21246               93       009
# 33492810       007    EJ21526               93       007
# 33492811       007    EJ21526               93       007
# 33492812       007    EJ21526               93       007
# 33500061       004    EJ23915               93       004
# 33507136       010    EJ26464               93       010
# 33508637       012    EJ26967               93       012
# 33509674       010    EJ27308               93       010
# 33510580       011    EJ27801               93       011
# 33525457       010     EJ6430               93       010
# 33565326        P1    EK20895               94        P1
# 34142042        MH    EM94079               54        MH
# 34535877      PRWM    EP67692               98      PRWM
# 34634357      SFAL    ER15626               99      SFAL
#
# [410 rows x 10 columns]

# %%
exact_dup_vhis['election_desc'].value_counts()
# Out:
# 11/06/2012 GENERAL                                    144
# 05/08/2012 PRIMARY                                     69
# 11/04/2014 GENERAL                                     37
# 11/08/2016 GENERAL                                     35
# 11/06/2018 GENERAL                                     29
# 03/15/2016 PRIMARY                                     18
# 05/06/2014 PRIMARY                                     16
# 07/17/2012 SECOND PRIMARY                              10
# 11/08/2011 MUNICIPAL GENERAL/CITY OF MONROE RUNOFF      7
# 03/03/2020 PRIMARY                                      7
# 11/03/2020 GENERAL                                      4
# 06/07/2016 CONGRESSIONAL PRIMARY                        3
# 07/15/2014 SECOND PRIMARY                               3
# 09/10/2019 GENERAL                                      3
# 05/08/2018 PRIMARY                                      3
# 11/05/2013 MUNICIPAL GENERAL/CITY OF MONROE             3
# 10/11/2011 RALEIGH CARY SCHOOL                          3
# 10/11/2011 MONROE MUNICIPAL ELECTION                    2
# 11/08/2011 MUNICIPAL GENERAL                            2
# 11/8/2011 MUNICIPAL                                     1
# 09/13/2011 MUNICIPAL PRIMARY                            1
# 11/05/2019 MUNICIPAL GENERAL                            1
# 11/05/2013 MUNICIPAL ELECTION                           1
# 11/05/2013 MUNICIPAL                                    1
# 11/03/2015 MUNICIPAL GENERAL                            1
# 10/06/2015 MONROE MUNICIPAL ELECTION                    1
# 10/08/2013 RALEIGH CARY SCHOOL                          1
# 10/08/2013 MONROE MUNICIPAL ELECTION                    1
# 11/05/2013 GENERAL                                      1
# 11/08/2011 MUNICIPAL                                    1
# 11/05/2013TOWN ROB/LS/TFD                               1
# Name: election_desc, dtype: int64

# %%
plot_count('election_desc', exact_dup_vhis, rotation=85);

# %%
plot_count('voting_method', exact_dup_vhis, rotation=45);

# %%
plot_count('voted_party_cd', exact_dup_vhis);

# %%
## Remove duplicate entries from records of voter history
nc_vhis.drop_duplicates(inplace=True)

# %%
# nc_vhis.to_csv('Data/ncvhis_Statewide_drop_dup.zip', index=False)

# %%
## There are 490 instances where an ncid shows up as casting a vote
  ## more than once in the same election where the records aren't exact copies
nc_vhis.duplicated(subset=['ncid','election_desc']).sum()
# Out:
# 490

# %%
## A total of 350 individuals show up more than once for a single election
dup_ncid_elecs = nc_vhis.loc[nc_vhis.duplicated(subset=['ncid', 'election_desc'], keep=False)]
display(dup_ncid_elecs.head())
dup_ncid_elecs['ncid'].nunique()
# Out:
#         county_id  voter_reg_num election_lbl       election_desc  \
# 200123          1        2332350   11/08/2016  11/08/2016 GENERAL
# 200124          1        2332350   03/15/2016  03/15/2016 PRIMARY
# 200126          1        2332350   11/08/2016  11/08/2016 GENERAL
# 200127          1        2332350   03/15/2016  03/15/2016 PRIMARY
# 217410         41       10191737   11/06/2012  11/06/2012 GENERAL
#
#            voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 200123         IN-PERSON            REP        02   AA16823                1
# 200124         IN-PERSON            REP        02   AA16823                1
# 200126  ABSENTEE ONESTOP            DEM        LI   AA16823               68
# 200127  ABSENTEE ONESTOP            DEM        LI   AA16823               68
# 217410         IN-PERSON            DEM       064  AA174391                1
#
#        vtd_label
# 200123        02
# 200124        02
# 200126        LI
# 200127        LI
# 217410       064
# 350

# %%
## Examine the complete recent voting history of the 350 ncid's that show up 
  ## multiple times for a single election to investigate how the records differ
for ncid in dup_ncid_elecs['ncid'].unique():
    display(nc_vhis.loc[nc_vhis['ncid']==ncid].sort_values(['election_desc']))
# Out:
#         county_id  voter_reg_num election_lbl              election_desc  \
# 200121          1        2332350   03/03/2020         03/03/2020 PRIMARY
# 200124          1        2332350   03/15/2016         03/15/2016 PRIMARY
# 200127          1        2332350   03/15/2016         03/15/2016 PRIMARY
# 200120          1        2332350   05/06/2014         05/06/2014 PRIMARY
# 200118          1        2332350   05/08/2012         05/08/2012 PRIMARY
# 200128          1        2332350   05/08/2018         05/08/2018 PRIMARY
# 200116          1        2332350   07/15/2014  07/15/2014 SECOND PRIMARY
# 200122          1        2332350   11/03/2020         11/03/2020 GENERAL
# 200119          1        2332350   11/04/2014         11/04/2014 GENERAL
# 200117          1        2332350   11/06/2012         11/06/2012 GENERAL
# 200125          1        2332350   11/06/2018         11/06/2018 GENERAL
# 200123          1        2332350   11/08/2016         11/08/2016 GENERAL
# 200126          1        2332350   11/08/2016         11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 200121         IN-PERSON            REP        02  AA16823                1
# 200124         IN-PERSON            REP        02  AA16823                1
# 200127  ABSENTEE ONESTOP            DEM        LI  AA16823               68
# 200120         IN-PERSON            REP        02  AA16823                1
# 200118         IN-PERSON            REP        02  AA16823                1
# 200128         IN-PERSON            DEM        LI  AA16823               68
# 200116         IN-PERSON            REP        02  AA16823                1
# 200122         IN-PERSON            REP        02  AA16823                1
# 200119         IN-PERSON            REP        02  AA16823                1
# 200117  ABSENTEE ONESTOP            REP        02  AA16823                1
# 200125         IN-PERSON            REP        02  AA16823                1
# 200123         IN-PERSON            REP        02  AA16823                1
# 200126  ABSENTEE ONESTOP            DEM        LI  AA16823               68
#
#        vtd_label
# 200121        02
# 200124        02
# 200127        LI
# 200120        02
# 200118        02
# 200128        LI
# 200116        02
# 200122        02
# 200119        02
# 200117        02
# 200125        02
# 200123        02
# 200126        LI
#         county_id  voter_reg_num election_lbl         election_desc  \
# 217413         41       10191737   03/03/2020    03/03/2020 PRIMARY
# 217416         41       10191737   03/15/2016    03/15/2016 PRIMARY
# 217419         41       10191737   05/08/2012    05/08/2012 PRIMARY
# 217412         41       10191737   11/03/2020    11/03/2020 GENERAL
# 217417         41       10191737   11/04/2014    11/04/2014 GENERAL
# 217414         41       10191737   11/05/2019  11/05/2019 MUNICIPAL
# 217410         41       10191737   11/06/2012    11/06/2012 GENERAL
# 217418         41       10191737   11/06/2012    11/06/2012 GENERAL
# 217411         41       10191737   11/06/2018    11/06/2018 GENERAL
# 217415         41       10191737   11/08/2016    11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 217413         IN-PERSON            DEM       H25  AA174391               41
# 217416  ABSENTEE ONESTOP            DEM       146  AA174391               60
# 217419         IN-PERSON            DEM       146  AA174391               60
# 217412  ABSENTEE ONESTOP            DEM       H25  AA174391               41
# 217417         IN-PERSON            DEM       146  AA174391               60
# 217414         IN-PERSON            DEM       H25  AA174391               41
# 217410         IN-PERSON            DEM       064  AA174391                1
# 217418  ABSENTEE ONESTOP            DEM       146  AA174391               60
# 217411         IN-PERSON            DEM       H25  AA174391               41
# 217415  ABSENTEE ONESTOP            DEM       146  AA174391               60
#
#        vtd_label
# 217413       H25
# 217416       146
# 217419       146
# 217412       H25
# 217417       146
# 217414       H25
# 217410       064
# 217418       146
# 217411       H25
# 217415       146
#         county_id  voter_reg_num election_lbl       election_desc  \
# 284313         26      166237613   11/03/2020  11/03/2020 GENERAL
# 284314         26      166237613   11/03/2020  11/03/2020 GENERAL
#
#            voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 284313  ABSENTEE BY MAIL            UNA       06S  AA210194                1
# 284314  ABSENTEE ONESTOP            DEM      CC13  AA210194               26
#
#        vtd_label
# 284313       06S
# 284314      CC13
#         county_id  voter_reg_num election_lbl  \
# 496996          4          32922   03/19/2013
# 497000          4          32922   05/06/2014
# 496995          4          32922   05/08/2012
# 496998          4          32922   07/15/2014
# 496997          4          32922   11/04/2014
# 496994          4          32922   11/06/2012
# 496999          4          32922   11/06/2012
# 497001          4          32922   11/08/2016
#
#                               election_desc     voting_method voted_party_cd  \
# 496996  03/19/2013 COUNTY WIDE ABC ELECTION       PROVISIONAL            REP
# 497000                   05/06/2014 PRIMARY         IN-PERSON            DEM
# 496995                   05/08/2012 PRIMARY         IN-PERSON            REP
# 496998            07/15/2014 SECOND PRIMARY         IN-PERSON            DEM
# 496997                   11/04/2014 GENERAL  ABSENTEE ONESTOP            DEM
# 496994                   11/06/2012 GENERAL         IN-PERSON            REP
# 496999                   11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM
# 497001                   11/08/2016 GENERAL         IN-PERSON            DEM
#
#        pct_label     ncid  voted_county_id vtd_label
# 496996        B2  AB14598                2        B2
# 497000      LILE  AB14598                4      LILE
# 496995        B2  AB14598                2        B2
# 496998      LILE  AB14598                4      LILE
# 496997      LILE  AB14598                4      LILE
# 496994        B2  AB14598                2        B2
# 496999      LILE  AB14598                4      LILE
# 497001      LILE  AB14598                4      LILE
#         county_id  voter_reg_num election_lbl  \
# 514900          2          25981   03/19/2013
# 514902          2          25981   11/03/2020
# 514901          2          25981   11/04/2014
# 514897          2          25981   11/06/2012
# 514898          2          25981   11/06/2012
# 514899          2          25981   11/06/2018
# 514903          2          25981   11/08/2016
#
#                               election_desc     voting_method voted_party_cd  \
# 514900  03/19/2013 COUNTY WIDE ABC ELECTION  ABSENTEE ONESTOP            REP
# 514902                   11/03/2020 GENERAL  ABSENTEE ONESTOP            UNA
# 514901                   11/04/2014 GENERAL  ABSENTEE ONESTOP            REP
# 514897                   11/06/2012 GENERAL         IN-PERSON            REP
# 514898                   11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 514899                   11/06/2018 GENERAL  ABSENTEE ONESTOP            UNA
# 514903                   11/08/2016 GENERAL  ABSENTEE ONESTOP            UNA
#
#        pct_label     ncid  voted_county_id vtd_label
# 514900        B1  AB22129                2        B1
# 514902        B1  AB22129                2        B1
# 514901        B1  AB22129                2        B1
# 514897        26  AB22129               18        26
# 514898        B1  AB22129                2        B1
# 514899        B1  AB22129                2        B1
# 514903        B1  AB22129                2        B1
#         county_id  voter_reg_num election_lbl       election_desc  \
# 618770          3          13451   03/15/2016  03/15/2016 PRIMARY
# 618769          3          13451   11/04/2014  11/04/2014 GENERAL
# 618767          3          13451   11/06/2012  11/06/2012 GENERAL
# 618772          3          13451   11/06/2012  11/06/2012 GENERAL
# 618771          3          13451   11/06/2018  11/06/2018 GENERAL
# 618768          3          13451   11/08/2016  11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 618770  ABSENTEE ONESTOP            DEM        06  AC13298                3
# 618769         IN-PERSON            UNA        06  AC13298                3
# 618767  ABSENTEE ONESTOP            UNA     01-23  AC13298               92
# 618772         IN-PERSON            UNA        06  AC13298                3
# 618771         IN-PERSON            UNA       06A  AC13298                3
# 618768         IN-PERSON            UNA       06A  AC13298                3
#
#        vtd_label
# 618770        06
# 618769        06
# 618767     01-23
# 618772        06
# 618771        06
# 618768        06
#         county_id  voter_reg_num election_lbl       election_desc  \
# 687646          4          36708   11/06/2012  11/06/2012 GENERAL
# 687644          4          36708   11/06/2018  11/06/2018 GENERAL
# 687643          4          36708   11/08/2016  11/08/2016 GENERAL
# 687645          4          36708   11/08/2016  11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 687646  ABSENTEE ONESTOP            DEM      0007  AD24600               84
# 687644         IN-PERSON            DEM      BURN  AD24600                4
# 687643       PROVISIONAL            DEM      BURN  AD24600                4
# 687645       PROVISIONAL            NaN      BURN  AD24600                4
#
#        vtd_label
# 687646      0007
# 687644      BURN
# 687643      BURN
# 687645      BURN
#         county_id  voter_reg_num election_lbl       election_desc  \
# 699875          4          31054   03/03/2020  03/03/2020 PRIMARY
# 699878          4          31054   05/08/2012  05/08/2012 PRIMARY
# 699874          4          31054   09/10/2019  09/10/2019 GENERAL
# 699880          4          31054   09/10/2019  09/10/2019 GENERAL
# 699876          4          31054   11/03/2020  11/03/2020 GENERAL
# 699879          4          31054   11/04/2014  11/04/2014 GENERAL
# 699877          4          31054   11/06/2012  11/06/2012 GENERAL
# 699881          4          31054   11/06/2018  11/06/2018 GENERAL
# 699882          4          31054   11/06/2018  11/06/2018 GENERAL
# 699883          4          31054   11/08/2016  11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 699875       PROVISIONAL            DEM     WADES  AD28554                4
# 699878         IN-PERSON            REP        W1  AD28554                4
# 699874         IN-PERSON            DEM        W1  AD28554                4
# 699880         IN-PERSON            REP        W1  AD28554                4
# 699876  ABSENTEE ONESTOP            UNA     WADES  AD28554                4
# 699879  ABSENTEE ONESTOP            REP        W1  AD28554                4
# 699877         IN-PERSON            REP        W1  AD28554                4
# 699881         IN-PERSON            REP        W1  AD28554                4
# 699882  ABSENTEE ONESTOP            DEM        W1  AD28554                4
# 699883  ABSENTEE ONESTOP            DEM        W1  AD28554                4
#
#        vtd_label
# 699875        W1
# 699878        W1
# 699874        W1
# 699880        W1
# 699876        W1
# 699879        W1
# 699877        W1
# 699881        W1
# 699882        W1
# 699883        W1
#         county_id  voter_reg_num election_lbl  \
# 765562          5          39380   03/15/2016
# 765561          5          39380   05/06/2014
# 765558          5          39380   05/08/2012
# 765563          5          39380   06/07/2016
# 765560          5          39380   07/17/2012
# 765570          5          39380   11/03/2015
# 765577          5          39380   11/03/2020
# 765565          5          39380   11/04/2014
# 765574          5          39380   11/04/2014
# 765566          5          39380   11/06/2012
# 765567          5          39380   11/06/2012
# 765564          5          39380   11/08/2011
# 765559          5          39380   11/08/2016
# 765576          5          39380   11/08/2016
#
#                            election_desc     voting_method voted_party_cd  \
# 765562                03/15/2016 PRIMARY         IN-PERSON            REP
# 765561                05/06/2014 PRIMARY         IN-PERSON            REP
# 765558                05/08/2012 PRIMARY         IN-PERSON            REP
# 765563  06/07/2016 CONGRESSIONAL PRIMARY         IN-PERSON            REP
# 765560         07/17/2012 SECOND PRIMARY         IN-PERSON            REP
# 765570              11/03/2015 MUNICIPAL         IN-PERSON            UNA
# 765577                11/03/2020 GENERAL         IN-PERSON            UNA
# 765565                11/04/2014 GENERAL  ABSENTEE ONESTOP            UNA
# 765574                11/04/2014 GENERAL         IN-PERSON            UNA
# 765566                11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
# 765567                11/06/2012 GENERAL         IN-PERSON            UNA
# 765564              11/08/2011 MUNICIPAL         IN-PERSON            UNA
# 765559                11/08/2016 GENERAL  ABSENTEE ONESTOP            UNA
# 765576                11/08/2016 GENERAL         IN-PERSON            UNA
#
#        pct_label     ncid  voted_county_id vtd_label
# 765562        09  AE20677                5        09
# 765561        09  AE20677                5        09
# 765558        09  AE20677                5        09
# 765563        09  AE20677                5        09
# 765560        09  AE20677                5        09
# 765570        09  AE20677                5        09
# 765577        09  AE20677                5        20
# 765565        09  AE20677                5        09
# 765574        09  AE20677                5        09
# 765566        09  AE20677                5        09
# 765567        09  AE20677                5        09
# 765564        09  AE20677                5        09
# 765559        09  AE20677                5        09
# 765576        09  AE20677                5        09
#         county_id  voter_reg_num election_lbl              election_desc  \
# 839968          6          23708   03/03/2020         03/03/2020 PRIMARY
# 839959          6          23708   03/15/2016         03/15/2016 PRIMARY
# 839963          6          23708   05/06/2014         05/06/2014 PRIMARY
# 839965          6          23708   05/08/2012         05/08/2012 PRIMARY
# 839958          6          23708   05/08/2018         05/08/2018 PRIMARY
# 839970          6          23708   06/23/2020  06/23/2020 SECOND PRIMARY
# 839962          6          23708   07/17/2012  07/17/2012 SECOND PRIMARY
# 839969          6          23708   11/03/2020         11/03/2020 GENERAL
# 839964          6          23708   11/04/2014         11/04/2014 GENERAL
# 839961          6          23708   11/06/2012         11/06/2012 GENERAL
# 839957          6          23708   11/06/2018         11/06/2018 GENERAL
# 839960          6          23708   11/06/2018         11/06/2018 GENERAL
# 839966          6          23708   11/08/2016         11/08/2016 GENERAL
#
#        voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 839968     IN-PERSON            REP        07  AF14599                6
# 839959     IN-PERSON            REP        17  AF14599                6
# 839963     IN-PERSON            REP        17  AF14599                6
# 839965     IN-PERSON            REP        17  AF14599                6
# 839958   PROVISIONAL            REP        07  AF14599                6
# 839970     IN-PERSON            REP        07  AF14599                6
# 839962     IN-PERSON            REP        17  AF14599                6
# 839969     IN-PERSON            REP        07  AF14599                6
# 839964     IN-PERSON            REP        17  AF14599                6
# 839961     IN-PERSON            REP        17  AF14599                6
# 839957   PROVISIONAL            REP        07  AF14599                6
# 839960   PROVISIONAL            NaN        07  AF14599                6
# 839966     IN-PERSON            REP        17  AF14599                6
#
#        vtd_label
# 839968        07
# 839959        17
# 839963        17
# 839965        17
# 839958        07
# 839970        07
# 839962        17
# 839969        07
# 839964        17
# 839961        17
# 839957        07
# 839960        07
# 839966        17
#         county_id  voter_reg_num election_lbl       election_desc  \
# 872193         57       30019169   03/15/2016  03/15/2016 PRIMARY
# 872191         57       30019169   05/08/2018  05/08/2018 PRIMARY
# 872194         57       30019169   05/08/2018  05/08/2018 PRIMARY
# 872192         57       30019169   11/06/2018  11/06/2018 GENERAL
# 872195         57       30019169   11/08/2016  11/08/2016 GENERAL
#
#            voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 872193         IN-PERSON            REP        07  AF26449                6
# 872191  ABSENTEE ONESTOP            DEM    MARS H  AF26449               57
# 872194  ABSENTEE ONESTOP            REP        07  AF26449                6
# 872192  ABSENTEE ONESTOP            UNA    MARS H  AF26449               57
# 872195  ABSENTEE ONESTOP            REP        07  AF26449                6
#
#        vtd_label
# 872193        07
# 872191    MARS-H
# 872194        07
# 872192    MARS-H
# 872195        07
#          county_id  voter_reg_num election_lbl       election_desc  \
# 1095554          7           9244   05/08/2012  05/08/2012 PRIMARY
# 1095552          7           9244   11/03/2020  11/03/2020 GENERAL
# 1095553          7           9244   11/04/2014  11/04/2014 GENERAL
# 1095556          7           9244   11/04/2014  11/04/2014 GENERAL
# 1095550          7           9244   11/06/2012  11/06/2012 GENERAL
# 1095557          7           9244   11/06/2012  11/06/2012 GENERAL
# 1095551          7           9244   11/06/2018  11/06/2018 GENERAL
# 1095555          7           9244   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label    ncid  voted_county_id  \
# 1095554         IN-PERSON            DEM     CHOCO  AG9878                7
# 1095552  ABSENTEE ONESTOP            DEM     WASH4  AG9878                7
# 1095553  ABSENTEE ONESTOP            DEM     CHOCO  AG9878                7
# 1095556  ABSENTEE ONESTOP            DEM     WASH4  AG9878                7
# 1095550  ABSENTEE ONESTOP            DEM     CHOCO  AG9878                7
# 1095557  ABSENTEE ONESTOP            DEM     WASH4  AG9878                7
# 1095551  ABSENTEE ONESTOP            DEM     CHOCO  AG9878                7
# 1095555  ABSENTEE ONESTOP            DEM     CHOCO  AG9878                7
#
#         vtd_label
# 1095554     CHOCO
# 1095552     WASH4
# 1095553     CHOCO
# 1095556     WASH4
# 1095550     CHOCO
# 1095557     WASH4
# 1095551     CHOCO
# 1095555     CHOCO
#          county_id  voter_reg_num election_lbl       election_desc  \
# 1116660          8          15156   03/03/2020  03/03/2020 PRIMARY
# 1116661          8          15156   05/08/2018  05/08/2018 PRIMARY
# 1116663          8          15156   11/03/2020  11/03/2020 GENERAL
# 1116658          8          15156   11/04/2014  11/04/2014 GENERAL
# 1116664          8          15156   11/06/2012  11/06/2012 GENERAL
# 1116662          8          15156   11/06/2018  11/06/2018 GENERAL
# 1116657          8          15156   11/08/2016  11/08/2016 GENERAL
# 1116659          8          15156   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 1116660  ABSENTEE ONESTOP            DEM        MH  AH17190                8
# 1116661  ABSENTEE ONESTOP            DEM        MH  AH17190                8
# 1116663  ABSENTEE ONESTOP            DEM        MH  AH17190                8
# 1116658         IN-PERSON            DEM        MH  AH17190                8
# 1116664  ABSENTEE ONESTOP            DEM        W1  AH17190                8
# 1116662  ABSENTEE ONESTOP            DEM        MH  AH17190                8
# 1116657  ABSENTEE ONESTOP            UNA     01-46  AH17190               92
# 1116659  ABSENTEE ONESTOP            DEM        MH  AH17190                8
#
#         vtd_label
# 1116660        MH
# 1116661        MH
# 1116663        MH
# 1116658        MH
# 1116664        W1
# 1116662        MH
# 1116657     01-46
# 1116659        MH
#          county_id  voter_reg_num election_lbl       election_desc  \
# 1137891          8          23342   03/03/2020  03/03/2020 PRIMARY
# 1137896          8          23342   03/15/2016  03/15/2016 PRIMARY
# 1137894          8          23342   05/08/2012  05/08/2012 PRIMARY
# 1137892          8          23342   11/04/2014  11/04/2014 GENERAL
# 1137895          8          23342   11/06/2012  11/06/2012 GENERAL
# 1137890          8          23342   11/06/2018  11/06/2018 GENERAL
# 1137889          8          23342   11/08/2016  11/08/2016 GENERAL
# 1137893          8          23342   11/08/2016  11/08/2016 GENERAL
#
#         voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 1137891      CURBSIDE            DEM        RX  AH24528                8
# 1137896     IN-PERSON            DEM        RX  AH24528                8
# 1137894     IN-PERSON            DEM        RX  AH24528                8
# 1137892     IN-PERSON            DEM        RX  AH24528                8
# 1137895     IN-PERSON            DEM        RX  AH24528                8
# 1137890     IN-PERSON            DEM        RX  AH24528                8
# 1137889     IN-PERSON            DEM        RX  AH24528                8
# 1137893      CURBSIDE            DEM        RX  AH24528                8
#
#         vtd_label
# 1137891        RX
# 1137896        RX
# 1137894        RX
# 1137892        RX
# 1137895        RX
# 1137890        RX
# 1137889        RX
# 1137893        RX
#          county_id  voter_reg_num election_lbl       election_desc  \
# 1270393          9          62998   03/15/2016  03/15/2016 PRIMARY
# 1270395          9          62998   05/08/2012  05/08/2012 PRIMARY
# 1270396          9          62998   11/04/2014  11/04/2014 GENERAL
# 1270394          9          62998   11/06/2012  11/06/2012 GENERAL
# 1270397          9          62998   11/08/2016  11/08/2016 GENERAL
# 1270398          9          62998   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 1270393         IN-PERSON            REP      P19A  AJ43003               64
# 1270395         IN-PERSON            DEM      0037  AJ43003               64
# 1270396  ABSENTEE ONESTOP            DEM      0037  AJ43003               64
# 1270394  ABSENTEE ONESTOP            DEM      0037  AJ43003               64
# 1270397  ABSENTEE ONESTOP            REP      P19A  AJ43003               64
# 1270398  ABSENTEE ONESTOP            UNA      P202  AJ43003                9
#
#         vtd_label
# 1270393      0037
# 1270395      0037
# 1270396      0037
# 1270394      0037
# 1270397      0037
# 1270398      P202
#          county_id  voter_reg_num election_lbl         election_desc  \
# 1342354         10      600027098   03/15/2016    03/15/2016 PRIMARY
# 1342358         10      600027098   05/08/2012    05/08/2012 PRIMARY
# 1342359         10      600027098   11/03/2015  11/03/2015 MUNICIPAL
# 1342360         10      600027098   11/03/2020    11/03/2020 GENERAL
# 1342357         10      600027098   11/04/2014    11/04/2014 GENERAL
# 1342353         10      600027098   11/06/2012    11/06/2012 GENERAL
# 1342355         10      600027098   11/06/2012    11/06/2012 GENERAL
# 1342356         10      600027098   11/08/2011  11/08/2011 MUNICIPAL
# 1342361         10      600027098   11/08/2016    11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 1342354         IN-PERSON            DEM        07  AK112621               10
# 1342358         IN-PERSON            DEM        07  AK112621               10
# 1342359         IN-PERSON            UNA        07  AK112621               10
# 1342360  ABSENTEE BY MAIL            DEM        03  AK112621               10
# 1342357  ABSENTEE ONESTOP            UNA        07  AK112621               10
# 1342353  ABSENTEE ONESTOP            DEM       W31  AK112621               65
# 1342355         IN-PERSON            UNA        07  AK112621               10
# 1342356         IN-PERSON            UNA        07  AK112621               10
# 1342361         IN-PERSON            UNA        07  AK112621               10
#
#         vtd_label
# 1342354        07
# 1342358        07
# 1342359        07
# 1342360        03
# 1342357        07
# 1342353       W31
# 1342355        07
# 1342356        07
# 1342361        07
#          county_id  voter_reg_num election_lbl         election_desc  \
# 1714089         10        1470954   05/06/2014    05/06/2014 PRIMARY
# 1714092         10        1470954   05/08/2012    05/08/2012 PRIMARY
# 1714093         10        1470954   11/03/2015  11/03/2015 MUNICIPAL
# 1714094         10        1470954   11/03/2020    11/03/2020 GENERAL
# 1714091         10        1470954   11/04/2014    11/04/2014 GENERAL
# 1714090         10        1470954   11/06/2012    11/06/2012 GENERAL
# 1714096         10        1470954   11/06/2012    11/06/2012 GENERAL
# 1714095         10        1470954   11/08/2016    11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 1714089  ABSENTEE ONESTOP            REP      04C1  AK89408               10
# 1714092  ABSENTEE ONESTOP            REP       04C  AK89408               10
# 1714093         IN-PERSON            REP      04C1  AK89408               10
# 1714094  ABSENTEE ONESTOP            REP        12  AK89408               10
# 1714091  ABSENTEE ONESTOP            REP      04C1  AK89408               10
# 1714090  ABSENTEE ONESTOP            REP       04C  AK89408               10
# 1714096  ABSENTEE BY MAIL            REP        05  AK89408               30
# 1714095  ABSENTEE ONESTOP            REP        12  AK89408               10
#
#         vtd_label
# 1714089        04
# 1714092        04
# 1714093        04
# 1714094        12
# 1714091        04
# 1714090        04
# 1714096        05
# 1714095        12
#          county_id  voter_reg_num election_lbl       election_desc  \
# 1749699         10      600092384   03/15/2016  03/15/2016 PRIMARY
# 1749701         10      600092384   05/08/2012  05/08/2012 PRIMARY
# 1749696         10      600092384   11/03/2020  11/03/2020 GENERAL
# 1749697         10      600092384   11/03/2020  11/03/2020 GENERAL
# 1749703         10      600092384   11/04/2014  11/04/2014 GENERAL
# 1749698         10      600092384   11/06/2012  11/06/2012 GENERAL
# 1749700         10      600092384   11/06/2018  11/06/2018 GENERAL
# 1749702         10      600092384   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 1749699           CURBSIDE            REP        A1  AK98540               53
# 1749701   ABSENTEE ONESTOP            REP        A1  AK98540               53
# 1749696   ABSENTEE ONESTOP            REP       10A  AK98540               10
# 1749697  ABSENTEE CURBSIDE            REP       10A  AK98540               10
# 1749703          IN-PERSON            REP        A1  AK98540               53
# 1749698   ABSENTEE ONESTOP            REP        A1  AK98540               53
# 1749700   ABSENTEE BY MAIL            REP        A1  AK98540               53
# 1749702  ABSENTEE CURBSIDE            REP        A1  AK98540               53
#
#         vtd_label
# 1749699         A
# 1749701         A
# 1749696        10
# 1749697        10
# 1749703         A
# 1749698         A
# 1749700         A
# 1749702         A
#          county_id  voter_reg_num election_lbl       election_desc  \
# 2261430         36        7688117   03/15/2016  03/15/2016 PRIMARY
# 2261428         36        7688117   05/08/2012  05/08/2012 PRIMARY
# 2261436         36        7688117   05/08/2018  05/08/2018 PRIMARY
# 2261432         36        7688117   11/03/2020  11/03/2020 GENERAL
# 2261433         36        7688117   11/04/2014  11/04/2014 GENERAL
# 2261429         36        7688117   11/06/2012  11/06/2012 GENERAL
# 2261435         36        7688117   11/06/2012  11/06/2012 GENERAL
# 2261431         36        7688117   11/06/2018  11/06/2018 GENERAL
# 2261434         36        7688117   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 2261430  ABSENTEE ONESTOP            DEM        33  AL244926               36
# 2261428  ABSENTEE BY MAIL            DEM      28.1  AL244926               11
# 2261436         IN-PERSON            DEM        36  AL244926               36
# 2261432  ABSENTEE BY MAIL            UNA        36  AL244926               36
# 2261433  ABSENTEE ONESTOP            UNA        33  AL244926               36
# 2261429         IN-PERSON            REP        20  AL244926               18
# 2261435  ABSENTEE ONESTOP            UNA        33  AL244926               36
# 2261431         IN-PERSON            UNA        36  AL244926               36
# 2261434         IN-PERSON            UNA        36  AL244926               36
#
#         vtd_label
# 2261430        33
# 2261428      28.1
# 2261436        36
# 2261432        36
# 2261433        33
# 2261429        20
# 2261435        33
# 2261431        36
# 2261434        36
#          county_id  voter_reg_num election_lbl                 election_desc  \
# 2350236         11         372852   03/03/2020            03/03/2020 PRIMARY
# 2350233         11         372852   05/06/2014            05/06/2014 PRIMARY
# 2350235         11         372852   05/08/2018            05/08/2018 PRIMARY
# 2350238         11         372852   11/03/2020            11/03/2020 GENERAL
# 2350234         11         372852   11/04/2014            11/04/2014 GENERAL
# 2350240         11         372852   11/06/2012            11/06/2012 GENERAL
# 2350242         11         372852   11/06/2012            11/06/2012 GENERAL
# 2350237         11         372852   11/06/2018            11/06/2018 GENERAL
# 2350239         11         372852   11/07/2017  11/07/2017 MUNICIPAL GENERAL
# 2350241         11         372852   11/08/2016            11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 2350236         IN-PERSON            DEM      01.1  AL266672               11
# 2350233         IN-PERSON            DEM      01.1  AL266672               11
# 2350235         IN-PERSON            DEM      01.1  AL266672               11
# 2350238  ABSENTEE ONESTOP            DEM      01.1  AL266672               11
# 2350234         IN-PERSON            DEM      01.1  AL266672               11
# 2350240  ABSENTEE ONESTOP            DEM      01.1  AL266672               11
# 2350242         IN-PERSON            DEM      01.1  AL266672               11
# 2350237         IN-PERSON            DEM      01.1  AL266672               11
# 2350239         IN-PERSON            DEM      01.1  AL266672               11
# 2350241         IN-PERSON            DEM      01.1  AL266672               11
#
#         vtd_label
# 2350236      01.1
# 2350233      01.1
# 2350235      01.1
# 2350238      01.1
# 2350234      01.1
# 2350240      01.1
# 2350242      01.1
# 2350237      01.1
# 2350239      01.1
# 2350241      01.1
#          county_id  voter_reg_num election_lbl                 election_desc  \
# 2697210         11         130793   03/03/2020            03/03/2020 PRIMARY
# 2697203         11         130793   03/15/2016            03/15/2016 PRIMARY
# 2697208         11         130793   05/08/2012            05/08/2012 PRIMARY
# 2697202         11         130793   06/23/2020     06/23/2020 SECOND PRIMARY
# 2697204         11         130793   11/03/2020            11/03/2020 GENERAL
# 2697206         11         130793   11/04/2014            11/04/2014 GENERAL
# 2697212         11         130793   11/04/2014            11/04/2014 GENERAL
# 2697207         11         130793   11/06/2012            11/06/2012 GENERAL
# 2697214         11         130793   11/06/2012            11/06/2012 GENERAL
# 2697211         11         130793   11/06/2018            11/06/2018 GENERAL
# 2697205         11         130793   11/08/2011  11/08/2011 MUNICIPAL GENERAL
# 2697209         11         130793   11/08/2016            11/08/2016 GENERAL
# 2697213         11         130793   11/08/2016            11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 2697210         IN-PERSON            REP      01.1  AL57870               11
# 2697203         IN-PERSON            REP      42.1  AL57870               11
# 2697208  ABSENTEE ONESTOP            REP      42.1  AL57870               11
# 2697202  ABSENTEE ONESTOP            REP      01.1  AL57870               11
# 2697204  ABSENTEE ONESTOP            REP      01.1  AL57870               11
# 2697206         IN-PERSON            REP      42.1  AL57870               11
# 2697212  ABSENTEE BY MAIL            REP     13-01  AL57870               92
# 2697207  ABSENTEE ONESTOP            REP      42.1  AL57870               11
# 2697214  ABSENTEE ONESTOP            REP     13-01  AL57870               92
# 2697211  ABSENTEE ONESTOP            REP      45.1  AL57870               11
# 2697205         IN-PERSON            REP      42.1  AL57870               11
# 2697209  ABSENTEE ONESTOP            REP      42.1  AL57870               11
# 2697213  ABSENTEE ONESTOP            REP     13-01  AL57870               92
#
#         vtd_label
# 2697210      01.1
# 2697203     105.1
# 2697208     105.1
# 2697202      01.1
# 2697204      01.1
# 2697206     105.1
# 2697212     13-01
# 2697207     105.1
# 2697214     13-01
# 2697211      45.1
# 2697205     105.1
# 2697209     105.1
# 2697213     13-01
#          county_id  voter_reg_num election_lbl       election_desc  \
# 2853674         12           9570   03/15/2016  03/15/2016 PRIMARY
# 2853676         12           9570   05/08/2012  05/08/2012 PRIMARY
# 2853675         12           9570   11/03/2020  11/03/2020 GENERAL
# 2853673         12           9570   11/06/2012  11/06/2012 GENERAL
# 2853679         12           9570   11/06/2012  11/06/2012 GENERAL
# 2853677         12           9570   11/06/2018  11/06/2018 GENERAL
# 2853678         12           9570   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 2853674         IN-PERSON            DEM      0022  AM11597               12
# 2853676         IN-PERSON            REP      0001  AM11597               12
# 2853675  ABSENTEE ONESTOP            UNA      0022  AM11597               12
# 2853673         IN-PERSON            UNA        35  AM11597               18
# 2853679  ABSENTEE ONESTOP            REP      0001  AM11597               12
# 2853677         IN-PERSON            UNA      0022  AM11597               12
# 2853678  ABSENTEE ONESTOP            UNA      0022  AM11597               12
#
#         vtd_label
# 2853674      0022
# 2853676      0001
# 2853675      0022
# 2853673        35
# 2853679      0001
# 2853677      0022
# 2853678      0022
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3206685         13       30033550   11/03/2020  11/03/2020 GENERAL
# 3206683         13       30033550   11/04/2014  11/04/2014 GENERAL
# 3206686         13       30033550   11/04/2014  11/04/2014 GENERAL
# 3206682         13       30033550   11/06/2012  11/06/2012 GENERAL
# 3206681         13       30033550   11/06/2018  11/06/2018 GENERAL
# 3206684         13       30033550   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 3206685  ABSENTEE ONESTOP            DEM     04-09  AN125465               13
# 3206683         IN-PERSON            DEM     04-09  AN125465               13
# 3206686         IN-PERSON            DEM       043  AN125465               60
# 3206682         IN-PERSON            DEM     04-09  AN125465               13
# 3206681         IN-PERSON            DEM     04-09  AN125465               13
# 3206684         IN-PERSON            DEM     04-09  AN125465               13
#
#         vtd_label
# 3206685     04-09
# 3206683     04-09
# 3206686       043
# 3206682     04-09
# 3206681     04-09
# 3206684     04-09
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3430649         65         446126   11/03/2020  11/03/2020 GENERAL
# 3430650         65         446126   11/03/2020  11/03/2020 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 3430649         IN-PERSON            REP       H04  AN197368               65
# 3430650  ABSENTEE BY MAIL            REP     01-04  AN197368               13
#
#         vtd_label
# 3430649       H04
# 3430650     01-04
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3451432         50      320365773   11/03/2020  11/03/2020 GENERAL
# 3451433         50      320365773   11/03/2020  11/03/2020 GENERAL
# 3451434         50      320365773   11/06/2018  11/06/2018 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 3451432  ABSENTEE ONESTOP            DEM     01-04  AN207398               13
# 3451433  ABSENTEE ONESTOP            UNA       CUL  AN207398               50
# 3451434  ABSENTEE ONESTOP            DEM       CUL  AN207398               50
#
#         vtd_label
# 3451432     01-04
# 3451433       CUL
# 3451434       CUL
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3467931         60     1000648693   11/03/2020  11/03/2020 GENERAL
# 3467932         60     1000648693   11/03/2020  11/03/2020 GENERAL
#
#             voting_method voted_party_cd pct_label      ncid  voted_county_id  \
# 3467931  ABSENTEE ONESTOP            DEM     01-04  AN217205               13
# 3467932  ABSENTEE ONESTOP            UNA       105  AN217205               60
#
#         vtd_label
# 3467931     01-04
# 3467932       105
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3617935         24          67357   03/15/2016  03/15/2016 PRIMARY
# 3617937         24          67357   05/08/2012  05/08/2012 PRIMARY
# 3617938         24          67357   05/08/2018  05/08/2018 PRIMARY
# 3617940         24          67357   11/04/2014  11/04/2014 GENERAL
# 3617934         24          67357   11/06/2012  11/06/2012 GENERAL
# 3617939         24          67357   11/06/2012  11/06/2012 GENERAL
# 3617936         24          67357   11/06/2018  11/06/2018 GENERAL
# 3617941         24          67357   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 3617935  ABSENTEE ONESTOP            REP      P26B  AN63014               24
# 3617937         IN-PERSON            REP      P26A  AN63014               24
# 3617938         IN-PERSON            REP      P26B  AN63014               24
# 3617940  ABSENTEE ONESTOP            REP      P26B  AN63014               24
# 3617934         IN-PERSON            REP       905  AN63014               34
# 3617939  ABSENTEE ONESTOP            REP      P26A  AN63014               24
# 3617936  ABSENTEE ONESTOP            REP      P26B  AN63014               24
# 3617941  ABSENTEE ONESTOP            REP      P26B  AN63014               24
#
#         vtd_label
# 3617935       P26
# 3617937       P26
# 3617938       P26
# 3617940       P26
# 3617934       905
# 3617939       P26
# 3617936       P26
# 3617941       P26
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3838225         14       14501015   03/15/2016  03/15/2016 PRIMARY
# 3838229         14       14501015   05/06/2014  05/06/2014 PRIMARY
# 3838223         14       14501015   05/08/2012  05/08/2012 PRIMARY
# 3838224         14       14501015   05/08/2012  05/08/2012 PRIMARY
# 3838226         14       14501015   11/04/2014  11/04/2014 GENERAL
# 3838228         14       14501015   11/06/2012  11/06/2012 GENERAL
# 3838227         14       14501015   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 3838225         IN-PERSON            DEM      PR29  AP48595               14
# 3838229         IN-PERSON            DEM      PR29  AP48595               14
# 3838223  ABSENTEE ONESTOP            DEM      PR06  AP48595               14
# 3838224  ABSENTEE ONESTOP            DEM      PR29  AP48595               14
# 3838226  ABSENTEE ONESTOP            DEM      PR29  AP48595               14
# 3838228  ABSENTEE ONESTOP            DEM      PR29  AP48595               14
# 3838227  ABSENTEE ONESTOP            DEM      PR29  AP48595               14
#
#         vtd_label
# 3838225      PR29
# 3838229      PR29
# 3838223      PR06
# 3838224      PR29
# 3838226      PR29
# 3838228      PR29
# 3838227      PR29
#          county_id  voter_reg_num election_lbl       election_desc  \
# 3941168         14       14514646   11/08/2016  11/08/2016 GENERAL
# 3941169         14       14514646   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 3941168  ABSENTEE ONESTOP            DEM      PR34  AP84737               14
# 3941169  ABSENTEE ONESTOP            DEM        12  AP84737               18
#
#         vtd_label
# 3941168      PR15
# 3941169        12
#          county_id  voter_reg_num election_lbl       election_desc  \
# 4016466         10      600067713   05/08/2012  05/08/2012 PRIMARY
# 4016462         10      600067713   11/06/2012  11/06/2012 GENERAL
# 4016465         10      600067713   11/06/2012  11/06/2012 GENERAL
# 4016464         10      600067713   11/06/2018  11/06/2018 GENERAL
# 4016463         10      600067713   11/08/2016  11/08/2016 GENERAL
#
#             voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 4016466         IN-PERSON            REP      WILD  AS12896               16
# 4016462         IN-PERSON            REP        11  AS12896                1
# 4016465         IN-PERSON            REP      WILD  AS12896               16
# 4016464  ABSENTEE ONESTOP            REP        15  AS12896               10
# 4016463  ABSENTEE ONESTOP            REP        15  AS12896               10
#
#         vtd_label
# 4016466      WILD
# 4016462        11
# 4016465      WILD
# 4016464        15
# 4016463        15
#          county_id  voter_reg_num election_lbl  \
# 4046201         16          21687   03/03/2020
# 4046191         16          21687   03/15/2016
# 4046195         16          21687   03/15/2016
# 4046198         16          21687   05/08/2012
# 4046204         16          21687   05/08/2018
# 4046202         16          21687   06/07/2016
# 4046200         16          21687   07/09/2019
# 4046199         16          21687   09/10/2019
# 4046203         16          21687   11/03/2020
# 4046190         16          21687   11/04/2014
# 4046205         16          21687   11/04/2014
# 4046192         16          21687   11/06/2012
# 4046197         16          21687   11/06/2012
# 4046196         16          21687   11/06/2018
# 4046193         16          21687   11/08/2016
# 4046194         16          21687   11/08/2016
#
#                             election_desc     voting_method voted_party_cd  \
# 4046201                03/03/2020 PRIMARY         IN-PERSON            REP
# 4046191                03/15/2016 PRIMARY         IN-PERSON            REP
# 4046195                03/15/2016 PRIMARY         IN-PERSON            REP
# 4046198                05/08/2012 PRIMARY         IN-PERSON            UNA
# 4046204                05/08/2018 PRIMARY         IN-PERSON            REP
# 4046202  06/07/2016 CONGRESSIONAL PRIMARY         IN-PERSON            UNA
# 4046200         07/09/2019 SECOND PRIMARY         IN-PERSON            REP
# 4046199                09/10/2019 GENERAL         IN-PERSON            UNA
# 4046203                11/03/2020 GENERAL  ABSENTEE ONESTOP            UNA
# 4046190                11/04/2014 GENERAL  ABSENTEE ONESTOP            REP
# 4046205                11/04/2014 GENERAL         IN-PERSON            UNA
# 4046192                11/06/2012 GENERAL  ABSENTEE ONESTOP            REP
# 4046197                11/06/2012 GENERAL         IN-PERSON            UNA
# 4046196                11/06/2018 GENERAL         IN-PERSON            UNA
# 4046193                11/08/2016 GENERAL  ABSENTEE ONESTOP            REP
# 4046194                11/08/2016 GENERAL         IN-PERSON            UNA
#
#         pct_label     ncid  voted_county_id vtd_label
# 4046201      MCRK  AS21627               16      MCRK
# 4046191        08  AS21627               25        08
# 4046195      STEL  AS21627               16      STEL
# 4046198      STEL  AS21627               16      STEL
# 4046204      MCRK  AS21627               16      MCRK
# 4046202      STEL  AS21627               16      STEL
# 4046200      MCRK  AS21627               16      MCRK
# 4046199      MCRK  AS21627               16      MCRK
# 4046203      MCRK  AS21627               16      MCRK
# 4046190        08  AS21627               25        08
# 4046205      STEL  AS21627               16      STEL
# 4046192        08  AS21627               25        08
# 4046197      STEL  AS21627               16      STEL
# 4046196      MCRK  AS21627               16      MCRK
# 4046193        08  AS21627               25        08
# 4046194      STEL  AS21627               16      STEL
#          county_id  voter_reg_num election_lbl         election_desc  \
# 4101270         16          46448   03/15/2016    03/15/2016 PRIMARY
# 4101272         16          46448   05/08/2018    05/08/2018 PRIMARY
# 4101268         16          46448   11/03/2020    11/03/2020 GENERAL
# 4101267         16          46448   11/06/2012    11/06/2012 GENERAL
# 4101273         16          46448   11/06/2012    11/06/2012 GENERAL
# 4101271         16          46448   11/06/2018    11/06/2018 GENERAL
# 4101274         16          46448   11/08/2011  11/08/2011 MUNICIPAL
# 4101269         16          46448   11/08/2016    11/08/2016 GENERAL
#
#         voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 4101270      TRANSFER            REP      OTBE  AS39491               16
# 4101272     IN-PERSON            REP      OTBE  AS39491               16
# 4101268     IN-PERSON            REP     OTBEG  AS39491               16
# 4101267     IN-PERSON            REP      HAIS  AS39491               16
# 4101273     IN-PERSON            DEM        D2  AS39491               53
# 4101271     IN-PERSON            REP      OTBE  AS39491               16
# 4101274     IN-PERSON            DEM        D2  AS39491               53
# 4101269      TRANSFER            UNA      OTBE  AS39491               16
#
#         vtd_label
# 4101270      OTST
# 4101272      OTST
# 4101268      OTST
# 4101267      HAIS
# 4101273         D
# 4101271      OTST
# 4101274         D
# 4101269      OTST
# ...
# 34043097  ABSENTEE BY MAIL            UNA     19-12  EM61269               92
#
#          vtd_label
# 34043093        05
# 34043096     19-12
# 34043094        18
# 34043095     19-12
# 34043097     19-12
#           county_id  voter_reg_num election_lbl              election_desc  \
# 34136649         96       30036476   03/03/2020         03/03/2020 PRIMARY
# 34136644         96       30036476   03/15/2016         03/15/2016 PRIMARY
# 34136642         96       30036476   05/06/2014         05/06/2014 PRIMARY
# 34136646         96       30036476   05/08/2012         05/08/2012 PRIMARY
# 34136651         96       30036476   05/08/2012         05/08/2012 PRIMARY
# 34136641         96       30036476   07/17/2012  07/17/2012 SECOND PRIMARY
# 34136648         96       30036476   11/03/2020         11/03/2020 GENERAL
# 34136647         96       30036476   11/04/2014         11/04/2014 GENERAL
# 34136650         96       30036476   11/06/2012         11/06/2012 GENERAL
# 34136645         96       30036476   11/06/2018         11/06/2018 GENERAL
# 34136643         96       30036476   11/08/2016         11/08/2016 GENERAL
#
#          voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34136649     IN-PERSON            REP        07  EM92240               96
# 34136644     IN-PERSON            REP        07  EM92240               96
# 34136642     IN-PERSON            REP        07  EM92240               96
# 34136646     IN-PERSON            UNA        05  EM92240               96
# 34136651     IN-PERSON            REP        28  EM92240               96
# 34136641   PROVISIONAL            REP        07  EM92240               96
# 34136648     IN-PERSON            REP        07  EM92240               96
# 34136647     IN-PERSON            REP        07  EM92240               96
# 34136650     IN-PERSON            REP        07  EM92240               96
# 34136645     IN-PERSON            REP        07  EM92240               96
# 34136643     IN-PERSON            REP        07  EM92240               96
#
#          vtd_label
# 34136649        07
# 34136644        07
# 34136642        07
# 34136646        05
# 34136651        28
# 34136641        07
# 34136648        07
# 34136647        07
# 34136650        07
# 34136645        07
# 34136643        07
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34212930         97          39722   03/15/2016  03/15/2016 PRIMARY
# 34212928         97          39722   05/06/2014  05/06/2014 PRIMARY
# 34212931         97          39722   05/08/2012  05/08/2012 PRIMARY
# 34212929         97          39722   11/04/2014  11/04/2014 GENERAL
# 34212927         97          39722   11/06/2012  11/06/2012 GENERAL
# 34212926         97          39722   11/08/2016  11/08/2016 GENERAL
# 34212932         97          39722   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34212930         IN-PERSON            REP       114  EN24153               97
# 34212928         IN-PERSON            REP       114  EN24153               97
# 34212931         IN-PERSON            REP       114  EN24153               97
# 34212929         IN-PERSON            UNA       114  EN24153               97
# 34212927         IN-PERSON            UNA       114  EN24153               97
# 34212926  ABSENTEE ONESTOP            REP        07  EN24153               30
# 34212932  ABSENTEE ONESTOP            UNA       114  EN24153               97
#
#          vtd_label
# 34212930       114
# 34212928       114
# 34212931       114
# 34212929       114
# 34212927       114
# 34212926        07
# 34212932       114
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34302528         97       30011084   03/03/2020  03/03/2020 PRIMARY
# 34302535         97       30011084   03/15/2016  03/15/2016 PRIMARY
# 34302531         97       30011084   05/08/2012  05/08/2012 PRIMARY
# 34302530         97       30011084   05/08/2018  05/08/2018 PRIMARY
# 34302533         97       30011084   11/03/2020  11/03/2020 GENERAL
# 34302534         97       30011084   11/06/2012  11/06/2012 GENERAL
# 34302536         97       30011084   11/06/2012  11/06/2012 GENERAL
# 34302532         97       30011084   11/06/2018  11/06/2018 GENERAL
# 34302529         97       30011084   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34302528         IN-PERSON            REP       122  EN54804               97
# 34302535  ABSENTEE ONESTOP            REP       119  EN54804               97
# 34302531         IN-PERSON            REP       110  EN54804               97
# 34302530         IN-PERSON            REP       119  EN54804               97
# 34302533  ABSENTEE ONESTOP            UNA       122  EN54804               97
# 34302534         IN-PERSON            REP       110  EN54804               97
# 34302536  ABSENTEE ONESTOP            DEM        13  EN54804                5
# 34302532  ABSENTEE ONESTOP            UNA       119  EN54804               97
# 34302529  ABSENTEE ONESTOP            UNA       119  EN54804               97
#
#          vtd_label
# 34302528       122
# 34302535       119
# 34302531       110
# 34302530       119
# 34302533       122
# 34302534       110
# 34302536        13
# 34302532       119
# 34302529       119
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34351523         34       30368690   11/03/2020  11/03/2020 GENERAL
# 34351521         34       30368690   11/08/2016  11/08/2016 GENERAL
# 34351522         34       30368690   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34351523  ABSENTEE ONESTOP            REP       705  EN70230               34
# 34351521  ABSENTEE ONESTOP            UNA        07  EN70230               95
# 34351522  ABSENTEE ONESTOP            REP       119  EN70230               97
#
#          vtd_label
# 34351523       705
# 34351521        07
# 34351522       119
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34358814         97       30034536   03/03/2020  03/03/2020 PRIMARY
# 34358815         97       30034536   11/03/2020  11/03/2020 GENERAL
# 34358818         97       30034536   11/06/2012  11/06/2012 GENERAL
# 34358813         97       30034536   11/06/2018  11/06/2018 GENERAL
# 34358817         97       30034536   11/06/2018  11/06/2018 GENERAL
# 34358816         97       30034536   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34358814         IN-PERSON            REP       128  EN73164               97
# 34358815  ABSENTEE ONESTOP            REP       128  EN73164               97
# 34358818         IN-PERSON            DEM       102  EN73164               97
# 34358813         IN-PERSON            REP       128  EN73164               97
# 34358817       PROVISIONAL            DEM       102  EN73164               97
# 34358816  ABSENTEE ONESTOP            DEM       102  EN73164               97
#
#          vtd_label
# 34358814       128
# 34358815       128
# 34358818       102
# 34358813       128
# 34358817       102
# 34358816       102
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34414045         98          27375   05/08/2012  05/08/2012 PRIMARY
# 34414043         98          27375   11/04/2014  11/04/2014 GENERAL
# 34414040         98          27375   11/06/2012  11/06/2012 GENERAL
# 34414044         98          27375   11/06/2012  11/06/2012 GENERAL
# 34414041         98          27375   11/06/2018  11/06/2018 GENERAL
# 34414042         98          27375   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34414045         IN-PERSON            REP      0035  EP21414               64
# 34414043         IN-PERSON            REP      0035  EP21414               64
# 34414040  ABSENTEE ONESTOP            DEM      PRCR  EP21414               98
# 34414044  ABSENTEE ONESTOP            REP      0035  EP21414               64
# 34414041  ABSENTEE ONESTOP            REP      PRGA  EP21414               98
# 34414042  ABSENTEE ONESTOP            REP      PRGA  EP21414               98
#
#          vtd_label
# 34414045      0035
# 34414043      0035
# 34414040      PRCR
# 34414044      0035
# 34414041      PRGA
# 34414042      PRGA
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34425198         98          31940   03/15/2016  03/15/2016 PRIMARY
# 34425200         98          31940   03/15/2016  03/15/2016 PRIMARY
# 34425201         98          31940   11/06/2018  11/06/2018 GENERAL
# 34425199         98          31940   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34425198       PROVISIONAL            REP      PROL  EP24867               98
# 34425200       PROVISIONAL            REP      PROL  EP24867               98
# 34425201  ABSENTEE ONESTOP            REP      PRWM  EP24867               98
# 34425199  ABSENTEE ONESTOP            REP      PRWM  EP24867               98
#
#          vtd_label
# 34425198      PRWM
# 34425200      PROL
# 34425201      PRWM
# 34425199      PRWM
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34480924         98      757513184   05/08/2012  05/08/2012 PRIMARY
# 34480923         98      757513184   11/04/2014  11/04/2014 GENERAL
# 34480922         98      757513184   11/06/2012  11/06/2012 GENERAL
# 34480925         98      757513184   11/06/2012  11/06/2012 GENERAL
# 34480921         98      757513184   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34480924         IN-PERSON            REP        16  EP46816               10
# 34480923         IN-PERSON            REP        16  EP46816               10
# 34480922         IN-PERSON            REP        16  EP46816               10
# 34480925  ABSENTEE ONESTOP            DEM      PRGA  EP46816               98
# 34480921         IN-PERSON            REP        16  EP46816               10
#
#          vtd_label
# 34480924        16
# 34480923        16
# 34480922        16
# 34480925      PRGA
# 34480921        16
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34535875         98       57484692   03/03/2020  03/03/2020 PRIMARY
# 34535878         98       57484692   03/03/2020  03/03/2020 PRIMARY
# 34535874         98       57484692   11/06/2012  11/06/2012 GENERAL
# 34535876         98       57484692   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34535875       PROVISIONAL            DEM      PRWE  EP67692               98
# 34535878         IN-PERSON            DEM      PRWE  EP67692               98
# 34535874  ABSENTEE ONESTOP            DEM      PRWM  EP67692               98
# 34535876         IN-PERSON            DEM      PRWM  EP67692               98
#
#          vtd_label
# 34535875      PRWI
# 34535878      PRWE
# 34535874      PRWM
# 34535876      PRWM
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34572235         98      757480595   05/08/2012  05/08/2012 PRIMARY
# 34572236         98      757480595   11/04/2014  11/04/2014 GENERAL
# 34572231         98      757480595   11/06/2012  11/06/2012 GENERAL
# 34572234         98      757480595   11/06/2012  11/06/2012 GENERAL
# 34572233         98      757480595   11/06/2018  11/06/2018 GENERAL
# 34572232         98      757480595   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34572235  ABSENTEE ONESTOP            DEM      PRSP  EP80424               98
# 34572236         IN-PERSON            DEM      PRSP  EP80424               98
# 34572231  ABSENTEE ONESTOP            DEM       4-B  EP80424               70
# 34572234  ABSENTEE ONESTOP            DEM      PRSP  EP80424               98
# 34572233         IN-PERSON            DEM      PRSP  EP80424               98
# 34572232         IN-PERSON            DEM      PRSP  EP80424               98
#
#          vtd_label
# 34572235      PRSP
# 34572236      PRSP
# 34572231       4-B
# 34572234      PRSP
# 34572233      PRSP
# 34572232      PRSP
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34634353         99          15048   03/03/2020  03/03/2020 PRIMARY
# 34634351         99          15048   03/15/2016  03/15/2016 PRIMARY
# 34634355         99          15048   05/06/2014  05/06/2014 PRIMARY
# 34634347         99          15048   05/08/2012  05/08/2012 PRIMARY
# 34634360         99          15048   05/08/2012  05/08/2012 PRIMARY
# 34634352         99          15048   05/08/2018  05/08/2018 PRIMARY
# 34634358         99          15048   11/03/2020  11/03/2020 GENERAL
# 34634348         99          15048   11/04/2014  11/04/2014 GENERAL
# 34634359         99          15048   11/04/2014  11/04/2014 GENERAL
# 34634350         99          15048   11/06/2012  11/06/2012 GENERAL
# 34634354         99          15048   11/06/2012  11/06/2012 GENERAL
# 34634346         99          15048   11/06/2018  11/06/2018 GENERAL
# 34634349         99          15048   11/08/2016  11/08/2016 GENERAL
# 34634356         99          15048   11/08/2016  11/08/2016 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34634353         IN-PERSON            REP      SFAL  ER15626               99
# 34634351         IN-PERSON            REP      SFAL  ER15626               99
# 34634355         IN-PERSON            REP      SFAL  ER15626               99
# 34634347         IN-PERSON            REP       133  ER15626               34
# 34634360         IN-PERSON            REP      SFAL  ER15626               99
# 34634352         IN-PERSON            REP      SFAL  ER15626               99
# 34634358  ABSENTEE ONESTOP            REP      SFAL  ER15626               99
# 34634348         IN-PERSON            REP       133  ER15626               34
# 34634359         IN-PERSON            REP      SFAL  ER15626               99
# 34634350  ABSENTEE BY MAIL            REP       133  ER15626               34
# 34634354  ABSENTEE ONESTOP            REP      SFAL  ER15626               99
# 34634346  ABSENTEE ONESTOP            REP      SFAL  ER15626               99
# 34634349  ABSENTEE ONESTOP            REP       133  ER15626               34
# 34634356         IN-PERSON            REP      SFAL  ER15626               99
#
#          vtd_label
# 34634353      SFAL
# 34634351      SFAL
# 34634355      SFAL
# 34634347       133
# 34634360      SFAL
# 34634352      SFAL
# 34634358      SFAL
# 34634348       133
# 34634359      SFAL
# 34634350       133
# 34634354      SFAL
# 34634346      SFAL
# 34634349       133
# 34634356      SFAL
#           county_id  voter_reg_num election_lbl       election_desc  \
# 34719308         99          79756   05/08/2018  05/08/2018 PRIMARY
# 34719310         99          79756   11/03/2020  11/03/2020 GENERAL
# 34719309         99          79756   11/06/2018  11/06/2018 GENERAL
# 34719311         99          79756   11/06/2018  11/06/2018 GENERAL
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 34719308  ABSENTEE ONESTOP            REP      BNVL  ER43863               99
# 34719310  ABSENTEE ONESTOP            REP      BNVL  ER43863               99
# 34719309  ABSENTEE ONESTOP            REP      BNVL  ER43863               99
# 34719311  ABSENTEE ONESTOP            REP      1507  ER43863               74
#
#          vtd_label
# 34719308      BNVL
# 34719310      BNVL
# 34719309      BNVL
# 34719311      1507

# %%
plot_count('election_desc', dup_ncid_elecs, rotation=85);

# %%
plot_count('voting_method', dup_ncid_elecs, rotation=45);

# %%
plot_count('voted_party_cd', dup_ncid_elecs);

# %%
plot_count('voted_county_id', dup_ncid_elecs, figsize=(18,7), rotation=45);

# %% [markdown]
# ## Explore Voter Registration Records

# %%
## Check number of unique individuals represented in voter reg records
nc_vreg['ncid'].nunique()
# Out:
# 8309352

# %%
## Check voter status information -- Should any categories be removed??
nc_vreg['voter_status_desc'].value_counts()
# Out:
# ACTIVE       6667206
# REMOVED       754889
# INACTIVE      738674
# DENIED        138925
# TEMPORARY       9658
# Name: voter_status_desc, dtype: int64

# %%
plot_count('voter_status_desc', nc_vreg);

# %%
plot_count('race_code', nc_vreg);

# %%
plot_count('gender_code', nc_vreg);

# %%
plot_count('party_cd', nc_vreg); # registered party

# %%
nc_vreg['birth_year'].min()
# Out:
# 1753

# %%
nc_vreg['birth_year'].nsmallest(30)
# Out:
# 1701638    1753
# 4242158    1753
# 6589173    1753
# 4900708    1765
# 4890112    1772
# 1952809    1776
# 4419417    1779
# 5674295    1796
# 5201124    1801
# 1561970    1853
# 5550045    1853
# 6449327    1868
# 5587351    1870
# 3126729    1882
# 5815404    1882
# 2293056    1884
# 3086414    1884
# 4434632    1884
# 6325575    1884
# 2868126    1885
# 6462127    1885
# 3885849    1893
# 328240     1897
# 8203917    1897
# 6316820    1899
# 6330060    1899
# 8055795    1899
# 34093      1900
# 84638      1900
# 126130     1900
# Name: birth_year, dtype: int64

# %%
## Plot distribution of current age as of EOY 2020 
plt.figure(figsize=(10,7))
ax = sns.histplot(nc_vreg['birth_age'])
ax.set_title('Current Age Counts', fontsize=16, weight='bold')
ax.set_xlabel('Age', fontsize=14, weight='bold')
ax.set_ylabel('Count', fontsize=14, weight='bold')
# There is one voter listed as having been born in 1753 that throws off x axis
ax.set_xlim(15,115);

# %%
# fig = px.histogram(nc_vreg, x='birth_age', hover_data=nc_vreg.columns)
# fig.show()

# %%
# fig = px.histogram(nc_vreg, x='birth_age',
#                    color='voter_status_desc', hover_data=nc_vreg.columns)
# fig.show()

# %% [markdown]
# ### Active Voters

# %%
active_voters = nc_vreg.groupby('voter_status_desc').get_group('ACTIVE')
print(len(active_voters))
active_voters.head()
# Out:
# 6667206
#   voter_status_desc voter_status_reason_desc   last_name first_name  \
# 0            ACTIVE                 VERIFIED       AABEL       RUTH
# 1            ACTIVE                 VERIFIED      AARDEN       JONI
# 2            ACTIVE     VERIFICATION PENDING  AARMSTRONG    TIMOTHY
# 3            ACTIVE                 VERIFIED       AARON  CHRISTINA
# 4            ACTIVE                 VERIFIED       AARON    CLAUDIA
#
#   middle_name                   res_street_address res_city_desc state_cd  \
# 0      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 1      AUTUMN                     117 W CLAY ST           MEBANE       NC
# 2       DUANE               3670  COVINGTON TRL           MEBANE       NC
# 3    CASTAGNA                    421  WHITT AVE       BURLINGTON       NC
# 4      HAYDEN                    1013  EDITH ST       BURLINGTON       NC
#
#    zip_code race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0   27253.0         W          NL      UNA           F         85          NY
# 1   27302.0         W          UN      UNA           F         42          DC
# 2   27302.0         W          UN      REP           M         54          AL
# 3   27215.0         W          UN      UNA           F         44          NC
# 4   27215.0         W          NL      UNA           F         75          VA
#
#   drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           N  10/01/1984            08N             13.0               15A
# 1           Y  02/23/2018            10N             13.0               15A
# 2           N  10/31/2020            103             13.0               15A
# 3           Y  03/26/1996            03S             13.0               15A
# 4           Y  08/15/1989            124             13.0               15A
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 0              15A             24.0            64.0               NaN
# 1              15A             24.0            63.0               NaN
# 2              15A             24.0            63.0               NaN
# 3              15A             24.0            64.0               NaN
# 4              15A             24.0            63.0               NaN
#
#    dist_1_abbrv confidential_ind  birth_year      ncid vtd_abbrv
# 0          17.0                N        1935   AA56273       08N
# 1          17.0                N        1978  AA201627       10N
# 2          17.0                N        1966  AA216996       103
# 3          17.0                N        1976   AA98377       03S
# 4          17.0                N        1945   AA69747       124

# %%
active_voters['voter_status_reason_desc'].value_counts()
# Out:
# VERIFIED                               6416896
# VERIFICATION PENDING                    116526
# LEGACY DATA                              44892
# UNVERIFIED                               40825
# UNVERIFIED NEW                           25253
# CONFIRMATION PENDING                     19291
# CONFIRMATION NOT RETURNED                 1834
# CONFIRMATION RETURNED UNDELIVERABLE       1594
# ARMED FORCES                                93
# ADMINISTRATIVE                               1
# Name: voter_status_reason_desc, dtype: int64

# %%
compare_age_distr(nc_vreg, 'Registered Voters', 
                  active_voters, 'Active Voters');

# %%
plot_count('race_code', active_voters);

# %%
plot_count('gender_code', active_voters);

# %%
plot_count('party_cd', active_voters);

# %% [markdown]
# ### Denied Voters

# %%
denied_voters = nc_vreg.groupby('voter_status_desc').get_group('DENIED')
print(len(denied_voters))
denied_voters.head()
# Out:
# 138925
#     voter_status_desc             voter_status_reason_desc last_name  \
# 32             DENIED  VERIFICATION RETURNED UNDELIVERABLE    ABBOTT
# 55             DENIED  VERIFICATION RETURNED UNDELIVERABLE    ABBOTT
# 192            DENIED  VERIFICATION RETURNED UNDELIVERABLE     ACORD
# 359            DENIED    UNAVAILABLE ESSENTIAL INFORMATION     ADAMS
# 443            DENIED  VERIFICATION RETURNED UNDELIVERABLE     ADEYO
#
#     first_name middle_name      res_street_address res_city_desc state_cd  \
# 32      ASHLEY      LAUREN  700 E HAGGARD AVE   #J          ELON       NC
# 55        TERI         LEE  334  ROLLINGWOOD DR       BURLINGTON       NC
# 192    REXANNA         NaN       302  GRAHAM RD           GRAHAM       NC
# 359       PAUL     WENDELL  1426  CLOVERDALE ST       BURLINGTON       NC
# 443    ADENIKE      CELINA    1301 E DOGWOOD DR           MEBANE       NC
#
#      zip_code race_code ethnic_code party_cd gender_code  birth_age  \
# 32    27244.0         W          NL      UNA           F         24
# 55    27217.0         U          UN      UNA           U         55
# 192   27253.0         W          NL      REP           F         68
# 359   27217.0         W          NL      REP           M         62
# 443   27302.0         B          NL      DEM           F         39
#
#     birth_state drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv  \
# 32           NJ           N  09/30/2014            NaN              NaN
# 55          NaN           Y  10/08/2020            NaN              NaN
# 192          WV           Y  01/18/2007            NaN              NaN
# 359          SC           N  12/13/1996            NaN              NaN
# 443          OC           Y  07/19/2017            NaN              NaN
#
#     super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 32                NaN              NaN              NaN             NaN
# 55                NaN              NaN              NaN             NaN
# 192               NaN              NaN              NaN             NaN
# 359               NaN              NaN              NaN             NaN
# 443               NaN              NaN              NaN             NaN
#
#     school_dist_abbrv  dist_1_abbrv confidential_ind  birth_year      ncid  \
# 32                NaN           NaN                N        1996  AA183324
# 55                NaN           NaN                N        1965  AA215561
# 192               NaN           NaN                N        1952  AA148645
# 359               NaN           NaN                N        1958  AA105378
# 443               NaN           NaN                N        1981  AA196431
#
#     vtd_abbrv
# 32        NaN
# 55        NaN
# 192       NaN
# 359       NaN
# 443       NaN

# %%
denied_voters['voter_status_reason_desc'].value_counts()
# Out:
# VERIFICATION RETURNED UNDELIVERABLE    132786
# UNAVAILABLE ESSENTIAL INFORMATION        6100
# MOVED FROM COUNTY                          14
# CONFIRMATION NOT RETURNED                  10
# FELONY CONVICTION                           8
# MOVED FROM STATE                            4
# DUPLICATE                                   1
# DECEASED                                    1
# UNVERIFIED                                  1
# Name: voter_status_reason_desc, dtype: int64

# %%
compare_age_distr(nc_vreg, 'Registered Voters', 
                  denied_voters, 'Denied Voters');

# %%
plot_count('race_code', denied_voters);

# %%
plot_count('gender_code', denied_voters);

# %%
plot_count('party_cd', denied_voters);

# %% [markdown]
# ### Inactive Voters

# %%
inactive_voters = nc_vreg.groupby('voter_status_desc').get_group('INACTIVE')
print(len(inactive_voters))
inactive_voters.head()
# Out:
# 738674
#     voter_status_desc   voter_status_reason_desc    last_name first_name  \
# 18           INACTIVE  CONFIRMATION NOT RETURNED     ABADILLA      STEVE
# 47           INACTIVE  CONFIRMATION NOT RETURNED       ABBOTT      MARIA
# 61           INACTIVE  CONFIRMATION NOT RETURNED  ABDEL-MAGID       LISA
# 79           INACTIVE  CONFIRMATION NOT RETURNED        ABELE      KYLIE
# 101          INACTIVE  CONFIRMATION NOT RETURNED    ABERNATHY  JEFFERSON
#
#     middle_name  res_street_address res_city_desc state_cd  zip_code  \
# 18        ARCEO   105 N SIXTH ST           MEBANE       NC   27302.0
# 47      LYNETTE   614  TUCKER ST       BURLINGTON       NC   27215.0
# 61          ANN  1841  DUNBAR PL       BURLINGTON       NC   27215.0
# 79           JO    336  SLATE DR      GIBSONVILLE       NC   27249.0
# 101        REID   27  HOLMESWAY              ELON       NC   27244.0
#
#     race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 18          O          NL      UNA           M         31          OC
# 47          B          NL      DEM           F         35          NC
# 61          W          NL      UNA           F         60          DC
# 79          W          NL      REP           F         33          WV
# 101         W          UN      REP           M        101          WV
#
#     drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 18            Y  07/03/2014            10N             13.0               15A
# 47            Y  05/02/2008            128             13.0               15A
# 61            Y  11/10/2011            03S             13.0               15A
# 79            N  03/22/2012            03W             13.0               15A
# 101           Y  04/06/1969            035             13.0               15A
#
#     judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 18               15A             24.0            63.0               NaN
# 47               15A             24.0            64.0               NaN
# 61               15A             24.0            64.0               NaN
# 79               15A             24.0            64.0               NaN
# 101              15A             24.0            64.0               NaN
#
#      dist_1_abbrv confidential_ind  birth_year      ncid vtd_abbrv
# 18           17.0                N        1989  DE236758       10N
# 47           17.0                N        1985  BY382231       128
# 61           17.0                N        1960  AA169698       03S
# 79           17.0                N        1987  AA171060       03W
# 101          17.0                N        1919    AA2056       035

# %%
inactive_voters['voter_status_reason_desc'].value_counts()
# Out:
# CONFIRMATION NOT RETURNED              430273
# CONFIRMATION RETURNED UNDELIVERABLE    308250
# ADMINISTRATIVE                            150
# UNVERIFIED                                  1
# Name: voter_status_reason_desc, dtype: int64

# %%
compare_age_distr(nc_vreg, 'Registered Voters', 
                  inactive_voters, 'Inactive Voters');

# %%
plot_count('race_code', inactive_voters);

# %%
plot_count('gender_code', inactive_voters);

# %%
plot_count('party_cd', inactive_voters);

# %% [markdown]
# ### Removed Voters

# %%
removed_voters = nc_vreg.groupby('voter_status_desc').get_group('REMOVED')
print(len(removed_voters))
removed_voters.head()
# Out:
# 754889
#    voter_status_desc                           voter_status_reason_desc  \
# 36           REMOVED                                  MOVED FROM COUNTY
# 40           REMOVED                                           DECEASED
# 44           REMOVED                                   MOVED FROM STATE
# 78           REMOVED  REMOVED AFTER 2 FED GENERAL ELECTIONS IN INACT...
# 89           REMOVED                                           DECEASED
#
#       last_name  first_name  middle_name res_street_address res_city_desc  \
# 36       ABBOTT       DEREK       ANDREW            REMOVED           NaN
# 40       ABBOTT      GLADYS  MARIE MILES            REMOVED           NaN
# 44       ABBOTT       JOYCE       HODGES            REMOVED           NaN
# 78        ABELE        KLAY      MATTHEW            REMOVED           NaN
# 89  ABERCROMBIE  JACQUELINE     LINVILLE            REMOVED           NaN
#
#    state_cd  zip_code race_code ethnic_code party_cd gender_code  birth_age  \
# 36      NaN       NaN         W          NL      UNA           M         52
# 40      NaN       NaN         B          NL      DEM           F         68
# 44      NaN       NaN         W          NL      DEM           F         73
# 78      NaN       NaN         W          NL      UNA           M         33
# 89      NaN       NaN         W          NL      DEM           F         80
#
#    birth_state drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv  \
# 36          OH           Y  02/20/2014            NaN              NaN
# 40          NC           Y  11/05/2002            NaN              NaN
# 44          VA           Y  09/24/1990            NaN              NaN
# 78          OH           Y  03/26/2012            NaN              NaN
# 89          NC           Y  05/02/1964            NaN              NaN
#
#    super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 36               NaN              NaN              NaN             NaN
# 40               NaN              NaN              NaN             NaN
# 44               NaN              NaN              NaN             NaN
# 78               NaN              NaN              NaN             NaN
# 89               NaN              NaN              NaN             NaN
#
#    school_dist_abbrv  dist_1_abbrv confidential_ind  birth_year      ncid  \
# 36               NaN           NaN                N        1968  BY552572
# 40               NaN           NaN                N        1952  AA128440
# 44               NaN           NaN                N        1947   AA73791
# 78               NaN           NaN                N        1986  AA171094
# 89               NaN           NaN                N        1939    AA2049
#
#    vtd_abbrv
# 36       NaN
# 40       NaN
# 44       NaN
# 78       NaN
# 89       NaN

# %%
removed_voters['voter_status_reason_desc'].value_counts()
# Out:
# DECEASED                                                    389685
# MOVED FROM STATE                                            133502
# REMOVED AFTER 2 FED GENERAL ELECTIONS IN INACTIVE STATUS     98576
# MOVED FROM COUNTY                                            85768
# FELONY CONVICTION                                            13621
# MOVED WITHIN STATE                                           10530
# REQUEST FROM VOTER                                            6813
# FELONY SENTENCE COMPLETED                                     5523
# TEMPORARY REGISTRANT                                          5260
# DUPLICATE                                                     3741
# ADMINISTRATIVE                                                1165
# REMOVED DUE TO SUSTAINED CHALLENGE                             700
# REMOVED UNDER OLD PURGE LAW                                      3
# UNVERIFIED                                                       2
# Name: voter_status_reason_desc, dtype: int64

# %%
compare_age_distr(nc_vreg, 'Registered Voters', 
                  removed_voters, 'Removed Voters');

# %%
plot_count('race_code', removed_voters);

# %%
plot_count('gender_code', removed_voters);

# %%
plot_count('party_cd', removed_voters);

# %% [markdown]
# ## Merge Voter Registration Data with Voter History Data

# %%
## Merge voter registration information onto records of voter history based 
  ## on unique ncid
    
## Use right join so we're only including ncid's for which their is
  ## registration and demographic information, including for those 
    ## people who are registered, but have never voted
all_nc_voters = nc_vhis.merge(nc_vreg, how='right', on='ncid')
# inspect new dataframe
display(all_nc_voters.head())
all_nc_voters.tail()
# Out:
#    county_id  voter_reg_num election_lbl       election_desc  \
# 0        1.0      9005990.0   11/03/2020  11/03/2020 GENERAL
# 1        1.0      9005990.0   11/04/2014  11/04/2014 GENERAL
# 2        1.0      9005990.0   11/06/2012  11/06/2012 GENERAL
# 3        1.0      9005990.0   11/08/2016  11/08/2016 GENERAL
# 4        1.0      9005990.0   03/15/2016  03/15/2016 PRIMARY
#
#       voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 0  ABSENTEE BY MAIL            UNA       08N  AA56273              1.0
# 1         IN-PERSON            UNA       08N  AA56273              1.0
# 2         IN-PERSON            UNA       08N  AA56273              1.0
# 3         IN-PERSON            UNA       08N  AA56273              1.0
# 4         IN-PERSON            DEM       08N  AA56273              1.0
#
#   vtd_label voter_status_desc voter_status_reason_desc last_name first_name  \
# 0       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 1       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 2       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 3       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 4       08N            ACTIVE                 VERIFIED     AABEL       RUTH
#
#   middle_name                   res_street_address res_city_desc state_cd  \
# 0      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 1      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 2      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 3      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 4      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
#
#    zip_code race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0   27253.0         W          NL      UNA           F         85          NY
# 1   27253.0         W          NL      UNA           F         85          NY
# 2   27253.0         W          NL      UNA           F         85          NY
# 3   27253.0         W          NL      UNA           F         85          NY
# 4   27253.0         W          NL      UNA           F         85          NY
#
#   drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           N  10/01/1984            08N             13.0               15A
# 1           N  10/01/1984            08N             13.0               15A
# 2           N  10/01/1984            08N             13.0               15A
# 3           N  10/01/1984            08N             13.0               15A
# 4           N  10/01/1984            08N             13.0               15A
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 0              15A             24.0            64.0               NaN
# 1              15A             24.0            64.0               NaN
# 2              15A             24.0            64.0               NaN
# 3              15A             24.0            64.0               NaN
# 4              15A             24.0            64.0               NaN
#
#    dist_1_abbrv confidential_ind  birth_year vtd_abbrv
# 0          17.0                N        1935       08N
# 1          17.0                N        1935       08N
# 2          17.0                N        1935       08N
# 3          17.0                N        1935       08N
# 4          17.0                N        1935       08N
#           county_id  voter_reg_num election_lbl       election_desc  \
# 35870783      100.0        26014.0   11/06/2018  11/06/2018 GENERAL
# 35870784      100.0        26014.0   11/03/2020  11/03/2020 GENERAL
# 35870785      100.0        26085.0   11/03/2020  11/03/2020 GENERAL
# 35870786        NaN            NaN          NaN                 NaN
# 35870787        NaN            NaN          NaN                 NaN
#
#              voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 35870783  ABSENTEE ONESTOP            REP    08 CRA  ES26341            100.0
# 35870784  ABSENTEE ONESTOP            REP    08 CRA  ES26341            100.0
# 35870785  ABSENTEE BY MAIL            UNA    01 BUR  ES26380            100.0
# 35870786               NaN            NaN       NaN  ES28936              NaN
# 35870787               NaN            NaN       NaN  ES27200              NaN
#
#          vtd_label voter_status_desc   voter_status_reason_desc  last_name  \
# 35870783    08-CRA            ACTIVE                   VERIFIED     ZULICK
# 35870784    08-CRA            ACTIVE                   VERIFIED     ZULICK
# 35870785    01-BUR            ACTIVE                   VERIFIED  ZULLINGER
# 35870786       NaN            ACTIVE                   VERIFIED   ZURAWSKI
# 35870787       NaN          INACTIVE  CONFIRMATION NOT RETURNED      ZYNDA
#
#          first_name middle_name            res_street_address   res_city_desc  \
# 35870783       DAWN   ELISABETH       250  LAUREL ACRES RD         BURNSVILLE
# 35870784       DAWN   ELISABETH       250  LAUREL ACRES RD         BURNSVILLE
# 35870785     PAMELA       YOUNG  91 W BURNSVILLE CHURCH RD         BURNSVILLE
# 35870786     ELAINE    MICHELLE            225  GARLAND LN     GREEN MOUNTAIN
# 35870787      PAULA    MARGARET  115  STONEY FALLS LOOP   #D3      BURNSVILLE
#
#          state_cd  zip_code race_code ethnic_code party_cd gender_code  \
# 35870783       NC   28714.0         W          NL      REP           F
# 35870784       NC   28714.0         W          NL      REP           F
# 35870785       NC   28714.0         W          NL      UNA           F
# 35870786       NC   28740.0         U          UN      UNA           U
# 35870787       NC   28714.0         W          NL      REP           F
#
#           birth_age birth_state drivers_lic  registr_dt precinct_abbrv  \
# 35870783         57          CO           Y  11/30/2015         08 CRA
# 35870784         57          CO           Y  11/30/2015         08 CRA
# 35870785         65          NC           Y  12/18/2015         01 BUR
# 35870786         35         NaN           Y  06/09/2020         05 GRE
# 35870787         56          IN           Y  12/29/2016         11 PRI
#
#           cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 35870783             11.0                24               24             47.0
# 35870784             11.0                24               24             47.0
# 35870785             11.0                24               24             47.0
# 35870786             11.0                24               24             47.0
# 35870787             11.0                24               24             47.0
#
#           nc_house_abbrv school_dist_abbrv  dist_1_abbrv confidential_ind  \
# 35870783           118.0               NaN          35.0                N
# 35870784           118.0               NaN          35.0                N
# 35870785           118.0               NaN          35.0                N
# 35870786           118.0               NaN          35.0                N
# 35870787           118.0               NaN          35.0                N
#
#           birth_year vtd_abbrv
# 35870783        1963    08-CRA
# 35870784        1963    08-CRA
# 35870785        1955    01-BUR
# 35870786        1984    05-GRE
# 35870787        1964    11-PRI

# %%
## Check number of unique individuals represented in all records
print(all_nc_voters['ncid'].nunique())
len(all_nc_voters)
# Out:
# 8309352
# 35870788

# %% [markdown]
# ## Drop 'Removed' and 'Denied' Voters - Further Exploration

# %%
## Drop voters who have been removed or had their registration denied
nc_voters = all_nc_voters.loc[all_nc_voters['voter_status_desc'] != 'REMOVED']
nc_voters = nc_voters.loc[nc_voters['voter_status_desc'] != 'DENIED']
nc_voters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33538405 entries, 0 to 35870787
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   county_id                 float64
#  1   voter_reg_num             float64
#  2   election_lbl              object
#  3   election_desc             object
#  4   voting_method             object
#  5   voted_party_cd            object
#  6   pct_label                 object
#  7   ncid                      object
#  8   voted_county_id           float64
#  9   vtd_label                 object
#  10  voter_status_desc         object
#  11  voter_status_reason_desc  object
#  12  last_name                 object
#  13  first_name                object
#  14  middle_name               object
#  15  res_street_address        object
#  16  res_city_desc             object
#  17  state_cd                  object
#  18  zip_code                  float64
#  19  race_code                 object
#  20  ethnic_code               object
#  21  party_cd                  object
#  22  gender_code               object
#  23  birth_age                 int64
#  24  birth_state               object
#  25  drivers_lic               object
#  26  registr_dt                object
#  27  precinct_abbrv            object
#  28  cong_dist_abbrv           float64
#  29  super_court_abbrv         object
#  30  judic_dist_abbrv          object
#  31  nc_senate_abbrv           float64
#  32  nc_house_abbrv            float64
#  33  school_dist_abbrv         object
#  34  dist_1_abbrv              float64
#  35  confidential_ind          object
#  36  birth_year                int64
#  37  vtd_abbrv                 object
# dtypes: float64(8), int64(2), object(28)
# memory usage: 9.7+ GB

# %%
## Check remaining number of unique individuals represented in the data
nc_voters['ncid'].nunique()
# Out:
# 7415538

# %%
## Check the number of records corresponding to the top 15 elections
elec_counts_df = nc_voters['election_desc'].value_counts().to_frame()
elec_counts_df.iloc[:15]
# Out:
#                                   election_desc
# 11/03/2020 GENERAL                      5353370
# 11/08/2016 GENERAL                      4488337
# 11/06/2012 GENERAL                      3927827
# 11/06/2018 GENERAL                      3655825
# 11/04/2014 GENERAL                      2668840
# 03/15/2016 PRIMARY                      2179956
# 03/03/2020 PRIMARY                      2150401
# 05/08/2012 PRIMARY                      1877251
# 05/08/2018 PRIMARY                       928285
# 05/06/2014 PRIMARY                       919808
# 06/07/2016 CONGRESSIONAL PRIMARY         475542
# 09/10/2019 GENERAL                       235166
# 11/07/2017 MUNICIPAL                     197219
# 11/05/2019 MUNICIPAL                     188871
# 07/17/2012 SECOND PRIMARY                188086

# %%
# nc_voters.to_csv('Data/NC_voters.zip', index=False)

# %% [markdown]
# ## Engineer Features for Grouping/ Database Manipulation

# %%
# nc_voters = pd.read_csv('Data/NC_voters.zip',
#                         dtype={'precinct_abbrv': str, 
#                               'super_court_abbrv': str, 
#                               'judic_dist_abbrv': str,
#                               'school_dist_abbrv': str,
#                               'vtd_abbrv': str
#                              })

# %%
nc_voters.head()
# Out:
#    county_id  voter_reg_num election_lbl       election_desc  \
# 0        1.0      9005990.0   11/03/2020  11/03/2020 GENERAL
# 1        1.0      9005990.0   11/04/2014  11/04/2014 GENERAL
# 2        1.0      9005990.0   11/06/2012  11/06/2012 GENERAL
# 3        1.0      9005990.0   11/08/2016  11/08/2016 GENERAL
# 4        1.0      9005990.0   03/15/2016  03/15/2016 PRIMARY
#
#       voting_method voted_party_cd pct_label     ncid  voted_county_id  \
# 0  ABSENTEE BY MAIL            UNA       08N  AA56273              1.0
# 1         IN-PERSON            UNA       08N  AA56273              1.0
# 2         IN-PERSON            UNA       08N  AA56273              1.0
# 3         IN-PERSON            UNA       08N  AA56273              1.0
# 4         IN-PERSON            DEM       08N  AA56273              1.0
#
#   vtd_label voter_status_desc voter_status_reason_desc last_name first_name  \
# 0       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 1       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 2       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 3       08N            ACTIVE                 VERIFIED     AABEL       RUTH
# 4       08N            ACTIVE                 VERIFIED     AABEL       RUTH
#
#   middle_name                   res_street_address res_city_desc state_cd  \
# 0      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 1      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 2      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 3      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 4      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
#
#    zip_code race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0   27253.0         W          NL      UNA           F         85          NY
# 1   27253.0         W          NL      UNA           F         85          NY
# 2   27253.0         W          NL      UNA           F         85          NY
# 3   27253.0         W          NL      UNA           F         85          NY
# 4   27253.0         W          NL      UNA           F         85          NY
#
#   drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           N  10/01/1984            08N             13.0               15A
# 1           N  10/01/1984            08N             13.0               15A
# 2           N  10/01/1984            08N             13.0               15A
# 3           N  10/01/1984            08N             13.0               15A
# 4           N  10/01/1984            08N             13.0               15A
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 0              15A             24.0            64.0               NaN
# 1              15A             24.0            64.0               NaN
# 2              15A             24.0            64.0               NaN
# 3              15A             24.0            64.0               NaN
# 4              15A             24.0            64.0               NaN
#
#    dist_1_abbrv confidential_ind  birth_year vtd_abbrv
# 0          17.0                N        1935       08N
# 1          17.0                N        1935       08N
# 2          17.0                N        1935       08N
# 3          17.0                N        1935       08N
# 4          17.0                N        1935       08N

# %%
## Create a new column specifying the election category based on the
  ## election description col
nc_voters.insert(loc=4, column='election_cat', 
                 value=nc_voters['election_desc'].str.split(n=1,
                                                            expand=True)[1])
# If the category was general or primary, leave as is, otherwise 'other'
nc_voters['election_cat'] = np.where(nc_voters['election_cat'].isin(
                                                    ['GENERAL', 'PRIMARY']),
                                     nc_voters['election_cat'], 'other')

# %%
## Recast election_lbl as datetime and create a new col for just the year
nc_voters['election_lbl'] = pd.to_datetime(nc_voters['election_lbl'])
nc_voters.insert(loc=4, column='election_yr',
                 value=nc_voters['election_lbl'].dt.year)

# %%
## Create a new binary variable indicating if it was a major election
nc_voters.insert(loc=6, column='major_elec',
                 value=np.where(((nc_voters['election_yr']%2 == 0) & 
                                 (nc_voters['election_cat'].isin(
                                     ['GENERAL', 'PRIMARY']))),
                                1,0))

# Exclude 2020 primary runoff from major elections
nc_voters.loc[nc_voters['election_desc']=='06/23/2020 PRIMARY',
              ['major_elec']]=0

# %%
## Group original vote methods into more general categories in a new variable
# Map the original categoriess to new ones
vote_method_map = {'ABSENTEE ONESTOP': 'Early',
                   'IN-PERSON': 'Election Day',
                   'ABSENTEE BY MAIL': 'Early',
                   'ABSENTEE CURBSIDE': 'Early',
                   'TRANSFER': 'Other',
                   'PROVISIONAL': 'Other',
                   'CURBSIDE': 'Election Day'}

# Apply the map to create new vote_method_cat column
nc_voters.insert(loc=8, column='vote_method_cat',
                 value=nc_voters['voting_method'].map(vote_method_map))

# %%
## Null values in the election_desc col indicate individuals that are 
  ## registered to vote, but have not voted in a recent major election.
    ## Thus, election_cat, major_elec, and presid_elec 
    ## are irrelevant for these records
# Fill irrelevant fields with null values
nc_voters.loc[nc_voters['election_desc'].isna(),
              ['election_cat', 'major_elec']] = np.nan

# Fill with NaN with 'None' in election_desc col to preserve info for
  # registered voters without a voting history when merging df's based on 
    # ncid and election_desc below
nc_voters['election_desc'].fillna('None', inplace=True)

# Inspect updated dataframe
nc_voters.head()

# %%
nc_voters.to_csv('Data/NC_voters.zip', index=False)

# %%
## Check number of unique individuals represented by the data
nc_voters['ncid'].nunique()
# Out:
# 7415538

# %%
## Store index of non-major and non-null election types
other_elec_idx = nc_voters.loc[nc_voters['election_cat']=='other'].index

## Create a df containing only major and null elections
major_elec_df = nc_voters.drop(index=other_elec_idx)

# Check number of unique individuals that voted in a recent major election, 
  # plus those with no voting history
print(major_elec_df['ncid'].nunique())

# 7588 registered voters voted in a non-major election,
  # but no major elections
nc_voters['ncid'].nunique() - major_elec_df['ncid'].nunique()
# Out:
# 7407950
# 7588

# %% [markdown]
# ## Merge DataFrames - Focus on Recent Major Elections

# %%
# nc_voters = pd.read_csv('Data/NC_voters.zip',
#                         dtype={'precinct_abbrv': str, 
#                               'super_court_abbrv': str, 
#                               'judic_dist_abbrv': str,
#                               'school_dist_abbrv': str,
#                               'vtd_abbrv': str
#                              })

# %%
## Get list of unique ncids
nc_ncid_list = list(nc_voters['ncid'].unique())

## Add 'None' to the list to capture individuals that have not voted in any 
  ## recent major election when merging dataframes on ncid and election_desc
elec_desc_list = ['11/03/2020 GENERAL',
                  '11/06/2018 GENERAL',
                  '11/08/2016 GENERAL',
                  '11/04/2014 GENERAL',
                  '11/06/2012 GENERAL',
                  'None']

# %%
## Create multiindex that lists every election for every registered voter
mltidx = pd.MultiIndex.from_tuples(
    [(ncid, elec) for ncid in nc_ncid_list for elec in elec_desc_list],
    names=['ncid', 'election_desc'])

## Use multiindex to create new dataframe
elecs_by_voter = pd.DataFrame(index=mltidx)

# %%
## Check length and inspect structure of new dataframe
print(len(elecs_by_voter))
elecs_by_voter.head(15)
# Out:
# 44493228
# Empty DataFrame
# Columns: []
# Index: [(AA56273, 11/03/2020 GENERAL), (AA56273, 11/06/2018 GENERAL), (AA56273, 11/08/2016 GENERAL), (AA56273, 11/04/2014 GENERAL), (AA56273, 11/06/2012 GENERAL), (AA56273, None), (AA201627, 11/03/2020 GENERAL), (AA201627, 11/06/2018 GENERAL), (AA201627, 11/08/2016 GENERAL), (AA201627, 11/04/2014 GENERAL), (AA201627, 11/06/2012 GENERAL), (AA201627, None), (AA216996, 11/03/2020 GENERAL), (AA216996, 11/06/2018 GENERAL), (AA216996, 11/08/2016 GENERAL)]

# %%
## Merge voter histories using the created multiindex as the keys to join
  ## each ncid onto every election and 'None'
voter_elecs = elecs_by_voter.merge(nc_vhis, how='left',
                                   on=['ncid', 'election_desc'])
# Inspect new df
print(len(voter_elecs))
display(voter_elecs.head())
voter_elecs.tail()
# Out:
# 44493612
#       ncid       election_desc  county_id  voter_reg_num election_lbl  \
# 0  AA56273  11/03/2020 GENERAL        1.0      9005990.0   11/03/2020
# 1  AA56273  11/06/2018 GENERAL        1.0      9005990.0   11/06/2018
# 2  AA56273  11/08/2016 GENERAL        1.0      9005990.0   11/08/2016
# 3  AA56273  11/04/2014 GENERAL        1.0      9005990.0   11/04/2014
# 4  AA56273  11/06/2012 GENERAL        1.0      9005990.0   11/06/2012
#
#       voting_method voted_party_cd pct_label  voted_county_id vtd_label
# 0  ABSENTEE BY MAIL            UNA       08N              1.0       08N
# 1         IN-PERSON            UNA       08N              1.0       08N
# 2         IN-PERSON            UNA       08N              1.0       08N
# 3         IN-PERSON            UNA       08N              1.0       08N
# 4         IN-PERSON            UNA       08N              1.0       08N
#              ncid       election_desc  county_id  voter_reg_num election_lbl  \
# 44493607  ES27200  11/06/2018 GENERAL        NaN            NaN          NaN
# 44493608  ES27200  11/08/2016 GENERAL        NaN            NaN          NaN
# 44493609  ES27200  11/04/2014 GENERAL        NaN            NaN          NaN
# 44493610  ES27200  11/06/2012 GENERAL        NaN            NaN          NaN
# 44493611  ES27200                None        NaN            NaN          NaN
#
#          voting_method voted_party_cd pct_label  voted_county_id vtd_label
# 44493607           NaN            NaN       NaN              NaN       NaN
# 44493608           NaN            NaN       NaN              NaN       NaN
# 44493609           NaN            NaN       NaN              NaN       NaN
# 44493610           NaN            NaN       NaN              NaN       NaN
# 44493611           NaN            NaN       NaN              NaN       NaN

# %%
## Check for duplicate rows
# voter_elecs.duplicated().sum()
# Out:
# 0

# %%
# voter_elecs.to_csv('Data/NC_full_voter_elecs.zip', index=False)

# %%
nc_vreg.head()
# Out:
#   voter_status_desc voter_status_reason_desc   last_name first_name  \
# 0            ACTIVE                 VERIFIED       AABEL       RUTH
# 1            ACTIVE                 VERIFIED      AARDEN       JONI
# 2            ACTIVE     VERIFICATION PENDING  AARMSTRONG    TIMOTHY
# 3            ACTIVE                 VERIFIED       AARON  CHRISTINA
# 4            ACTIVE                 VERIFIED       AARON    CLAUDIA
#
#   middle_name                   res_street_address res_city_desc state_cd  \
# 0      EVELYN  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC
# 1      AUTUMN                     117 W CLAY ST           MEBANE       NC
# 2       DUANE               3670  COVINGTON TRL           MEBANE       NC
# 3    CASTAGNA                    421  WHITT AVE       BURLINGTON       NC
# 4      HAYDEN                    1013  EDITH ST       BURLINGTON       NC
#
#    zip_code race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0   27253.0         W          NL      UNA           F         85          NY
# 1   27302.0         W          UN      UNA           F         42          DC
# 2   27302.0         W          UN      REP           M         54          AL
# 3   27215.0         W          UN      UNA           F         44          NC
# 4   27215.0         W          NL      UNA           F         75          VA
#
#   drivers_lic  registr_dt precinct_abbrv   precinct_desc  cong_dist_abbrv  \
# 0           N  10/01/1984            08N    NORTH NEWLIN             13.0
# 1           Y  02/23/2018            10N  NORTH MELVILLE             13.0
# 2           N  10/31/2020            103      MELVILLE 3             13.0
# 3           Y  03/26/1996            03S     SOUTH BOONE             13.0
# 4           Y  08/15/1989            124    BURLINGTON 4             13.0
#
#   super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 0               15A              15A             24.0            64.0
# 1               15A              15A             24.0            63.0
# 2               15A              15A             24.0            63.0
# 3               15A              15A             24.0            64.0
# 4               15A              15A             24.0            63.0
#
#   school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 0               NaN              NaN          17.0  17TH PROSECUTORIAL
# 1               NaN              NaN          17.0  17TH PROSECUTORIAL
# 2               NaN              NaN          17.0  17TH PROSECUTORIAL
# 3               NaN              NaN          17.0  17TH PROSECUTORIAL
# 4               NaN              NaN          17.0  17TH PROSECUTORIAL
#
#   confidential_ind  birth_year      ncid vtd_abbrv vtd_desc
# 0                N        1935   AA56273       08N      08N
# 1                N        1978  AA201627       10N      10N
# 2                N        1966  AA216996       103      103
# 3                N        1976   AA98377       03S      03S
# 4                N        1945   AA69747       124      124

# %%
nc_vreg.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8309352 entries, 0 to 8309351
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   voter_status_desc         8309352 non-null  object
#  1   voter_status_reason_desc  8309351 non-null  object
#  2   last_name                 8309163 non-null  object
#  3   first_name                8309199 non-null  object
#  4   middle_name               7712276 non-null  object
#  5   res_street_address        8309352 non-null  object
#  6   res_city_desc             7553949 non-null  object
#  7   state_cd                  7554189 non-null  object
#  8   zip_code                  7553848 non-null  float64
#  9   race_code                 8309352 non-null  object
#  10  ethnic_code               8309352 non-null  object
#  11  party_cd                  8309352 non-null  object
#  12  gender_code               8309352 non-null  object
#  13  birth_age                 8309352 non-null  int64
#  14  birth_state               6688979 non-null  object
#  15  drivers_lic               8309352 non-null  object
#  16  registr_dt                8309352 non-null  object
#  17  precinct_abbrv            7414614 non-null  object
#  18  precinct_desc             7414614 non-null  object
#  19  cong_dist_abbrv           7414614 non-null  float64
#  20  super_court_abbrv         7414614 non-null  object
#  21  judic_dist_abbrv          7414614 non-null  object
#  22  nc_senate_abbrv           7414614 non-null  float64
#  23  nc_house_abbrv            7414614 non-null  float64
#  24  school_dist_abbrv         5857959 non-null  object
#  25  school_dist_desc          5857959 non-null  object
#  26  dist_1_abbrv              7414614 non-null  float64
#  27  dist_1_desc               7414614 non-null  object
#  28  confidential_ind          8309352 non-null  object
#  29  birth_year                8309352 non-null  int64
#  30  ncid                      8309352 non-null  object
#  31  vtd_abbrv                 7414614 non-null  object
#  32  vtd_desc                  7414614 non-null  object
# dtypes: float64(5), int64(2), object(26)
# memory usage: 2.0+ GB

# %%
# voter_elecs = pd.read_csv('Data/NC_full_voter_elecs.zip')
# voter_elecs.head()
# Out:
#       ncid       election_desc  county_id  voter_reg_num election_lbl  \
# 0  AA56273  11/03/2020 GENERAL        1.0      9005990.0   11/03/2020
# 1  AA56273  11/04/2014 GENERAL        1.0      9005990.0   11/04/2014
# 2  AA56273  11/06/2012 GENERAL        1.0      9005990.0   11/06/2012
# 3  AA56273  11/08/2016 GENERAL        1.0      9005990.0   11/08/2016
# 4  AA56273  03/15/2016 PRIMARY        1.0      9005990.0   03/15/2016
#
#       voting_method voted_party_cd pct_label  voted_county_id vtd_label
# 0  ABSENTEE BY MAIL            UNA       08N              1.0       08N
# 1         IN-PERSON            UNA       08N              1.0       08N
# 2         IN-PERSON            UNA       08N              1.0       08N
# 3         IN-PERSON            UNA       08N              1.0       08N
# 4         IN-PERSON            DEM       08N              1.0       08N

# %%
## Merge voter registration information onto the new df based on ncid
voter_elecs = voter_elecs.merge(nc_vreg, how='left', on='ncid')
# Inspect resulting df
voter_elecs.head()
# Out:
#       ncid       election_desc  county_id  voter_reg_num election_lbl  \
# 0  AA56273  11/03/2020 GENERAL        1.0      9005990.0   11/03/2020
# 1  AA56273  11/06/2018 GENERAL        1.0      9005990.0   11/06/2018
# 2  AA56273  11/08/2016 GENERAL        1.0      9005990.0   11/08/2016
# 3  AA56273  11/04/2014 GENERAL        1.0      9005990.0   11/04/2014
# 4  AA56273  11/06/2012 GENERAL        1.0      9005990.0   11/06/2012
#
#       voting_method voted_party_cd pct_label  voted_county_id vtd_label  \
# 0  ABSENTEE BY MAIL            UNA       08N              1.0       08N
# 1         IN-PERSON            UNA       08N              1.0       08N
# 2         IN-PERSON            UNA       08N              1.0       08N
# 3         IN-PERSON            UNA       08N              1.0       08N
# 4         IN-PERSON            UNA       08N              1.0       08N
#
#   voter_status_desc voter_status_reason_desc last_name first_name middle_name  \
# 0            ACTIVE                 VERIFIED     AABEL       RUTH      EVELYN
# 1            ACTIVE                 VERIFIED     AABEL       RUTH      EVELYN
# 2            ACTIVE                 VERIFIED     AABEL       RUTH      EVELYN
# 3            ACTIVE                 VERIFIED     AABEL       RUTH      EVELYN
# 4            ACTIVE                 VERIFIED     AABEL       RUTH      EVELYN
#
#                     res_street_address res_city_desc state_cd  zip_code  \
# 0  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC   27253.0
# 1  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC   27253.0
# 2  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC   27253.0
# 3  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC   27253.0
# 4  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC   27253.0
#
#   race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 0         W          NL      UNA           F         85          NY
# 1         W          NL      UNA           F         85          NY
# 2         W          NL      UNA           F         85          NY
# 3         W          NL      UNA           F         85          NY
# 4         W          NL      UNA           F         85          NY
#
#   drivers_lic  registr_dt precinct_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           N  10/01/1984            08N             13.0               15A
# 1           N  10/01/1984            08N             13.0               15A
# 2           N  10/01/1984            08N             13.0               15A
# 3           N  10/01/1984            08N             13.0               15A
# 4           N  10/01/1984            08N             13.0               15A
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv school_dist_abbrv  \
# 0              15A             24.0            64.0               NaN
# 1              15A             24.0            64.0               NaN
# 2              15A             24.0            64.0               NaN
# 3              15A             24.0            64.0               NaN
# 4              15A             24.0            64.0               NaN
#
#    dist_1_abbrv confidential_ind  birth_year vtd_abbrv
# 0          17.0                N        1935       08N
# 1          17.0                N        1935       08N
# 2          17.0                N        1935       08N
# 3          17.0                N        1935       08N
# 4          17.0                N        1935       08N

# %%
voter_elecs.to_csv('Data/NC_full_voter_elecs.zip', index=False)

# %%
voter_elecs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44493612 entries, 0 to 44493611
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ncid                      object
#  1   election_desc             object
#  2   county_id                 float64
#  3   voter_reg_num             float64
#  4   election_lbl              object
#  5   voting_method             object
#  6   voted_party_cd            object
#  7   pct_label                 object
#  8   voted_county_id           float64
#  9   vtd_label                 object
#  10  voter_status_desc         object
#  11  voter_status_reason_desc  object
#  12  last_name                 object
#  13  first_name                object
#  14  middle_name               object
#  15  res_street_address        object
#  16  res_city_desc             object
#  17  state_cd                  object
#  18  zip_code                  float64
#  19  race_code                 object
#  20  ethnic_code               object
#  21  party_cd                  object
#  22  gender_code               object
#  23  birth_age                 int64
#  24  birth_state               object
#  25  drivers_lic               object
#  26  registr_dt                object
#  27  precinct_abbrv            object
#  28  cong_dist_abbrv           float64
#  29  super_court_abbrv         object
#  30  judic_dist_abbrv          object
#  31  nc_senate_abbrv           float64
#  32  nc_house_abbrv            float64
#  33  school_dist_abbrv         object
#  34  dist_1_abbrv              float64
#  35  confidential_ind          object
#  36  birth_year                int64
#  37  vtd_abbrv                 object
# dtypes: float64(8), int64(2), object(28)
# memory usage: 12.9+ GB
