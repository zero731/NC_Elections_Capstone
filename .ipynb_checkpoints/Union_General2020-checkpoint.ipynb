# %% [markdown]
# # Predicting Voting Method in Union County NC in the 2020 General Election

# %% [markdown]
# <font size=3rem>
#
# - **[Introduction](#Introduction)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[INTERPRET](#INTERPRET)**<br>
# - **[Conclusions/Recommendations](#Conclusions/Recommendations)<br>**
# </font>

# %% [markdown]
# # Introduction

# %% [markdown]
# # OBTAIN

# %%
## Import Numpy and set random seed for notebook
import numpy as np
np.random.seed(319)

# %%
## Import functions made specifically for this project
from capstone_functions import *

# %%
## Import remaining necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt
from tzlocal import get_localzone

# %%
## Set options for displaying Pandas DataFrames
pd.options.display.max_columns = 50
pd.options.display.max_rows = 100

# %%
## Import and preview dataset
elec_df = pd.read_csv('Data/UC_gen_2020.zip')
elec_df.head()
# Out:
#        ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 0  EF230133            0           46.0  ABSENTEE ONESTOP    Early
# 1  EF231096            0           46.0  ABSENTEE ONESTOP    Early
# 2  AL261840            1           26.0               NaN  No Vote
# 3  AL178177            0           62.0  ABSENTEE ONESTOP    Early
# 4  AL193958            0           62.0  ABSENTEE ONESTOP    Early
#
#    vote_early  vote_by_mail  vote_curbside Pri_2020 party_cd gender_code  \
# 0         1.0           0.0            0.0  No Vote      UNA           M
# 1         1.0           0.0            0.0  No Vote      DEM           F
# 2         0.0           0.0            0.0  No Vote      UNA           F
# 3         1.0           0.0            0.0  No Vote      UNA           M
# 4         1.0           0.0            0.0  No Vote      REP           F
#
#    birth_year  registr_dt race_code ethnic_code  zip_code  \
# 0        1974  2019-04-25         W          NL   28173.0
# 1        1974  2019-06-24         A          NL   28173.0
# 2        1994  2013-11-04         W          NL   28079.0
# 3        1958  2014-09-17         W          UN   28079.0
# 4        1958  2013-07-24         W          NL   28079.0
#
#           res_street_address res_city_desc birth_state drivers_lic  \
# 0   4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 1   4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 2  1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 3  1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 4  1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
#
#   precinct_abbrv vtd_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0           020A      020A              9.0               20B
# 1           020A      020A              9.0               20B
# 2           029A      029A              9.0               20B
# 3           029A      029A              9.0               20B
# 4           029A      029A              9.0               20B
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv
# 0              20C             35.0            68.0                2.0
# 1              20C             35.0            68.0                2.0
# 2              20C             35.0            68.0                3.0
# 3              20C             35.0            68.0                3.0
# 4              20C             35.0            68.0                3.0

# %% [markdown]
# # SCRUB

# %%
elec_df.duplicated(subset=['ncid']).sum()
# Out:
# 0

# %%
## Check df metadata
elec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168463 entries, 0 to 168462
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ncid                168463 non-null  object
#  1   no_vote_his         168463 non-null  int64
#  2   birth_age_adj       168463 non-null  float64
#  3   voting_method       131414 non-null  object
#  4   Gen_2020            168463 non-null  object
#  5   vote_early          168463 non-null  float64
#  6   vote_by_mail        168463 non-null  float64
#  7   vote_curbside       168463 non-null  float64
#  8   Pri_2020            168463 non-null  object
#  9   party_cd            168463 non-null  object
#  10  gender_code         168463 non-null  object
#  11  birth_year          168463 non-null  int64
#  12  registr_dt          168463 non-null  object
#  13  race_code           168463 non-null  object
#  14  ethnic_code         168463 non-null  object
#  15  zip_code            168460 non-null  float64
#  16  res_street_address  168463 non-null  object
#  17  res_city_desc       168460 non-null  object
#  18  birth_state         127622 non-null  object
#  19  drivers_lic         168463 non-null  object
#  20  precinct_abbrv      168463 non-null  object
#  21  vtd_abbrv           168463 non-null  object
#  22  cong_dist_abbrv     168463 non-null  float64
#  23  super_court_abbrv   168463 non-null  object
#  24  judic_dist_abbrv    168463 non-null  object
#  25  nc_senate_abbrv     168463 non-null  float64
#  26  nc_house_abbrv      168463 non-null  float64
#  27  school_dist_abbrv   168463 non-null  float64
# dtypes: float64(9), int64(2), object(17)
# memory usage: 36.0+ MB

# %% [markdown]
# > Columns with missing values:
# * `voting_method`: missing values are all cases where the individual did not cast a vote in this election
# * `zip_code`: investigate filling in the 3 missing values based on provided address
# * `res_city_desc`: same as for `zip_code`
# * `birth_state`: with so many values missing, probably want to make 'missing' its own category for this feature
#
# > Column dtypes:
# * `registr_dt`: recast as datetime
# * `zip_code`: likely more useful to treat as a categorical variable rather than as numeric
# * `drivers_lic`: change from Y or N to 1 or 0

# %%
## Fill null values in voting_method with 'No Vote'
elec_df['voting_method'].fillna(value='No Vote', inplace=True)

# %%
## Fill null values in birth_state with 'Missing'
elec_df['birth_state'].fillna(value='Missing', inplace=True)

# %%
## Check records with missing zip_code
elec_df.loc[elec_df['zip_code'].isna()]
# Out:
#            ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 54280   EF35182            0           62.0           No Vote  No Vote
# 69484  EF173508            0           26.0  ABSENTEE ONESTOP    Early
# 90712  EF203192            0           59.0  ABSENTEE ONESTOP    Early
#
#        vote_early  vote_by_mail  vote_curbside      Pri_2020 party_cd  \
# 54280         0.0           0.0            0.0       No Vote      REP
# 69484         1.0           0.0            0.0         Early      REP
# 90712         1.0           0.0            0.0  Election Day      UNA
#
#       gender_code  birth_year  registr_dt race_code ethnic_code  zip_code  \
# 54280           F        1958  1991-03-15         W          NL       NaN
# 69484           M        1994  2016-09-26         W          UN       NaN
# 90712           F        1961  2016-05-25         W          NL       NaN
#
#       res_street_address res_city_desc birth_state drivers_lic precinct_abbrv  \
# 54280       CONFIDENTIAL           NaN          NC           Y            030
# 69484       CONFIDENTIAL           NaN          NC           Y           017A
# 90712       CONFIDENTIAL           NaN          PA           Y           029C
#
#       vtd_abbrv  cong_dist_abbrv super_court_abbrv judic_dist_abbrv  \
# 54280       030              9.0               20B              20C
# 69484      017A              9.0               20B              20C
# 90712      029C              9.0               20B              20C
#
#        nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv
# 54280             35.0            69.0                1.0
# 69484             35.0            68.0                3.0
# 90712             35.0            68.0                5.0

# %%
## Examine common zip codes for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==1) & \
            (elec_df['precinct_abbrv']=='030')]['zip_code'].value_counts()
# Out:
# 28110.0    649
# Name: zip_code, dtype: int64

# %%
## Examine common cities for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==1) & \
            (elec_df['precinct_abbrv']=='030')]['res_city_desc'].value_counts()
# Out:
# MONROE    649
# Name: res_city_desc, dtype: int64

# %%
## Examine common zip codes for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==3) & \
            (elec_df['precinct_abbrv']=='017A')]['zip_code'].value_counts()
# Out:
# 28110.0    2904
# 28104.0     346
# 28173.0      97
# 28079.0      36
# Name: zip_code, dtype: int64

# %%
## Examine common cities for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==3) & \
            (elec_df['precinct_abbrv']=='017A')]['res_city_desc'].value_counts()
# Out:
# MONROE          2904
# MATTHEWS         346
# WAXHAW            97
# INDIAN TRAIL      36
# Name: res_city_desc, dtype: int64

# %%
## Examine common zip codes for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==5) & \
            (elec_df['precinct_abbrv']=='029C')]['zip_code'].value_counts()
# Out:
# 28079.0    1879
# 28104.0     871
# Name: zip_code, dtype: int64

# %%
## Examine common cities for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==5) & \
            (elec_df['precinct_abbrv']=='029C')]['res_city_desc'].value_counts()
# Out:
# INDIAN TRAIL    1879
# MATTHEWS         871
# Name: res_city_desc, dtype: int64

# %% [markdown]
# > These three records missing `zip_code` also correspond to the three records missing `res_city_desc`, most likely because the residential address is confidential for these individuals. These records can have the group mode imputed for the specific combination of school district and voting precinct as part of the pipeline for modeling.

# %%
## Change drivers_license to binary indicator
elec_df['drivers_lic'] = np.where(elec_df['drivers_lic']=='Y', 1, 0)

# %%
## Recast zip_code as category
elec_df['zip_code'] = elec_df['zip_code'].astype('category')

# %%
## Recast registr_dt as datetime variable
elec_df['registr_dt'] = pd.to_datetime(elec_df['registr_dt'])

# %%
## Recheck elec_df metadata
elec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168463 entries, 0 to 168462
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ncid                168463 non-null  object
#  1   no_vote_his         168463 non-null  int64
#  2   birth_age_adj       168463 non-null  float64
#  3   voting_method       168463 non-null  object
#  4   Gen_2020            168463 non-null  object
#  5   vote_early          168463 non-null  float64
#  6   vote_by_mail        168463 non-null  float64
#  7   vote_curbside       168463 non-null  float64
#  8   Pri_2020            168463 non-null  object
#  9   party_cd            168463 non-null  object
#  10  gender_code         168463 non-null  object
#  11  birth_year          168463 non-null  int64
#  12  registr_dt          168463 non-null  datetime64[ns]
#  13  race_code           168463 non-null  object
#  14  ethnic_code         168463 non-null  object
#  15  zip_code            168460 non-null  category
#  16  res_street_address  168463 non-null  object
#  17  res_city_desc       168460 non-null  object
#  18  birth_state         168463 non-null  object
#  19  drivers_lic         168463 non-null  int64
#  20  precinct_abbrv      168463 non-null  object
#  21  vtd_abbrv           168463 non-null  object
#  22  cong_dist_abbrv     168463 non-null  float64
#  23  super_court_abbrv   168463 non-null  object
#  24  judic_dist_abbrv    168463 non-null  object
#  25  nc_senate_abbrv     168463 non-null  float64
#  26  nc_house_abbrv      168463 non-null  float64
#  27  school_dist_abbrv   168463 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(8), int64(3), object(15)
# memory usage: 34.9+ MB

# %% [markdown]
# # EXPLORE

# %% [markdown]
# ## Categorical Variables

# %%
check_unique('voting_method', elec_df)
# Out:
#                    count      %
# ABSENTEE ONESTOP   88057  52.27
# No Vote            37049  21.99
# IN-PERSON          19809  11.76
# ABSENTEE BY MAIL   19657  11.67
# ABSENTEE CURBSIDE   2953   1.75
# PROVISIONAL          381   0.23
# TRANSFER             353   0.21
# CURBSIDE             204   0.12

# %%
check_unique('Gen_2020', elec_df)
# Out:
#                count      %
# Early         110667  65.69
# No Vote        37049  21.99
# Election Day   20013  11.88
# Other            734   0.44

# %% [markdown]
# > The 'Other' category is made up of only 734 individuals that voted with either a provisional or transfer ballot. Need to consider dropping this extremely rare category or somehow adding those records into one of the other categories.

# %%
check_unique('Pri_2020', elec_df)
# Out:
#                count      %
# No Vote       125191  74.31
# Election Day   25817  15.33
# Early          17138  10.17
# Other            317   0.19

# %% [markdown]
# > 'Other' category also extremely rare for `Pri_2020` as well. If this is used as a predictor, consider changing to a binary variable indicating simply whether or not the person voted in the Primary.

# %%
check_unique('party_cd', elec_df)
# Out:
#      count      %
# REP  69147  41.05
# UNA  57672  34.23
# DEM  40488  24.03
# LIB    991   0.59
# CST     93   0.06
# GRE     72   0.04

# %% [markdown]
# > LIB, CST, and GRE extremely rare within the county. Need to deal with this in some way, but grouping into a single 'Rare' category won't necessarily solve the issue since that would still represent barely more than 0.5% of voters in this election. It could make sense to combine these three parties with UNA (unaffiliated) to simply represent voters that do not align with one of the two major parties.

# %%
check_unique('gender_code', elec_df)
# Out:
#    count      %
# F  80750  47.93
# M  72716  43.16
# U  14997   8.90

# %%
check_unique('race_code', elec_df)
# Out:
#     count      %
# W  120058  71.27
# B   19246  11.42
# U   18744  11.13
# O    6136   3.64
# A    2940   1.75
# M     908   0.54
# I     425   0.25
# P       6   0.00

# %% [markdown]
# > The most infrequent categories (Other, Asian, Multiple, Native American, Pacific Islander/Native Hawaiian) each represent less than 5% of voters. To deal with these rare labels, it is probably best from a modeling standpoint to group them all under 'Other'.

# %%
check_unique('ethnic_code', elec_df)
# Out:
#      count      %
# NL  124346  73.81
# UN   37188  22.07
# HL    6929   4.11

# %% [markdown]
# > Voters that chose to identify themselves as Hispanic or Latino represent less than 5% of voters. Check below to see how disclosed racial and ethnic identities intersect.

# %%
## Investigate how race intersects with ethnic code
for code in elec_df['ethnic_code'].unique():
    print('*****{}*****'.format(code))
    display(elec_df.loc[elec_df['ethnic_code']==code]['race_code'].value_counts().to_frame())
    print()
# Out:
# *****NL*****
#    race_code
# W     103610
# B      15209
# O       2314
# A       2119
# U        385
# M        381
# I        327
# P          1
# *****UN*****
#    race_code
# U      16681
# W      14956
# B       3950
# A        811
# O        471
# M        229
# I         87
# P          3
# *****HL*****
#    race_code
# O       3351
# U       1678
# W       1492
# M        298
# B         87
# I         11
# A         10
# P          2

# %% [markdown]
# > Patterns of intersection between race and ethnicity are somewhat unclear. The majority of voters that chose not to disclose their race also chose not to disclose their ethnicity (16,681 out of 18,744). The majority of voters that identified themselves as Hispanic or Latino when registering listed their race as 'Other'(3,351 out of 6,929), with the next most frequent category being 'Undesignated' (1,678 out of 6,929), then 'White' (1,492 out of 6,929). As such, I am uncertain how useful this feature will be as a predictor, especially given that the 'HL' category is so rare.

# %%
check_unique('zip_code', elec_df)
# Out:
#          count      %
# 28173.0  47693  28.31
# 28110.0  34808  20.66
# 28079.0  28267  16.78
# 28104.0  25648  15.22
# 28112.0  18073  10.73
# 28103.0   7306   4.34
# 28174.0   5787   3.44
# 28227.0    397   0.24
# 28105.0    236   0.14
# 28133.0    155   0.09
# 28107.0     88   0.05
# NaN          3   0.00
# 28135.0      2   0.00

# %% [markdown]
# > Seven of the 12 zip codes are rare labels (each representing less than 5% of the voters). It may be best to use grouped cities as a predictor (see immediately below) rather than zip codes, especially since the two will be highly correlated.

# %%
check_unique('res_city_desc', elec_df)
# Out:
#               count      %
# MONROE        52881  31.39
# WAXHAW        47693  28.31
# INDIAN TRAIL  28267  16.78
# MATTHEWS      25884  15.36
# MARSHVILLE     7306   4.34
# WINGATE        5787   3.44
# CHARLOTTE       397   0.24
# PEACHLAND       155   0.09
# MIDLAND          88   0.05
# NaN               3   0.00
# POLKTON           2   0.00

# %% [markdown]
# > There are several rare labels, so if `res_city_desc` is to be used as a predictor, cities besides Monroe, Waxhaw, Indian Trail, and Matthews should probably be combined into an 'Other' category.

# %%
check_unique('birth_state', elec_df)
# Out:
#          count      %
# NC       46506  27.61
# Missing  40841  24.24
# NY       13239   7.86
# OC       10038   5.96
# SC        4762   2.83
# NJ        4510   2.68
# OH        4347   2.58
# PA        4347   2.58
# FL        3794   2.25
# CA        3355   1.99
# VA        3053   1.81
# MI        2440   1.45
# IL        2427   1.44
# GA        2343   1.39
# TX        1846   1.10
# MA        1793   1.06
# WV        1639   0.97
# MD        1622   0.96
# CT        1443   0.86
# IN        1288   0.76
# TN        1236   0.73
# AL         837   0.50
# KY         833   0.49
# WI         747   0.44
# MO         742   0.44
# LA         640   0.38
# DC         615   0.37
# MN         525   0.31
# CO         484   0.29
# PR         471   0.28
# IA         469   0.28
# WA         453   0.27
# MS         426   0.25
# AZ         422   0.25
# OK         357   0.21
# KS         352   0.21
# RI         316   0.19
# AR         270   0.16
# NH         260   0.15
# NE         251   0.15
# ME         247   0.15
# DE         236   0.14
# UT         217   0.13
# OR         215   0.13
# VT         208   0.12
# NM         150   0.09
# HI         149   0.09
# NV         125   0.07
# ID         113   0.07
# AK         106   0.06
# ND         102   0.06
# SD          97   0.06
# MT          95   0.06
# WY          40   0.02
# VI          15   0.01
# GU           8   0.00
# NO           1   0.00

# %%
elec_df.loc[elec_df['birth_state']=='OC']
# Out:
#             ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 0       EF230133            0           46.0  ABSENTEE ONESTOP    Early
# 1       EF231096            0           46.0  ABSENTEE ONESTOP    Early
# 15      EF122494            0           53.0  ABSENTEE ONESTOP    Early
# 16      EF105789            0           91.0  ABSENTEE BY MAIL    Early
# 17      EF191560            0           43.0  ABSENTEE ONESTOP    Early
# ...          ...          ...            ...               ...      ...
# 168416  EF100421            0           72.0           No Vote  No Vote
# 168420  EF226310            0           63.0  ABSENTEE BY MAIL    Early
# 168421  EF225995            0           34.0  ABSENTEE BY MAIL    Early
# 168446  EF221316            0           50.0  ABSENTEE ONESTOP    Early
# 168457  EF180541            0           63.0  ABSENTEE ONESTOP    Early
#
#         vote_early  vote_by_mail  vote_curbside Pri_2020 party_cd gender_code  \
# 0              1.0           0.0            0.0  No Vote      UNA           M
# 1              1.0           0.0            0.0  No Vote      DEM           F
# 15             1.0           0.0            0.0  No Vote      DEM           F
# 16             0.0           1.0            0.0  No Vote      REP           F
# 17             1.0           0.0            0.0  No Vote      UNA           F
# ...            ...           ...            ...      ...      ...         ...
# 168416         0.0           0.0            0.0  No Vote      REP           F
# 168420         0.0           1.0            0.0  No Vote      UNA           M
# 168421         0.0           1.0            0.0  No Vote      UNA           M
# 168446         1.0           0.0            0.0  No Vote      UNA           F
# 168457         1.0           0.0            0.0  No Vote      REP           F
#
#         birth_year registr_dt race_code ethnic_code zip_code  \
# 0             1974 2019-04-25         W          NL  28173.0
# 1             1974 2019-06-24         A          NL  28173.0
# 15            1967 2005-08-02         W          NL  28079.0
# 16            1929 2004-01-21         W          NL  28227.0
# 17            1977 2014-09-26         A          NL  28173.0
# ...            ...        ...       ...         ...      ...
# 168416        1948 2003-01-29         O          NL  28104.0
# 168420        1957 2018-12-27         A          NL  28104.0
# 168421        1986 2018-12-11         A          NL  28104.0
# 168446        1970 2018-08-03         B          NL  28173.0
# 168457        1957 2012-10-16         W          NL  28079.0
#
#                 res_street_address res_city_desc birth_state  drivers_lic  \
# 0         4009  MILLBRIDGE PKWY           WAXHAW          OC            1
# 1         4009  MILLBRIDGE PKWY           WAXHAW          OC            1
# 15         2000  RIDLEY PARK CT     INDIAN TRAIL          OC            1
# 16      10929  SYCAMORE CLUB DR        CHARLOTTE          OC            1
# 17           5506  VERRAZANO DR           WAXHAW          OC            1
# ...                            ...           ...         ...          ...
# 168416            108  UNION RD         MATTHEWS          OC            1
# 168420      7008  SHADOWROCK CT         MATTHEWS          OC            1
# 168421      7008  SHADOWROCK CT         MATTHEWS          OC            1
# 168446          212  ALNWICK LN           WAXHAW          OC            1
# 168457   2110  HUNTERS TRAIL DR     INDIAN TRAIL          OC            1
#
#        precinct_abbrv vtd_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0                020A      020A              9.0               20B
# 1                020A      020A              9.0               20B
# 15               029A      029A              9.0               20B
# 16                032       032              9.0               20B
# 17                019       019              9.0               20B
# ...               ...       ...              ...               ...
# 168416            032       032              9.0               20B
# 168420           017B      017B              9.0               20B
# 168421           017B      017B              9.0               20B
# 168446           028B       028              9.0               20B
# 168457           038A      038A              9.0               20B
#
#        judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv
# 0                   20C             35.0            68.0                2.0
# 1                   20C             35.0            68.0                2.0
# 15                  20C             35.0            68.0                3.0
# 16                  20C             36.0            69.0                4.0
# 17                  20C             35.0            68.0                6.0
# ...                 ...              ...             ...                ...
# 168416              20C             36.0            69.0                4.0
# 168420              20C             35.0            68.0                6.0
# 168421              20C             35.0            68.0                6.0
# 168446              20C             35.0            68.0                6.0
# 168457              20C             35.0            69.0                4.0
#
# [10038 rows x 28 columns]

# %%
elec_df.loc[elec_df['birth_state']=='NO'] # Hunter Scott Holshouser
# It seems like this may have somehow been a typo and he was likely born in 
# NC, but I can't confirm this, so change to "missing"
# Out:
#            ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 69497  EF171044            0           26.0  ABSENTEE ONESTOP    Early
#
#        vote_early  vote_by_mail  vote_curbside Pri_2020 party_cd gender_code  \
# 69497         1.0           0.0            0.0  No Vote      REP           M
#
#        birth_year registr_dt race_code ethnic_code zip_code  \
# 69497        1994 2010-05-18         W          NL  28079.0
#
#       res_street_address res_city_desc birth_state  drivers_lic  \
# 69497  517 W BRIEF RD     INDIAN TRAIL          NO            1
#
#       precinct_abbrv vtd_abbrv  cong_dist_abbrv super_court_abbrv  \
# 69497            032       032              9.0               20B
#
#       judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv
# 69497              20C             36.0            69.0                4.0

# %% [markdown]
# > The majority of `birth_state` labels are rare categories (less than 5% of voters). Some of the codes do not appear to be U.S. states or territories. These rare labels could be dealt with in a couple ways. They could all be grouped into an 'Other' category, or they could be grouped according to geographic region of the U.S. with an additional category for naturalized U.S. citizens.

# %%
check_unique('drivers_lic', elec_df)
# Out:
#     count      %
# 1  153024  90.84
# 0   15439   9.16

# %%
check_unique('precinct_abbrv', elec_df)
# Out:
#       count     %
# 019    6616  3.93
# 020A   6138  3.64
# 037A   5906  3.51
# 028A   5850  3.47
# 016    5688  3.38
# 028D   5316  3.16
# 029A   5289  3.14
# 017B   5103  3.03
# 020B   5101  3.03
# 030    5065  3.01
# 015    4823  2.86
# 041    4623  2.74
# 028B   4363  2.59
# 031    4106  2.44
# 038A   4105  2.44
# 040    4066  2.41
# 028C   4006  2.38
# 007    3695  2.19
# 034    3620  2.15
# 005    3484  2.07
# 032    3462  2.06
# 017A   3384  2.01
# 018    3231  1.92
# 008    3002  1.78
# 022    2879  1.71
# 013    2780  1.65
# 029C   2751  1.63
# 011    2731  1.62
# 038B   2687  1.60
# 021    2640  1.57
# 033    2628  1.56
# 039    2610  1.55
# 012    2503  1.49
# 024    2479  1.47
# 042    2272  1.35
# 023    2217  1.32
# 036    2136  1.27
# 025    2076  1.23
# 026    2064  1.23
# 035    2034  1.21
# 027    1929  1.15
# 006    1861  1.10
# 029B   1827  1.08
# 002    1796  1.07
# 037B   1642  0.97
# 009    1614  0.96
# 014    1513  0.90
# 004    1491  0.89
# 001    1424  0.85
# 010    1343  0.80
# 003    1341  0.80
# 043    1153  0.68

# %%
check_unique('vtd_abbrv', elec_df)
# Out:
#       count      %
# 028   19535  11.60
# 019    6616   3.93
# 020A   6138   3.64
# 037A   5906   3.51
# 016    5688   3.38
# 029A   5289   3.14
# 017B   5103   3.03
# 020B   5101   3.03
# 030    5065   3.01
# 015    4823   2.86
# 041    4623   2.74
# 031    4106   2.44
# 038A   4105   2.44
# 040    4066   2.41
# 007    3695   2.19
# 034    3620   2.15
# 005    3484   2.07
# 032    3462   2.06
# 017A   3384   2.01
# 018    3231   1.92
# 008    3002   1.78
# 022    2879   1.71
# 013    2780   1.65
# 029C   2751   1.63
# 011    2731   1.62
# 038B   2687   1.60
# 021    2640   1.57
# 033    2628   1.56
# 039    2610   1.55
# 012    2503   1.49
# 024    2479   1.47
# 042    2272   1.35
# 023    2217   1.32
# 036    2136   1.27
# 025    2076   1.23
# 026    2064   1.23
# 035    2034   1.21
# 027    1929   1.15
# 006    1861   1.10
# 029B   1827   1.08
# 002    1796   1.07
# 037B   1642   0.97
# 009    1614   0.96
# 014    1513   0.90
# 004    1491   0.89
# 001    1424   0.85
# 010    1343   0.80
# 003    1341   0.80
# 043    1153   0.68

# %%
check_unique('cong_dist_abbrv', elec_df)
# Out:
#       count      %
# 9.0  168463  100.0

# %%
check_unique('nc_senate_abbrv', elec_df)
# Out:
#        count      %
# 35.0  158822  94.28
# 36.0    9641   5.72

# %%
check_unique('nc_house_abbrv', elec_df)
# Out:
#       count      %
# 68.0  75811  45.00
# 69.0  58041  34.45
# 55.0  34611  20.55

# %%
check_unique('school_dist_abbrv', elec_df)
# Out:
#      count      %
# 6.0  36355  21.58
# 5.0  30382  18.03
# 2.0  29528  17.53
# 4.0  28600  16.98
# 3.0  26255  15.59
# 1.0  17343  10.29

# %% [markdown]
# ## Group Rare Categories

# %%
## Create new column that is a binary variable indicating whether the voter
  ## cast a vote in the 2020 election or not
elec_df['Gen_2020_binary'] = np.where(elec_df['Gen_2020']=='No Vote',
                                0, 1)

## Check distribution
check_unique('Gen_2020_binary', elec_df)
# Out:
#     count      %
# 1  131414  78.01
# 0   37049  21.99

# %%
## Create new column that is a binary variable indicating whether the voter
  ## cast a vote in the 2020 election or not
elec_df['Pri_2020_binary'] = np.where(elec_df['Pri_2020']=='No Vote',
                                0, 1)

## Check distribution
check_unique('Pri_2020_binary', elec_df)
# Out:
#     count      %
# 0  125191  74.31
# 1   43272  25.69

# %%
## Create new column grouping most infrequent party categories (<5% of voters)
  ## into same group as those who are unaffiliated
elec_df['party_grp'] = np.where(elec_df['party_cd'].isin(['REP', 'DEM']),
                                elec_df['party_cd'], 'Other')

## Check distribution
check_unique('party_grp', elec_df)
# Out:
#        count      %
# REP    69147  41.05
# Other  58828  34.92
# DEM    40488  24.03

# %%
## Create new column grouping most infrequent race categories (<5% of voters)
elec_df['race_grp'] = np.where(elec_df['race_code'].isin(['W', 'B', 'U']),
                               elec_df['race_code'], 'O')

## Check distribution
check_unique('race_grp', elec_df)
# Out:
#     count      %
# W  120058  71.27
# B   19246  11.42
# U   18744  11.13
# O   10415   6.18

# %%
## Create new column grouping most infrequent cities (<5% of voters)
elec_df['city_grp'] = np.where(elec_df['res_city_desc'].isin(['MONROE', 
                                                              'WAXHAW',
                                                              'INDIAN TRAIL',
                                                              'MATTHEWS']),
                                elec_df['res_city_desc'], 'Other')

## Check distribution
check_unique('city_grp', elec_df)
# Out:
#               count      %
# MONROE        52881  31.39
# WAXHAW        47693  28.31
# INDIAN TRAIL  28267  16.78
# MATTHEWS      25884  15.36
# Other         13738   8.15

# %%
## Create a function for grouping birth_state into U.S. Census regions, 
  ## also lumping territories and out of country into 'Other'
def get_birth_reg_census_other(state):
    
    if state in ['AS', 'GU', 'MP', 'PR', 'VI', 'OC']:
        return 'Other'
    
    # the rest of the categories are based on U.S. Census Bureau regions
    elif state in ['CT', 'ME', 'MA', 'NH', 'RI', 'VT',
                     'NJ', 'NY', 'PA']:
        return 'Northeast'
    
    elif state in ['DE', 'FL', 'GA', 'MD', 'NC', 'SC', 'VA', 
                     'DC', 'WV', 'AL', 'KY', 'MS', 'TN', 'AR',
                     'LA', 'OK', 'TX']:
        return 'South'
    
    elif state in ['IL', 'IN', 'MI', 'OH', 'WI',
                     'IA', 'KS', 'MN', 'MO', 'NE', 'ND', 'SD']:
        return 'Midwest'
    
    elif state in ['AZ', 'CO', 'ID', 'MT', 'NV', 'NM', 'UT',
                     'WY', 'AK', 'CA', 'HI', 'OR', 'WA']:
        return 'West'
    
    else:
        return 'Missing'

# %%
## Create a new column grouping birth_state into U.S. Census regions,
  ## this time lumping territories and out of country into 'Other'
elec_df['birth_reg_other'] = elec_df['birth_state'].apply(get_birth_reg_census_other)
check_unique('birth_reg_other', elec_df)
# Out:
#            count      %
# South      71015  42.15
# Missing    40842  24.24
# Northeast  26363  15.65
# Midwest    13787   8.18
# Other      10532   6.25
# West        5924   3.52

# %% [markdown]
# ## Numeric Variables

# %%
## Plot distribution of current age as of EOY 2020 
plt.figure(figsize=(10,7))
ax = sns.histplot(elec_df['birth_age_adj'], stat='density')
ax.set_title('Distribution of Age', fontsize=16, weight='bold')
ax.set_xlabel('Age', fontsize=14, weight='bold')
ax.set_ylabel('Count', fontsize=14, weight='bold')
ax.set_xlim(15,115);

# %% [markdown]
# ## Relationship to Target (Gen_2020 voting method)

# %%
count_by_method('Pri_2020', 'Gen_2020', elec_df);

# %%
count_by_method('Pri_2020_binary', 'Gen_2020', elec_df);

# %%
count_by_method('party_cd', 'Gen_2020', elec_df);

# %%
count_by_method('party_grp', 'Gen_2020', elec_df);

# %% [markdown]
# # MODEL

# %% [markdown]
# # INTERPRET

# %% [markdown]
# # Conclusions/Recommendations
