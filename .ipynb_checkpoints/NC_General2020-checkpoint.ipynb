# %% [markdown]
# # Predicting Voting Method in North Carolina in the 2020 General Election

# %% [markdown]
# <font size=3rem>
#
# - **[Introduction](#Introduction)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[INTERPRET](#INTERPRET)**<br>
# - **[Conclusions/Recommendations](#Conclusions/Recommendations)<br>**
# </font>

# %% [markdown]
# # Introduction

# %% [markdown]
# # OBTAIN

# %%
## Import Numpy and set random seed for notebook
import numpy as np
np.random.seed(319)

# %%
## Import functions made specifically for this project
from capstone_functions import *

# %%
## Import remaining necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt
from tzlocal import get_localzone

# %%
## Set options for displaying Pandas DataFrames
pd.options.display.max_columns = 50
pd.options.display.max_rows = 100

# %%
## Import and preview dataset
elec_df = pd.read_csv('Data/NC_gen_2020.zip',
                     dtype={'precinct_abbrv': str, 
                              'super_court_abbrv': str, 
                              'judic_dist_abbrv': str,
                              'school_dist_abbrv': str,
                              'vtd_abbrv': str
                             })
elec_df.drop(columns=['county_id'], inplace=True)

elec_df.head()
# Out:
#        ncid  no_vote_his  birth_age_adj     voting_method Gen_2020 party_cd  \
# 0   AA56273            0           85.0  ABSENTEE BY MAIL    Early      UNA
# 1  AA201627            0           42.0  ABSENTEE ONESTOP    Early      UNA
# 2  AA216996            0           54.0  ABSENTEE ONESTOP    Early      REP
# 3   AA98377            0           44.0  ABSENTEE ONESTOP    Early      UNA
# 4   AA69747            0           75.0  ABSENTEE ONESTOP    Early      UNA
#
#   gender_code  birth_year  registr_dt race_code ethnic_code  zip_code  \
# 0           F        1935  1984-10-01         W          NL   27253.0
# 1           F        1978  2018-02-23         W          UN   27302.0
# 2           M        1966  2020-10-31         W          UN   27302.0
# 3           F        1976  1996-03-26         W          UN   27215.0
# 4           F        1945  1989-08-15         W          NL   27215.0
#
#                     res_street_address res_city_desc state_cd birth_state  \
# 0  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC          NY
# 1                     117 W CLAY ST           MEBANE       NC          DC
# 2               3670  COVINGTON TRL           MEBANE       NC          AL
# 3                    421  WHITT AVE       BURLINGTON       NC          NC
# 4                    1013  EDITH ST       BURLINGTON       NC          VA
#
#   drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  cong_dist_abbrv  \
# 0           N              1.0            08N       08N             13.0
# 1           Y              1.0            10N       10N             13.0
# 2           N              1.0            103       103             13.0
# 3           Y              1.0            03S       03S             13.0
# 4           Y              1.0            124       124             13.0
#
#   super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 0               15A              15A             24.0            64.0
# 1               15A              15A             24.0            63.0
# 2               15A              15A             24.0            63.0
# 3               15A              15A             24.0            64.0
# 4               15A              15A             24.0            63.0
#
#   school_dist_abbrv
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
len(elec_df)
# Out:
# 7347946

# %%
## Load in voter registration data for NC
nc_vreg = pd.read_table('Data/ncvoter_Statewide.zip', encoding='ISO-8859-1',
                        usecols=['ncid', 'county_id'])
nc_vreg.head()
# Out:
#    county_id      ncid
# 0          1   AA56273
# 1          1  AA201627
# 2          1  AA216996
# 3          1   AA98377
# 4          1   AA69747

# %%
print(len(nc_vreg))
nc_vreg['ncid'].nunique()
# Out:
# 8309352
# 8309352

# %%
## Merge county_id from voter registration info onto elec_df based on ncid
elec_df = elec_df.merge(nc_vreg, how='left', on='ncid')
# Inspect resulting df
elec_df.head()
# Out:
#        ncid  no_vote_his  birth_age_adj     voting_method Gen_2020 party_cd  \
# 0   AA56273            0           85.0  ABSENTEE BY MAIL    Early      UNA
# 1  AA201627            0           42.0  ABSENTEE ONESTOP    Early      UNA
# 2  AA216996            0           54.0  ABSENTEE ONESTOP    Early      REP
# 3   AA98377            0           44.0  ABSENTEE ONESTOP    Early      UNA
# 4   AA69747            0           75.0  ABSENTEE ONESTOP    Early      UNA
#
#   gender_code  birth_year  registr_dt race_code ethnic_code  zip_code  \
# 0           F        1935  1984-10-01         W          NL   27253.0
# 1           F        1978  2018-02-23         W          UN   27302.0
# 2           M        1966  2020-10-31         W          UN   27302.0
# 3           F        1976  1996-03-26         W          UN   27215.0
# 4           F        1945  1989-08-15         W          NL   27215.0
#
#                     res_street_address res_city_desc state_cd birth_state  \
# 0  4430 E GREENSBORO-CHAPEL HILL RD           GRAHAM       NC          NY
# 1                     117 W CLAY ST           MEBANE       NC          DC
# 2               3670  COVINGTON TRL           MEBANE       NC          AL
# 3                    421  WHITT AVE       BURLINGTON       NC          NC
# 4                    1013  EDITH ST       BURLINGTON       NC          VA
#
#   drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  cong_dist_abbrv  \
# 0           N              1.0            08N       08N             13.0
# 1           Y              1.0            10N       10N             13.0
# 2           N              1.0            103       103             13.0
# 3           Y              1.0            03S       03S             13.0
# 4           Y              1.0            124       124             13.0
#
#   super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 0               15A              15A             24.0            64.0
# 1               15A              15A             24.0            63.0
# 2               15A              15A             24.0            63.0
# 3               15A              15A             24.0            64.0
# 4               15A              15A             24.0            63.0
#
#   school_dist_abbrv  county_id
# 0               NaN          1
# 1               NaN          1
# 2               NaN          1
# 3               NaN          1
# 4               NaN          1

# %% [markdown]
# # SCRUB

# %%
## Check df metadata
elec_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7347946 entries, 0 to 7347945
# Data columns (total 27 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ncid                7347946 non-null  object
#  1   no_vote_his         7347946 non-null  int64
#  2   birth_age_adj       7347946 non-null  float64
#  3   voting_method       5353091 non-null  object
#  4   Gen_2020            7347946 non-null  object
#  5   party_cd            7347946 non-null  object
#  6   gender_code         7347946 non-null  object
#  7   birth_year          7347946 non-null  int64
#  8   registr_dt          7347946 non-null  object
#  9   race_code           7347946 non-null  object
#  10  ethnic_code         7347946 non-null  object
#  11  zip_code            7347686 non-null  float64
#  12  res_street_address  7347946 non-null  object
#  13  res_city_desc       7347686 non-null  object
#  14  state_cd            7347686 non-null  object
#  15  birth_state         5933008 non-null  object
#  16  drivers_lic         7347946 non-null  object
#  17  voted_county_id     5353091 non-null  float64
#  18  precinct_abbrv      7346994 non-null  object
#  19  vtd_abbrv           7346994 non-null  object
#  20  cong_dist_abbrv     7346994 non-null  float64
#  21  super_court_abbrv   7346994 non-null  object
#  22  judic_dist_abbrv    7346994 non-null  object
#  23  nc_senate_abbrv     7346994 non-null  float64
#  24  nc_house_abbrv      7346994 non-null  float64
#  25  school_dist_abbrv   5805625 non-null  object
#  26  county_id           7347946 non-null  int64
# dtypes: float64(6), int64(3), object(18)
# memory usage: 1.5+ GB

# %% [markdown]
# > Columns with missing values:
# * `voting_method`: missing values are all cases where the individual did not cast a vote in this election
# * `zip_code`: missing where voter info is confidential
# * `res_street_address`: has no null values, but 260 values are "CONFIDENTIAL", corresponding to the 260 null values for `zip_code`, `res_city_desc`, and `state_cd`
# * `res_city_desc`: missing where voter info is confidential
# * `state_cd`: missing where voter info is confidential
# * `birth_state`: with so many values missing, probably want to make 'missing' its own category for this feature
# * `precinct_abbrv`:
# * `vtd_abbrv`:
# * `cong_dist_abbrv`:
# * `super_court_abbrv`:
# * `judic_dist_abbrv`:
# * `nc_senate_abbrv`:
# * `nc_house_abbrv`:
# * `school_dist_abbrv`:
#
# > Column dtypes:
# * `registr_dt`: recast as datetime
# * `zip_code`: likely more useful to treat as a categorical variable rather than as numeric
# * `drivers_lic`: change from Y or N to 1 or 0

# %%
## Fill null values in voting_method with 'No Vote'
elec_df['voting_method'].fillna(value='No Vote', inplace=True)

# %%
## Fill null values in birth_state with 'Missing'
elec_df['birth_state'].fillna(value='Missing', inplace=True)

# %%
## Change drivers_license to binary indicator
elec_df['drivers_lic'] = np.where(elec_df['drivers_lic']=='Y', 1, 0)

# %%
## Recast zip_code as category
elec_df['zip_code'] = elec_df['zip_code'].astype('category')

# %%
## Recast registr_dt as datetime variable
elec_df['registr_dt'] = pd.to_datetime(elec_df['registr_dt'])

# %%
## Recheck elec_df metadata
elec_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7347946 entries, 0 to 7347945
# Data columns (total 27 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ncid                7347946 non-null  object
#  1   no_vote_his         7347946 non-null  int64
#  2   birth_age_adj       7347946 non-null  float64
#  3   voting_method       7347946 non-null  object
#  4   Gen_2020            7347946 non-null  object
#  5   party_cd            7347946 non-null  object
#  6   gender_code         7347946 non-null  object
#  7   birth_year          7347946 non-null  int64
#  8   registr_dt          7347946 non-null  datetime64[ns]
#  9   race_code           7347946 non-null  object
#  10  ethnic_code         7347946 non-null  object
#  11  zip_code            7347686 non-null  category
#  12  res_street_address  7347946 non-null  object
#  13  res_city_desc       7347686 non-null  object
#  14  state_cd            7347686 non-null  object
#  15  birth_state         7347946 non-null  object
#  16  drivers_lic         7347946 non-null  int64
#  17  voted_county_id     5353091 non-null  float64
#  18  precinct_abbrv      7346994 non-null  object
#  19  vtd_abbrv           7346994 non-null  object
#  20  cong_dist_abbrv     7346994 non-null  float64
#  21  super_court_abbrv   7346994 non-null  object
#  22  judic_dist_abbrv    7346994 non-null  object
#  23  nc_senate_abbrv     7346994 non-null  float64
#  24  nc_house_abbrv      7346994 non-null  float64
#  25  school_dist_abbrv   5805625 non-null  object
#  26  county_id           7347946 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(5), int64(4), object(16)
# memory usage: 1.5+ GB

# %%
## Check number of null values for zip_code
elec_df['zip_code'].isna().sum()
# Out:
# 260

# %%
## Check the 260 records with missing zip_code
elec_df.loc[elec_df['zip_code'].isna()]
# Out:
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2020  \
# 8254      AA50616            0           55.0         IN-PERSON  Election Day
# 36754     AP84914            0           30.0  ABSENTEE ONESTOP         Early
# 56866    AA192589            0           30.0           No Vote       No Vote
# 95641    DE225925            0           33.0  ABSENTEE ONESTOP         Early
# 139484    AC14362            0           71.0           No Vote       No Vote
# ...           ...          ...            ...               ...           ...
# 7161011  EH665149            0           51.0           No Vote       No Vote
# 7273387  EH533456            0           65.0           No Vote       No Vote
# 7296920  EP108185            1           23.0           No Vote       No Vote
# 7309333   EB48098            0           43.0  ABSENTEE ONESTOP         Early
# 7345144   ES24559            0           28.0           No Vote       No Vote
#
#         party_cd gender_code  birth_year registr_dt race_code ethnic_code  \
# 8254         UNA           F        1965 1984-02-15         W          NL
# 36754        REP           F        1990 2020-08-10         W          NL
# 56866        UNA           M        1990 2016-10-10         B          NL
# 95641        DEM           F        1987 2019-10-03         W          NL
# 139484       UNA           M        1949 2010-09-09         W          UN
# ...          ...         ...         ...        ...       ...         ...
# 7161011      UNA           F        1969 2014-10-10         W          NL
# 7273387      UNA           U        1955 2020-09-28         U          UN
# 7296920      UNA           U        1997 2020-09-28         U          UN
# 7309333      UNA           F        1977 2016-02-22         W          NL
# 7345144      REP           M        1992 2011-12-12         W          NL
#
#         zip_code res_street_address res_city_desc state_cd birth_state  \
# 8254         NaN       CONFIDENTIAL           NaN      NaN          CA
# 36754        NaN       CONFIDENTIAL           NaN      NaN          NC
# 56866        NaN       CONFIDENTIAL           NaN      NaN          CT
# 95641        NaN       CONFIDENTIAL           NaN      NaN          NC
# 139484       NaN       CONFIDENTIAL           NaN      NaN          NJ
# ...          ...                ...           ...      ...         ...
# 7161011      NaN       CONFIDENTIAL           NaN      NaN          IA
# 7273387      NaN       CONFIDENTIAL           NaN      NaN     Missing
# 7296920      NaN       CONFIDENTIAL           NaN      NaN     Missing
# 7309333      NaN       CONFIDENTIAL           NaN      NaN          NC
# 7345144      NaN       CONFIDENTIAL           NaN      NaN          NC
#
#          drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 8254               1              1.0            103       103
# 36754              1              1.0            06E       06E
# 56866              1              NaN             13        13
# 95641              1              1.0             11        11
# 139484             1              NaN            06A        06
# ...              ...              ...            ...       ...
# 7161011            1              NaN             21        21
# 7273387            1              NaN           PRWM      PRWM
# 7296920            0              NaN           PRWM      PRWM
# 7309333            1             99.0           BNVL      BNVL
# 7345144            1              NaN         08 CRA    08-CRA
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 8254                13.0               15A              15A             24.0
# 36754               13.0               15A              15A             24.0
# 56866               13.0               15A              15A             24.0
# 95641               13.0               15A              15A             24.0
# 139484               5.0                23               23             45.0
# ...                  ...               ...              ...              ...
# 7161011              1.0               08B               08              7.0
# 7273387              1.0               07C               07              4.0
# 7296920              1.0               07C               07              4.0
# 7309333             10.0                23               23             34.0
# 7345144             11.0                24               24             47.0
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 8254               63.0               NaN          1
# 36754              63.0               NaN          1
# 56866              63.0               NaN          1
# 95641              63.0               NaN          1
# 139484             90.0               NaN          3
# ...                 ...               ...        ...
# 7161011            21.0                 6         96
# 7273387            24.0               SC3         98
# 7296920            24.0               SC3         98
# 7309333            73.0               NaN         99
# 7345144           118.0               NaN        100
#
# [260 rows x 27 columns]

# %%
## Examine common cities for this combination of school distr and precinct
elec_df.loc[(elec_df['school_dist_abbrv']==3) & \
            (elec_df['precinct_abbrv']=='017A')]['res_city_desc'].value_counts()
# Out:
# Series([], Name: res_city_desc, dtype: int64)

# %% [markdown]
# > The records missing `zip_code` also correspond to the records missing `res_city_desc` and `state_cd`, most likely because the residential address is confidential for these individuals. These records can have the group mode imputed for the specific combination of school district and voting precinct as part of the pipeline for modeling.

# %%
## Check number of null values for precinct_abbrv
elec_df['precinct_abbrv'].isna().sum()
# Out:
# 952

# %%
## Check the 952 records with missing precinct_abbrv
missing_precinct_info = elec_df.loc[elec_df['precinct_abbrv'].isna()]
missing_precinct_info
# Out:
#              ncid  no_vote_his  birth_age_adj voting_method Gen_2020 party_cd  \
# 34725    DE278765            0           58.0       No Vote  No Vote      DEM
# 180385    AF25244            0           32.0       No Vote  No Vote      UNA
# 187558    AF25346            1           35.0       No Vote  No Vote      UNA
# 190788     AF6115            0           44.0   PROVISIONAL    Other      REP
# 228017     AH4335            1           58.0       No Vote  No Vote      DEM
# ...           ...          ...            ...           ...      ...      ...
# 7097499   EL87130            0           24.0       No Vote  No Vote      UNA
# 7101150   EL89708            0           24.0       No Vote  No Vote      DEM
# 7261713   EP45149            1           44.0       No Vote  No Vote      UNA
# 7322732   ER29612            0           42.0       No Vote  No Vote      DEM
# 7333269   ER19437            1           45.0       No Vote  No Vote      REP
#
#         gender_code  birth_year registr_dt race_code ethnic_code zip_code  \
# 34725             U        1962 2016-09-23         U          UN  27302.0
# 180385            F        1988 2012-10-12         U          UN  28604.0
# 187558            U        1985 2012-11-06         U          UN  28604.0
# 190788            F        1976 1994-12-14         W          NL  28646.0
# 228017            F        1962 1984-09-29         B          NL  27924.0
# ...             ...         ...        ...       ...         ...      ...
# 7097499           M        1996 2016-11-03         W          UN  28604.0
# 7101150           F        1996 2016-03-15         W          UN  28604.0
# 7261713           M        1976 1996-06-18         W          NL  27893.0
# 7322732           F        1978 2002-08-14         B          NL  27011.0
# 7333269           M        1975 1994-05-03         W          NL  27055.0
#
#               res_street_address res_city_desc state_cd birth_state  \
# 34725    1026  MEBANE OAKS RD           MEBANE       NC     Missing
# 180385     5200  NC HWY 105  S      BANNER ELK       NC     Missing
# 187558     9189  NC HWY 105  S      BANNER ELK       NC     Missing
# 190788          0  COFFEY RD          LINVILLE       NC          CA
# 228017            0  UNKNOWN          COLERAIN       NC          NC
# ...                          ...           ...      ...         ...
# 7097499    202  SNOW CLOUD DR       BANNER ELK       NC          FL
# 7101150    202  SNOW CLOUD DR       BANNER ELK       NC          FL
# 7261713        608  WARREN ST           WILSON       NC          NC
# 7322732        1521  WOLFE RD        BOONVILLE       NC          NC
# 7333269           0  UNKNOWN       YADKINVILLE       NC          NC
#
#          drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 34725              1              NaN            NaN       NaN
# 180385             1              NaN            NaN       NaN
# 187558             1              NaN            NaN       NaN
# 190788             0              6.0            NaN       NaN
# 228017             0              NaN            NaN       NaN
# ...              ...              ...            ...       ...
# 7097499            1              NaN            NaN       NaN
# 7101150            1              NaN            NaN       NaN
# 7261713            0              NaN            NaN       NaN
# 7322732            1              NaN            NaN       NaN
# 7333269            0              NaN            NaN       NaN
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 34725                NaN               NaN              NaN              NaN
# 180385               NaN               NaN              NaN              NaN
# 187558               NaN               NaN              NaN              NaN
# 190788               NaN               NaN              NaN              NaN
# 228017               NaN               NaN              NaN              NaN
# ...                  ...               ...              ...              ...
# 7097499              NaN               NaN              NaN              NaN
# 7101150              NaN               NaN              NaN              NaN
# 7261713              NaN               NaN              NaN              NaN
# 7322732              NaN               NaN              NaN              NaN
# 7333269              NaN               NaN              NaN              NaN
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 34725               NaN               NaN          1
# 180385              NaN               NaN          6
# 187558              NaN               NaN          6
# 190788              NaN               NaN          6
# 228017              NaN               NaN          8
# ...                 ...               ...        ...
# 7097499             NaN               NaN         95
# 7101150             NaN               NaN         95
# 7261713             NaN               NaN         98
# 7322732             NaN               NaN         99
# 7333269             NaN               NaN         99
#
# [952 rows x 27 columns]

# %%
## Check what other district info is missing for records missing precinct
pct_dist_info = ['precinct_abbrv', 'vtd_abbrv', 'cong_dist_abbrv',
                 'super_court_abbrv', 'judic_dist_abbrv', 'nc_senate_abbrv',
                 'nc_house_abbrv', 'school_dist_abbrv']

for col in pct_dist_info:
    print('***** {} *****'.format(col))
    print('Total null values in column: {}'.format(missing_precinct_info[col].isna().sum()))
    print('---'*5)
    print()

# Every record with a null value for precinct is also missing all other
  # district info
# Out:
# ***** precinct_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** vtd_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** cong_dist_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** super_court_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** judic_dist_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** nc_senate_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** nc_house_abbrv *****
# Total null values in column: 952
# ---------------
#
# ***** school_dist_abbrv *****
# Total null values in column: 952
# ---------------

# %%
check_unique('voting_method', missing_precinct_info)
# Out:
#                   count      %
# No Vote             935  98.21
# PROVISIONAL           8   0.84
# ABSENTEE ONESTOP      5   0.53
# ABSENTEE BY MAIL      2   0.21
# CURBSIDE              1   0.11
# IN-PERSON             1   0.11

# %%
check_unique('no_vote_his', missing_precinct_info)
# Out:
#    count      %
# 1    541  56.83
# 0    411  43.17

# %%
check_unique('county_id', missing_precinct_info)
# Out:
#     count      %
# 60    192  20.17
# 50    186  19.54
# 11    184  19.33
# 26     62   6.51
# 78     43   4.52
# 74     40   4.20
# 32     35   3.68
# 71     34   3.57
# 68     31   3.26
# 8      18   1.89
# 41     13   1.37
# 14     11   1.16
# 67     10   1.05
# 13     10   1.05
# 76      9   0.95
# 25      8   0.84
# 51      7   0.74
# 72      6   0.63
# 77      6   0.63
# 69      5   0.53
# 62      4   0.42
# 22      3   0.32
# 6       3   0.32
# 59      3   0.32
# 42      2   0.21
# 24      2   0.21
# 12      2   0.21
# 99      2   0.21
# 79      2   0.21
# 95      2   0.21
# 54      2   0.21
# 65      2   0.21
# 46      1   0.11
# 87      1   0.11
# 9       1   0.11
# 86      1   0.11
# 81      1   0.11
# 19      1   0.11
# 75      1   0.11
# 39      1   0.11
# 66      1   0.11
# 63      1   0.11
# 98      1   0.11
# 34      1   0.11
# 1       1   0.11

# %% [markdown]
# # EXPLORE

# %% [markdown]
# ## Categorical Variables

# %%
check_unique('voting_method', elec_df)
# Out:
#                      count      %
# ABSENTEE ONESTOP   3343471  45.50
# No Vote            1994855  27.15
# ABSENTEE BY MAIL    983278  13.38
# IN-PERSON           830064  11.30
# ABSENTEE CURBSIDE   159034   2.16
# PROVISIONAL          14559   0.20
# CURBSIDE             13809   0.19
# TRANSFER              8876   0.12

# %%
check_unique('Gen_2020', elec_df)
# Out:
#                 count      %
# Early         4485783  61.05
# No Vote       1994855  27.15
# Election Day   843873  11.48
# Other           23435   0.32

# %% [markdown]
# > The 'Other' category is made up of only 23,435 individuals (<0.5%) that voted with either a provisional or transfer ballot. Need to consider dropping this extremely rare category or somehow adding those records into one of the other categories for purposes of modeling.

# %%
check_unique('party_cd', elec_df)
# Out:
#        count      %
# DEM  2616493  35.61
# UNA  2445503  33.28
# REP  2231019  30.36
# LIB    46490   0.63
# CST     4738   0.06
# GRE     3703   0.05

# %% [markdown]
# > LIB, CST, and GRE extremely rare within the state. Need to deal with this in some way, but grouping into a single 'Rare' category won't necessarily solve the issue since that would still represent barely more than 0.5% of voters in this election. It could make sense to combine these three parties with UNA (unaffiliated) to simply represent voters that do not align with one of the two major parties.

# %%
check_unique('gender_code', elec_df)
# Out:
#      count      %
# F  3644206  49.59
# M  3097211  42.15
# U   606523   8.25
#          6   0.00

# %%
## Inspect records where gender_code is encoded as whitespace
elec_df.loc[elec_df['gender_code']==' ']
# Out:
#              ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 143538    AD16896            0           55.0  ABSENTEE ONESTOP    Early
# 146513   CW730457            0           41.0  ABSENTEE ONESTOP    Early
# 151670    AD31495            0           33.0  ABSENTEE ONESTOP    Early
# 1209536   BC35157            0           62.0           No Vote  No Vote
# 2342599   BP59036            0           28.0  ABSENTEE ONESTOP    Early
# 7345546   ES24715            0           82.0  ABSENTEE ONESTOP    Early
#
#         party_cd gender_code  birth_year registr_dt race_code ethnic_code  \
# 143538       UNA                    1965 1997-08-15         W          NL
# 146513       DEM                    1979 2020-02-04         W          UN
# 151670       DEM                    1987 2008-11-04         B          UN
# 1209536      REP                    1958 1996-05-30         B          NL
# 2342599      REP                    1992 2020-10-08         U          UN
# 7345546      REP                    1938 2020-10-30         U          UN
#
#         zip_code             res_street_address res_city_desc state_cd  \
# 143538   28170.0            247  HIGHLAND DR        WADESBORO       NC
# 146513   28170.0         211 S RUTHERFORD ST        WADESBORO       NC
# 151670   28119.0               7355  NC 145            MORVEN       NC
# 1209536  28431.0  5264  ANDREW JACKSON HWY SW       CHADBOURN       NC
# 2342599  27525.0              50  CATLETT LN      FRANKLINTON       NC
# 7345546  28714.0       1156  GEORGES FORK RD       BURNSVILLE       NC
#
#         birth_state  drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 143538           NC            1              4.0          WADES        W3
# 146513      Missing            1              4.0          WADES        W2
# 151670      Missing            1              4.0             MM        MM
# 1209536          NC            1              NaN            P06       P06
# 2342599     Missing            1             35.0             14        14
# 7345546          NC            0            100.0         01 BUR    01-BUR
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 143538               9.0               16A              16A             25.0
# 146513               9.0               16A              16A             25.0
# 151670               9.0               16A              16A             25.0
# 1209536              7.0               13A               13             13.0
# 2342599              4.0                09               09             18.0
# 7345546             11.0                24               24             47.0
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 143538             55.0              SCH5          4
# 146513             55.0              SCH6          4
# 151670             55.0              SCH3          4
# 1209536            46.0                CO         24
# 2342599             7.0              SBO5         35
# 7345546           118.0               NaN        100

# %%
## For the 6 individuals whose gender is encoded as whitespace, replace with
  ## 'U' for undesignated
elec_df.loc[elec_df['gender_code']==' ', 'gender_code']='U'
check_unique('gender_code', elec_df)
# Out:
#      count      %
# F  3644206  49.59
# M  3097211  42.15
# U   606529   8.25

# %%
check_unique('race_code', elec_df)
# Out:
#      count      %
# W  4687551  63.79
# B  1512246  20.58
# U   742438  10.10
# O   198464   2.70
# A   104311   1.42
# I    55648   0.76
# M    46897   0.64
# P      389   0.01
#          2   0.00

# %%
## Inspect records where race_code is encoded as whitespace
elec_df.loc[elec_df['race_code']==' ']
# Out:
#             ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 3250136   CE7034            0           56.0  ABSENTEE ONESTOP    Early
# 5275378  DG12086            0           54.0  ABSENTEE ONESTOP    Early
#
#         party_cd gender_code  birth_year registr_dt race_code ethnic_code  \
# 3250136      UNA           M        1964 1986-04-23                    NL
# 5275378      REP           F        1966 2006-11-07                    UN
#
#         zip_code  res_street_address res_city_desc state_cd birth_state  \
# 3250136  28376.0   136  LEBEAU DR          RAEFORD       NC          NC
# 5275378  27944.0  140  PATRICK DR         HERTFORD       NC          NC
#
#          drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 3250136            1             47.0            06B        06
# 5275378            1             72.0         NEW HO    NEW-HO
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 3250136              9.0               19D              19D             21.0
# 5275378              3.0                01               01              1.0
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 3250136            48.0               NaN         47
# 5275378             1.0               NaN         72

# %%
## For the 2 individuals whose race is encoded as whitespace, replace with
  ## 'U' for undesignated
elec_df.loc[elec_df['race_code']==' ', 'race_code']='U'
check_unique('race_code', elec_df)
# Out:
#      count      %
# W  4687551  63.79
# B  1512246  20.58
# U   742440  10.10
# O   198464   2.70
# A   104311   1.42
# I    55648   0.76
# M    46897   0.64
# P      389   0.01

# %% [markdown]
# > The most infrequent categories (Other, Asian, Native American, Multiple, Pacific Islander/Native Hawaiian) each represent less than 5% of voters. To deal with these rare labels, it is probably best from a modeling standpoint to group them all under 'Other'.

# %%
check_unique('ethnic_code', elec_df)
# Out:
#       count      %
# NL  5201605  70.79
# UN  1919067  26.12
# HL   227274   3.09

# %% [markdown]
# > Voters that chose to identify themselves as Hispanic or Latino represent less than 5% of voters. Check below to see how disclosed racial and ethnic identities intersect.

# %%
## Investigate how race intersects with ethnic code
for code in elec_df['ethnic_code'].unique():
    print('*****{}*****'.format(code))
    display(elec_df.loc[elec_df['ethnic_code']==code]['race_code'].value_counts().to_frame())
    print()
# Out:
# *****NL*****
#    race_code
# W    3835684
# B    1122210
# O      82874
# A      69917
# I      46213
# U      22709
# M      21803
# P        195
# *****UN*****
#    race_code
# W     797584
# U     657576
# B     382311
# A      33485
# O      25886
# M      13531
# I       8539
# P        155
# *****HL*****
#    race_code
# O      89704
# U      62155
# W      54283
# M      11563
# B       7725
# A        909
# I        896
# P         39

# %% [markdown]
# > Patterns of intersection between race and ethnicity are somewhat unclear. The majority of voters that chose not to disclose their race (U) also chose not to disclose their ethnicity (UN) (657,576 out of 742,440). The majority of voters that identified themselves as Hispanic or Latino when registering listed their race as 'Other'(89,704 out of 227,274) or 'Undesignated' (62,155 out of 227,274), then 'White' (54,283 out of 227,274). As such, I am uncertain how useful this feature will be as a predictor, especially given that the 'HL' category is so rare.

# %%
check_unique('zip_code', elec_df)
# Out:
#          count     %
# 28269.0  57914  0.79
# 27587.0  56290  0.77
# 28277.0  54540  0.74
# 28078.0  49949  0.68
# 27610.0  49660  0.68
# ...        ...   ...
# 28765.0      3  0.00
# 27593.0      2  0.00
# 23917.0      2  0.00
# 28019.0      1  0.00
# 27836.0      1  0.00
#
# [843 rows x 2 columns]

# %% [markdown]
# > There are 843 different zip codes and many of them are only represented by a few records.

# %%
check_unique('res_city_desc', elec_df)
# Out:
#                 count     %
# CHARLOTTE      670287  9.12
# RALEIGH        402033  5.47
# GREENSBORO     240518  3.27
# DURHAM         229942  3.13
# WINSTON SALEM  177266  2.41
# ...               ...   ...
# PENLAND             3  0.00
# LEWISTON            2  0.00
# BOYDTON             2  0.00
# WILSONS MILLS       2  0.00
# CAROLEEN            1  0.00
#
# [765 rows x 2 columns]

# %% [markdown]
# > There are 765 different cities represented for the whole state.

# %%
check_unique('state_cd', elec_df)
# Out:
#        count      %
# NC   7347668  100.0
# NaN      260    0.0
# GA        12    0.0
# VA         6    0.0

# %%
## Inspect the 18 records (12 from GA, 6 from VA) where the voter's
  ## residential state_cd is outside NC
elec_df.loc[elec_df['state_cd'].isin(['GA', 'VA'])]
# Out:
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2020  \
# 1124594   BA15985            0           68.0  ABSENTEE ONESTOP         Early
# 1124595   BA19020            0           38.0  ABSENTEE ONESTOP         Early
# 1126277    BA5483            0           62.0           No Vote       No Vote
# 1126961   BA19429            0           19.0         IN-PERSON  Election Day
# 1126975    BA6026            0           75.0           No Vote       No Vote
# 1126996    BA6053            0           47.0  ABSENTEE ONESTOP         Early
# 1126997    BA3428            0           47.0  ABSENTEE ONESTOP         Early
# 1127006   BA19892            0           22.0  ABSENTEE ONESTOP         Early
# 1127650    BA6548            0           51.0         IN-PERSON  Election Day
# 1127657   BA14352            0           47.0         IN-PERSON  Election Day
# 1127675    BA6576            0           73.0           No Vote       No Vote
# 1129679   CB13409            0           73.0  ABSENTEE ONESTOP         Early
# 5672141  DS118823            1           79.0           No Vote       No Vote
# 5679863   DS76068            0           78.0           No Vote       No Vote
# 5707566   DS47767            0           59.0           No Vote       No Vote
# 5707568   DS27729            0           56.0           No Vote       No Vote
# 7076722   EJ20356            0           72.0  ABSENTEE ONESTOP         Early
# 7076723   EJ20355            0           71.0  ABSENTEE ONESTOP         Early
#
#         party_cd gender_code  birth_year registr_dt race_code ethnic_code  \
# 1124594      DEM           F        1952 2012-09-24         W          NL
# 1124595      DEM           F        1982 2019-06-18         W          NL
# 1126277      REP           M        1958 1990-10-08         W          NL
# 1126961      REP           M        2001 2020-02-05         W          UN
# 1126975      REP           M        1945 1986-08-25         W          NL
# 1126996      REP           M        1973 1992-03-27         W          NL
# 1126997      REP           F        1973 1992-04-03         W          NL
# 1127006      DEM           U        1998 2020-10-09         U          UN
# 1127650      REP           M        1969 2014-06-09         W          UN
# 1127657      UNA           F        1973 2008-10-29         W          NL
# 1127675      REP           F        1947 1979-01-04         W          NL
# 1129679      DEM           F        1947 2013-05-22         W          NL
# 5672141      REP           M        1941 2018-10-21         W          UN
# 5679863      UNA           F        1942 2000-10-09         W          NL
# 5707566      REP           M        1961 1992-09-23         W          NL
# 5707568      REP           F        1964 1984-09-18         W          NL
# 7076722      UNA           M        1948 2004-07-15         W          UN
# 7076723      UNA           F        1949 2004-07-15         W          UN
#
#         zip_code           res_street_address res_city_desc state_cd  \
# 1124594  30546.0             391  KOLBY LN        HIAWASSEE       GA
# 1124595  30546.0             391  KOLBY LN        HIAWASSEE       GA
# 1126277  30546.0        3035  ELLINGTON RD        HIAWASSEE       GA
# 1126961  30546.0  693  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1126975  30546.0  927  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1126996  30546.0  693  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1126997  30546.0  693  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1127006  30546.0  693  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1127650  30546.0  207  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1127657  30546.0  207  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1127675  30546.0    3  UPPER BELL CREEK RD        HIAWASSEE       GA
# 1129679  30546.0            216  JUSTUS RD        HIAWASSEE       GA
# 5672141  24148.0            372  POWELL RD         RIDGEWAY       VA
# 5679863  24148.0        1772  FARMBROOK RD         RIDGEWAY       VA
# 5707566  24148.0        1549  FARMBROOK RD         RIDGEWAY       VA
# 5707568  24148.0        1549  FARMBROOK RD         RIDGEWAY       VA
# 7076722  23917.0         58  BELL ARBOR CT          BOYDTON       VA
# 7076723  23917.0         58  BELL ARBOR CT          BOYDTON       VA
#
#         birth_state  drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 1124594          GA            1             22.0           HIAW      HIAW
# 1124595          CO            1             22.0           HIAW      HIAW
# 1126277          OH            0              NaN           HIAW      HIAW
# 1126961          GA            1             22.0           HIAW      HIAW
# 1126975          GA            0              NaN           HIAW      HIAW
# 1126996          GA            1             22.0           HIAW      HIAW
# 1126997          GA            0             22.0           HIAW      HIAW
# 1127006     Missing            1             22.0           HIAW      HIAW
# 1127650          GA            1             22.0           HIAW      HIAW
# 1127657     Missing            1             22.0           HIAW      HIAW
# 1127675          GA            0              NaN           HIAW      HIAW
# 1129679          DC            1             22.0           HIAW      HIAW
# 5672141     Missing            0              NaN           ED-1      ED-1
# 5679863          GA            0              NaN             MA        MA
# 5707566          NC            1              NaN             MA        MA
# 5707568          NC            1              NaN             MA        MA
# 7076722          VA            0             93.0            003       003
# 7076723          VA            0             93.0            003       003
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 1124594             11.0               30A               30             50.0
# 1124595             11.0               30A               30             50.0
# 1126277             11.0               30A               30             50.0
# 1126961             11.0               30A               30             50.0
# 1126975             11.0               30A               30             50.0
# 1126996             11.0               30A               30             50.0
# 1126997             11.0               30A               30             50.0
# 1127006             11.0               30A               30             50.0
# 1127650             11.0               30A               30             50.0
# 1127657             11.0               30A               30             50.0
# 1127675             11.0               30A               30             50.0
# 1129679             11.0               30A               30             50.0
# 5672141             10.0               17A              17A             30.0
# 5679863             10.0               17A              17A             30.0
# 5707566             10.0               17A              17A             30.0
# 5707568             10.0               17A              17A             30.0
# 7076722              1.0                09              09B              3.0
# 7076723              1.0                09              09B              3.0
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 1124594           120.0               NaN         22
# 1124595           120.0               NaN         22
# 1126277           120.0               NaN         22
# 1126961           120.0               NaN         22
# 1126975           120.0               NaN         22
# 1126996           120.0               NaN         22
# 1126997           120.0               NaN         22
# 1127006           120.0               NaN         22
# 1127650           120.0               NaN         22
# 1127657           120.0               NaN         22
# 1127675           120.0               NaN         22
# 1129679           120.0               NaN         22
# 5672141            65.0              SCH3         79
# 5679863            65.0              SCH4         79
# 5707566            65.0              SCH4         79
# 5707568            65.0              SCH4         79
# 7076722            32.0               003         93
# 7076723            32.0               003         93

# %% [markdown]
# > The 18 records above represent individuals that live in either GA or VA, very close to the NC border. The `county_id` under which their voter registrations are listed are the nearest NC county to the `res_city_desc` provided as part of their residential address. How are several of these voters casting votes in NC?? They likely ought to be removed from analysis.

# %%
## Drop voters whose registration lists them as living in GA or VA
elec_df.drop(index=elec_df.loc[elec_df['state_cd'].isin(['GA', 'VA'])].index, inplace=True)
check_unique('state_cd', elec_df)
# Out:
#        count      %
# NC   7347668  100.0
# NaN      260    0.0

# %%
check_unique('birth_state', elec_df)
# Out:
#            count      %
# NC       2891497  39.35
# Missing  1414935  19.26
# NY        398080   5.42
# OC        255578   3.48
# VA        227581   3.10
# PA        171287   2.33
# SC        155578   2.12
# FL        154066   2.10
# NJ        149064   2.03
# OH        141601   1.93
# CA        132436   1.80
# GA        101947   1.39
# MI         93620   1.27
# IL         91856   1.25
# MD         81301   1.11
# TX         78927   1.07
# MA         70817   0.96
# WV         61851   0.84
# TN         58361   0.79
# CT         52235   0.71
# IN         48248   0.66
# DC         41870   0.57
# AL         38655   0.53
# KY         36742   0.50
# MO         29672   0.40
# WI         29362   0.40
# LA         28788   0.39
# CO         21543   0.29
# MS         20813   0.28
# PR         20322   0.28
# MN         20245   0.28
# WA         20174   0.27
# IA         18580   0.25
# OK         16523   0.22
# KS         16171   0.22
# AZ         14036   0.19
# RI         12673   0.17
# ME         12412   0.17
# NH         11816   0.16
# AR         11808   0.16
# DE         11196   0.15
# NE         10273   0.14
# UT          8830   0.12
# OR          8621   0.12
# HI          8287   0.11
# VT          8094   0.11
# NM          7006   0.10
# AK          5893   0.08
# NV          4969   0.07
# ID          4470   0.06
# ND          4420   0.06
# MT          4189   0.06
# SD          3888   0.05
# WY          2571   0.03
# VI          1575   0.02
# GU           528   0.01
# AS            33   0.00
# MP            13   0.00
# NO             1   0.00

# %% [markdown]
# > The majority of `birth_state` labels are rare categories (less than 5% of voters). Some of the codes do not appear to be U.S. states or territories. These rare labels could be dealt with in a couple ways. They could all be grouped into an 'Other' category, or they could be grouped according to geographic region of the U.S. with an additional category for naturalized U.S. citizens.

# %%
elec_df.loc[elec_df['birth_state']=='OC']
# Out:
#              ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 18       DE236758            1           31.0           No Vote  No Vote
# 53       AA196723            0           26.0  ABSENTEE ONESTOP    Early
# 57       AA148060            0           53.0  ABSENTEE ONESTOP    Early
# 60       DL221658            0           30.0  ABSENTEE ONESTOP    Early
# 61       AA202162            0           29.0  ABSENTEE ONESTOP    Early
# ...           ...          ...            ...               ...      ...
# 7347135   ES21607            0           37.0  ABSENTEE ONESTOP    Early
# 7347157   ES26188            0           72.0  ABSENTEE ONESTOP    Early
# 7347512   ES26269            0           57.0  ABSENTEE BY MAIL    Early
# 7347553   ES22073            0           71.0  ABSENTEE BY MAIL    Early
# 7347765   ES21410            0           82.0           No Vote  No Vote
#
#         party_cd gender_code  birth_year registr_dt race_code ethnic_code  \
# 18           UNA           M        1989 2014-07-03         O          NL
# 53           UNA           M        1994 2017-08-21         W          NL
# 57           DEM           M        1967 2006-10-25         O          NL
# 60           DEM           M        1990 2020-03-12         O          UN
# 61           DEM           F        1991 2018-11-06         O          UN
# ...          ...         ...         ...        ...       ...         ...
# 7347135      UNA           M        1983 2006-11-28         W          NL
# 7347157      UNA           M        1948 2015-06-16         W          NL
# 7347512      REP           F        1963 2015-09-04         W          UN
# 7347553      UNA           F        1949 2007-12-04         W          NL
# 7347765      UNA           F        1938 2006-09-11         W          NL
#
#         zip_code             res_street_address res_city_desc state_cd  \
# 18       27302.0              105 N SIXTH ST           MEBANE       NC
# 53       27215.0        3031  WINSTON DR   #204    BURLINGTON       NC
# 57       27215.0  2954  ETHAN POINTE DR   #4203    BURLINGTON       NC
# 60       27302.0        1335  MEBANE OAKS RD           MEBANE       NC
# 61       27302.0  2000  QUAKER CREEK DR   #2101        MEBANE       NC
# ...          ...                            ...           ...      ...
# 7347135  28714.0      159  MOODY MOUNTAIN RD       BURNSVILLE       NC
# 7347157  28714.0          2238  WHITE OAK RD       BURNSVILLE       NC
# 7347512  28714.0             376  KYANITE DR       BURNSVILLE       NC
# 7347553  28714.0           243  WHITE OAK RD       BURNSVILLE       NC
# 7347765  28714.0             91  SKY VIEW DR       BURNSVILLE       NC
#
#         birth_state  drivers_lic  voted_county_id precinct_abbrv vtd_abbrv  \
# 18               OC            1              NaN            10N       10N
# 53               OC            1              1.0            129       129
# 57               OC            1              1.0            03S       03S
# 60               OC            1              1.0           10S1       10S
# 61               OC            1              1.0           10S1       10S
# ...             ...          ...              ...            ...       ...
# 7347135          OC            1            100.0         10 PEN    10-PEN
# 7347157          OC            1            100.0         09 SOU    09-SOU
# 7347512          OC            1            100.0         09 SOU    09-SOU
# 7347553          OC            1            100.0         09 SOU    09-SOU
# 7347765          OC            1              NaN         01 BUR    01-BUR
#
#          cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 18                  13.0               15A              15A             24.0
# 53                  13.0               15A              15A             24.0
# 57                  13.0               15A              15A             24.0
# 60                  13.0               15A              15A             24.0
# 61                  13.0               15A              15A             24.0
# ...                  ...               ...              ...              ...
# 7347135             11.0                24               24             47.0
# 7347157             11.0                24               24             47.0
# 7347512             11.0                24               24             47.0
# 7347553             11.0                24               24             47.0
# 7347765             11.0                24               24             47.0
#
#          nc_house_abbrv school_dist_abbrv  county_id
# 18                 63.0               NaN          1
# 53                 63.0               NaN          1
# 57                 64.0               NaN          1
# 60                 63.0               NaN          1
# 61                 63.0               NaN          1
# ...                 ...               ...        ...
# 7347135           118.0               NaN        100
# 7347157           118.0               NaN        100
# 7347512           118.0               NaN        100
# 7347553           118.0               NaN        100
# 7347765           118.0               NaN        100
#
# [255578 rows x 27 columns]

# %%
check_unique('drivers_lic', elec_df)
# Out:
#      count      %
# 1  6391114  86.98
# 0   956814  13.02

# %%
check_unique('precinct_abbrv', elec_df)
# Out:
#       count     %
# 02    57379  0.78
# 04    53866  0.73
# 15    44120  0.60
# 11    44050  0.60
# 05    43690  0.59
# ...     ...   ...
# CT03    199  0.00
# 4HB     190  0.00
# FC-2    168  0.00
# STPT    141  0.00
# EL       81  0.00
#
# [1893 rows x 2 columns]

# %%
check_unique('vtd_abbrv', elec_df)
# Out:
#       count     %
# 04    75999  1.03
# 02    57859  0.79
# 05    54368  0.74
# 03    50108  0.68
# 06    47691  0.65
# ...     ...   ...
# SLVL    187  0.00
# FC-2    168  0.00
# STAC    144  0.00
# STPT    141  0.00
# EL       81  0.00
#
# [1806 rows x 2 columns]

# %%
check_unique('cong_dist_abbrv', elec_df)
# Out:
#        count     %
# 4.0   645718  8.79
# 2.0   636300  8.66
# 12.0  628910  8.56
# 7.0   605726  8.24
# 11.0  591127  8.04
# 6.0   573136  7.80
# 9.0   557622  7.59
# 8.0   541666  7.37
# 10.0  535677  7.29
# 3.0   515229  7.01
# 13.0  514745  7.01
# 5.0   513954  6.99
# 1.0   487166  6.63
# NaN      952  0.01

# %%
check_unique('nc_senate_abbrv', elec_df)
# Out:
#        count     %
# 17.0  200283  2.73
# 8.0   183944  2.50
# 9.0   174371  2.37
# 41.0  174067  2.37
# 20.0  173020  2.35
# 49.0  169714  2.31
# 23.0  169421  2.31
# 38.0  168402  2.29
# 18.0  167343  2.28
# 27.0  164885  2.24
# 32.0  160239  2.18
# 16.0  160130  2.18
# 39.0  160025  2.18
# 36.0  159892  2.18
# 35.0  158650  2.16
# 15.0  157585  2.14
# 37.0  155827  2.12
# 34.0  155241  2.11
# 14.0  154821  2.11
# 24.0  151704  2.06
# 48.0  151390  2.06
# 50.0  151198  2.06
# 28.0  150503  2.05
# 11.0  150186  2.04
# 1.0   146125  1.99
# 43.0  144468  1.97
# 31.0  143630  1.95
# 25.0  142046  1.93
# 45.0  140547  1.91
# 33.0  140303  1.91
# 22.0  138505  1.88
# 44.0  137182  1.87
# 19.0  136197  1.85
# 2.0   134937  1.84
# 47.0  134840  1.84
# 5.0   134144  1.83
# 42.0  133434  1.82
# 12.0  133349  1.81
# 40.0  133186  1.81
# 30.0  131034  1.78
# 29.0  130623  1.78
# 4.0   129094  1.76
# 46.0  125324  1.71
# 6.0   124496  1.69
# 21.0  123267  1.68
# 26.0  122575  1.67
# 3.0   120699  1.64
# 10.0  118111  1.61
# 7.0   114460  1.56
# 13.0  111559  1.52
# NaN      952  0.01

# %%
check_unique('nc_house_abbrv', elec_df)
# Out:
#       count     %
# 37.0  87063  1.18
# 41.0  81667  1.11
# 26.0  81651  1.11
# 98.0  80489  1.10
# 17.0  80025  1.09
# ...     ...   ...
# 4.0   47140  0.64
# 47.0  46909  0.64
# 46.0  45179  0.61
# 15.0  44073  0.60
# NaN     952  0.01
#
# [121 rows x 2 columns]

# %%
check_unique('school_dist_abbrv', elec_df)
# Out:
#           count      %
# NaN     1542309  20.99
# 2        554040   7.54
# 1        539947   7.35
# 5        367652   5.00
# 3        347047   4.72
# ...         ...    ...
# FINE       1288   0.02
# 4TH        1230   0.02
# L02        1152   0.02
# DIST D     1035   0.01
# S08          46   0.00
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Group Rare Categories

# %%
## Create new column that is a binary variable indicating whether the voter
  ## cast a vote in the 2020 election or not
elec_df['Gen_2020_binary'] = np.where(elec_df['Gen_2020']=='No Vote',
                                0, 1)

## Check distribution
check_unique('Gen_2020_binary', elec_df)
# Out:
#      count      %
# 1  5353080  72.85
# 0  1994848  27.15

# %%
## Create new column grouping most infrequent party categories (<5% of voters)
  ## into same group as those who are unaffiliated
elec_df['party_grp'] = np.where(elec_df['party_cd'].isin(['REP', 'DEM']),
                                elec_df['party_cd'], 'Other')

## Check distribution
check_unique('party_grp', elec_df)
# Out:
#          count      %
# DEM    2616489  35.61
# Other  2500430  34.03
# REP    2231009  30.36

# %%
## Create new column grouping most infrequent race categories (<5% of voters)
elec_df['race_grp'] = np.where(elec_df['race_code'].isin(['W', 'B', 'U']),
                               elec_df['race_code'], 'O')

## Check distribution
check_unique('race_grp', elec_df)
# Out:
#      count      %
# W  4687534  63.79
# B  1512246  20.58
# U   742439  10.10
# O   405709   5.52

# %% [markdown]
# ## Numeric Variables

# %%
## Plot distribution of current age as of EOY 2020 
plt.figure(figsize=(10,7))
ax = sns.histplot(elec_df['birth_age_adj'], stat='density')
ax.set_title('Distribution of Age', fontsize=16, weight='bold')
ax.set_xlabel('Age', fontsize=14, weight='bold')
ax.set_ylabel('Count', fontsize=14, weight='bold')
ax.set_xlim(15,115);

# %% [markdown]
# ## Relationship to Target (Gen_2020 voting method)

# %%
count_by_method('party_cd', 'Gen_2020', elec_df);

# %%
count_by_method('party_grp', 'Gen_2020', elec_df);

# %% [markdown]
# # MODEL

# %% [markdown]
# # INTERPRET

# %% [markdown]
# # Conclusions/Recommendations
