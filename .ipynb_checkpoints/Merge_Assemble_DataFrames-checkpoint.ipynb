# %% [markdown]
# # Obtain

# %%
## Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt

# %%
## Set options for displaying Pandas DataFrames
pd.options.display.max_columns = 100
pd.options.display.max_rows = 120

# %%
## Load in voter registration data for Union County
uc_vreg = pd.read_table('Data/ncvoter90.zip', encoding='ISO-8859-1')
uc_vreg.head()
# Out:
#    county_id county_desc  voter_reg_num status_cd voter_status_desc reason_cd  \
# 0         90       UNION         346446         A            ACTIVE        AV
# 1         90       UNION         348004         A            ACTIVE        AV
# 2         90       UNION         281016         A            ACTIVE        AV
# 3         90       UNION         288489         A            ACTIVE        AV
# 4         90       UNION         279308         A            ACTIVE        AV
#
#   voter_status_reason_desc absent_ind name_prefx_cd last_name first_name  \
# 0                 VERIFIED                             AALAEI       ARIO
# 1                 VERIFIED                             AALAEI    KAVITHA
# 2                 VERIFIED                            AALBORG     ALEXIS
# 3                 VERIFIED                            AALBORG      BRYAN
# 4                 VERIFIED                            AALBORG     SHARON
#
#     middle_name name_suffix_lbl         res_street_address res_city_desc  \
# 0           NaN             NaN   4009  MILLBRIDGE PKWY           WAXHAW
# 1           NaN             NaN   4009  MILLBRIDGE PKWY           WAXHAW
# 2         LEANN             NaN  1001  STEVENS PRIDE CT     INDIAN TRAIL
# 3           LEE             NaN  1001  STEVENS PRIDE CT     INDIAN TRAIL
# 4  SCHLEENBAKER             NaN  1001  STEVENS PRIDE CT     INDIAN TRAIL
#
#   state_cd  zip_code             mail_addr1 mail_addr2 mail_addr3 mail_addr4  \
# 0       NC   28173.0   4009 MILLBRIDGE PKWY        NaN        NaN        NaN
# 1       NC   28173.0   4009 MILLBRIDGE PKWY        NaN        NaN        NaN
# 2       NC   28079.0  1001 STEVENS PRIDE CT        NaN        NaN        NaN
# 3       NC   28079.0  1001 STEVENS PRIDE CT        NaN        NaN        NaN
# 4       NC   28079.0  1001 STEVENS PRIDE CT        NaN        NaN        NaN
#
#       mail_city mail_state mail_zipcode  full_phone_number race_code  \
# 0        WAXHAW         NC        28173                NaN         W
# 1        WAXHAW         NC        28173                NaN         A
# 2  INDIAN TRAIL         NC        28079                NaN         W
# 3  INDIAN TRAIL         NC        28079                NaN         W
# 4  INDIAN TRAIL         NC        28079                NaN         W
#
#   ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 0          NL      UNA           M         46          OC           Y
# 1          NL      DEM           F         46          OC           Y
# 2          NL      UNA           F         26          IA           Y
# 3          UN      UNA           M         62          OK           Y
# 4          NL      REP           F         62          PA           Y
#
#    registr_dt precinct_abbrv precinct_desc  municipality_abbrv  \
# 0  04/25/2019           020A          020A                 5.0
# 1  06/24/2019           020A          020A                 5.0
# 2  11/04/2013           029A          029A                 6.0
# 3  09/17/2014           029A          029A                 6.0
# 4  07/24/2013           029A          029A                 6.0
#
#   municipality_desc  ward_abbrv  ward_desc  cong_dist_abbrv super_court_abbrv  \
# 0            WAXHAW         NaN        NaN              9.0               20B
# 1            WAXHAW         NaN        NaN              9.0               20B
# 2      INDIAN TRAIL         NaN        NaN              9.0               20B
# 3      INDIAN TRAIL         NaN        NaN              9.0               20B
# 4      INDIAN TRAIL         NaN        NaN              9.0               20B
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  county_commiss_abbrv  \
# 0              20C             35.0            68.0                   NaN
# 1              20C             35.0            68.0                   NaN
# 2              20C             35.0            68.0                   NaN
# 3              20C             35.0            68.0                   NaN
# 4              20C             35.0            68.0                   NaN
#
#    county_commiss_desc  township_abbrv  township_desc  school_dist_abbrv  \
# 0                  NaN             NaN            NaN                2.0
# 1                  NaN             NaN            NaN                2.0
# 2                  NaN             NaN            NaN                3.0
# 3                  NaN             NaN            NaN                3.0
# 4                  NaN             NaN            NaN                3.0
#
#   school_dist_desc  fire_dist_abbrv  fire_dist_desc  water_dist_abbrv  \
# 0        SCHOOL #2              NaN             NaN               NaN
# 1        SCHOOL #2              NaN             NaN               NaN
# 2        SCHOOL #3              NaN             NaN               NaN
# 3        SCHOOL #3              NaN             NaN               NaN
# 4        SCHOOL #3              NaN             NaN               NaN
#
#    water_dist_desc  sewer_dist_abbrv  sewer_dist_desc  sanit_dist_abbrv  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#    sanit_dist_desc  rescue_dist_abbrv  rescue_dist_desc  munic_dist_abbrv  \
# 0              NaN                NaN               NaN               5.0
# 1              NaN                NaN               NaN               5.0
# 2              NaN                NaN               NaN               6.0
# 3              NaN                NaN               NaN               6.0
# 4              NaN                NaN               NaN               6.0
#
#   munic_dist_desc  dist_1_abbrv         dist_1_desc dist_2_abbrv dist_2_desc  \
# 0          WAXHAW          30.0  30TH PROSECUTORIAL
# 1          WAXHAW          30.0  30TH PROSECUTORIAL
# 2    INDIAN TRAIL          30.0  30TH PROSECUTORIAL
# 3    INDIAN TRAIL          30.0  30TH PROSECUTORIAL
# 4    INDIAN TRAIL          30.0  30TH PROSECUTORIAL
#
#   confidential_ind  birth_year      ncid vtd_abbrv vtd_desc
# 0                N        1974  EF230133      020A     020A
# 1                N        1974  EF231096      020A     020A
# 2                N        1994  AL261840      029A     029A
# 3                N        1958  AL178177      029A     029A
# 4                N        1958  AL193958      029A     029A

# %%
## Load in voter history data for Union County
uc_vhis = pd.read_table('Data/ncvhis90.zip')
uc_vhis.head()
# Out:
#    county_id county_desc  voter_reg_num election_lbl       election_desc  \
# 0         90       UNION         285297   11/06/2018  11/06/2018 GENERAL
# 1         90       UNION         285297   11/03/2020  11/03/2020 GENERAL
# 2         90       UNION         285297   11/08/2016  11/08/2016 GENERAL
# 3         90       UNION         285297   09/10/2019  09/10/2019 GENERAL
# 4         90       UNION         285297   03/03/2020  03/03/2020 PRIMARY
#
#       voting_method voted_party_cd voted_party_desc pct_label pct_description  \
# 0  ABSENTEE ONESTOP            REP       REPUBLICAN       016             016
# 1  ABSENTEE ONESTOP            REP       REPUBLICAN       016             016
# 2  ABSENTEE ONESTOP            REP       REPUBLICAN       016             016
# 3  ABSENTEE ONESTOP            REP       REPUBLICAN       016             016
# 4         IN-PERSON            REP       REPUBLICAN       016             016
#
#        ncid  voted_county_id voted_county_desc vtd_label vtd_description
# 0  AA100547               90             UNION       016             016
# 1  AA100547               90             UNION       016             016
# 2  AA100547               90             UNION       016             016
# 3  AA100547               90             UNION       016             016
# 4  AA100547               90             UNION       016             016

# %% [markdown]
# # Scrub and Explore (Part I)

# %%
## Check metadata for voter registration dataframe
uc_vreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183969 entries, 0 to 183968
# Data columns (total 71 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county_id                 183969 non-null  int64
#  1   county_desc               183969 non-null  object
#  2   voter_reg_num             183969 non-null  int64
#  3   status_cd                 183969 non-null  object
#  4   voter_status_desc         183969 non-null  object
#  5   reason_cd                 183969 non-null  object
#  6   voter_status_reason_desc  183969 non-null  object
#  7   absent_ind                183969 non-null  object
#  8   name_prefx_cd             183969 non-null  object
#  9   last_name                 183965 non-null  object
#  10  first_name                183967 non-null  object
#  11  middle_name               168871 non-null  object
#  12  name_suffix_lbl           20984 non-null   object
#  13  res_street_address        183969 non-null  object
#  14  res_city_desc             170603 non-null  object
#  15  state_cd                  170603 non-null  object
#  16  zip_code                  170603 non-null  float64
#  17  mail_addr1                183966 non-null  object
#  18  mail_addr2                15196 non-null   object
#  19  mail_addr3                14447 non-null   object
#  20  mail_addr4                14450 non-null   object
#  21  mail_city                 183966 non-null  object
#  22  mail_state                183966 non-null  object
#  23  mail_zipcode              183966 non-null  object
#  24  full_phone_number         338 non-null     float64
#  25  race_code                 183969 non-null  object
#  26  ethnic_code               183969 non-null  object
#  27  party_cd                  183969 non-null  object
#  28  gender_code               183969 non-null  object
#  29  birth_age                 183969 non-null  int64
#  30  birth_state               138511 non-null  object
#  31  drivers_lic               183969 non-null  object
#  32  registr_dt                183969 non-null  object
#  33  precinct_abbrv            169252 non-null  object
#  34  precinct_desc             169252 non-null  object
#  35  municipality_abbrv        114437 non-null  float64
#  36  municipality_desc         114437 non-null  object
#  37  ward_abbrv                0 non-null       float64
#  38  ward_desc                 0 non-null       float64
#  39  cong_dist_abbrv           169252 non-null  float64
#  40  super_court_abbrv         169252 non-null  object
#  41  judic_dist_abbrv          169252 non-null  object
#  42  nc_senate_abbrv           169252 non-null  float64
#  43  nc_house_abbrv            169252 non-null  float64
#  44  county_commiss_abbrv      0 non-null       float64
#  45  county_commiss_desc       0 non-null       float64
#  46  township_abbrv            0 non-null       float64
#  47  township_desc             0 non-null       float64
#  48  school_dist_abbrv         169252 non-null  float64
#  49  school_dist_desc          169252 non-null  object
#  50  fire_dist_abbrv           0 non-null       float64
#  51  fire_dist_desc            0 non-null       float64
#  52  water_dist_abbrv          0 non-null       float64
#  53  water_dist_desc           0 non-null       float64
#  54  sewer_dist_abbrv          0 non-null       float64
#  55  sewer_dist_desc           0 non-null       float64
#  56  sanit_dist_abbrv          0 non-null       float64
#  57  sanit_dist_desc           0 non-null       float64
#  58  rescue_dist_abbrv         0 non-null       float64
#  59  rescue_dist_desc          0 non-null       float64
#  60  munic_dist_abbrv          114437 non-null  float64
#  61  munic_dist_desc           114437 non-null  object
#  62  dist_1_abbrv              169252 non-null  float64
#  63  dist_1_desc               169252 non-null  object
#  64  dist_2_abbrv              183969 non-null  object
#  65  dist_2_desc               183969 non-null  object
#  66  confidential_ind          183969 non-null  object
#  67  birth_year                183969 non-null  int64
#  68  ncid                      183969 non-null  object
#  69  vtd_abbrv                 169252 non-null  object
#  70  vtd_desc                  169252 non-null  object
# dtypes: float64(25), int64(4), object(42)
# memory usage: 99.7+ MB

# %%
## Check metadata for voter history dataframe
uc_vhis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806996 entries, 0 to 806995
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   county_id          806996 non-null  int64
#  1   county_desc        806996 non-null  object
#  2   voter_reg_num      806996 non-null  int64
#  3   election_lbl       806996 non-null  object
#  4   election_desc      806996 non-null  object
#  5   voting_method      806996 non-null  object
#  6   voted_party_cd     806932 non-null  object
#  7   voted_party_desc   806932 non-null  object
#  8   pct_label          806996 non-null  object
#  9   pct_description    806996 non-null  object
#  10  ncid               806996 non-null  object
#  11  voted_county_id    806996 non-null  int64
#  12  voted_county_desc  806996 non-null  object
#  13  vtd_label          806828 non-null  object
#  14  vtd_description    806828 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 92.4+ MB

# %%
## Check for duplicate entries in voter registration data
uc_vreg.duplicated().sum()
# Out:
# 0

# %%
## Check for duplicate entries in voter history data
uc_vhis.duplicated().sum()
# Out:
# 132

# %%
## Inspect duplicate entries in voter history data
uc_vhis.loc[uc_vhis.duplicated()]
# Out:
#         county_id county_desc  voter_reg_num election_lbl       election_desc  \
# 9023           90       UNION         325228   03/03/2020  03/03/2020 PRIMARY
# 9025           90       UNION         325228   09/10/2019  09/10/2019 GENERAL
# 26366          90       UNION         205258   11/06/2012  11/06/2012 GENERAL
# 35914          90       UNION         338757   11/06/2018  11/06/2018 GENERAL
# 74971          90       UNION         204911   11/06/2012  11/06/2012 GENERAL
# ...           ...         ...            ...          ...                 ...
# 746626         90       UNION          10836   11/08/2016  11/08/2016 GENERAL
# 767799         90       UNION         338953   11/06/2018  11/06/2018 GENERAL
# 768673         90       UNION         167702   05/08/2012  05/08/2012 PRIMARY
# 773146         90       UNION         271801   11/06/2012  11/06/2012 GENERAL
# 782229         90       UNION         172038   11/06/2012  11/06/2012 GENERAL
#
#            voting_method voted_party_cd voted_party_desc pct_label  \
# 9023    ABSENTEE ONESTOP            DEM       DEMOCRATIC      020A
# 9025           IN-PERSON            DEM       DEMOCRATIC      020A
# 26366   ABSENTEE ONESTOP            UNA     UNAFFILIATED      029C
# 35914        PROVISIONAL            REP       REPUBLICAN      037A
# 74971   ABSENTEE ONESTOP            DEM       DEMOCRATIC       036
# ...                  ...            ...              ...       ...
# 746626  ABSENTEE ONESTOP            REP       REPUBLICAN       024
# 767799       PROVISIONAL            UNA     UNAFFILIATED       012
# 768673         IN-PERSON            REP       REPUBLICAN       036
# 773146  ABSENTEE ONESTOP            REP       REPUBLICAN       042
# 782229         IN-PERSON            UNA     UNAFFILIATED       013
#
#        pct_description       ncid  voted_county_id voted_county_desc  \
# 9023              020A   AN168178               90             UNION
# 9025              020A   AN168178               90             UNION
# 26366             029C    CE19807               90             UNION
# 35914             037A  CW1070559               90             UNION
# 74971              036   CW455149               90             UNION
# ...                ...        ...              ...               ...
# 746626             024     EF8430               90             UNION
# 767799             012    EF90843               90             UNION
# 768673             036    EF91060               90             UNION
# 773146             042    EF92439               90             UNION
# 782229             013    EF95396               90             UNION
#
#        vtd_label vtd_description
# 9023        020A            020A
# 9025        020A            020A
# 26366       029C            029C
# 35914       037A            037A
# 74971        036             036
# ...          ...             ...
# 746626       024             024
# 767799       012             012
# 768673       036             036
# 773146       042             042
# 782229       013             013
#
# [132 rows x 15 columns]

# %%
## Remove duplicate entries from records of voter history
uc_vhis.drop_duplicates(inplace=True)

# %% [markdown]
# ## Merge Voter Registration Data with Voter History Data

# %%
## Merge voter registration information onto records of voter history based 
  ## on unique ncid
    
## Use right join so we're only including ncid's for which their is
  ## registration and demographic information, including for those 
    ## people who are registered, but have never voted
all_uc_voters = uc_vhis.merge(uc_vreg.drop(columns=['county_id', 'county_desc',
                                                'voter_reg_num'], axis=1),
                                       how='right', on='ncid')
# inspect new dataframe
display(all_uc_voters.head())
all_uc_voters.tail()
# Out:
#    county_id county_desc  voter_reg_num election_lbl  \
# 0       90.0       UNION       346446.0   11/03/2020
# 1       90.0       UNION       348004.0   11/03/2020
# 2        NaN         NaN            NaN          NaN
# 3       90.0       UNION       288489.0   11/08/2011
# 4       90.0       UNION       288489.0   11/06/2012
#
#                   election_desc     voting_method voted_party_cd  \
# 0            11/03/2020 GENERAL  ABSENTEE ONESTOP            UNA
# 1            11/03/2020 GENERAL  ABSENTEE ONESTOP            DEM
# 2                           NaN               NaN            NaN
# 3  11/08/2011 MUNICIPAL GENERAL         IN-PERSON            UNA
# 4            11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
#
#   voted_party_desc pct_label pct_description      ncid  voted_county_id  \
# 0     UNAFFILIATED      020A            020A  EF230133             90.0
# 1       DEMOCRATIC      020A            020A  EF231096             90.0
# 2              NaN       NaN             NaN  AL261840              NaN
# 3     UNAFFILIATED      26.1            26.1  AL178177             11.0
# 4     UNAFFILIATED      26.1            26.1  AL178177             11.0
#
#   voted_county_desc vtd_label vtd_description status_cd voter_status_desc  \
# 0             UNION      020A            020A         A            ACTIVE
# 1             UNION      020A            020A         A            ACTIVE
# 2               NaN       NaN             NaN         A            ACTIVE
# 3          BUNCOMBE      26.1            26.1         A            ACTIVE
# 4          BUNCOMBE      26.1            26.1         A            ACTIVE
#
#   reason_cd voter_status_reason_desc absent_ind name_prefx_cd last_name  \
# 0        AV                 VERIFIED                             AALAEI
# 1        AV                 VERIFIED                             AALAEI
# 2        AV                 VERIFIED                            AALBORG
# 3        AV                 VERIFIED                            AALBORG
# 4        AV                 VERIFIED                            AALBORG
#
#   first_name middle_name name_suffix_lbl         res_street_address  \
# 0       ARIO         NaN             NaN   4009  MILLBRIDGE PKWY
# 1    KAVITHA         NaN             NaN   4009  MILLBRIDGE PKWY
# 2     ALEXIS       LEANN             NaN  1001  STEVENS PRIDE CT
# 3      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
# 4      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
#
#   res_city_desc state_cd  zip_code             mail_addr1 mail_addr2  \
# 0        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 1        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 2  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 3  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 4  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
#
#   mail_addr3 mail_addr4     mail_city mail_state mail_zipcode  \
# 0        NaN        NaN        WAXHAW         NC        28173
# 1        NaN        NaN        WAXHAW         NC        28173
# 2        NaN        NaN  INDIAN TRAIL         NC        28079
# 3        NaN        NaN  INDIAN TRAIL         NC        28079
# 4        NaN        NaN  INDIAN TRAIL         NC        28079
#
#    full_phone_number race_code ethnic_code party_cd gender_code  birth_age  \
# 0                NaN         W          NL      UNA           M         46
# 1                NaN         A          NL      DEM           F         46
# 2                NaN         W          NL      UNA           F         26
# 3                NaN         W          UN      UNA           M         62
# 4                NaN         W          UN      UNA           M         62
#
#   birth_state drivers_lic  registr_dt precinct_abbrv precinct_desc  \
# 0          OC           Y  04/25/2019           020A          020A
# 1          OC           Y  06/24/2019           020A          020A
# 2          IA           Y  11/04/2013           029A          029A
# 3          OK           Y  09/17/2014           029A          029A
# 4          OK           Y  09/17/2014           029A          029A
#
#    municipality_abbrv municipality_desc  ward_abbrv  ward_desc  \
# 0                 5.0            WAXHAW         NaN        NaN
# 1                 5.0            WAXHAW         NaN        NaN
# 2                 6.0      INDIAN TRAIL         NaN        NaN
# 3                 6.0      INDIAN TRAIL         NaN        NaN
# 4                 6.0      INDIAN TRAIL         NaN        NaN
#
#    cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 0              9.0               20B              20C             35.0
# 1              9.0               20B              20C             35.0
# 2              9.0               20B              20C             35.0
# 3              9.0               20B              20C             35.0
# 4              9.0               20B              20C             35.0
#
#    nc_house_abbrv  county_commiss_abbrv  county_commiss_desc  township_abbrv  \
# 0            68.0                   NaN                  NaN             NaN
# 1            68.0                   NaN                  NaN             NaN
# 2            68.0                   NaN                  NaN             NaN
# 3            68.0                   NaN                  NaN             NaN
# 4            68.0                   NaN                  NaN             NaN
#
#    township_desc  school_dist_abbrv school_dist_desc  fire_dist_abbrv  \
# 0            NaN                2.0        SCHOOL #2              NaN
# 1            NaN                2.0        SCHOOL #2              NaN
# 2            NaN                3.0        SCHOOL #3              NaN
# 3            NaN                3.0        SCHOOL #3              NaN
# 4            NaN                3.0        SCHOOL #3              NaN
#
#    fire_dist_desc  water_dist_abbrv  water_dist_desc  sewer_dist_abbrv  \
# 0             NaN               NaN              NaN               NaN
# 1             NaN               NaN              NaN               NaN
# 2             NaN               NaN              NaN               NaN
# 3             NaN               NaN              NaN               NaN
# 4             NaN               NaN              NaN               NaN
#
#    sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  rescue_dist_abbrv  \
# 0              NaN               NaN              NaN                NaN
# 1              NaN               NaN              NaN                NaN
# 2              NaN               NaN              NaN                NaN
# 3              NaN               NaN              NaN                NaN
# 4              NaN               NaN              NaN                NaN
#
#    rescue_dist_desc  munic_dist_abbrv munic_dist_desc  dist_1_abbrv  \
# 0               NaN               5.0          WAXHAW          30.0
# 1               NaN               5.0          WAXHAW          30.0
# 2               NaN               6.0    INDIAN TRAIL          30.0
# 3               NaN               6.0    INDIAN TRAIL          30.0
# 4               NaN               6.0    INDIAN TRAIL          30.0
#
#           dist_1_desc dist_2_abbrv dist_2_desc confidential_ind  birth_year  \
# 0  30TH PROSECUTORIAL                                         N        1974
# 1  30TH PROSECUTORIAL                                         N        1974
# 2  30TH PROSECUTORIAL                                         N        1994
# 3  30TH PROSECUTORIAL                                         N        1958
# 4  30TH PROSECUTORIAL                                         N        1958
#
#   vtd_abbrv vtd_desc
# 0      020A     020A
# 1      020A     020A
# 2      029A     029A
# 3      029A     029A
# 4      029A     029A
#         county_id county_desc  voter_reg_num election_lbl       election_desc  \
# 825812       90.0       UNION       243464.0   11/06/2018  11/06/2018 GENERAL
# 825813       90.0       UNION       243464.0   11/03/2020  11/03/2020 GENERAL
# 825814       90.0       UNION       243464.0   05/08/2018  05/08/2018 PRIMARY
# 825815       90.0       UNION       243464.0   09/10/2019  09/10/2019 GENERAL
# 825816        NaN         NaN            NaN          NaN                 NaN
#
#            voting_method voted_party_cd voted_party_desc pct_label  \
# 825812  ABSENTEE ONESTOP            DEM       DEMOCRATIC       025
# 825813  ABSENTEE ONESTOP            DEM       DEMOCRATIC       025
# 825814  ABSENTEE ONESTOP            DEM       DEMOCRATIC       025
# 825815  ABSENTEE ONESTOP            DEM       DEMOCRATIC       025
# 825816               NaN            NaN              NaN       NaN
#
#        pct_description      ncid  voted_county_id voted_county_desc vtd_label  \
# 825812             025  EF157599             90.0             UNION       025
# 825813             025  EF157599             90.0             UNION       025
# 825814             025  EF157599             90.0             UNION       025
# 825815             025  EF157599             90.0             UNION       025
# 825816             NaN  EF219265              NaN               NaN       NaN
#
#        vtd_description status_cd voter_status_desc reason_cd  \
# 825812             025         A            ACTIVE        AV
# 825813             025         A            ACTIVE        AV
# 825814             025         A            ACTIVE        AV
# 825815             025         A            ACTIVE        AV
# 825816             NaN         I          INACTIVE        IU
#
#                    voter_status_reason_desc absent_ind name_prefx_cd  \
# 825812                             VERIFIED
# 825813                             VERIFIED
# 825814                             VERIFIED
# 825815                             VERIFIED
# 825816  CONFIRMATION RETURNED UNDELIVERABLE
#
#        last_name first_name middle_name name_suffix_lbl  \
# 825812    ZYNSKY      JAMES      ROBERT             NaN
# 825813    ZYNSKY      JAMES      ROBERT             NaN
# 825814    ZYNSKY      JAMES      ROBERT             NaN
# 825815    ZYNSKY      JAMES      ROBERT             NaN
# 825816   ZYWICKI   JENNIFER         ANN             NaN
#
#            res_street_address res_city_desc state_cd  zip_code  \
# 825812     2905  MEDLIN RD           MONROE       NC   28112.0
# 825813     2905  MEDLIN RD           MONROE       NC   28112.0
# 825814     2905  MEDLIN RD           MONROE       NC   28112.0
# 825815     2905  MEDLIN RD           MONROE       NC   28112.0
# 825816  5719  PARKSTONE DR         MATTHEWS       NC   28104.0
#
#                mail_addr1 mail_addr2 mail_addr3 mail_addr4 mail_city  \
# 825812     2905 MEDLIN RD        NaN        NaN        NaN    MONROE
# 825813     2905 MEDLIN RD        NaN        NaN        NaN    MONROE
# 825814     2905 MEDLIN RD        NaN        NaN        NaN    MONROE
# 825815     2905 MEDLIN RD        NaN        NaN        NaN    MONROE
# 825816  5719 PARKSTONE DR        NaN        NaN        NaN  MATTHEWS
#
#        mail_state mail_zipcode  full_phone_number race_code ethnic_code  \
# 825812         NC        28112                NaN         W          NL
# 825813         NC        28112                NaN         W          NL
# 825814         NC        28112                NaN         W          NL
# 825815         NC        28112                NaN         W          NL
# 825816         NC        28104                NaN         W          NL
#
#        party_cd gender_code  birth_age birth_state drivers_lic  registr_dt  \
# 825812      DEM           M         68          MA           Y  08/28/2009
# 825813      DEM           M         68          MA           Y  08/28/2009
# 825814      DEM           M         68          MA           Y  08/28/2009
# 825815      DEM           M         68          MA           Y  08/28/2009
# 825816      DEM           F         51          NY           Y  03/26/2018
#
#        precinct_abbrv precinct_desc  municipality_abbrv municipality_desc  \
# 825812            025           025                 NaN               NaN
# 825813            025           025                 NaN               NaN
# 825814            025           025                 NaN               NaN
# 825815            025           025                 NaN               NaN
# 825816            040           040                 NaN               NaN
#
#         ward_abbrv  ward_desc  cong_dist_abbrv super_court_abbrv  \
# 825812         NaN        NaN              9.0               20B
# 825813         NaN        NaN              9.0               20B
# 825814         NaN        NaN              9.0               20B
# 825815         NaN        NaN              9.0               20B
# 825816         NaN        NaN              9.0               20B
#
#        judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 825812              20C             35.0            55.0
# 825813              20C             35.0            55.0
# 825814              20C             35.0            55.0
# 825815              20C             35.0            55.0
# 825816              20C             35.0            68.0
#
#         county_commiss_abbrv  county_commiss_desc  township_abbrv  \
# 825812                   NaN                  NaN             NaN
# 825813                   NaN                  NaN             NaN
# 825814                   NaN                  NaN             NaN
# 825815                   NaN                  NaN             NaN
# 825816                   NaN                  NaN             NaN
#
#         township_desc  school_dist_abbrv school_dist_desc  fire_dist_abbrv  \
# 825812            NaN                2.0        SCHOOL #2              NaN
# 825813            NaN                2.0        SCHOOL #2              NaN
# 825814            NaN                2.0        SCHOOL #2              NaN
# 825815            NaN                2.0        SCHOOL #2              NaN
# 825816            NaN                5.0        SCHOOL #5              NaN
#
#         fire_dist_desc  water_dist_abbrv  water_dist_desc  sewer_dist_abbrv  \
# 825812             NaN               NaN              NaN               NaN
# 825813             NaN               NaN              NaN               NaN
# 825814             NaN               NaN              NaN               NaN
# 825815             NaN               NaN              NaN               NaN
# 825816             NaN               NaN              NaN               NaN
#
#         sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  rescue_dist_abbrv  \
# 825812              NaN               NaN              NaN                NaN
# 825813              NaN               NaN              NaN                NaN
# 825814              NaN               NaN              NaN                NaN
# 825815              NaN               NaN              NaN                NaN
# 825816              NaN               NaN              NaN                NaN
#
#         rescue_dist_desc  munic_dist_abbrv munic_dist_desc  dist_1_abbrv  \
# 825812               NaN               NaN             NaN          30.0
# 825813               NaN               NaN             NaN          30.0
# 825814               NaN               NaN             NaN          30.0
# 825815               NaN               NaN             NaN          30.0
# 825816               NaN               NaN             NaN          30.0
#
#                dist_1_desc dist_2_abbrv dist_2_desc confidential_ind  \
# 825812  30TH PROSECUTORIAL                                         N
# 825813  30TH PROSECUTORIAL                                         N
# 825814  30TH PROSECUTORIAL                                         N
# 825815  30TH PROSECUTORIAL                                         N
# 825816  30TH PROSECUTORIAL                                         N
#
#         birth_year vtd_abbrv vtd_desc
# 825812        1952       025      025
# 825813        1952       025      025
# 825814        1952       025      025
# 825815        1952       025      025
# 825816        1968       040      040

# %%
## Check number of unique individuals represented in all records
all_uc_voters['ncid'].nunique()
# Out:
# 183969

# %%
## Check voter status information -- Should any categories be removed??
all_uc_voters['voter_status_desc'].value_counts()
# Out:
# ACTIVE       761412
# REMOVED       39285
# INACTIVE      23528
# DENIED         1354
# TEMPORARY       238
# Name: voter_status_desc, dtype: int64

# %% [markdown]
# ### Active Voters

# %%
active_voters = all_uc_voters.groupby('voter_status_desc').get_group('ACTIVE')
print(len(active_voters))
active_voters.head()
# Out:
# 761412
#    county_id county_desc  voter_reg_num election_lbl  \
# 0       90.0       UNION       346446.0   11/03/2020
# 1       90.0       UNION       348004.0   11/03/2020
# 2        NaN         NaN            NaN          NaN
# 3       90.0       UNION       288489.0   11/08/2011
# 4       90.0       UNION       288489.0   11/06/2012
#
#                   election_desc     voting_method voted_party_cd  \
# 0            11/03/2020 GENERAL  ABSENTEE ONESTOP            UNA
# 1            11/03/2020 GENERAL  ABSENTEE ONESTOP            DEM
# 2                           NaN               NaN            NaN
# 3  11/08/2011 MUNICIPAL GENERAL         IN-PERSON            UNA
# 4            11/06/2012 GENERAL  ABSENTEE ONESTOP            UNA
#
#   voted_party_desc pct_label pct_description      ncid  voted_county_id  \
# 0     UNAFFILIATED      020A            020A  EF230133             90.0
# 1       DEMOCRATIC      020A            020A  EF231096             90.0
# 2              NaN       NaN             NaN  AL261840              NaN
# 3     UNAFFILIATED      26.1            26.1  AL178177             11.0
# 4     UNAFFILIATED      26.1            26.1  AL178177             11.0
#
#   voted_county_desc vtd_label vtd_description status_cd voter_status_desc  \
# 0             UNION      020A            020A         A            ACTIVE
# 1             UNION      020A            020A         A            ACTIVE
# 2               NaN       NaN             NaN         A            ACTIVE
# 3          BUNCOMBE      26.1            26.1         A            ACTIVE
# 4          BUNCOMBE      26.1            26.1         A            ACTIVE
#
#   reason_cd voter_status_reason_desc absent_ind name_prefx_cd last_name  \
# 0        AV                 VERIFIED                             AALAEI
# 1        AV                 VERIFIED                             AALAEI
# 2        AV                 VERIFIED                            AALBORG
# 3        AV                 VERIFIED                            AALBORG
# 4        AV                 VERIFIED                            AALBORG
#
#   first_name middle_name name_suffix_lbl         res_street_address  \
# 0       ARIO         NaN             NaN   4009  MILLBRIDGE PKWY
# 1    KAVITHA         NaN             NaN   4009  MILLBRIDGE PKWY
# 2     ALEXIS       LEANN             NaN  1001  STEVENS PRIDE CT
# 3      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
# 4      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
#
#   res_city_desc state_cd  zip_code             mail_addr1 mail_addr2  \
# 0        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 1        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 2  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 3  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 4  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
#
#   mail_addr3 mail_addr4     mail_city mail_state mail_zipcode  \
# 0        NaN        NaN        WAXHAW         NC        28173
# 1        NaN        NaN        WAXHAW         NC        28173
# 2        NaN        NaN  INDIAN TRAIL         NC        28079
# 3        NaN        NaN  INDIAN TRAIL         NC        28079
# 4        NaN        NaN  INDIAN TRAIL         NC        28079
#
#    full_phone_number race_code ethnic_code party_cd gender_code  birth_age  \
# 0                NaN         W          NL      UNA           M         46
# 1                NaN         A          NL      DEM           F         46
# 2                NaN         W          NL      UNA           F         26
# 3                NaN         W          UN      UNA           M         62
# 4                NaN         W          UN      UNA           M         62
#
#   birth_state drivers_lic  registr_dt precinct_abbrv precinct_desc  \
# 0          OC           Y  04/25/2019           020A          020A
# 1          OC           Y  06/24/2019           020A          020A
# 2          IA           Y  11/04/2013           029A          029A
# 3          OK           Y  09/17/2014           029A          029A
# 4          OK           Y  09/17/2014           029A          029A
#
#    municipality_abbrv municipality_desc  ward_abbrv  ward_desc  \
# 0                 5.0            WAXHAW         NaN        NaN
# 1                 5.0            WAXHAW         NaN        NaN
# 2                 6.0      INDIAN TRAIL         NaN        NaN
# 3                 6.0      INDIAN TRAIL         NaN        NaN
# 4                 6.0      INDIAN TRAIL         NaN        NaN
#
#    cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 0              9.0               20B              20C             35.0
# 1              9.0               20B              20C             35.0
# 2              9.0               20B              20C             35.0
# 3              9.0               20B              20C             35.0
# 4              9.0               20B              20C             35.0
#
#    nc_house_abbrv  county_commiss_abbrv  county_commiss_desc  township_abbrv  \
# 0            68.0                   NaN                  NaN             NaN
# 1            68.0                   NaN                  NaN             NaN
# 2            68.0                   NaN                  NaN             NaN
# 3            68.0                   NaN                  NaN             NaN
# 4            68.0                   NaN                  NaN             NaN
#
#    township_desc  school_dist_abbrv school_dist_desc  fire_dist_abbrv  \
# 0            NaN                2.0        SCHOOL #2              NaN
# 1            NaN                2.0        SCHOOL #2              NaN
# 2            NaN                3.0        SCHOOL #3              NaN
# 3            NaN                3.0        SCHOOL #3              NaN
# 4            NaN                3.0        SCHOOL #3              NaN
#
#    fire_dist_desc  water_dist_abbrv  water_dist_desc  sewer_dist_abbrv  \
# 0             NaN               NaN              NaN               NaN
# 1             NaN               NaN              NaN               NaN
# 2             NaN               NaN              NaN               NaN
# 3             NaN               NaN              NaN               NaN
# 4             NaN               NaN              NaN               NaN
#
#    sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  rescue_dist_abbrv  \
# 0              NaN               NaN              NaN                NaN
# 1              NaN               NaN              NaN                NaN
# 2              NaN               NaN              NaN                NaN
# 3              NaN               NaN              NaN                NaN
# 4              NaN               NaN              NaN                NaN
#
#    rescue_dist_desc  munic_dist_abbrv munic_dist_desc  dist_1_abbrv  \
# 0               NaN               5.0          WAXHAW          30.0
# 1               NaN               5.0          WAXHAW          30.0
# 2               NaN               6.0    INDIAN TRAIL          30.0
# 3               NaN               6.0    INDIAN TRAIL          30.0
# 4               NaN               6.0    INDIAN TRAIL          30.0
#
#           dist_1_desc dist_2_abbrv dist_2_desc confidential_ind  birth_year  \
# 0  30TH PROSECUTORIAL                                         N        1974
# 1  30TH PROSECUTORIAL                                         N        1974
# 2  30TH PROSECUTORIAL                                         N        1994
# 3  30TH PROSECUTORIAL                                         N        1958
# 4  30TH PROSECUTORIAL                                         N        1958
#
#   vtd_abbrv vtd_desc
# 0      020A     020A
# 1      020A     020A
# 2      029A     029A
# 3      029A     029A
# 4      029A     029A

# %%
active_voters['voter_status_reason_desc'].value_counts()
# Out:
# VERIFIED                               732430
# LEGACY DATA                             22500
# UNVERIFIED                               4905
# UNVERIFIED NEW                           1101
# VERIFICATION PENDING                      284
# CONFIRMATION PENDING                       77
# CONFIRMATION RETURNED UNDELIVERABLE        61
# CONFIRMATION NOT RETURNED                  50
# ARMED FORCES                                4
# Name: voter_status_reason_desc, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(uc_vreg['birth_age'], stat='density', color='r', ax=ax)
sns.histplot(active_voters['birth_age'], stat='density', alpha=0.6, ax=ax)
ax.set_xlim(18,110)
# Out:
# (18.0, 110.0)

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='race_code', data=active_voters,
                   order=(active_voters['race_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='gender_code', data=active_voters,
                   order=(active_voters['gender_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %% [markdown]
# ### Denied Voters

# %%
denied_voters = all_uc_voters.groupby('voter_status_desc').get_group('DENIED')
print(len(denied_voters))
denied_voters.head()
# Out:
# 1354
#       county_id county_desc  voter_reg_num election_lbl election_desc  \
# 504         NaN         NaN            NaN          NaN           NaN
# 1358        NaN         NaN            NaN          NaN           NaN
# 2132        NaN         NaN            NaN          NaN           NaN
# 2373        NaN         NaN            NaN          NaN           NaN
# 2413        NaN         NaN            NaN          NaN           NaN
#
#      voting_method voted_party_cd voted_party_desc pct_label pct_description  \
# 504            NaN            NaN              NaN       NaN             NaN
# 1358           NaN            NaN              NaN       NaN             NaN
# 2132           NaN            NaN              NaN       NaN             NaN
# 2373           NaN            NaN              NaN       NaN             NaN
# 2413           NaN            NaN              NaN       NaN             NaN
#
#           ncid  voted_county_id voted_county_desc vtd_label vtd_description  \
# 504   EF174501              NaN               NaN       NaN             NaN
# 1358  EF242578              NaN               NaN       NaN             NaN
# 2132  EF156089              NaN               NaN       NaN             NaN
# 2373  EF122557              NaN               NaN       NaN             NaN
# 2413  EF210300              NaN               NaN       NaN             NaN
#
#      status_cd voter_status_desc reason_cd  \
# 504          D            DENIED        DU
# 1358         D            DENIED        DU
# 2132         D            DENIED        DU
# 2373         D            DENIED        DU
# 2413         D            DENIED        DU
#
#                  voter_status_reason_desc absent_ind name_prefx_cd  \
# 504   VERIFICATION RETURNED UNDELIVERABLE
# 1358  VERIFICATION RETURNED UNDELIVERABLE
# 2132  VERIFICATION RETURNED UNDELIVERABLE
# 2373  VERIFICATION RETURNED UNDELIVERABLE
# 2413  VERIFICATION RETURNED UNDELIVERABLE
#
#         last_name first_name middle_name name_suffix_lbl  \
# 504   ABDELRAHMAN     SAMIRA        IMAD             NaN
# 1358      ABSHERE  CHRISTINE         MAE             NaN
# 2132        ADAMO     ANGELO         NaN             NaN
# 2373        ADAMS     CHERYL      YVONNE             NaN
# 2413        ADAMS    DANIELE   ELIZABETH             NaN
#
#             res_street_address res_city_desc state_cd  zip_code  \
# 504   1007  MILLS HARRIS RD       MARSHVILLE       NC   28103.0
# 1358  1516  MILLS HARRIS RD          WINGATE       NC   28174.0
# 2132      1003  SANDBOX CIR     INDIAN TRAIL       NC   28079.0
# 2373         4909 E HWY 74           WINGATE       NC   28174.0
# 2413   3300  BROOKSTONE TRL     INDIAN TRAIL       NC   28079.0
#
#                 mail_addr1 mail_addr2 mail_addr3 mail_addr4     mail_city  \
# 504   1007 MILLS HARRIS RD        NaN        NaN        NaN    MARSHVILLE
# 1358  1516 MILLS HARRIS RD        NaN        NaN        NaN       WINGATE
# 2132      1003 SANDBOX CIR        NaN        NaN        NaN  INDIAN TRAIL
# 2373         4909 E HWY 74        NaN        NaN        NaN       WINGATE
# 2413   3300 BROOKSTONE TRL        NaN        NaN        NaN  INDIAN TRAIL
#
#      mail_state mail_zipcode  full_phone_number race_code ethnic_code  \
# 504          NC        28103                NaN         B          NL
# 1358         NC        28174                NaN         U          UN
# 2132         NC        28079                NaN         W          NL
# 2373         NC        28174                NaN         W          NL
# 2413         NC        28079                NaN         W          NL
#
#      party_cd gender_code  birth_age birth_state drivers_lic  registr_dt  \
# 504       UNA           F         28          NC           Y  07/27/2012
# 1358      REP           U         59         NaN           Y  08/06/2020
# 2132      UNA           M         76          OC           Y  05/01/2009
# 2373      UNA           F         49          TX           Y  08/03/2005
# 2413      UNA           F         31          OC           Y  10/29/2016
#
#      precinct_abbrv precinct_desc  municipality_abbrv municipality_desc  \
# 504             NaN           NaN                 NaN               NaN
# 1358            NaN           NaN                 NaN               NaN
# 2132            NaN           NaN                 NaN               NaN
# 2373            NaN           NaN                 NaN               NaN
# 2413            NaN           NaN                 NaN               NaN
#
#       ward_abbrv  ward_desc  cong_dist_abbrv super_court_abbrv  \
# 504          NaN        NaN              NaN               NaN
# 1358         NaN        NaN              NaN               NaN
# 2132         NaN        NaN              NaN               NaN
# 2373         NaN        NaN              NaN               NaN
# 2413         NaN        NaN              NaN               NaN
#
#      judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  county_commiss_abbrv  \
# 504               NaN              NaN             NaN                   NaN
# 1358              NaN              NaN             NaN                   NaN
# 2132              NaN              NaN             NaN                   NaN
# 2373              NaN              NaN             NaN                   NaN
# 2413              NaN              NaN             NaN                   NaN
#
#       county_commiss_desc  township_abbrv  township_desc  school_dist_abbrv  \
# 504                   NaN             NaN            NaN                NaN
# 1358                  NaN             NaN            NaN                NaN
# 2132                  NaN             NaN            NaN                NaN
# 2373                  NaN             NaN            NaN                NaN
# 2413                  NaN             NaN            NaN                NaN
#
#      school_dist_desc  fire_dist_abbrv  fire_dist_desc  water_dist_abbrv  \
# 504               NaN              NaN             NaN               NaN
# 1358              NaN              NaN             NaN               NaN
# 2132              NaN              NaN             NaN               NaN
# 2373              NaN              NaN             NaN               NaN
# 2413              NaN              NaN             NaN               NaN
#
#       water_dist_desc  sewer_dist_abbrv  sewer_dist_desc  sanit_dist_abbrv  \
# 504               NaN               NaN              NaN               NaN
# 1358              NaN               NaN              NaN               NaN
# 2132              NaN               NaN              NaN               NaN
# 2373              NaN               NaN              NaN               NaN
# 2413              NaN               NaN              NaN               NaN
#
#       sanit_dist_desc  rescue_dist_abbrv  rescue_dist_desc  munic_dist_abbrv  \
# 504               NaN                NaN               NaN               NaN
# 1358              NaN                NaN               NaN               NaN
# 2132              NaN                NaN               NaN               NaN
# 2373              NaN                NaN               NaN               NaN
# 2413              NaN                NaN               NaN               NaN
#
#      munic_dist_desc  dist_1_abbrv dist_1_desc dist_2_abbrv dist_2_desc  \
# 504              NaN           NaN         NaN
# 1358             NaN           NaN         NaN
# 2132             NaN           NaN         NaN
# 2373             NaN           NaN         NaN
# 2413             NaN           NaN         NaN
#
#      confidential_ind  birth_year vtd_abbrv vtd_desc
# 504                 N        1992       NaN      NaN
# 1358                N        1961       NaN      NaN
# 2132                N        1944       NaN      NaN
# 2373                N        1971       NaN      NaN
# 2413                N        1989       NaN      NaN

# %%
denied_voters['voter_status_reason_desc'].value_counts()
# Out:
# VERIFICATION RETURNED UNDELIVERABLE    1354
# Name: voter_status_reason_desc, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(uc_vreg['birth_age'], stat='density', color='r', ax=ax)
sns.histplot(denied_voters['birth_age'], stat='density', alpha=0.6, ax=ax)
ax.set_xlim(18,110)
# Out:
# (18.0, 110.0)

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='race_code', data=denied_voters,
                   order=(denied_voters['race_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='gender_code', data=denied_voters,
                   order=(denied_voters['gender_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %% [markdown]
# ### Inactive Voters

# %%
inactive_voters = all_uc_voters.groupby('voter_status_desc').get_group('INACTIVE')
print(len(inactive_voters))
inactive_voters.head()
# Out:
# 23528
#      county_id county_desc  voter_reg_num election_lbl       election_desc  \
# 87         NaN         NaN            NaN          NaN                 NaN
# 109        NaN         NaN            NaN          NaN                 NaN
# 145       90.0       UNION       200444.0   11/06/2012  11/06/2012 GENERAL
# 347       90.0       UNION       240783.0   11/06/2012  11/06/2012 GENERAL
# 362       90.0       UNION       236007.0   11/06/2018  11/06/2018 GENERAL
#
#         voting_method voted_party_cd voted_party_desc pct_label  \
# 87                NaN            NaN              NaN       NaN
# 109               NaN            NaN              NaN       NaN
# 145  ABSENTEE ONESTOP            UNA     UNAFFILIATED       013
# 347         IN-PERSON            UNA     UNAFFILIATED      020A
# 362         IN-PERSON            UNA     UNAFFILIATED       031
#
#     pct_description      ncid  voted_county_id voted_county_desc vtd_label  \
# 87              NaN  EF187881              NaN               NaN       NaN
# 109             NaN  EF201789              NaN               NaN       NaN
# 145             013  EF123802             90.0             UNION       013
# 347            020A  EF155408             90.0             UNION      020A
# 362             031  EF151749             90.0             UNION       031
#
#     vtd_description status_cd voter_status_desc reason_cd  \
# 87              NaN         I          INACTIVE        IN
# 109             NaN         I          INACTIVE        IN
# 145             013         I          INACTIVE        IN
# 347            020A         I          INACTIVE        IN
# 362             031         I          INACTIVE        IN
#
#       voter_status_reason_desc absent_ind name_prefx_cd       last_name  \
# 87   CONFIRMATION NOT RETURNED                                     ABAR
# 109  CONFIRMATION NOT RETURNED                           ABARCA-NICOLAS
# 145  CONFIRMATION NOT RETURNED                                    ABBAS
# 347  CONFIRMATION NOT RETURNED                                   ABBOTT
# 362  CONFIRMATION NOT RETURNED                                   ABBOTT
#
#     first_name middle_name name_suffix_lbl             res_street_address  \
# 87     KRISTEN      ELAINE             NaN             5523  CHERAW RD
# 109       JOSE     ALBERTO             NaN               616  JONES ST
# 145       OMAR     MOHAMED             NaN  2206  HONEYCUTT SIMPSON RD
# 347       MARY         SUE             NaN              4122  EUTAW DR
# 362       NEIL         NaN             NaN           5127  CRUZ BAY DR
#
#     res_city_desc state_cd  zip_code                 mail_addr1 mail_addr2  \
# 87     MARSHVILLE       NC   28103.0             5523 CHERAW RD        NaN
# 109        MONROE       NC   28110.0               616 JONES ST        NaN
# 145        MONROE       NC   28110.0  2206 HONEYCUTT SIMPSON RD        NaN
# 347        WAXHAW       NC   28173.0              4122 EUTAW DR        NaN
# 362        MONROE       NC   28110.0           5127 CRUZ BAY DR        NaN
#
#     mail_addr3 mail_addr4   mail_city mail_state mail_zipcode  \
# 87         NaN        NaN  MARSHVILLE         NC        28103
# 109        NaN        NaN      MONROE         NC        28110
# 145        NaN        NaN      MONROE         NC        28110
# 347        NaN        NaN      WAXHAW         NC        28173
# 362        NaN        NaN      MONROE         NC        28110
#
#      full_phone_number race_code ethnic_code party_cd gender_code  birth_age  \
# 87                 NaN         W          NL      DEM           F         24
# 109                NaN         O          NL      UNA           M         22
# 145                NaN         O          UN      UNA           M         33
# 347                NaN         W          NL      UNA           F         40
# 362                NaN         W          UN      UNA           U         41
#
#     birth_state drivers_lic  registr_dt precinct_abbrv precinct_desc  \
# 87           NC           Y  02/17/2014            026           026
# 109          NC           Y  04/26/2016            004           004
# 145          NJ           Y  10/03/2005            013           013
# 347          WV           Y  03/04/2009           020A          020A
# 362         NaN           Y  10/10/2008            031           031
#
#      municipality_abbrv municipality_desc  ward_abbrv  ward_desc  \
# 87                  NaN               NaN         NaN        NaN
# 109                 2.0            MONROE         NaN        NaN
# 145                98.0        UNIONVILLE         NaN        NaN
# 347                 5.0            WAXHAW         NaN        NaN
# 362                 NaN               NaN         NaN        NaN
#
#      cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 87               9.0               20B              20C             35.0
# 109              9.0               20B              20B             35.0
# 145              9.0               20B              20B             35.0
# 347              9.0               20B              20C             35.0
# 362              9.0               20B              20C             35.0
#
#      nc_house_abbrv  county_commiss_abbrv  county_commiss_desc  \
# 87             55.0                   NaN                  NaN
# 109            69.0                   NaN                  NaN
# 145            69.0                   NaN                  NaN
# 347            68.0                   NaN                  NaN
# 362            55.0                   NaN                  NaN
#
#      township_abbrv  township_desc  school_dist_abbrv school_dist_desc  \
# 87              NaN            NaN                2.0        SCHOOL #2
# 109             NaN            NaN                1.0        SCHOOL #1
# 145             NaN            NaN                4.0        SCHOOL #4
# 347             NaN            NaN                2.0        SCHOOL #2
# 362             NaN            NaN                3.0        SCHOOL #3
#
#      fire_dist_abbrv  fire_dist_desc  water_dist_abbrv  water_dist_desc  \
# 87               NaN             NaN               NaN              NaN
# 109              NaN             NaN               NaN              NaN
# 145              NaN             NaN               NaN              NaN
# 347              NaN             NaN               NaN              NaN
# 362              NaN             NaN               NaN              NaN
#
#      sewer_dist_abbrv  sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  \
# 87                NaN              NaN               NaN              NaN
# 109               NaN              NaN               NaN              NaN
# 145               NaN              NaN               NaN              NaN
# 347               NaN              NaN               NaN              NaN
# 362               NaN              NaN               NaN              NaN
#
#      rescue_dist_abbrv  rescue_dist_desc  munic_dist_abbrv munic_dist_desc  \
# 87                 NaN               NaN               NaN             NaN
# 109                NaN               NaN               2.0          MONROE
# 145                NaN               NaN              98.0      UNIONVILLE
# 347                NaN               NaN               5.0          WAXHAW
# 362                NaN               NaN               NaN             NaN
#
#      dist_1_abbrv         dist_1_desc dist_2_abbrv dist_2_desc  \
# 87           30.0  30TH PROSECUTORIAL
# 109          30.0  30TH PROSECUTORIAL
# 145          30.0  30TH PROSECUTORIAL
# 347          30.0  30TH PROSECUTORIAL
# 362          30.0  30TH PROSECUTORIAL
#
#     confidential_ind  birth_year vtd_abbrv vtd_desc
# 87                 N        1996       026      026
# 109                N        1998       004      004
# 145                N        1987       013      013
# 347                N        1980      020A     020A
# 362                N        1979       031      031

# %%
inactive_voters['voter_status_reason_desc'].value_counts()
# Out:
# CONFIRMATION NOT RETURNED              12980
# CONFIRMATION RETURNED UNDELIVERABLE    10547
# ADMINISTRATIVE                             1
# Name: voter_status_reason_desc, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='voted_party_cd', data=inactive_voters,
                   order=(inactive_voters[
                       'voted_party_cd'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='gender_code', data=inactive_voters,
                   order=(inactive_voters['gender_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='race_code', data=inactive_voters,
                   order=(inactive_voters['race_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(uc_vreg['birth_age'], stat='density', color='r', ax=ax)
sns.histplot(inactive_voters['birth_age'], stat='density', alpha=0.6, ax=ax)
ax.set_xlim(18,110)
# Out:
# (18.0, 110.0)

# %% [markdown]
# ### Removed Voters

# %%
removed_voters = all_uc_voters.groupby('voter_status_desc').get_group('REMOVED')
print(len(removed_voters))
removed_voters.head()
# Out:
# 39285
#      county_id county_desc  voter_reg_num election_lbl       election_desc  \
# 85        90.0       UNION       259695.0   11/06/2012  11/06/2012 GENERAL
# 86        90.0       UNION       259695.0   11/04/2014  11/04/2014 GENERAL
# 214       90.0       UNION       243470.0   11/06/2012  11/06/2012 GENERAL
# 256       90.0       UNION       190348.0   11/06/2012  11/06/2012 GENERAL
# 257       90.0       UNION       190348.0   11/04/2014  11/04/2014 GENERAL
#
#         voting_method voted_party_cd voted_party_desc pct_label  \
# 85          IN-PERSON            REP       REPUBLICAN       006
# 86          IN-PERSON            REP       REPUBLICAN       024
# 214         IN-PERSON            REP       REPUBLICAN      028B
# 256  ABSENTEE ONESTOP            REP       REPUBLICAN       019
# 257  ABSENTEE ONESTOP            REP       REPUBLICAN       019
#
#     pct_description      ncid  voted_county_id voted_county_desc vtd_label  \
# 85              006  EF170044             90.0             UNION       006
# 86              024  EF170044             90.0             UNION       024
# 214            028B  EF157603             90.0             UNION       028
# 256             019  EF113706             90.0             UNION       019
# 257             019  EF113706             90.0             UNION       019
#
#     vtd_description status_cd voter_status_desc reason_cd  \
# 85              006         R           REMOVED        RM
# 86              024         R           REMOVED        RM
# 214             028         R           REMOVED        RL
# 256             019         R           REMOVED        RS
# 257             019         R           REMOVED        RS
#
#                               voter_status_reason_desc absent_ind  \
# 85   REMOVED AFTER 2 FED GENERAL ELECTIONS IN INACT...
# 86   REMOVED AFTER 2 FED GENERAL ELECTIONS IN INACT...
# 214                                  MOVED FROM COUNTY
# 256                                   MOVED FROM STATE
# 257                                   MOVED FROM STATE
#
#     name_prefx_cd last_name first_name middle_name name_suffix_lbl  \
# 85                     ABAR      JAMES   FREDERICK
# 86                     ABAR      JAMES   FREDERICK
# 214                   ABBEN     LAURIN     DOROTHY
# 256                  ABBOTT       ALAN      WALTER
# 257                  ABBOTT       ALAN      WALTER
#
#     res_street_address res_city_desc state_cd  zip_code mail_addr1 mail_addr2  \
# 85             REMOVED           NaN      NaN       NaN
# 86             REMOVED           NaN      NaN       NaN
# 214            REMOVED           NaN      NaN       NaN
# 256            REMOVED           NaN      NaN       NaN
# 257            REMOVED           NaN      NaN       NaN
#
#     mail_addr3 mail_addr4 mail_city mail_state mail_zipcode  \
# 85
# 86
# 214
# 256
# 257
#
#      full_phone_number race_code ethnic_code party_cd gender_code  birth_age  \
# 85                 NaN         W          NL      REP           M         49
# 86                 NaN         W          NL      REP           M         49
# 214                NaN         W          NL      REP           F         29
# 256                NaN         W          NL      REP           M         52
# 257                NaN         W          NL      REP           M         52
#
#     birth_state drivers_lic  registr_dt precinct_abbrv precinct_desc  \
# 85           MI           Y  02/09/2012            NaN           NaN
# 86           MI           Y  02/09/2012            NaN           NaN
# 214          FL           N  09/01/2009            NaN           NaN
# 256          NY           Y  09/15/2004            NaN           NaN
# 257          NY           Y  09/15/2004            NaN           NaN
#
#      municipality_abbrv municipality_desc  ward_abbrv  ward_desc  \
# 85                  NaN               NaN         NaN        NaN
# 86                  NaN               NaN         NaN        NaN
# 214                 NaN               NaN         NaN        NaN
# 256                 NaN               NaN         NaN        NaN
# 257                 NaN               NaN         NaN        NaN
#
#      cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 85               NaN               NaN              NaN              NaN
# 86               NaN               NaN              NaN              NaN
# 214              NaN               NaN              NaN              NaN
# 256              NaN               NaN              NaN              NaN
# 257              NaN               NaN              NaN              NaN
#
#      nc_house_abbrv  county_commiss_abbrv  county_commiss_desc  \
# 85              NaN                   NaN                  NaN
# 86              NaN                   NaN                  NaN
# 214             NaN                   NaN                  NaN
# 256             NaN                   NaN                  NaN
# 257             NaN                   NaN                  NaN
#
#      township_abbrv  township_desc  school_dist_abbrv school_dist_desc  \
# 85              NaN            NaN                NaN              NaN
# 86              NaN            NaN                NaN              NaN
# 214             NaN            NaN                NaN              NaN
# 256             NaN            NaN                NaN              NaN
# 257             NaN            NaN                NaN              NaN
#
#      fire_dist_abbrv  fire_dist_desc  water_dist_abbrv  water_dist_desc  \
# 85               NaN             NaN               NaN              NaN
# 86               NaN             NaN               NaN              NaN
# 214              NaN             NaN               NaN              NaN
# 256              NaN             NaN               NaN              NaN
# 257              NaN             NaN               NaN              NaN
#
#      sewer_dist_abbrv  sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  \
# 85                NaN              NaN               NaN              NaN
# 86                NaN              NaN               NaN              NaN
# 214               NaN              NaN               NaN              NaN
# 256               NaN              NaN               NaN              NaN
# 257               NaN              NaN               NaN              NaN
#
#      rescue_dist_abbrv  rescue_dist_desc  munic_dist_abbrv munic_dist_desc  \
# 85                 NaN               NaN               NaN             NaN
# 86                 NaN               NaN               NaN             NaN
# 214                NaN               NaN               NaN             NaN
# 256                NaN               NaN               NaN             NaN
# 257                NaN               NaN               NaN             NaN
#
#      dist_1_abbrv dist_1_desc dist_2_abbrv dist_2_desc confidential_ind  \
# 85            NaN         NaN                                         N
# 86            NaN         NaN                                         N
# 214           NaN         NaN                                         N
# 256           NaN         NaN                                         N
# 257           NaN         NaN                                         N
#
#      birth_year vtd_abbrv vtd_desc
# 85         1971       NaN      NaN
# 86         1971       NaN      NaN
# 214        1991       NaN      NaN
# 256        1968       NaN      NaN
# 257        1968       NaN      NaN

# %%
removed_voters['voter_status_reason_desc'].value_counts()
# Out:
# DECEASED                                                    21403
# MOVED FROM STATE                                            11032
# MOVED FROM COUNTY                                            3170
# REMOVED AFTER 2 FED GENERAL ELECTIONS IN INACTIVE STATUS     2230
# REQUEST FROM VOTER                                            518
# MOVED WITHIN STATE                                            329
# FELONY CONVICTION                                             234
# FELONY SENTENCE COMPLETED                                     217
# TEMPORARY REGISTRANT                                           93
# DUPLICATE                                                      45
# ADMINISTRATIVE                                                 14
# Name: voter_status_reason_desc, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='voter_status_reason_desc', data=removed_voters,
                   order=(removed_voters[
                       'voter_status_reason_desc'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='voted_party_cd', data=removed_voters,
                   order=(removed_voters[
                       'voted_party_cd'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='gender_code', data=removed_voters,
                   order=(removed_voters['gender_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(11,8))
ax = sns.countplot(x='race_code', data=removed_voters,
                   order=(removed_voters['race_code'].value_counts().index))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(uc_vreg['birth_age'], stat='density', color='r', ax=ax)
sns.histplot(removed_voters['birth_age'], stat='density', alpha=0.6, ax=ax)
ax.set_xlim(18,110)
# Out:
# (18.0, 110.0)

# %% [markdown]
# ## Drop 'Removed' and 'Denied' Voters - Further Exploration

# %%
## Drop voters who have been removed or had their registration denied
uc_voters = all_uc_voters.loc[all_uc_voters['voter_status_desc'] != 'REMOVED']
uc_voters = uc_voters.loc[uc_voters['voter_status_desc'] != 'DENIED']
# uc_voters.info()

# %%
## Check remaining number of unique individuals represented in the data
uc_voters['ncid'].nunique()
# Out:
# 169252

# %%
## Find record(s) with the most missing information
print(uc_voters.isna().mean(axis=1).max())
uc_voters.loc[uc_voters.isna().mean(axis=1).idxmax()]
# Max amount of missing values per row = 50%
# Example below is for an individual who has no voting history
# Out:
# 0.5
# county_id                                     NaN
# county_desc                                   NaN
# voter_reg_num                                 NaN
# election_lbl                                  NaN
# election_desc                                 NaN
# voting_method                                 NaN
# voted_party_cd                                NaN
# voted_party_desc                              NaN
# pct_label                                     NaN
# pct_description                               NaN
# ncid                                     EF229843
# voted_county_id                               NaN
# voted_county_desc                             NaN
# vtd_label                                     NaN
# vtd_description                               NaN
# status_cd                                       A
# voter_status_desc                          ACTIVE
# reason_cd                                      AV
# voter_status_reason_desc                 VERIFIED
# absent_ind
# name_prefx_cd
# last_name                                AGUILERA
# first_name                                 MOISES
# middle_name                                   NaN
# name_suffix_lbl                               NaN
# res_street_address          1008  CRESCENT WAY
# res_city_desc                             WINGATE
# state_cd                                       NC
# zip_code                                    28174
# mail_addr1                      1008 CRESCENT WAY
# mail_addr2                                    NaN
# mail_addr3                                    NaN
# mail_addr4                                    NaN
# mail_city                                 WINGATE
# mail_state                                     NC
# mail_zipcode                                28174
# full_phone_number                             NaN
# race_code                                       U
# ethnic_code                                    HL
# party_cd                                      DEM
# gender_code                                     M
# birth_age                                      47
# birth_state                                   NaN
# drivers_lic                                     N
# registr_dt                             04/08/2019
# precinct_abbrv                                034
# precinct_desc                                 034
# municipality_abbrv                            NaN
# municipality_desc                             NaN
# ward_abbrv                                    NaN
# ward_desc                                     NaN
# cong_dist_abbrv                                 9
# super_court_abbrv                             20B
# judic_dist_abbrv                              20B
# nc_senate_abbrv                                35
# nc_house_abbrv                                 69
# county_commiss_abbrv                          NaN
# county_commiss_desc                           NaN
# township_abbrv                                NaN
# township_desc                                 NaN
# school_dist_abbrv                               1
# school_dist_desc                        SCHOOL #1
# fire_dist_abbrv                               NaN
# fire_dist_desc                                NaN
# water_dist_abbrv                              NaN
# water_dist_desc                               NaN
# sewer_dist_abbrv                              NaN
# sewer_dist_desc                               NaN
# sanit_dist_abbrv                              NaN
# sanit_dist_desc                               NaN
# rescue_dist_abbrv                             NaN
# rescue_dist_desc                              NaN
# munic_dist_abbrv                              NaN
# munic_dist_desc                               NaN
# dist_1_abbrv                                   30
# dist_1_desc                    30TH PROSECUTORIAL
# dist_2_abbrv
# dist_2_desc
# confidential_ind                                N
# birth_year                                   1973
# vtd_abbrv                                     034
# vtd_desc                                      034
# Name: 4825, dtype: object

# %%
## The majority of records have at least 2/3 of the information
uc_voters.isna().mean(axis=1).value_counts().sort_index(ascending=False)
## No records are perfectly complete due to several unused columns
# Out:
# 0.500000       104
# 0.487805      1023
# 0.475610      4126
# 0.463415       200
# 0.451220       412
# 0.439024      2726
# 0.426829      8993
# 0.414634       480
# 0.402439         7
# 0.390244         3
# 0.378049         1
# 0.353659         4
# 0.341463        31
# 0.329268      3825
# 0.317073     67947
# 0.304878    159146
# 0.292683      9134
# 0.280488     10719
# 0.268293    144012
# 0.256098    346741
# 0.243902     19716
# 0.231707      4012
# 0.219512      1706
# 0.207317       110
# dtype: int64

# %%
## Check the number of records corresponding to the top 15 elections
elec_counts_df = uc_voters['election_desc'].value_counts().to_frame()
elec_counts_df.iloc[:15]
# Out:
#                                   election_desc
# 11/03/2020 GENERAL                       131416
# 11/08/2016 GENERAL                       102352
# 11/06/2012 GENERAL                        86577
# 11/06/2018 GENERAL                        86162
# 09/10/2019 GENERAL                        59172
# 11/04/2014 GENERAL                        54937
# 03/15/2016 PRIMARY                        44139
# 03/03/2020 PRIMARY                        43285
# 05/08/2012 PRIMARY                        36411
# 05/08/2018 PRIMARY                        17575
# 05/06/2014 PRIMARY                        14227
# 05/14/2019 PRIMARY                        12509
# 11/05/2019 MUNICIPAL                      12433
# 06/07/2016 CONGRESSIONAL PRIMARY          11659
# 11/07/2017 MUNICIPAL                      10749

# %% [markdown]
# ## Engineer Features for Grouping/ Database Manipulation

# %%
## Create a new column specifying the election category based on the
  ## election description col
uc_voters.insert(loc=5, column='election_cat', 
                 value=uc_voters['election_desc'].str.split(n=1,
                                                            expand=True)[1])
# If the category was general or primary, leave as is, otherwise 'other'
uc_voters['election_cat'] = np.where(uc_voters['election_cat'].isin(
                                                    ['GENERAL', 'PRIMARY']),
                                     uc_voters['election_cat'], 'other')

# %%
## Recast election_lbl as datetime and create a new col for just the year
uc_voters['election_lbl'] = pd.to_datetime(uc_voters['election_lbl'])
uc_voters.insert(loc=5, column='election_yr',
                 value=uc_voters['election_lbl'].dt.year)

# %%
## Create a new binary variable indicating if it was a major election
uc_voters.insert(loc=7, column='major_elec',
                 value=np.where(((uc_voters['election_yr']%2 == 0) & 
                                 (uc_voters['election_cat'].isin(
                                     ['GENERAL', 'PRIMARY']))),
                                1,0))

## Create a new binary variable indicating if it was a presidential election
uc_voters.insert(loc=8, column='presid_elec',
                 value=np.where(((uc_voters['election_yr']%4 == 0) & 
                                 (uc_voters['election_cat'].isin(
                                     ['GENERAL', 'PRIMARY']))),
                                1,0))

# %%
## Group original vote methods into more general categories in a new variable
# Map the original categoriess to new ones
vote_method_map = {'ABSENTEE ONESTOP': 'Early',
                   'IN-PERSON': 'Election Day',
                   'ABSENTEE BY MAIL': 'Early',
                   'ABSENTEE CURBSIDE': 'Early',
                   'TRANSFER': 'Other',
                   'PROVISIONAL': 'Other',
                   'CURBSIDE': 'Election Day'}

# Apply the map to create new vote_method_cat column
uc_voters.insert(loc=10, column='vote_method_cat',
                 value=uc_voters['voting_method'].map(vote_method_map))

# %%
## Null values in the election_desc col indicate individuals that are 
  ## registered to vote, but have not voted in a recent major election.
    ## Thus, election_cat, major_elec, and presid_elec 
    ## are irrelevant for these records
# Fill irrelevant fields with null values
uc_voters.loc[uc_voters['election_desc'].isna(),
              ['election_cat', 'major_elec',
               'presid_elec']] = np.nan

# Fill with NaN with 'None' in election_desc col to preserve info for
  # registered voters without a voting history when merging df's based on 
    # ncid and election_desc below
uc_voters['election_desc'].fillna('None', inplace=True)

# Inspect updated dataframe
uc_voters.head()
# Out:
#    county_id county_desc  voter_reg_num election_lbl  \
# 0       90.0       UNION       346446.0   2020-11-03
# 1       90.0       UNION       348004.0   2020-11-03
# 2        NaN         NaN            NaN          NaT
# 3       90.0       UNION       288489.0   2011-11-08
# 4       90.0       UNION       288489.0   2012-11-06
#
#                   election_desc  election_yr election_cat  major_elec  \
# 0            11/03/2020 GENERAL       2020.0      GENERAL         1.0
# 1            11/03/2020 GENERAL       2020.0      GENERAL         1.0
# 2                          None          NaN          NaN         NaN
# 3  11/08/2011 MUNICIPAL GENERAL       2011.0        other         0.0
# 4            11/06/2012 GENERAL       2012.0      GENERAL         1.0
#
#    presid_elec     voting_method vote_method_cat voted_party_cd  \
# 0          1.0  ABSENTEE ONESTOP           Early            UNA
# 1          1.0  ABSENTEE ONESTOP           Early            DEM
# 2          NaN               NaN             NaN            NaN
# 3          0.0         IN-PERSON    Election Day            UNA
# 4          1.0  ABSENTEE ONESTOP           Early            UNA
#
#   voted_party_desc pct_label pct_description      ncid  voted_county_id  \
# 0     UNAFFILIATED      020A            020A  EF230133             90.0
# 1       DEMOCRATIC      020A            020A  EF231096             90.0
# 2              NaN       NaN             NaN  AL261840              NaN
# 3     UNAFFILIATED      26.1            26.1  AL178177             11.0
# 4     UNAFFILIATED      26.1            26.1  AL178177             11.0
#
#   voted_county_desc vtd_label vtd_description status_cd voter_status_desc  \
# 0             UNION      020A            020A         A            ACTIVE
# 1             UNION      020A            020A         A            ACTIVE
# 2               NaN       NaN             NaN         A            ACTIVE
# 3          BUNCOMBE      26.1            26.1         A            ACTIVE
# 4          BUNCOMBE      26.1            26.1         A            ACTIVE
#
#   reason_cd voter_status_reason_desc absent_ind name_prefx_cd last_name  \
# 0        AV                 VERIFIED                             AALAEI
# 1        AV                 VERIFIED                             AALAEI
# 2        AV                 VERIFIED                            AALBORG
# 3        AV                 VERIFIED                            AALBORG
# 4        AV                 VERIFIED                            AALBORG
#
#   first_name middle_name name_suffix_lbl         res_street_address  \
# 0       ARIO         NaN             NaN   4009  MILLBRIDGE PKWY
# 1    KAVITHA         NaN             NaN   4009  MILLBRIDGE PKWY
# 2     ALEXIS       LEANN             NaN  1001  STEVENS PRIDE CT
# 3      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
# 4      BRYAN         LEE             NaN  1001  STEVENS PRIDE CT
#
#   res_city_desc state_cd  zip_code             mail_addr1 mail_addr2  \
# 0        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 1        WAXHAW       NC   28173.0   4009 MILLBRIDGE PKWY        NaN
# 2  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 3  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
# 4  INDIAN TRAIL       NC   28079.0  1001 STEVENS PRIDE CT        NaN
#
#   mail_addr3 mail_addr4     mail_city mail_state mail_zipcode  \
# 0        NaN        NaN        WAXHAW         NC        28173
# 1        NaN        NaN        WAXHAW         NC        28173
# 2        NaN        NaN  INDIAN TRAIL         NC        28079
# 3        NaN        NaN  INDIAN TRAIL         NC        28079
# 4        NaN        NaN  INDIAN TRAIL         NC        28079
#
#    full_phone_number race_code ethnic_code party_cd gender_code  birth_age  \
# 0                NaN         W          NL      UNA           M         46
# 1                NaN         A          NL      DEM           F         46
# 2                NaN         W          NL      UNA           F         26
# 3                NaN         W          UN      UNA           M         62
# 4                NaN         W          UN      UNA           M         62
#
#   birth_state drivers_lic  registr_dt precinct_abbrv precinct_desc  \
# 0          OC           Y  04/25/2019           020A          020A
# 1          OC           Y  06/24/2019           020A          020A
# 2          IA           Y  11/04/2013           029A          029A
# 3          OK           Y  09/17/2014           029A          029A
# 4          OK           Y  09/17/2014           029A          029A
#
#    municipality_abbrv municipality_desc  ward_abbrv  ward_desc  \
# 0                 5.0            WAXHAW         NaN        NaN
# 1                 5.0            WAXHAW         NaN        NaN
# 2                 6.0      INDIAN TRAIL         NaN        NaN
# 3                 6.0      INDIAN TRAIL         NaN        NaN
# 4                 6.0      INDIAN TRAIL         NaN        NaN
#
#    cong_dist_abbrv super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  \
# 0              9.0               20B              20C             35.0
# 1              9.0               20B              20C             35.0
# 2              9.0               20B              20C             35.0
# 3              9.0               20B              20C             35.0
# 4              9.0               20B              20C             35.0
#
#    nc_house_abbrv  county_commiss_abbrv  county_commiss_desc  township_abbrv  \
# 0            68.0                   NaN                  NaN             NaN
# 1            68.0                   NaN                  NaN             NaN
# 2            68.0                   NaN                  NaN             NaN
# 3            68.0                   NaN                  NaN             NaN
# 4            68.0                   NaN                  NaN             NaN
#
#    township_desc  school_dist_abbrv school_dist_desc  fire_dist_abbrv  \
# 0            NaN                2.0        SCHOOL #2              NaN
# 1            NaN                2.0        SCHOOL #2              NaN
# 2            NaN                3.0        SCHOOL #3              NaN
# 3            NaN                3.0        SCHOOL #3              NaN
# 4            NaN                3.0        SCHOOL #3              NaN
#
#    fire_dist_desc  water_dist_abbrv  water_dist_desc  sewer_dist_abbrv  \
# 0             NaN               NaN              NaN               NaN
# 1             NaN               NaN              NaN               NaN
# 2             NaN               NaN              NaN               NaN
# 3             NaN               NaN              NaN               NaN
# 4             NaN               NaN              NaN               NaN
#
#    sewer_dist_desc  sanit_dist_abbrv  sanit_dist_desc  rescue_dist_abbrv  \
# 0              NaN               NaN              NaN                NaN
# 1              NaN               NaN              NaN                NaN
# 2              NaN               NaN              NaN                NaN
# 3              NaN               NaN              NaN                NaN
# 4              NaN               NaN              NaN                NaN
#
#    rescue_dist_desc  munic_dist_abbrv munic_dist_desc  dist_1_abbrv  \
# 0               NaN               5.0          WAXHAW          30.0
# 1               NaN               5.0          WAXHAW          30.0
# 2               NaN               6.0    INDIAN TRAIL          30.0
# 3               NaN               6.0    INDIAN TRAIL          30.0
# 4               NaN               6.0    INDIAN TRAIL          30.0
#
#           dist_1_desc dist_2_abbrv dist_2_desc confidential_ind  birth_year  \
# 0  30TH PROSECUTORIAL                                         N        1974
# 1  30TH PROSECUTORIAL                                         N        1974
# 2  30TH PROSECUTORIAL                                         N        1994
# 3  30TH PROSECUTORIAL                                         N        1958
# 4  30TH PROSECUTORIAL                                         N        1958
#
#   vtd_abbrv vtd_desc
# 0      020A     020A
# 1      020A     020A
# 2      029A     029A
# 3      029A     029A
# 4      029A     029A

# %%
## Check number of unique individuals represented by the data
uc_voters['ncid'].nunique()
# Out:
# 169252

# %%
## Store index of non-major and non-null election types
other_elec_idx = uc_voters.loc[uc_voters['election_cat']=='other'].index

## Create a df containing only major and null elections
major_elec_df = uc_voters.drop(index=other_elec_idx)

# Check number of unique individuals that voted in a recent major election, 
  # plus those with no voting history
print(major_elec_df['ncid'].nunique())

# 131 registered voters voted in a non-major election, but no major elections
uc_voters['ncid'].nunique() - major_elec_df['ncid'].nunique()
# Out:
# 169121
# 131

# %% [markdown]
# ## Merge DataFrames - Focus on Recent Major Elections

# %%
## Get list of unique ncids
uc_ncid_list = list(uc_voters['ncid'].unique())

## Get list of unique election descriptions
major_elections = list(uc_voters.groupby('major_elec').get_group(1)['election_desc'].unique())

## Add 'None' to the list to capture individuals that have not voted in any 
  ## recent major election when merging dataframes on ncid and election_desc
elec_desc_list = major_elections + ['None']
elec_desc_list
# Out:
# ['11/03/2020 GENERAL',
#  '11/06/2012 GENERAL',
#  '05/08/2012 PRIMARY',
#  '03/15/2016 PRIMARY',
#  '11/06/2018 GENERAL',
#  '11/08/2016 GENERAL',
#  '11/04/2014 GENERAL',
#  '03/03/2020 PRIMARY',
#  '05/08/2018 PRIMARY',
#  '05/06/2014 PRIMARY',
#  'None']

# %%
## Create multiindex that lists every election for every registered voter
mltidx = pd.MultiIndex.from_tuples(
    [(ncid, elec) for ncid in uc_ncid_list for elec in elec_desc_list],
    names=['ncid', 'election_desc'])

## Use multiindex to create new dataframe
elecs_by_voter = pd.DataFrame(index=mltidx)

# %%
## Check length and inspect structure of new dataframe
print(len(elecs_by_voter))
elecs_by_voter.head(15)
# Out:
# 1861772
# Empty DataFrame
# Columns: []
# Index: [(EF230133, 11/03/2020 GENERAL), (EF230133, 11/06/2012 GENERAL), (EF230133, 05/08/2012 PRIMARY), (EF230133, 03/15/2016 PRIMARY), (EF230133, 11/06/2018 GENERAL), (EF230133, 11/08/2016 GENERAL), (EF230133, 11/04/2014 GENERAL), (EF230133, 03/03/2020 PRIMARY), (EF230133, 05/08/2018 PRIMARY), (EF230133, 05/06/2014 PRIMARY), (EF230133, None), (EF231096, 11/03/2020 GENERAL), (EF231096, 11/06/2012 GENERAL), (EF231096, 05/08/2012 PRIMARY), (EF231096, 03/15/2016 PRIMARY)]

# %%
## Merge voter histories using the created multiindex as the keys to join
  ## each ncid onto every election and 'None'
voter_elecs = elecs_by_voter.merge(uc_vhis, how='left',
                                   on=['ncid', 'election_desc'])
# Inspect new df
print(len(voter_elecs))
display(voter_elecs.head())
voter_elecs.tail()
# Out:
# 1861781
#        ncid       election_desc  county_id county_desc  voter_reg_num  \
# 0  EF230133  11/03/2020 GENERAL       90.0       UNION       346446.0
# 1  EF230133  11/06/2012 GENERAL        NaN         NaN            NaN
# 2  EF230133  05/08/2012 PRIMARY        NaN         NaN            NaN
# 3  EF230133  03/15/2016 PRIMARY        NaN         NaN            NaN
# 4  EF230133  11/06/2018 GENERAL        NaN         NaN            NaN
#
#   election_lbl     voting_method voted_party_cd voted_party_desc pct_label  \
# 0   11/03/2020  ABSENTEE ONESTOP            UNA     UNAFFILIATED      020A
# 1          NaN               NaN            NaN              NaN       NaN
# 2          NaN               NaN            NaN              NaN       NaN
# 3          NaN               NaN            NaN              NaN       NaN
# 4          NaN               NaN            NaN              NaN       NaN
#
#   pct_description  voted_county_id voted_county_desc vtd_label vtd_description
# 0            020A             90.0             UNION      020A            020A
# 1             NaN              NaN               NaN       NaN             NaN
# 2             NaN              NaN               NaN       NaN             NaN
# 3             NaN              NaN               NaN       NaN             NaN
# 4             NaN              NaN               NaN       NaN             NaN
#              ncid       election_desc  county_id county_desc  voter_reg_num  \
# 1861776  EF219265  11/04/2014 GENERAL        NaN         NaN            NaN
# 1861777  EF219265  03/03/2020 PRIMARY        NaN         NaN            NaN
# 1861778  EF219265  05/08/2018 PRIMARY        NaN         NaN            NaN
# 1861779  EF219265  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1861780  EF219265                None        NaN         NaN            NaN
#
#         election_lbl voting_method voted_party_cd voted_party_desc pct_label  \
# 1861776          NaN           NaN            NaN              NaN       NaN
# 1861777          NaN           NaN            NaN              NaN       NaN
# 1861778          NaN           NaN            NaN              NaN       NaN
# 1861779          NaN           NaN            NaN              NaN       NaN
# 1861780          NaN           NaN            NaN              NaN       NaN
#
#         pct_description  voted_county_id voted_county_desc vtd_label  \
# 1861776             NaN              NaN               NaN       NaN
# 1861777             NaN              NaN               NaN       NaN
# 1861778             NaN              NaN               NaN       NaN
# 1861779             NaN              NaN               NaN       NaN
# 1861780             NaN              NaN               NaN       NaN
#
#         vtd_description
# 1861776             NaN
# 1861777             NaN
# 1861778             NaN
# 1861779             NaN
# 1861780             NaN

# %%
## Check for duplicate rows
voter_elecs.duplicated().sum()
# Out:
# 0

# %%
## Create a list of columns to drop when performing next merge to limit size
  ## of new dataframe
# List of columns that were mostly null for original merged df
mostly_null_cols = [col for col in all_uc_voters.columns if all_uc_voters[col].isna().mean() >= 0.9]

# List of columns that are filled with empty white space
empty_cols = [col for col in all_uc_voters.columns if all_uc_voters[col].unique()[0] == ' ']

# List of municipality and mailing address info columns 
  # (not very useful, a lot of NaN)
munic_cols = [col for col in all_uc_voters.columns if col.startswith('munic')]
mail_cols = [col for col in all_uc_voters.columns if col.startswith('mail')]

# Combine all lists into one list of columns to drop
cols_to_drop = mostly_null_cols + empty_cols + munic_cols + mail_cols

# %%
## Merge voter registration information onto the new df based on ncid
voter_elecs = voter_elecs.merge(uc_vreg.drop(columns=cols_to_drop+['county_id',
                                                      'county_desc',
                                                      'voter_reg_num'],
                                             axis=1),
                                how='left', on='ncid')
# Inspect resulting df
voter_elecs.head()
# Out:
#        ncid       election_desc  county_id county_desc  voter_reg_num  \
# 0  EF230133  11/03/2020 GENERAL       90.0       UNION       346446.0
# 1  EF230133  11/06/2012 GENERAL        NaN         NaN            NaN
# 2  EF230133  05/08/2012 PRIMARY        NaN         NaN            NaN
# 3  EF230133  03/15/2016 PRIMARY        NaN         NaN            NaN
# 4  EF230133  11/06/2018 GENERAL        NaN         NaN            NaN
#
#   election_lbl     voting_method voted_party_cd voted_party_desc pct_label  \
# 0   11/03/2020  ABSENTEE ONESTOP            UNA     UNAFFILIATED      020A
# 1          NaN               NaN            NaN              NaN       NaN
# 2          NaN               NaN            NaN              NaN       NaN
# 3          NaN               NaN            NaN              NaN       NaN
# 4          NaN               NaN            NaN              NaN       NaN
#
#   pct_description  voted_county_id voted_county_desc vtd_label  \
# 0            020A             90.0             UNION      020A
# 1             NaN              NaN               NaN       NaN
# 2             NaN              NaN               NaN       NaN
# 3             NaN              NaN               NaN       NaN
# 4             NaN              NaN               NaN       NaN
#
#   vtd_description status_cd voter_status_desc reason_cd  \
# 0            020A         A            ACTIVE        AV
# 1             NaN         A            ACTIVE        AV
# 2             NaN         A            ACTIVE        AV
# 3             NaN         A            ACTIVE        AV
# 4             NaN         A            ACTIVE        AV
#
#   voter_status_reason_desc last_name first_name middle_name  \
# 0                 VERIFIED    AALAEI       ARIO         NaN
# 1                 VERIFIED    AALAEI       ARIO         NaN
# 2                 VERIFIED    AALAEI       ARIO         NaN
# 3                 VERIFIED    AALAEI       ARIO         NaN
# 4                 VERIFIED    AALAEI       ARIO         NaN
#
#          res_street_address res_city_desc state_cd  zip_code race_code  \
# 0  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 1  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 2  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 3  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 4  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
#
#   ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 0          NL      UNA           M         46          OC           Y
# 1          NL      UNA           M         46          OC           Y
# 2          NL      UNA           M         46          OC           Y
# 3          NL      UNA           M         46          OC           Y
# 4          NL      UNA           M         46          OC           Y
#
#    registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv super_court_abbrv  \
# 0  04/25/2019           020A          020A              9.0               20B
# 1  04/25/2019           020A          020A              9.0               20B
# 2  04/25/2019           020A          020A              9.0               20B
# 3  04/25/2019           020A          020A              9.0               20B
# 4  04/25/2019           020A          020A              9.0               20B
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 0              20C             35.0            68.0                2.0
# 1              20C             35.0            68.0                2.0
# 2              20C             35.0            68.0                2.0
# 3              20C             35.0            68.0                2.0
# 4              20C             35.0            68.0                2.0
#
#   school_dist_desc  dist_1_abbrv         dist_1_desc confidential_ind  \
# 0        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 1        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 2        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 3        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 4        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
#
#    birth_year vtd_abbrv vtd_desc
# 0        1974      020A     020A
# 1        1974      020A     020A
# 2        1974      020A     020A
# 3        1974      020A     020A
# 4        1974      020A     020A

# %% [markdown]
# # Scrub and Explore (Part II)

# %% [markdown]
# ## Drop Duplicate and Obviously Incorrect Records

# %%
## Check for duplicate identical rows
voter_elecs.duplicated().sum()
# Out:
# 0

# %%
## Check length of new df
len(voter_elecs)
# Out:
# 1861781

# %%
## Check the intended length of the new df if every unique ncid
  ## appears only once for each election description
voter_elecs['ncid'].nunique() * voter_elecs['election_desc'].nunique()
# Out:
# 1861772

# %%
## There are 9 instances where an ncid shows up as casting a vote
  ## more than once in the same election
voter_elecs.duplicated(subset=['ncid', 'election_desc']).sum()
# Out:
# 9

# %%
## A total of 6 individuals show up twice for a single election
  ## One individual shows up twice in 3 separate elections
dup_ncid_elecs = voter_elecs.loc[voter_elecs.duplicated(subset=['ncid', 'election_desc'], keep=False)]
dup_ncid_elecs
# Out:
#               ncid       election_desc  county_id county_desc  voter_reg_num  \
# 252774     EF78820  11/08/2016 GENERAL       90.0       UNION       341724.0
# 252775     EF78820  11/08/2016 GENERAL       90.0       UNION       341724.0
# 281899     EF93894  11/06/2012 GENERAL       90.0       UNION       272193.0
# 281900     EF93894  11/06/2012 GENERAL       90.0       UNION       272193.0
# 698514     EF69085  11/06/2012 GENERAL       90.0       UNION       144979.0
# 698515     EF69085  11/06/2012 GENERAL       90.0       UNION       144979.0
# 757079    EF186914  11/06/2012 GENERAL       90.0       UNION       307237.0
# 757080    EF186914  11/06/2012 GENERAL       90.0       UNION       307237.0
# 1358607  CW1012090  11/06/2018 GENERAL       90.0       UNION       338735.0
# 1358608  CW1012090  11/06/2018 GENERAL       90.0       UNION       338735.0
# 1543343   EF164225  11/08/2016 GENERAL       90.0       UNION       252400.0
# 1543344   EF164225  11/08/2016 GENERAL       90.0       UNION       252400.0
# 1625686   DB153036  11/06/2012 GENERAL       90.0       UNION       364740.0
# 1625687   DB153036  11/06/2012 GENERAL       90.0       UNION       364740.0
# 1625689   DB153036  03/15/2016 PRIMARY       90.0       UNION       364740.0
# 1625690   DB153036  03/15/2016 PRIMARY       90.0       UNION       364740.0
# 1625692   DB153036  11/08/2016 GENERAL       90.0       UNION       364740.0
# 1625693   DB153036  11/08/2016 GENERAL       90.0       UNION       364740.0
#
#         election_lbl     voting_method voted_party_cd voted_party_desc  \
# 252774    11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 252775    11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 281899    11/06/2012         IN-PERSON            DEM       DEMOCRATIC
# 281900    11/06/2012  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 698514    11/06/2012         IN-PERSON            REP       REPUBLICAN
# 698515    11/06/2012         IN-PERSON            REP       REPUBLICAN
# 757079    11/06/2012         IN-PERSON            REP       REPUBLICAN
# 757080    11/06/2012  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1358607   11/06/2018       PROVISIONAL            REP       REPUBLICAN
# 1358608   11/06/2018         IN-PERSON            REP       REPUBLICAN
# 1543343   11/08/2016         IN-PERSON            DEM       DEMOCRATIC
# 1543344   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1625686   11/06/2012  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1625687   11/06/2012  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1625689   03/15/2016  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 1625690   03/15/2016         IN-PERSON            REP       REPUBLICAN
# 1625692   11/08/2016  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1625693   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
#
#         pct_label pct_description  voted_county_id voted_county_desc  \
# 252774       029A            029A             90.0             UNION
# 252775      11-01           11-01             13.0          CABARRUS
# 281899       BURN      BURNSVILLE              4.0             ANSON
# 281900        009             009             90.0             UNION
# 698514        039             039             90.0             UNION
# 698515        039             039             90.0             UNION
# 757079       038A            038A             90.0             UNION
# 757080        CUL       CULLOWHEE             50.0           JACKSON
# 1358607      020B            020B             90.0             UNION
# 1358608       058         PCT 058             60.0       MECKLENBURG
# 1543343      028D            028D             90.0             UNION
# 1543344       022         PCT 022             60.0       MECKLENBURG
# 1625686       W25             W25             65.0       NEW HANOVER
# 1625687      0070           SALEM             12.0             BURKE
# 1625689       W16             W16             65.0       NEW HANOVER
# 1625690      0070           SALEM             12.0             BURKE
# 1625692       W16             W16             65.0       NEW HANOVER
# 1625693      0070           SALEM             12.0             BURKE
#
#         vtd_label vtd_description status_cd voter_status_desc reason_cd  \
# 252774       029A            029A         A            ACTIVE        AV
# 252775      11-01           11-01         A            ACTIVE        AV
# 281899       BURN            BURN         A            ACTIVE        AV
# 281900        009             009         A            ACTIVE        AV
# 698514       038A            038A         A            ACTIVE        AV
# 698515        039             039         A            ACTIVE        AV
# 757079       038A            038A         A            ACTIVE        AV
# 757080        CUL             CUL         A            ACTIVE        AV
# 1358607      020B            020B         A            ACTIVE        AV
# 1358608       058             058         A            ACTIVE        AV
# 1543343       028             028         A            ACTIVE        AV
# 1543344       022             022         A            ACTIVE        AV
# 1625686       W25             W25         A            ACTIVE        AV
# 1625687      0070            0070         A            ACTIVE        AV
# 1625689       W16             W16         A            ACTIVE        AV
# 1625690      0070            0070         A            ACTIVE        AV
# 1625692       W16             W16         A            ACTIVE        AV
# 1625693      0070            0070         A            ACTIVE        AV
#
#         voter_status_reason_desc last_name first_name middle_name  \
# 252774                  VERIFIED    CAPUTO       LISA         RAE
# 252775                  VERIFIED    CAPUTO       LISA         RAE
# 281899                  VERIFIED  CHAMBERS      RONDA     SHENICE
# 281900                  VERIFIED  CHAMBERS      RONDA     SHENICE
# 698514                  VERIFIED  HAULISKA      DAVID     CHARLES
# 698515                  VERIFIED  HAULISKA      DAVID     CHARLES
# 757079                  VERIFIED     HOBBS     ASHLEY      NICOLE
# 757080                  VERIFIED     HOBBS     ASHLEY      NICOLE
# 1358607                 VERIFIED     RACER      JESSE      THOMAS
# 1358608                 VERIFIED     RACER      JESSE      THOMAS
# 1543343                 VERIFIED     SMITH      ANDRE     MAURICE
# 1543344                 VERIFIED     SMITH      ANDRE     MAURICE
# 1625686                 VERIFIED   SUMMERS      JASON        BRAD
# 1625687                 VERIFIED   SUMMERS      JASON        BRAD
# 1625689                 VERIFIED   SUMMERS      JASON        BRAD
# 1625690                 VERIFIED   SUMMERS      JASON        BRAD
# 1625692                 VERIFIED   SUMMERS      JASON        BRAD
# 1625693                 VERIFIED   SUMMERS      JASON        BRAD
#
#                    res_street_address res_city_desc state_cd  zip_code  \
# 252774    3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252775    3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 281899             710  KINTYRE DR           MONROE       NC   28112.0
# 281900             710  KINTYRE DR           MONROE       NC   28112.0
# 698514      6015  LANDER BENTON RD           MONROE       NC   28110.0
# 698515      6015  LANDER BENTON RD           MONROE       NC   28110.0
# 757079   6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757080   6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 1358607          805  ABBEYWOOD DR           WAXHAW       NC   28173.0
# 1358608          805  ABBEYWOOD DR           WAXHAW       NC   28173.0
# 1543343        1401  RIDGEHAVEN RD           WAXHAW       NC   28173.0
# 1543344        1401  RIDGEHAVEN RD           WAXHAW       NC   28173.0
# 1625686           3806  CASSIDY DR           WAXHAW       NC   28173.0
# 1625687           3806  CASSIDY DR           WAXHAW       NC   28173.0
# 1625689           3806  CASSIDY DR           WAXHAW       NC   28173.0
# 1625690           3806  CASSIDY DR           WAXHAW       NC   28173.0
# 1625692           3806  CASSIDY DR           WAXHAW       NC   28173.0
# 1625693           3806  CASSIDY DR           WAXHAW       NC   28173.0
#
#         race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 252774          U          UN      REP           U         40         NaN
# 252775          U          UN      REP           U         40         NaN
# 281899          B          NL      DEM           F         41          NC
# 281900          B          NL      DEM           F         41          NC
# 698514          W          NL      REP           M         52          PA
# 698515          W          NL      REP           M         52          PA
# 757079          W          NL      REP           F         26          NC
# 757080          W          NL      REP           F         26          NC
# 1358607         W          NL      REP           M         32         NaN
# 1358608         W          NL      REP           M         32         NaN
# 1543343         B          NL      DEM           M         40          MO
# 1543344         B          NL      DEM           M         40          MO
# 1625686         U          UN      REP           U         48         NaN
# 1625687         U          UN      REP           U         48         NaN
# 1625689         U          UN      REP           U         48         NaN
# 1625690         U          UN      REP           U         48         NaN
# 1625692         U          UN      REP           U         48         NaN
# 1625693         U          UN      REP           U         48         NaN
#
#         drivers_lic  registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 252774            Y  01/10/2019           038A          038A              9.0
# 252775            Y  01/10/2019           038A          038A              9.0
# 281899            Y  10/23/2012            004           004              9.0
# 281900            Y  10/23/2012            004           004              9.0
# 698514            Y  05/07/1998            039           039              9.0
# 698515            Y  05/07/1998            039           039              9.0
# 757079            Y  07/09/2016            013           013              9.0
# 757080            Y  07/09/2016            013           013              9.0
# 1358607           Y  11/06/2018           020B          020B              9.0
# 1358608           Y  11/06/2018           020B          020B              9.0
# 1543343           Y  01/13/2011           028D          028D              9.0
# 1543344           Y  01/13/2011           028D          028D              9.0
# 1625686           Y  07/17/2020           020A          020A              9.0
# 1625687           Y  07/17/2020           020A          020A              9.0
# 1625689           Y  07/17/2020           020A          020A              9.0
# 1625690           Y  07/17/2020           020A          020A              9.0
# 1625692           Y  07/17/2020           020A          020A              9.0
# 1625693           Y  07/17/2020           020A          020A              9.0
#
#         super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 252774                20B              20C             35.0            69.0
# 252775                20B              20C             35.0            69.0
# 281899                20B              20B             35.0            69.0
# 281900                20B              20B             35.0            69.0
# 698514                20B              20C             35.0            69.0
# 698515                20B              20C             35.0            69.0
# 757079                20B              20B             35.0            69.0
# 757080                20B              20B             35.0            69.0
# 1358607               20B              20C             35.0            68.0
# 1358608               20B              20C             35.0            68.0
# 1543343               20B              20C             35.0            68.0
# 1543344               20B              20C             35.0            68.0
# 1625686               20B              20C             35.0            68.0
# 1625687               20B              20C             35.0            68.0
# 1625689               20B              20C             35.0            68.0
# 1625690               20B              20C             35.0            68.0
# 1625692               20B              20C             35.0            68.0
# 1625693               20B              20C             35.0            68.0
#
#          school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 252774                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252775                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 281899                 1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281900                 1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 698514                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698515                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757079                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757080                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 1358607                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1358608                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543343                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543344                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1625686                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625687                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625689                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625690                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625692                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625693                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
#
#         confidential_ind  birth_year vtd_abbrv vtd_desc
# 252774                 N        1980      038A     038A
# 252775                 N        1980      038A     038A
# 281899                 N        1979       004      004
# 281900                 N        1979       004      004
# 698514                 N        1968       039      039
# 698515                 N        1968       039      039
# 757079                 N        1994       013      013
# 757080                 N        1994       013      013
# 1358607                N        1988      020B     020B
# 1358608                N        1988      020B     020B
# 1543343                N        1980       028      028
# 1543344                N        1980       028      028
# 1625686                N        1972      020A     020A
# 1625687                N        1972      020A     020A
# 1625689                N        1972      020A     020A
# 1625690                N        1972      020A     020A
# 1625692                N        1972      020A     020A
# 1625693                N        1972      020A     020A

# %%
## Examine the complete recent voting history of the 7 ncid's that show up 
  ## twice for a single election to investigate how the records differ
    ## and determine which record(s) to drop
for ncid in dup_ncid_elecs['ncid'].unique():
    display(voter_elecs.loc[voter_elecs['ncid']==ncid])
# Out:
#            ncid       election_desc  county_id county_desc  voter_reg_num  \
# 252769  EF78820  11/03/2020 GENERAL       90.0       UNION       341724.0
# 252770  EF78820  11/06/2012 GENERAL        NaN         NaN            NaN
# 252771  EF78820  05/08/2012 PRIMARY        NaN         NaN            NaN
# 252772  EF78820  03/15/2016 PRIMARY        NaN         NaN            NaN
# 252773  EF78820  11/06/2018 GENERAL        NaN         NaN            NaN
# 252774  EF78820  11/08/2016 GENERAL       90.0       UNION       341724.0
# 252775  EF78820  11/08/2016 GENERAL       90.0       UNION       341724.0
# 252776  EF78820  11/04/2014 GENERAL        NaN         NaN            NaN
# 252777  EF78820  03/03/2020 PRIMARY        NaN         NaN            NaN
# 252778  EF78820  05/08/2018 PRIMARY        NaN         NaN            NaN
# 252779  EF78820  05/06/2014 PRIMARY        NaN         NaN            NaN
# 252780  EF78820                None        NaN         NaN            NaN
#
#        election_lbl     voting_method voted_party_cd voted_party_desc  \
# 252769   11/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 252770          NaN               NaN            NaN              NaN
# 252771          NaN               NaN            NaN              NaN
# 252772          NaN               NaN            NaN              NaN
# 252773          NaN               NaN            NaN              NaN
# 252774   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 252775   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 252776          NaN               NaN            NaN              NaN
# 252777          NaN               NaN            NaN              NaN
# 252778          NaN               NaN            NaN              NaN
# 252779          NaN               NaN            NaN              NaN
# 252780          NaN               NaN            NaN              NaN
#
#        pct_label pct_description  voted_county_id voted_county_desc vtd_label  \
# 252769      038A            038A             90.0             UNION      038A
# 252770       NaN             NaN              NaN               NaN       NaN
# 252771       NaN             NaN              NaN               NaN       NaN
# 252772       NaN             NaN              NaN               NaN       NaN
# 252773       NaN             NaN              NaN               NaN       NaN
# 252774      029A            029A             90.0             UNION      029A
# 252775     11-01           11-01             13.0          CABARRUS     11-01
# 252776       NaN             NaN              NaN               NaN       NaN
# 252777       NaN             NaN              NaN               NaN       NaN
# 252778       NaN             NaN              NaN               NaN       NaN
# 252779       NaN             NaN              NaN               NaN       NaN
# 252780       NaN             NaN              NaN               NaN       NaN
#
#        vtd_description status_cd voter_status_desc reason_cd  \
# 252769            038A         A            ACTIVE        AV
# 252770             NaN         A            ACTIVE        AV
# 252771             NaN         A            ACTIVE        AV
# 252772             NaN         A            ACTIVE        AV
# 252773             NaN         A            ACTIVE        AV
# 252774            029A         A            ACTIVE        AV
# 252775           11-01         A            ACTIVE        AV
# 252776             NaN         A            ACTIVE        AV
# 252777             NaN         A            ACTIVE        AV
# 252778             NaN         A            ACTIVE        AV
# 252779             NaN         A            ACTIVE        AV
# 252780             NaN         A            ACTIVE        AV
#
#        voter_status_reason_desc last_name first_name middle_name  \
# 252769                 VERIFIED    CAPUTO       LISA         RAE
# 252770                 VERIFIED    CAPUTO       LISA         RAE
# 252771                 VERIFIED    CAPUTO       LISA         RAE
# 252772                 VERIFIED    CAPUTO       LISA         RAE
# 252773                 VERIFIED    CAPUTO       LISA         RAE
# 252774                 VERIFIED    CAPUTO       LISA         RAE
# 252775                 VERIFIED    CAPUTO       LISA         RAE
# 252776                 VERIFIED    CAPUTO       LISA         RAE
# 252777                 VERIFIED    CAPUTO       LISA         RAE
# 252778                 VERIFIED    CAPUTO       LISA         RAE
# 252779                 VERIFIED    CAPUTO       LISA         RAE
# 252780                 VERIFIED    CAPUTO       LISA         RAE
#
#                  res_street_address res_city_desc state_cd  zip_code  \
# 252769  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252770  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252771  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252772  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252773  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252774  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252775  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252776  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252777  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252778  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252779  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
# 252780  3503  SOUTHERN GINGER DR     INDIAN TRAIL       NC   28079.0
#
#        race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 252769         U          UN      REP           U         40         NaN
# 252770         U          UN      REP           U         40         NaN
# 252771         U          UN      REP           U         40         NaN
# 252772         U          UN      REP           U         40         NaN
# 252773         U          UN      REP           U         40         NaN
# 252774         U          UN      REP           U         40         NaN
# 252775         U          UN      REP           U         40         NaN
# 252776         U          UN      REP           U         40         NaN
# 252777         U          UN      REP           U         40         NaN
# 252778         U          UN      REP           U         40         NaN
# 252779         U          UN      REP           U         40         NaN
# 252780         U          UN      REP           U         40         NaN
#
#        drivers_lic  registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 252769           Y  01/10/2019           038A          038A              9.0
# 252770           Y  01/10/2019           038A          038A              9.0
# 252771           Y  01/10/2019           038A          038A              9.0
# 252772           Y  01/10/2019           038A          038A              9.0
# 252773           Y  01/10/2019           038A          038A              9.0
# 252774           Y  01/10/2019           038A          038A              9.0
# 252775           Y  01/10/2019           038A          038A              9.0
# 252776           Y  01/10/2019           038A          038A              9.0
# 252777           Y  01/10/2019           038A          038A              9.0
# 252778           Y  01/10/2019           038A          038A              9.0
# 252779           Y  01/10/2019           038A          038A              9.0
# 252780           Y  01/10/2019           038A          038A              9.0
#
#        super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 252769               20B              20C             35.0            69.0
# 252770               20B              20C             35.0            69.0
# 252771               20B              20C             35.0            69.0
# 252772               20B              20C             35.0            69.0
# 252773               20B              20C             35.0            69.0
# 252774               20B              20C             35.0            69.0
# 252775               20B              20C             35.0            69.0
# 252776               20B              20C             35.0            69.0
# 252777               20B              20C             35.0            69.0
# 252778               20B              20C             35.0            69.0
# 252779               20B              20C             35.0            69.0
# 252780               20B              20C             35.0            69.0
#
#         school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 252769                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252770                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252771                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252772                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252773                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252774                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252775                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252776                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252777                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252778                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252779                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 252780                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
#
#        confidential_ind  birth_year vtd_abbrv vtd_desc
# 252769                N        1980      038A     038A
# 252770                N        1980      038A     038A
# 252771                N        1980      038A     038A
# 252772                N        1980      038A     038A
# 252773                N        1980      038A     038A
# 252774                N        1980      038A     038A
# 252775                N        1980      038A     038A
# 252776                N        1980      038A     038A
# 252777                N        1980      038A     038A
# 252778                N        1980      038A     038A
# 252779                N        1980      038A     038A
# 252780                N        1980      038A     038A
#            ncid       election_desc  county_id county_desc  voter_reg_num  \
# 281898  EF93894  11/03/2020 GENERAL        NaN         NaN            NaN
# 281899  EF93894  11/06/2012 GENERAL       90.0       UNION       272193.0
# 281900  EF93894  11/06/2012 GENERAL       90.0       UNION       272193.0
# 281901  EF93894  05/08/2012 PRIMARY        NaN         NaN            NaN
# 281902  EF93894  03/15/2016 PRIMARY        NaN         NaN            NaN
# 281903  EF93894  11/06/2018 GENERAL        NaN         NaN            NaN
# 281904  EF93894  11/08/2016 GENERAL        NaN         NaN            NaN
# 281905  EF93894  11/04/2014 GENERAL        NaN         NaN            NaN
# 281906  EF93894  03/03/2020 PRIMARY        NaN         NaN            NaN
# 281907  EF93894  05/08/2018 PRIMARY        NaN         NaN            NaN
# 281908  EF93894  05/06/2014 PRIMARY        NaN         NaN            NaN
# 281909  EF93894                None        NaN         NaN            NaN
#
#        election_lbl     voting_method voted_party_cd voted_party_desc  \
# 281898          NaN               NaN            NaN              NaN
# 281899   11/06/2012         IN-PERSON            DEM       DEMOCRATIC
# 281900   11/06/2012  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 281901          NaN               NaN            NaN              NaN
# 281902          NaN               NaN            NaN              NaN
# 281903          NaN               NaN            NaN              NaN
# 281904          NaN               NaN            NaN              NaN
# 281905          NaN               NaN            NaN              NaN
# 281906          NaN               NaN            NaN              NaN
# 281907          NaN               NaN            NaN              NaN
# 281908          NaN               NaN            NaN              NaN
# 281909          NaN               NaN            NaN              NaN
#
#        pct_label pct_description  voted_county_id voted_county_desc vtd_label  \
# 281898       NaN             NaN              NaN               NaN       NaN
# 281899      BURN      BURNSVILLE              4.0             ANSON      BURN
# 281900       009             009             90.0             UNION       009
# 281901       NaN             NaN              NaN               NaN       NaN
# 281902       NaN             NaN              NaN               NaN       NaN
# 281903       NaN             NaN              NaN               NaN       NaN
# 281904       NaN             NaN              NaN               NaN       NaN
# 281905       NaN             NaN              NaN               NaN       NaN
# 281906       NaN             NaN              NaN               NaN       NaN
# 281907       NaN             NaN              NaN               NaN       NaN
# 281908       NaN             NaN              NaN               NaN       NaN
# 281909       NaN             NaN              NaN               NaN       NaN
#
#        vtd_description status_cd voter_status_desc reason_cd  \
# 281898             NaN         A            ACTIVE        AV
# 281899            BURN         A            ACTIVE        AV
# 281900             009         A            ACTIVE        AV
# 281901             NaN         A            ACTIVE        AV
# 281902             NaN         A            ACTIVE        AV
# 281903             NaN         A            ACTIVE        AV
# 281904             NaN         A            ACTIVE        AV
# 281905             NaN         A            ACTIVE        AV
# 281906             NaN         A            ACTIVE        AV
# 281907             NaN         A            ACTIVE        AV
# 281908             NaN         A            ACTIVE        AV
# 281909             NaN         A            ACTIVE        AV
#
#        voter_status_reason_desc last_name first_name middle_name  \
# 281898                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281899                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281900                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281901                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281902                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281903                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281904                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281905                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281906                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281907                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281908                 VERIFIED  CHAMBERS      RONDA     SHENICE
# 281909                 VERIFIED  CHAMBERS      RONDA     SHENICE
#
#         res_street_address res_city_desc state_cd  zip_code race_code  \
# 281898  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281899  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281900  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281901  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281902  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281903  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281904  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281905  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281906  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281907  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281908  710  KINTYRE DR           MONROE       NC   28112.0         B
# 281909  710  KINTYRE DR           MONROE       NC   28112.0         B
#
#        ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 281898          NL      DEM           F         41          NC           Y
# 281899          NL      DEM           F         41          NC           Y
# 281900          NL      DEM           F         41          NC           Y
# 281901          NL      DEM           F         41          NC           Y
# 281902          NL      DEM           F         41          NC           Y
# 281903          NL      DEM           F         41          NC           Y
# 281904          NL      DEM           F         41          NC           Y
# 281905          NL      DEM           F         41          NC           Y
# 281906          NL      DEM           F         41          NC           Y
# 281907          NL      DEM           F         41          NC           Y
# 281908          NL      DEM           F         41          NC           Y
# 281909          NL      DEM           F         41          NC           Y
#
#         registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 281898  10/23/2012            004           004              9.0
# 281899  10/23/2012            004           004              9.0
# 281900  10/23/2012            004           004              9.0
# 281901  10/23/2012            004           004              9.0
# 281902  10/23/2012            004           004              9.0
# 281903  10/23/2012            004           004              9.0
# 281904  10/23/2012            004           004              9.0
# 281905  10/23/2012            004           004              9.0
# 281906  10/23/2012            004           004              9.0
# 281907  10/23/2012            004           004              9.0
# 281908  10/23/2012            004           004              9.0
# 281909  10/23/2012            004           004              9.0
#
#        super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 281898               20B              20B             35.0            69.0
# 281899               20B              20B             35.0            69.0
# 281900               20B              20B             35.0            69.0
# 281901               20B              20B             35.0            69.0
# 281902               20B              20B             35.0            69.0
# 281903               20B              20B             35.0            69.0
# 281904               20B              20B             35.0            69.0
# 281905               20B              20B             35.0            69.0
# 281906               20B              20B             35.0            69.0
# 281907               20B              20B             35.0            69.0
# 281908               20B              20B             35.0            69.0
# 281909               20B              20B             35.0            69.0
#
#         school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 281898                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281899                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281900                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281901                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281902                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281903                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281904                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281905                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281906                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281907                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281908                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 281909                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
#
#        confidential_ind  birth_year vtd_abbrv vtd_desc
# 281898                N        1979       004      004
# 281899                N        1979       004      004
# 281900                N        1979       004      004
# 281901                N        1979       004      004
# 281902                N        1979       004      004
# 281903                N        1979       004      004
# 281904                N        1979       004      004
# 281905                N        1979       004      004
# 281906                N        1979       004      004
# 281907                N        1979       004      004
# 281908                N        1979       004      004
# 281909                N        1979       004      004
#            ncid       election_desc  county_id county_desc  voter_reg_num  \
# 698513  EF69085  11/03/2020 GENERAL       90.0       UNION       144979.0
# 698514  EF69085  11/06/2012 GENERAL       90.0       UNION       144979.0
# 698515  EF69085  11/06/2012 GENERAL       90.0       UNION       144979.0
# 698516  EF69085  05/08/2012 PRIMARY        NaN         NaN            NaN
# 698517  EF69085  03/15/2016 PRIMARY        NaN         NaN            NaN
# 698518  EF69085  11/06/2018 GENERAL       90.0       UNION       144979.0
# 698519  EF69085  11/08/2016 GENERAL       90.0       UNION       144979.0
# 698520  EF69085  11/04/2014 GENERAL        NaN         NaN            NaN
# 698521  EF69085  03/03/2020 PRIMARY       90.0       UNION       144979.0
# 698522  EF69085  05/08/2018 PRIMARY        NaN         NaN            NaN
# 698523  EF69085  05/06/2014 PRIMARY        NaN         NaN            NaN
# 698524  EF69085                None        NaN         NaN            NaN
#
#        election_lbl     voting_method voted_party_cd voted_party_desc  \
# 698513   11/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 698514   11/06/2012         IN-PERSON            REP       REPUBLICAN
# 698515   11/06/2012         IN-PERSON            REP       REPUBLICAN
# 698516          NaN               NaN            NaN              NaN
# 698517          NaN               NaN            NaN              NaN
# 698518   11/06/2018         IN-PERSON            REP       REPUBLICAN
# 698519   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 698520          NaN               NaN            NaN              NaN
# 698521   03/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 698522          NaN               NaN            NaN              NaN
# 698523          NaN               NaN            NaN              NaN
# 698524          NaN               NaN            NaN              NaN
#
#        pct_label pct_description  voted_county_id voted_county_desc vtd_label  \
# 698513       039             039             90.0             UNION       039
# 698514       039             039             90.0             UNION      038A
# 698515       039             039             90.0             UNION       039
# 698516       NaN             NaN              NaN               NaN       NaN
# 698517       NaN             NaN              NaN               NaN       NaN
# 698518       039             039             90.0             UNION       039
# 698519       039             039             90.0             UNION       039
# 698520       NaN             NaN              NaN               NaN       NaN
# 698521       039             039             90.0             UNION       039
# 698522       NaN             NaN              NaN               NaN       NaN
# 698523       NaN             NaN              NaN               NaN       NaN
# 698524       NaN             NaN              NaN               NaN       NaN
#
#        vtd_description status_cd voter_status_desc reason_cd  \
# 698513             039         A            ACTIVE        AV
# 698514            038A         A            ACTIVE        AV
# 698515             039         A            ACTIVE        AV
# 698516             NaN         A            ACTIVE        AV
# 698517             NaN         A            ACTIVE        AV
# 698518             039         A            ACTIVE        AV
# 698519             039         A            ACTIVE        AV
# 698520             NaN         A            ACTIVE        AV
# 698521             039         A            ACTIVE        AV
# 698522             NaN         A            ACTIVE        AV
# 698523             NaN         A            ACTIVE        AV
# 698524             NaN         A            ACTIVE        AV
#
#        voter_status_reason_desc last_name first_name middle_name  \
# 698513                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698514                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698515                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698516                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698517                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698518                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698519                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698520                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698521                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698522                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698523                 VERIFIED  HAULISKA      DAVID     CHARLES
# 698524                 VERIFIED  HAULISKA      DAVID     CHARLES
#
#                res_street_address res_city_desc state_cd  zip_code race_code  \
# 698513  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698514  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698515  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698516  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698517  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698518  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698519  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698520  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698521  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698522  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698523  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
# 698524  6015  LANDER BENTON RD           MONROE       NC   28110.0         W
#
#        ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 698513          NL      REP           M         52          PA           Y
# 698514          NL      REP           M         52          PA           Y
# 698515          NL      REP           M         52          PA           Y
# 698516          NL      REP           M         52          PA           Y
# 698517          NL      REP           M         52          PA           Y
# 698518          NL      REP           M         52          PA           Y
# 698519          NL      REP           M         52          PA           Y
# 698520          NL      REP           M         52          PA           Y
# 698521          NL      REP           M         52          PA           Y
# 698522          NL      REP           M         52          PA           Y
# 698523          NL      REP           M         52          PA           Y
# 698524          NL      REP           M         52          PA           Y
#
#         registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 698513  05/07/1998            039           039              9.0
# 698514  05/07/1998            039           039              9.0
# 698515  05/07/1998            039           039              9.0
# 698516  05/07/1998            039           039              9.0
# 698517  05/07/1998            039           039              9.0
# 698518  05/07/1998            039           039              9.0
# 698519  05/07/1998            039           039              9.0
# 698520  05/07/1998            039           039              9.0
# 698521  05/07/1998            039           039              9.0
# 698522  05/07/1998            039           039              9.0
# 698523  05/07/1998            039           039              9.0
# 698524  05/07/1998            039           039              9.0
#
#        super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 698513               20B              20C             35.0            69.0
# 698514               20B              20C             35.0            69.0
# 698515               20B              20C             35.0            69.0
# 698516               20B              20C             35.0            69.0
# 698517               20B              20C             35.0            69.0
# 698518               20B              20C             35.0            69.0
# 698519               20B              20C             35.0            69.0
# 698520               20B              20C             35.0            69.0
# 698521               20B              20C             35.0            69.0
# 698522               20B              20C             35.0            69.0
# 698523               20B              20C             35.0            69.0
# 698524               20B              20C             35.0            69.0
#
#         school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 698513                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698514                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698515                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698516                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698517                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698518                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698519                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698520                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698521                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698522                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698523                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 698524                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
#
#        confidential_ind  birth_year vtd_abbrv vtd_desc
# 698513                N        1968       039      039
# 698514                N        1968       039      039
# 698515                N        1968       039      039
# 698516                N        1968       039      039
# 698517                N        1968       039      039
# 698518                N        1968       039      039
# 698519                N        1968       039      039
# 698520                N        1968       039      039
# 698521                N        1968       039      039
# 698522                N        1968       039      039
# 698523                N        1968       039      039
# 698524                N        1968       039      039
#             ncid       election_desc  county_id county_desc  voter_reg_num  \
# 757078  EF186914  11/03/2020 GENERAL       90.0       UNION       307237.0
# 757079  EF186914  11/06/2012 GENERAL       90.0       UNION       307237.0
# 757080  EF186914  11/06/2012 GENERAL       90.0       UNION       307237.0
# 757081  EF186914  05/08/2012 PRIMARY        NaN         NaN            NaN
# 757082  EF186914  03/15/2016 PRIMARY        NaN         NaN            NaN
# 757083  EF186914  11/06/2018 GENERAL        NaN         NaN            NaN
# 757084  EF186914  11/08/2016 GENERAL       90.0       UNION       307237.0
# 757085  EF186914  11/04/2014 GENERAL       90.0       UNION       307237.0
# 757086  EF186914  03/03/2020 PRIMARY        NaN         NaN            NaN
# 757087  EF186914  05/08/2018 PRIMARY        NaN         NaN            NaN
# 757088  EF186914  05/06/2014 PRIMARY        NaN         NaN            NaN
# 757089  EF186914                None        NaN         NaN            NaN
#
#        election_lbl     voting_method voted_party_cd voted_party_desc  \
# 757078   11/03/2020         IN-PERSON            REP       REPUBLICAN
# 757079   11/06/2012         IN-PERSON            REP       REPUBLICAN
# 757080   11/06/2012  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 757081          NaN               NaN            NaN              NaN
# 757082          NaN               NaN            NaN              NaN
# 757083          NaN               NaN            NaN              NaN
# 757084   11/08/2016         IN-PERSON            REP       REPUBLICAN
# 757085   11/04/2014         IN-PERSON            REP       REPUBLICAN
# 757086          NaN               NaN            NaN              NaN
# 757087          NaN               NaN            NaN              NaN
# 757088          NaN               NaN            NaN              NaN
# 757089          NaN               NaN            NaN              NaN
#
#        pct_label pct_description  voted_county_id voted_county_desc vtd_label  \
# 757078       013             013             90.0             UNION       013
# 757079      038A            038A             90.0             UNION      038A
# 757080       CUL       CULLOWHEE             50.0           JACKSON       CUL
# 757081       NaN             NaN              NaN               NaN       NaN
# 757082       NaN             NaN              NaN               NaN       NaN
# 757083       NaN             NaN              NaN               NaN       NaN
# 757084       039             039             90.0             UNION       039
# 757085      038A            038A             90.0             UNION      038A
# 757086       NaN             NaN              NaN               NaN       NaN
# 757087       NaN             NaN              NaN               NaN       NaN
# 757088       NaN             NaN              NaN               NaN       NaN
# 757089       NaN             NaN              NaN               NaN       NaN
#
#        vtd_description status_cd voter_status_desc reason_cd  \
# 757078             013         A            ACTIVE        AV
# 757079            038A         A            ACTIVE        AV
# 757080             CUL         A            ACTIVE        AV
# 757081             NaN         A            ACTIVE        AV
# 757082             NaN         A            ACTIVE        AV
# 757083             NaN         A            ACTIVE        AV
# 757084             039         A            ACTIVE        AV
# 757085            038A         A            ACTIVE        AV
# 757086             NaN         A            ACTIVE        AV
# 757087             NaN         A            ACTIVE        AV
# 757088             NaN         A            ACTIVE        AV
# 757089             NaN         A            ACTIVE        AV
#
#        voter_status_reason_desc last_name first_name middle_name  \
# 757078                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757079                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757080                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757081                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757082                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757083                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757084                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757085                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757086                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757087                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757088                 VERIFIED     HOBBS     ASHLEY      NICOLE
# 757089                 VERIFIED     HOBBS     ASHLEY      NICOLE
#
#                   res_street_address res_city_desc state_cd  zip_code  \
# 757078  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757079  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757080  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757081  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757082  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757083  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757084  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757085  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757086  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757087  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757088  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
# 757089  6714  UNIONVILLE BRIEF RD           MONROE       NC   28110.0
#
#        race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 757078         W          NL      REP           F         26          NC
# 757079         W          NL      REP           F         26          NC
# 757080         W          NL      REP           F         26          NC
# 757081         W          NL      REP           F         26          NC
# 757082         W          NL      REP           F         26          NC
# 757083         W          NL      REP           F         26          NC
# 757084         W          NL      REP           F         26          NC
# 757085         W          NL      REP           F         26          NC
# 757086         W          NL      REP           F         26          NC
# 757087         W          NL      REP           F         26          NC
# 757088         W          NL      REP           F         26          NC
# 757089         W          NL      REP           F         26          NC
#
#        drivers_lic  registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 757078           Y  07/09/2016            013           013              9.0
# 757079           Y  07/09/2016            013           013              9.0
# 757080           Y  07/09/2016            013           013              9.0
# 757081           Y  07/09/2016            013           013              9.0
# 757082           Y  07/09/2016            013           013              9.0
# 757083           Y  07/09/2016            013           013              9.0
# 757084           Y  07/09/2016            013           013              9.0
# 757085           Y  07/09/2016            013           013              9.0
# 757086           Y  07/09/2016            013           013              9.0
# 757087           Y  07/09/2016            013           013              9.0
# 757088           Y  07/09/2016            013           013              9.0
# 757089           Y  07/09/2016            013           013              9.0
#
#        super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 757078               20B              20B             35.0            69.0
# 757079               20B              20B             35.0            69.0
# 757080               20B              20B             35.0            69.0
# 757081               20B              20B             35.0            69.0
# 757082               20B              20B             35.0            69.0
# 757083               20B              20B             35.0            69.0
# 757084               20B              20B             35.0            69.0
# 757085               20B              20B             35.0            69.0
# 757086               20B              20B             35.0            69.0
# 757087               20B              20B             35.0            69.0
# 757088               20B              20B             35.0            69.0
# 757089               20B              20B             35.0            69.0
#
#         school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 757078                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757079                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757080                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757081                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757082                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757083                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757084                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757085                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757086                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757087                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757088                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 757089                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
#
#        confidential_ind  birth_year vtd_abbrv vtd_desc
# 757078                N        1994       013      013
# 757079                N        1994       013      013
# 757080                N        1994       013      013
# 757081                N        1994       013      013
# 757082                N        1994       013      013
# 757083                N        1994       013      013
# 757084                N        1994       013      013
# 757085                N        1994       013      013
# 757086                N        1994       013      013
# 757087                N        1994       013      013
# 757088                N        1994       013      013
# 757089                N        1994       013      013
#               ncid       election_desc  county_id county_desc  voter_reg_num  \
# 1358603  CW1012090  11/03/2020 GENERAL       90.0       UNION       338735.0
# 1358604  CW1012090  11/06/2012 GENERAL        NaN         NaN            NaN
# 1358605  CW1012090  05/08/2012 PRIMARY        NaN         NaN            NaN
# 1358606  CW1012090  03/15/2016 PRIMARY        NaN         NaN            NaN
# 1358607  CW1012090  11/06/2018 GENERAL       90.0       UNION       338735.0
# 1358608  CW1012090  11/06/2018 GENERAL       90.0       UNION       338735.0
# 1358609  CW1012090  11/08/2016 GENERAL       90.0       UNION       338735.0
# 1358610  CW1012090  11/04/2014 GENERAL       90.0       UNION       338735.0
# 1358611  CW1012090  03/03/2020 PRIMARY       90.0       UNION       338735.0
# 1358612  CW1012090  05/08/2018 PRIMARY        NaN         NaN            NaN
# 1358613  CW1012090  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1358614  CW1012090                None        NaN         NaN            NaN
#
#         election_lbl     voting_method voted_party_cd voted_party_desc  \
# 1358603   11/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1358604          NaN               NaN            NaN              NaN
# 1358605          NaN               NaN            NaN              NaN
# 1358606          NaN               NaN            NaN              NaN
# 1358607   11/06/2018       PROVISIONAL            REP       REPUBLICAN
# 1358608   11/06/2018         IN-PERSON            REP       REPUBLICAN
# 1358609   11/08/2016         IN-PERSON            REP       REPUBLICAN
# 1358610   11/04/2014         IN-PERSON            REP       REPUBLICAN
# 1358611   03/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1358612          NaN               NaN            NaN              NaN
# 1358613          NaN               NaN            NaN              NaN
# 1358614          NaN               NaN            NaN              NaN
#
#         pct_label pct_description  voted_county_id voted_county_desc  \
# 1358603      020B            020B             90.0             UNION
# 1358604       NaN             NaN              NaN               NaN
# 1358605       NaN             NaN              NaN               NaN
# 1358606       NaN             NaN              NaN               NaN
# 1358607      020B            020B             90.0             UNION
# 1358608       058         PCT 058             60.0       MECKLENBURG
# 1358609       058         PCT 058             60.0       MECKLENBURG
# 1358610       148         PCT 148             60.0       MECKLENBURG
# 1358611      020B            020B             90.0             UNION
# 1358612       NaN             NaN              NaN               NaN
# 1358613       NaN             NaN              NaN               NaN
# 1358614       NaN             NaN              NaN               NaN
#
#         vtd_label vtd_description status_cd voter_status_desc reason_cd  \
# 1358603      020B            020B         A            ACTIVE        AV
# 1358604       NaN             NaN         A            ACTIVE        AV
# 1358605       NaN             NaN         A            ACTIVE        AV
# 1358606       NaN             NaN         A            ACTIVE        AV
# 1358607      020B            020B         A            ACTIVE        AV
# 1358608       058             058         A            ACTIVE        AV
# 1358609       058             058         A            ACTIVE        AV
# 1358610       148             148         A            ACTIVE        AV
# 1358611      020B            020B         A            ACTIVE        AV
# 1358612       NaN             NaN         A            ACTIVE        AV
# 1358613       NaN             NaN         A            ACTIVE        AV
# 1358614       NaN             NaN         A            ACTIVE        AV
#
#         voter_status_reason_desc last_name first_name middle_name  \
# 1358603                 VERIFIED     RACER      JESSE      THOMAS
# 1358604                 VERIFIED     RACER      JESSE      THOMAS
# 1358605                 VERIFIED     RACER      JESSE      THOMAS
# 1358606                 VERIFIED     RACER      JESSE      THOMAS
# 1358607                 VERIFIED     RACER      JESSE      THOMAS
# 1358608                 VERIFIED     RACER      JESSE      THOMAS
# 1358609                 VERIFIED     RACER      JESSE      THOMAS
# 1358610                 VERIFIED     RACER      JESSE      THOMAS
# 1358611                 VERIFIED     RACER      JESSE      THOMAS
# 1358612                 VERIFIED     RACER      JESSE      THOMAS
# 1358613                 VERIFIED     RACER      JESSE      THOMAS
# 1358614                 VERIFIED     RACER      JESSE      THOMAS
#
#            res_street_address res_city_desc state_cd  zip_code race_code  \
# 1358603  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358604  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358605  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358606  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358607  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358608  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358609  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358610  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358611  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358612  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358613  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
# 1358614  805  ABBEYWOOD DR           WAXHAW       NC   28173.0         W
#
#         ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 1358603          NL      REP           M         32         NaN           Y
# 1358604          NL      REP           M         32         NaN           Y
# 1358605          NL      REP           M         32         NaN           Y
# ...
# 1543349          NL      DEM           M         40          MO           Y
#
#          registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 1543338  01/13/2011           028D          028D              9.0
# 1543339  01/13/2011           028D          028D              9.0
# 1543340  01/13/2011           028D          028D              9.0
# 1543341  01/13/2011           028D          028D              9.0
# 1543342  01/13/2011           028D          028D              9.0
# 1543343  01/13/2011           028D          028D              9.0
# 1543344  01/13/2011           028D          028D              9.0
# 1543345  01/13/2011           028D          028D              9.0
# 1543346  01/13/2011           028D          028D              9.0
# 1543347  01/13/2011           028D          028D              9.0
# 1543348  01/13/2011           028D          028D              9.0
# 1543349  01/13/2011           028D          028D              9.0
#
#         super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 1543338               20B              20C             35.0            68.0
# 1543339               20B              20C             35.0            68.0
# 1543340               20B              20C             35.0            68.0
# 1543341               20B              20C             35.0            68.0
# 1543342               20B              20C             35.0            68.0
# 1543343               20B              20C             35.0            68.0
# 1543344               20B              20C             35.0            68.0
# 1543345               20B              20C             35.0            68.0
# 1543346               20B              20C             35.0            68.0
# 1543347               20B              20C             35.0            68.0
# 1543348               20B              20C             35.0            68.0
# 1543349               20B              20C             35.0            68.0
#
#          school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 1543338                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543339                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543340                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543341                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543342                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543343                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543344                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543345                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543346                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543347                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543348                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1543349                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
#
#         confidential_ind  birth_year vtd_abbrv vtd_desc
# 1543338                N        1980       028      028
# 1543339                N        1980       028      028
# 1543340                N        1980       028      028
# 1543341                N        1980       028      028
# 1543342                N        1980       028      028
# 1543343                N        1980       028      028
# 1543344                N        1980       028      028
# 1543345                N        1980       028      028
# 1543346                N        1980       028      028
# 1543347                N        1980       028      028
# 1543348                N        1980       028      028
# 1543349                N        1980       028      028
#              ncid       election_desc  county_id county_desc  voter_reg_num  \
# 1625685  DB153036  11/03/2020 GENERAL       90.0       UNION       364740.0
# 1625686  DB153036  11/06/2012 GENERAL       90.0       UNION       364740.0
# 1625687  DB153036  11/06/2012 GENERAL       90.0       UNION       364740.0
# 1625688  DB153036  05/08/2012 PRIMARY       90.0       UNION       364740.0
# 1625689  DB153036  03/15/2016 PRIMARY       90.0       UNION       364740.0
# 1625690  DB153036  03/15/2016 PRIMARY       90.0       UNION       364740.0
# 1625691  DB153036  11/06/2018 GENERAL       90.0       UNION       364740.0
# 1625692  DB153036  11/08/2016 GENERAL       90.0       UNION       364740.0
# 1625693  DB153036  11/08/2016 GENERAL       90.0       UNION       364740.0
# 1625694  DB153036  11/04/2014 GENERAL       90.0       UNION       364740.0
# 1625695  DB153036  03/03/2020 PRIMARY        NaN         NaN            NaN
# 1625696  DB153036  05/08/2018 PRIMARY        NaN         NaN            NaN
# 1625697  DB153036  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1625698  DB153036                None        NaN         NaN            NaN
#
#         election_lbl     voting_method voted_party_cd voted_party_desc  \
# 1625685   11/03/2020  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1625686   11/06/2012  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1625687   11/06/2012  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1625688   05/08/2012         IN-PERSON            DEM       DEMOCRATIC
# 1625689   03/15/2016  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 1625690   03/15/2016         IN-PERSON            REP       REPUBLICAN
# 1625691   11/06/2018         IN-PERSON            UNA     UNAFFILIATED
# 1625692   11/08/2016  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1625693   11/08/2016  ABSENTEE ONESTOP            REP       REPUBLICAN
# 1625694   11/04/2014  ABSENTEE ONESTOP            UNA     UNAFFILIATED
# 1625695          NaN               NaN            NaN              NaN
# 1625696          NaN               NaN            NaN              NaN
# 1625697          NaN               NaN            NaN              NaN
# 1625698          NaN               NaN            NaN              NaN
#
#         pct_label pct_description  voted_county_id voted_county_desc  \
# 1625685      020A            020A             90.0             UNION
# 1625686       W25             W25             65.0       NEW HANOVER
# 1625687      0070           SALEM             12.0             BURKE
# 1625688       W25             W25             65.0       NEW HANOVER
# 1625689       W16             W16             65.0       NEW HANOVER
# 1625690      0070           SALEM             12.0             BURKE
# 1625691      CF02            CF02             65.0       NEW HANOVER
# 1625692       W16             W16             65.0       NEW HANOVER
# 1625693      0070           SALEM             12.0             BURKE
# 1625694       W16             W16             65.0       NEW HANOVER
# 1625695       NaN             NaN              NaN               NaN
# 1625696       NaN             NaN              NaN               NaN
# 1625697       NaN             NaN              NaN               NaN
# 1625698       NaN             NaN              NaN               NaN
#
#         vtd_label vtd_description status_cd voter_status_desc reason_cd  \
# 1625685      020A            020A         A            ACTIVE        AV
# 1625686       W25             W25         A            ACTIVE        AV
# 1625687      0070            0070         A            ACTIVE        AV
# 1625688       W25             W25         A            ACTIVE        AV
# 1625689       W16             W16         A            ACTIVE        AV
# 1625690      0070            0070         A            ACTIVE        AV
# 1625691      CF02            CF02         A            ACTIVE        AV
# 1625692       W16             W16         A            ACTIVE        AV
# 1625693      0070            0070         A            ACTIVE        AV
# 1625694       W16             W16         A            ACTIVE        AV
# 1625695       NaN             NaN         A            ACTIVE        AV
# 1625696       NaN             NaN         A            ACTIVE        AV
# 1625697       NaN             NaN         A            ACTIVE        AV
# 1625698       NaN             NaN         A            ACTIVE        AV
#
#         voter_status_reason_desc last_name first_name middle_name  \
# 1625685                 VERIFIED   SUMMERS      JASON        BRAD
# 1625686                 VERIFIED   SUMMERS      JASON        BRAD
# 1625687                 VERIFIED   SUMMERS      JASON        BRAD
# 1625688                 VERIFIED   SUMMERS      JASON        BRAD
# 1625689                 VERIFIED   SUMMERS      JASON        BRAD
# 1625690                 VERIFIED   SUMMERS      JASON        BRAD
# 1625691                 VERIFIED   SUMMERS      JASON        BRAD
# 1625692                 VERIFIED   SUMMERS      JASON        BRAD
# 1625693                 VERIFIED   SUMMERS      JASON        BRAD
# 1625694                 VERIFIED   SUMMERS      JASON        BRAD
# 1625695                 VERIFIED   SUMMERS      JASON        BRAD
# 1625696                 VERIFIED   SUMMERS      JASON        BRAD
# 1625697                 VERIFIED   SUMMERS      JASON        BRAD
# 1625698                 VERIFIED   SUMMERS      JASON        BRAD
#
#           res_street_address res_city_desc state_cd  zip_code race_code  \
# 1625685  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625686  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625687  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625688  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625689  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625690  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625691  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625692  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625693  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625694  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625695  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625696  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625697  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
# 1625698  3806  CASSIDY DR           WAXHAW       NC   28173.0         U
#
#         ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 1625685          UN      REP           U         48         NaN           Y
# 1625686          UN      REP           U         48         NaN           Y
# 1625687          UN      REP           U         48         NaN           Y
# 1625688          UN      REP           U         48         NaN           Y
# 1625689          UN      REP           U         48         NaN           Y
# 1625690          UN      REP           U         48         NaN           Y
# 1625691          UN      REP           U         48         NaN           Y
# 1625692          UN      REP           U         48         NaN           Y
# 1625693          UN      REP           U         48         NaN           Y
# 1625694          UN      REP           U         48         NaN           Y
# 1625695          UN      REP           U         48         NaN           Y
# 1625696          UN      REP           U         48         NaN           Y
# 1625697          UN      REP           U         48         NaN           Y
# 1625698          UN      REP           U         48         NaN           Y
#
#          registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 1625685  07/17/2020           020A          020A              9.0
# 1625686  07/17/2020           020A          020A              9.0
# 1625687  07/17/2020           020A          020A              9.0
# 1625688  07/17/2020           020A          020A              9.0
# 1625689  07/17/2020           020A          020A              9.0
# 1625690  07/17/2020           020A          020A              9.0
# 1625691  07/17/2020           020A          020A              9.0
# 1625692  07/17/2020           020A          020A              9.0
# 1625693  07/17/2020           020A          020A              9.0
# 1625694  07/17/2020           020A          020A              9.0
# 1625695  07/17/2020           020A          020A              9.0
# 1625696  07/17/2020           020A          020A              9.0
# 1625697  07/17/2020           020A          020A              9.0
# 1625698  07/17/2020           020A          020A              9.0
#
#         super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 1625685               20B              20C             35.0            68.0
# 1625686               20B              20C             35.0            68.0
# 1625687               20B              20C             35.0            68.0
# 1625688               20B              20C             35.0            68.0
# 1625689               20B              20C             35.0            68.0
# 1625690               20B              20C             35.0            68.0
# 1625691               20B              20C             35.0            68.0
# 1625692               20B              20C             35.0            68.0
# 1625693               20B              20C             35.0            68.0
# 1625694               20B              20C             35.0            68.0
# 1625695               20B              20C             35.0            68.0
# 1625696               20B              20C             35.0            68.0
# 1625697               20B              20C             35.0            68.0
# 1625698               20B              20C             35.0            68.0
#
#          school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 1625685                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625686                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625687                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625688                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625689                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625690                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625691                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625692                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625693                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625694                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625695                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625696                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625697                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1625698                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
#
#         confidential_ind  birth_year vtd_abbrv vtd_desc
# 1625685                N        1972      020A     020A
# 1625686                N        1972      020A     020A
# 1625687                N        1972      020A     020A
# 1625688                N        1972      020A     020A
# 1625689                N        1972      020A     020A
# 1625690                N        1972      020A     020A
# 1625691                N        1972      020A     020A
# 1625692                N        1972      020A     020A
# 1625693                N        1972      020A     020A
# 1625694                N        1972      020A     020A
# 1625695                N        1972      020A     020A
# 1625696                N        1972      020A     020A
# 1625697                N        1972      020A     020A
# 1625698                N        1972      020A     020A

# %%
#########################################################################
# Drop the following rows to deal with duplicate votes cast by same ncid 
# in same election:
#########################################################################

## Drop 252775 for EF78820 in 2016 General 
  ## to drop Cabarrus County record for Union based on address

## Drop 281899 for EF93894 in 2012 General
  ## to drop Anson County for Union based on address

## Drop 698514 for EF69085 in 2012 General
  ## because difference is only due to slight change in encoding of vtd_label

## Drop 757080 for EF186914 in 2012 General
  ## because other record better matches other voting history

## Drop 1358607 for CW1012090 in 2018 General
  ## to drop Provisional for In-Person

## Drop 1543344 for EF164225 in 2016 General
  ## because other record better matches other voting history
voter_elecs.drop(index=[252775, 281899, 698514,
                        757080, 1358607, 1543344], inplace=True)

## Drop all record for ncid DB153036 because it has 3 elections with
  ## conflicts and records are all very inconsistent
voter_elecs.drop(index=voter_elecs.loc[voter_elecs['ncid']=='DB153036'].index,
                inplace=True)

# %%
## Check that all duplicates have been successfully dealt with
voter_elecs.duplicated(subset=['ncid', 'election_desc']).sum()
# Out:
# 0

# %%
## Drop all records for ncid EF155672 because they are listed as 
  ## being over 200 years of age
voter_elecs.drop(index=voter_elecs.loc[voter_elecs['ncid']=='EF155672'].index,
                inplace=True)

# %% [markdown]
# ## Engineer Features for Grouping and Modeling

# %%
voter_elecs.head()
# Out:
#        ncid       election_desc  county_id county_desc  voter_reg_num  \
# 0  EF230133  11/03/2020 GENERAL       90.0       UNION       346446.0
# 1  EF230133  11/06/2012 GENERAL        NaN         NaN            NaN
# 2  EF230133  05/08/2012 PRIMARY        NaN         NaN            NaN
# 3  EF230133  03/15/2016 PRIMARY        NaN         NaN            NaN
# 4  EF230133  11/06/2018 GENERAL        NaN         NaN            NaN
#
#   election_lbl     voting_method voted_party_cd voted_party_desc pct_label  \
# 0   11/03/2020  ABSENTEE ONESTOP            UNA     UNAFFILIATED      020A
# 1          NaN               NaN            NaN              NaN       NaN
# 2          NaN               NaN            NaN              NaN       NaN
# 3          NaN               NaN            NaN              NaN       NaN
# 4          NaN               NaN            NaN              NaN       NaN
#
#   pct_description  voted_county_id voted_county_desc vtd_label  \
# 0            020A             90.0             UNION      020A
# 1             NaN              NaN               NaN       NaN
# 2             NaN              NaN               NaN       NaN
# 3             NaN              NaN               NaN       NaN
# 4             NaN              NaN               NaN       NaN
#
#   vtd_description status_cd voter_status_desc reason_cd  \
# 0            020A         A            ACTIVE        AV
# 1             NaN         A            ACTIVE        AV
# 2             NaN         A            ACTIVE        AV
# 3             NaN         A            ACTIVE        AV
# 4             NaN         A            ACTIVE        AV
#
#   voter_status_reason_desc last_name first_name middle_name  \
# 0                 VERIFIED    AALAEI       ARIO         NaN
# 1                 VERIFIED    AALAEI       ARIO         NaN
# 2                 VERIFIED    AALAEI       ARIO         NaN
# 3                 VERIFIED    AALAEI       ARIO         NaN
# 4                 VERIFIED    AALAEI       ARIO         NaN
#
#          res_street_address res_city_desc state_cd  zip_code race_code  \
# 0  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 1  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 2  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 3  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 4  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
#
#   ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 0          NL      UNA           M         46          OC           Y
# 1          NL      UNA           M         46          OC           Y
# 2          NL      UNA           M         46          OC           Y
# 3          NL      UNA           M         46          OC           Y
# 4          NL      UNA           M         46          OC           Y
#
#    registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv super_court_abbrv  \
# 0  04/25/2019           020A          020A              9.0               20B
# 1  04/25/2019           020A          020A              9.0               20B
# 2  04/25/2019           020A          020A              9.0               20B
# 3  04/25/2019           020A          020A              9.0               20B
# 4  04/25/2019           020A          020A              9.0               20B
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 0              20C             35.0            68.0                2.0
# 1              20C             35.0            68.0                2.0
# 2              20C             35.0            68.0                2.0
# 3              20C             35.0            68.0                2.0
# 4              20C             35.0            68.0                2.0
#
#   school_dist_desc  dist_1_abbrv         dist_1_desc confidential_ind  \
# 0        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 1        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 2        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 3        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 4        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
#
#    birth_year vtd_abbrv vtd_desc
# 0        1974      020A     020A
# 1        1974      020A     020A
# 2        1974      020A     020A
# 3        1974      020A     020A
# 4        1974      020A     020A

# %%
## Create a new column specifying the election category based on the
  ## election description col
voter_elecs.insert(loc=6, column='election_cat', 
                 value=voter_elecs['election_desc'].str.split(n=1,
                                                            expand=True)[1])

# If the category was general or primary, leave as is, otherwise 'other'
voter_elecs['election_cat'] = np.where(voter_elecs['election_cat'].isin(
                                                    ['GENERAL', 'PRIMARY']),
                                     voter_elecs['election_cat'], 'other')

# %%
## Recast election_lbl as datetime
voter_elecs['election_lbl'] = pd.to_datetime(
    voter_elecs['election_desc'].str.split(' ',
                                           n=1).apply(
        # Where election_desc is 'None' fill with NaN
        lambda x: x[0]).replace({'None':np.nan}))

## Create a new col for just the year
voter_elecs.insert(loc=5, column='election_yr',
                 value=voter_elecs['election_lbl'].dt.year)

# %%
## Create a binary variable indicating whether or not in individual registered
  ## in time to vote in that election

# Calculate normal registration deadline for the election
  # (25 days before election in NC, but afterwards have option to register 
  #  in person during early voting period)
voter_elecs.insert(loc=7, column='registr_deadline',
                 value=pd.to_datetime(voter_elecs['election_lbl'] - dt.timedelta(days=25)))

# Recast voter registration date as datetime variable 
voter_elecs['registr_dt'] = pd.to_datetime(voter_elecs['registr_dt'])

# Check whether or not an individual voted (if they did, they were registered
  # in time and may have registered in person after the normal deadline) and
  # compare registration date to registration deadline
voter_elecs.insert(loc=8, column='registr_in_time',
                 value=np.where(((voter_elecs['voting_method'].isna()) & 
                                 (voter_elecs['registr_dt'] > voter_elecs['registr_deadline'])),
                                0,1))

# %%
## Create a column for age adjusted according to the specific election year
voter_elecs.insert(loc=9, column='birth_age_adj',
                   value=voter_elecs['election_yr'].subtract(voter_elecs['birth_year']))

# %%
## Create a new binary variable indicating if it was a presidential election
voter_elecs.insert(loc=10, column='presid_elec',
                 value=np.where(((voter_elecs['election_yr']%4 == 0) & 
                                 (voter_elecs['election_cat'].isin(
                                     ['GENERAL', 'PRIMARY']))),
                                1,0))

# %%
## Group original vote methods into more general categories in a new variable
 # Map the original categoriess to new ones
vote_method_map = {'ABSENTEE ONESTOP': 'Early',
                   'IN-PERSON': 'Election Day',
                   'ABSENTEE BY MAIL': 'Early',
                   'ABSENTEE CURBSIDE': 'Early',
                   'TRANSFER': 'Other',
                   'PROVISIONAL': 'Other',
                   'CURBSIDE': 'Election Day'}

# Apply the map to create new vote_method_cat column
voter_elecs.insert(loc=11, column='vote_method_cat',
                 value=voter_elecs['voting_method'].map(vote_method_map))

## Create new binary variables indicating whether or not they voted:
# early
voter_elecs.insert(loc=12, column='vote_early',
                 value=np.where(voter_elecs['voting_method'].isin(
                     ['ABSENTEE ONESTOP', 'ABSENTEE CURBSIDE']),
                                1,0))
# by mail
voter_elecs.insert(loc=13, column='vote_by_mail',
                 value=np.where(voter_elecs['voting_method'] == 'ABSENTEE BY MAIL',
                                1,0))
# curbside 
voter_elecs.insert(loc=14, column='vote_curbside',
                 value=np.where(voter_elecs['voting_method'].isin(
                     ['CURBSIDE', 'ABSENTEE CURBSIDE']),
                                1,0))

# %%
## Where election_desc is 'None', the record is not specific to any election
  ## (serves as placeholder to keep in individuals that are registered but
    ## have no recent voting history), so the following fields should be null
voter_elecs.loc[voter_elecs['election_desc']=='None',
              ['election_cat', 'presid_elec',
               'vote_early', 'vote_by_mail',
               'vote_curbside']] = np.nan

# %%
## Inspect updated df
voter_elecs.head(35)
# Out:
#         ncid       election_desc  county_id county_desc  voter_reg_num  \
# 0   EF230133  11/03/2020 GENERAL       90.0       UNION       346446.0
# 1   EF230133  11/06/2012 GENERAL        NaN         NaN            NaN
# 2   EF230133  05/08/2012 PRIMARY        NaN         NaN            NaN
# 3   EF230133  03/15/2016 PRIMARY        NaN         NaN            NaN
# 4   EF230133  11/06/2018 GENERAL        NaN         NaN            NaN
# 5   EF230133  11/08/2016 GENERAL        NaN         NaN            NaN
# 6   EF230133  11/04/2014 GENERAL        NaN         NaN            NaN
# 7   EF230133  03/03/2020 PRIMARY        NaN         NaN            NaN
# 8   EF230133  05/08/2018 PRIMARY        NaN         NaN            NaN
# 9   EF230133  05/06/2014 PRIMARY        NaN         NaN            NaN
# 10  EF230133                None        NaN         NaN            NaN
# 11  EF231096  11/03/2020 GENERAL       90.0       UNION       348004.0
# 12  EF231096  11/06/2012 GENERAL        NaN         NaN            NaN
# 13  EF231096  05/08/2012 PRIMARY        NaN         NaN            NaN
# 14  EF231096  03/15/2016 PRIMARY        NaN         NaN            NaN
# 15  EF231096  11/06/2018 GENERAL        NaN         NaN            NaN
# 16  EF231096  11/08/2016 GENERAL        NaN         NaN            NaN
# 17  EF231096  11/04/2014 GENERAL        NaN         NaN            NaN
# 18  EF231096  03/03/2020 PRIMARY        NaN         NaN            NaN
# 19  EF231096  05/08/2018 PRIMARY        NaN         NaN            NaN
# 20  EF231096  05/06/2014 PRIMARY        NaN         NaN            NaN
# 21  EF231096                None        NaN         NaN            NaN
# 22  AL261840  11/03/2020 GENERAL        NaN         NaN            NaN
# 23  AL261840  11/06/2012 GENERAL        NaN         NaN            NaN
# 24  AL261840  05/08/2012 PRIMARY        NaN         NaN            NaN
# 25  AL261840  03/15/2016 PRIMARY        NaN         NaN            NaN
# 26  AL261840  11/06/2018 GENERAL        NaN         NaN            NaN
# 27  AL261840  11/08/2016 GENERAL        NaN         NaN            NaN
# 28  AL261840  11/04/2014 GENERAL        NaN         NaN            NaN
# 29  AL261840  03/03/2020 PRIMARY        NaN         NaN            NaN
# 30  AL261840  05/08/2018 PRIMARY        NaN         NaN            NaN
# 31  AL261840  05/06/2014 PRIMARY        NaN         NaN            NaN
# 32  AL261840                None        NaN         NaN            NaN
# 33  AL178177  11/03/2020 GENERAL       90.0       UNION       288489.0
# 34  AL178177  11/06/2012 GENERAL       90.0       UNION       288489.0
#
#     election_yr election_lbl registr_deadline  registr_in_time  birth_age_adj  \
# 0        2020.0   2020-11-03       2020-10-09                1           46.0
# 1        2012.0   2012-11-06       2012-10-12                0           38.0
# 2        2012.0   2012-05-08       2012-04-13                0           38.0
# 3        2016.0   2016-03-15       2016-02-19                0           42.0
# 4        2018.0   2018-11-06       2018-10-12                0           44.0
# 5        2016.0   2016-11-08       2016-10-14                0           42.0
# 6        2014.0   2014-11-04       2014-10-10                0           40.0
# 7        2020.0   2020-03-03       2020-02-07                1           46.0
# 8        2018.0   2018-05-08       2018-04-13                0           44.0
# 9        2014.0   2014-05-06       2014-04-11                0           40.0
# 10          NaN          NaT              NaT                1            NaN
# 11       2020.0   2020-11-03       2020-10-09                1           46.0
# 12       2012.0   2012-11-06       2012-10-12                0           38.0
# 13       2012.0   2012-05-08       2012-04-13                0           38.0
# 14       2016.0   2016-03-15       2016-02-19                0           42.0
# 15       2018.0   2018-11-06       2018-10-12                0           44.0
# 16       2016.0   2016-11-08       2016-10-14                0           42.0
# 17       2014.0   2014-11-04       2014-10-10                0           40.0
# 18       2020.0   2020-03-03       2020-02-07                1           46.0
# 19       2018.0   2018-05-08       2018-04-13                0           44.0
# 20       2014.0   2014-05-06       2014-04-11                0           40.0
# 21          NaN          NaT              NaT                1            NaN
# 22       2020.0   2020-11-03       2020-10-09                1           26.0
# 23       2012.0   2012-11-06       2012-10-12                0           18.0
# 24       2012.0   2012-05-08       2012-04-13                0           18.0
# 25       2016.0   2016-03-15       2016-02-19                1           22.0
# 26       2018.0   2018-11-06       2018-10-12                1           24.0
# 27       2016.0   2016-11-08       2016-10-14                1           22.0
# 28       2014.0   2014-11-04       2014-10-10                1           20.0
# 29       2020.0   2020-03-03       2020-02-07                1           26.0
# 30       2018.0   2018-05-08       2018-04-13                1           24.0
# 31       2014.0   2014-05-06       2014-04-11                1           20.0
# 32          NaN          NaT              NaT                1            NaN
# 33       2020.0   2020-11-03       2020-10-09                1           62.0
# 34       2012.0   2012-11-06       2012-10-12                1           54.0
#
#     presid_elec vote_method_cat  vote_early  vote_by_mail  vote_curbside  \
# 0           1.0           Early         1.0           0.0            0.0
# 1           1.0             NaN         0.0           0.0            0.0
# 2           1.0             NaN         0.0           0.0            0.0
# 3           1.0             NaN         0.0           0.0            0.0
# 4           0.0             NaN         0.0           0.0            0.0
# 5           1.0             NaN         0.0           0.0            0.0
# 6           0.0             NaN         0.0           0.0            0.0
# 7           1.0             NaN         0.0           0.0            0.0
# 8           0.0             NaN         0.0           0.0            0.0
# 9           0.0             NaN         0.0           0.0            0.0
# 10          NaN             NaN         NaN           NaN            NaN
# 11          1.0           Early         1.0           0.0            0.0
# 12          1.0             NaN         0.0           0.0            0.0
# 13          1.0             NaN         0.0           0.0            0.0
# 14          1.0             NaN         0.0           0.0            0.0
# 15          0.0             NaN         0.0           0.0            0.0
# 16          1.0             NaN         0.0           0.0            0.0
# 17          0.0             NaN         0.0           0.0            0.0
# 18          1.0             NaN         0.0           0.0            0.0
# 19          0.0             NaN         0.0           0.0            0.0
# 20          0.0             NaN         0.0           0.0            0.0
# 21          NaN             NaN         NaN           NaN            NaN
# 22          1.0             NaN         0.0           0.0            0.0
# 23          1.0             NaN         0.0           0.0            0.0
# 24          1.0             NaN         0.0           0.0            0.0
# 25          1.0             NaN         0.0           0.0            0.0
# 26          0.0             NaN         0.0           0.0            0.0
# 27          1.0             NaN         0.0           0.0            0.0
# 28          0.0             NaN         0.0           0.0            0.0
# 29          1.0             NaN         0.0           0.0            0.0
# 30          0.0             NaN         0.0           0.0            0.0
# 31          0.0             NaN         0.0           0.0            0.0
# 32          NaN             NaN         NaN           NaN            NaN
# 33          1.0           Early         1.0           0.0            0.0
# 34          1.0           Early         1.0           0.0            0.0
#
#    election_cat     voting_method voted_party_cd voted_party_desc pct_label  \
# 0       GENERAL  ABSENTEE ONESTOP            UNA     UNAFFILIATED      020A
# 1       GENERAL               NaN            NaN              NaN       NaN
# 2       PRIMARY               NaN            NaN              NaN       NaN
# 3       PRIMARY               NaN            NaN              NaN       NaN
# 4       GENERAL               NaN            NaN              NaN       NaN
# 5       GENERAL               NaN            NaN              NaN       NaN
# 6       GENERAL               NaN            NaN              NaN       NaN
# 7       PRIMARY               NaN            NaN              NaN       NaN
# 8       PRIMARY               NaN            NaN              NaN       NaN
# 9       PRIMARY               NaN            NaN              NaN       NaN
# 10          NaN               NaN            NaN              NaN       NaN
# 11      GENERAL  ABSENTEE ONESTOP            DEM       DEMOCRATIC      020A
# 12      GENERAL               NaN            NaN              NaN       NaN
# 13      PRIMARY               NaN            NaN              NaN       NaN
# 14      PRIMARY               NaN            NaN              NaN       NaN
# 15      GENERAL               NaN            NaN              NaN       NaN
# 16      GENERAL               NaN            NaN              NaN       NaN
# 17      GENERAL               NaN            NaN              NaN       NaN
# 18      PRIMARY               NaN            NaN              NaN       NaN
# 19      PRIMARY               NaN            NaN              NaN       NaN
# 20      PRIMARY               NaN            NaN              NaN       NaN
# 21          NaN               NaN            NaN              NaN       NaN
# 22      GENERAL               NaN            NaN              NaN       NaN
# 23      GENERAL               NaN            NaN              NaN       NaN
# 24      PRIMARY               NaN            NaN              NaN       NaN
# 25      PRIMARY               NaN            NaN              NaN       NaN
# 26      GENERAL               NaN            NaN              NaN       NaN
# 27      GENERAL               NaN            NaN              NaN       NaN
# 28      GENERAL               NaN            NaN              NaN       NaN
# 29      PRIMARY               NaN            NaN              NaN       NaN
# 30      PRIMARY               NaN            NaN              NaN       NaN
# 31      PRIMARY               NaN            NaN              NaN       NaN
# 32          NaN               NaN            NaN              NaN       NaN
# 33      GENERAL  ABSENTEE ONESTOP            UNA     UNAFFILIATED      029A
# 34      GENERAL  ABSENTEE ONESTOP            UNA     UNAFFILIATED      26.1
#
#    pct_description  voted_county_id voted_county_desc vtd_label  \
# 0             020A             90.0             UNION      020A
# 1              NaN              NaN               NaN       NaN
# 2              NaN              NaN               NaN       NaN
# 3              NaN              NaN               NaN       NaN
# 4              NaN              NaN               NaN       NaN
# 5              NaN              NaN               NaN       NaN
# 6              NaN              NaN               NaN       NaN
# 7              NaN              NaN               NaN       NaN
# 8              NaN              NaN               NaN       NaN
# 9              NaN              NaN               NaN       NaN
# 10             NaN              NaN               NaN       NaN
# 11            020A             90.0             UNION      020A
# 12             NaN              NaN               NaN       NaN
# 13             NaN              NaN               NaN       NaN
# 14             NaN              NaN               NaN       NaN
# 15             NaN              NaN               NaN       NaN
# 16             NaN              NaN               NaN       NaN
# 17             NaN              NaN               NaN       NaN
# 18             NaN              NaN               NaN       NaN
# 19             NaN              NaN               NaN       NaN
# 20             NaN              NaN               NaN       NaN
# 21             NaN              NaN               NaN       NaN
# 22             NaN              NaN               NaN       NaN
# 23             NaN              NaN               NaN       NaN
# 24             NaN              NaN               NaN       NaN
# 25             NaN              NaN               NaN       NaN
# 26             NaN              NaN               NaN       NaN
# 27             NaN              NaN               NaN       NaN
# 28             NaN              NaN               NaN       NaN
# 29             NaN              NaN               NaN       NaN
# 30             NaN              NaN               NaN       NaN
# 31             NaN              NaN               NaN       NaN
# 32             NaN              NaN               NaN       NaN
# 33            029A             90.0             UNION      029A
# 34            26.1             11.0          BUNCOMBE      26.1
#
#    vtd_description status_cd voter_status_desc reason_cd  \
# 0             020A         A            ACTIVE        AV
# 1              NaN         A            ACTIVE        AV
# 2              NaN         A            ACTIVE        AV
# 3              NaN         A            ACTIVE        AV
# 4              NaN         A            ACTIVE        AV
# 5              NaN         A            ACTIVE        AV
# 6              NaN         A            ACTIVE        AV
# 7              NaN         A            ACTIVE        AV
# 8              NaN         A            ACTIVE        AV
# 9              NaN         A            ACTIVE        AV
# 10             NaN         A            ACTIVE        AV
# 11            020A         A            ACTIVE        AV
# 12             NaN         A            ACTIVE        AV
# 13             NaN         A            ACTIVE        AV
# 14             NaN         A            ACTIVE        AV
# 15             NaN         A            ACTIVE        AV
# 16             NaN         A            ACTIVE        AV
# 17             NaN         A            ACTIVE        AV
# 18             NaN         A            ACTIVE        AV
# 19             NaN         A            ACTIVE        AV
# 20             NaN         A            ACTIVE        AV
# 21             NaN         A            ACTIVE        AV
# 22             NaN         A            ACTIVE        AV
# 23             NaN         A            ACTIVE        AV
# 24             NaN         A            ACTIVE        AV
# 25             NaN         A            ACTIVE        AV
# 26             NaN         A            ACTIVE        AV
# 27             NaN         A            ACTIVE        AV
# 28             NaN         A            ACTIVE        AV
# 29             NaN         A            ACTIVE        AV
# 30             NaN         A            ACTIVE        AV
# 31             NaN         A            ACTIVE        AV
# 32             NaN         A            ACTIVE        AV
# 33            029A         A            ACTIVE        AV
# 34            26.1         A            ACTIVE        AV
#
#    voter_status_reason_desc last_name first_name middle_name  \
# 0                  VERIFIED    AALAEI       ARIO         NaN
# 1                  VERIFIED    AALAEI       ARIO         NaN
# 2                  VERIFIED    AALAEI       ARIO         NaN
# 3                  VERIFIED    AALAEI       ARIO         NaN
# 4                  VERIFIED    AALAEI       ARIO         NaN
# 5                  VERIFIED    AALAEI       ARIO         NaN
# 6                  VERIFIED    AALAEI       ARIO         NaN
# 7                  VERIFIED    AALAEI       ARIO         NaN
# 8                  VERIFIED    AALAEI       ARIO         NaN
# 9                  VERIFIED    AALAEI       ARIO         NaN
# 10                 VERIFIED    AALAEI       ARIO         NaN
# 11                 VERIFIED    AALAEI    KAVITHA         NaN
# 12                 VERIFIED    AALAEI    KAVITHA         NaN
# 13                 VERIFIED    AALAEI    KAVITHA         NaN
# 14                 VERIFIED    AALAEI    KAVITHA         NaN
# 15                 VERIFIED    AALAEI    KAVITHA         NaN
# 16                 VERIFIED    AALAEI    KAVITHA         NaN
# 17                 VERIFIED    AALAEI    KAVITHA         NaN
# 18                 VERIFIED    AALAEI    KAVITHA         NaN
# 19                 VERIFIED    AALAEI    KAVITHA         NaN
# 20                 VERIFIED    AALAEI    KAVITHA         NaN
# 21                 VERIFIED    AALAEI    KAVITHA         NaN
# 22                 VERIFIED   AALBORG     ALEXIS       LEANN
# 23                 VERIFIED   AALBORG     ALEXIS       LEANN
# 24                 VERIFIED   AALBORG     ALEXIS       LEANN
# 25                 VERIFIED   AALBORG     ALEXIS       LEANN
# 26                 VERIFIED   AALBORG     ALEXIS       LEANN
# 27                 VERIFIED   AALBORG     ALEXIS       LEANN
# 28                 VERIFIED   AALBORG     ALEXIS       LEANN
# 29                 VERIFIED   AALBORG     ALEXIS       LEANN
# 30                 VERIFIED   AALBORG     ALEXIS       LEANN
# 31                 VERIFIED   AALBORG     ALEXIS       LEANN
# 32                 VERIFIED   AALBORG     ALEXIS       LEANN
# 33                 VERIFIED   AALBORG      BRYAN         LEE
# 34                 VERIFIED   AALBORG      BRYAN         LEE
#
#            res_street_address res_city_desc state_cd  zip_code race_code  \
# 0    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 1    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 2    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 3    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 4    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 5    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 6    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 7    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 8    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 9    4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 10   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 11   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 12   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 13   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 14   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 15   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 16   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 17   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 18   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 19   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 20   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 21   4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         A
# 22  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 23  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 24  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 25  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 26  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 27  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 28  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 29  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 30  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 31  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 32  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 33  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 34  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
#
#    ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 0           NL      UNA           M         46          OC           Y
# 1           NL      UNA           M         46          OC           Y
# 2           NL      UNA           M         46          OC           Y
# 3           NL      UNA           M         46          OC           Y
# 4           NL      UNA           M         46          OC           Y
# 5           NL      UNA           M         46          OC           Y
# 6           NL      UNA           M         46          OC           Y
# 7           NL      UNA           M         46          OC           Y
# 8           NL      UNA           M         46          OC           Y
# 9           NL      UNA           M         46          OC           Y
# 10          NL      UNA           M         46          OC           Y
# 11          NL      DEM           F         46          OC           Y
# 12          NL      DEM           F         46          OC           Y
# 13          NL      DEM           F         46          OC           Y
# 14          NL      DEM           F         46          OC           Y
# 15          NL      DEM           F         46          OC           Y
# 16          NL      DEM           F         46          OC           Y
# 17          NL      DEM           F         46          OC           Y
# 18          NL      DEM           F         46          OC           Y
# 19          NL      DEM           F         46          OC           Y
# 20          NL      DEM           F         46          OC           Y
# 21          NL      DEM           F         46          OC           Y
# 22          NL      UNA           F         26          IA           Y
# 23          NL      UNA           F         26          IA           Y
# 24          NL      UNA           F         26          IA           Y
# 25          NL      UNA           F         26          IA           Y
# 26          NL      UNA           F         26          IA           Y
# 27          NL      UNA           F         26          IA           Y
# 28          NL      UNA           F         26          IA           Y
# 29          NL      UNA           F         26          IA           Y
# 30          NL      UNA           F         26          IA           Y
# 31          NL      UNA           F         26          IA           Y
# 32          NL      UNA           F         26          IA           Y
# 33          UN      UNA           M         62          OK           Y
# 34          UN      UNA           M         62          OK           Y
#
#    registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv super_court_abbrv  \
# 0  2019-04-25           020A          020A              9.0               20B
# 1  2019-04-25           020A          020A              9.0               20B
# 2  2019-04-25           020A          020A              9.0               20B
# 3  2019-04-25           020A          020A              9.0               20B
# 4  2019-04-25           020A          020A              9.0               20B
# 5  2019-04-25           020A          020A              9.0               20B
# 6  2019-04-25           020A          020A              9.0               20B
# 7  2019-04-25           020A          020A              9.0               20B
# 8  2019-04-25           020A          020A              9.0               20B
# 9  2019-04-25           020A          020A              9.0               20B
# 10 2019-04-25           020A          020A              9.0               20B
# 11 2019-06-24           020A          020A              9.0               20B
# 12 2019-06-24           020A          020A              9.0               20B
# 13 2019-06-24           020A          020A              9.0               20B
# 14 2019-06-24           020A          020A              9.0               20B
# 15 2019-06-24           020A          020A              9.0               20B
# 16 2019-06-24           020A          020A              9.0               20B
# 17 2019-06-24           020A          020A              9.0               20B
# 18 2019-06-24           020A          020A              9.0               20B
# 19 2019-06-24           020A          020A              9.0               20B
# 20 2019-06-24           020A          020A              9.0               20B
# 21 2019-06-24           020A          020A              9.0               20B
# 22 2013-11-04           029A          029A              9.0               20B
# 23 2013-11-04           029A          029A              9.0               20B
# 24 2013-11-04           029A          029A              9.0               20B
# 25 2013-11-04           029A          029A              9.0               20B
# 26 2013-11-04           029A          029A              9.0               20B
# 27 2013-11-04           029A          029A              9.0               20B
# 28 2013-11-04           029A          029A              9.0               20B
# 29 2013-11-04           029A          029A              9.0               20B
# 30 2013-11-04           029A          029A              9.0               20B
# 31 2013-11-04           029A          029A              9.0               20B
# 32 2013-11-04           029A          029A              9.0               20B
# 33 2014-09-17           029A          029A              9.0               20B
# 34 2014-09-17           029A          029A              9.0               20B
#
#    judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 0               20C             35.0            68.0                2.0
# 1               20C             35.0            68.0                2.0
# 2               20C             35.0            68.0                2.0
# 3               20C             35.0            68.0                2.0
# 4               20C             35.0            68.0                2.0
# 5               20C             35.0            68.0                2.0
# 6               20C             35.0            68.0                2.0
# 7               20C             35.0            68.0                2.0
# 8               20C             35.0            68.0                2.0
# 9               20C             35.0            68.0                2.0
# 10              20C             35.0            68.0                2.0
# 11              20C             35.0            68.0                2.0
# 12              20C             35.0            68.0                2.0
# 13              20C             35.0            68.0                2.0
# 14              20C             35.0            68.0                2.0
# 15              20C             35.0            68.0                2.0
# 16              20C             35.0            68.0                2.0
# 17              20C             35.0            68.0                2.0
# 18              20C             35.0            68.0                2.0
# 19              20C             35.0            68.0                2.0
# 20              20C             35.0            68.0                2.0
# 21              20C             35.0            68.0                2.0
# 22              20C             35.0            68.0                3.0
# 23              20C             35.0            68.0                3.0
# 24              20C             35.0            68.0                3.0
# 25              20C             35.0            68.0                3.0
# 26              20C             35.0            68.0                3.0
# 27              20C             35.0            68.0                3.0
# 28              20C             35.0            68.0                3.0
# 29              20C             35.0            68.0                3.0
# 30              20C             35.0            68.0                3.0
# 31              20C             35.0            68.0                3.0
# 32              20C             35.0            68.0                3.0
# 33              20C             35.0            68.0                3.0
# 34              20C             35.0            68.0                3.0
#
#    school_dist_desc  dist_1_abbrv         dist_1_desc confidential_ind  \
# 0         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 1         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 2         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 3         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 4         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 5         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 6         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 7         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 8         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 9         SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 10        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 11        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 12        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 13        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 14        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 15        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 16        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 17        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 18        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 19        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 20        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 21        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 22        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 23        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 24        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 25        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 26        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 27        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 28        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 29        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 30        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 31        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 32        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 33        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 34        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
#
#     birth_year vtd_abbrv vtd_desc
# 0         1974      020A     020A
# 1         1974      020A     020A
# 2         1974      020A     020A
# 3         1974      020A     020A
# 4         1974      020A     020A
# 5         1974      020A     020A
# 6         1974      020A     020A
# 7         1974      020A     020A
# 8         1974      020A     020A
# 9         1974      020A     020A
# 10        1974      020A     020A
# 11        1974      020A     020A
# 12        1974      020A     020A
# 13        1974      020A     020A
# 14        1974      020A     020A
# 15        1974      020A     020A
# 16        1974      020A     020A
# 17        1974      020A     020A
# 18        1974      020A     020A
# 19        1974      020A     020A
# 20        1974      020A     020A
# 21        1974      020A     020A
# 22        1994      029A     029A
# 23        1994      029A     029A
# 24        1994      029A     029A
# 25        1994      029A     029A
# 26        1994      029A     029A
# 27        1994      029A     029A
# 28        1994      029A     029A
# 29        1994      029A     029A
# 30        1994      029A     029A
# 31        1994      029A     029A
# 32        1994      029A     029A
# 33        1958      029A     029A
# 34        1958      029A     029A

# %%
## Voters that are recorded as having registered in time to vote in a 
  ## specific election but were not old enough to vote
voter_elecs.loc[(voter_elecs['birth_age_adj']<18) & 
                (voter_elecs['registr_in_time']==1)]
## Only one record shows a vote, EF123256 who is recorded as having cast a 
  ## vote at the age of 16 in the 2012 general election
## All these records can be safely dropped for the corresponding election
# Out:
#              ncid       election_desc  county_id county_desc  voter_reg_num  \
# 2776     EF233487  11/06/2018 GENERAL        NaN         NaN            NaN
# 2780     EF233487  05/08/2018 PRIMARY        NaN         NaN            NaN
# 15141    EF219232  11/08/2016 GENERAL        NaN         NaN            NaN
# 37599    EF234272  11/06/2012 GENERAL        NaN         NaN            NaN
# 37600    EF234272  05/08/2012 PRIMARY        NaN         NaN            NaN
# 37601    EF234272  03/15/2016 PRIMARY        NaN         NaN            NaN
# 37602    EF234272  11/06/2018 GENERAL        NaN         NaN            NaN
# 37603    EF234272  11/08/2016 GENERAL        NaN         NaN            NaN
# 37604    EF234272  11/04/2014 GENERAL        NaN         NaN            NaN
# 37606    EF234272  05/08/2018 PRIMARY        NaN         NaN            NaN
# 37607    EF234272  05/06/2014 PRIMARY        NaN         NaN            NaN
# 45893    EF123256  11/06/2012 GENERAL       90.0       UNION       199898.0
# 45894    EF123256  05/08/2012 PRIMARY        NaN         NaN            NaN
# 63860    EF215487  11/08/2016 GENERAL        NaN         NaN            NaN
# 70742    EF207609  11/06/2012 GENERAL        NaN         NaN            NaN
# 70743    EF207609  05/08/2012 PRIMARY        NaN         NaN            NaN
# 70747    EF207609  11/04/2014 GENERAL        NaN         NaN            NaN
# 70750    EF207609  05/06/2014 PRIMARY        NaN         NaN            NaN
# 88885    EF214600  11/08/2016 GENERAL        NaN         NaN            NaN
# 94154    EF217651  11/08/2016 GENERAL        NaN         NaN            NaN
# 118144   EF228021  11/06/2018 GENERAL        NaN         NaN            NaN
# 118148   EF228021  05/08/2018 PRIMARY        NaN         NaN            NaN
# 167920   EF214599  11/08/2016 GENERAL        NaN         NaN            NaN
# 209686   EF227298  11/06/2018 GENERAL        NaN         NaN            NaN
# 209690   EF227298  05/08/2018 PRIMARY        NaN         NaN            NaN
# 250541   EF214955  11/08/2016 GENERAL        NaN         NaN            NaN
# 324936   EF214956  11/08/2016 GENERAL        NaN         NaN            NaN
# 340292   EF217652  11/08/2016 GENERAL        NaN         NaN            NaN
# 345461   EF234214  11/06/2018 GENERAL        NaN         NaN            NaN
# 345465   EF234214  05/08/2018 PRIMARY        NaN         NaN            NaN
# 358625   EF228471  11/06/2012 GENERAL        NaN         NaN            NaN
# 358626   EF228471  05/08/2012 PRIMARY        NaN         NaN            NaN
# 358627   EF228471  03/15/2016 PRIMARY        NaN         NaN            NaN
# 358628   EF228471  11/06/2018 GENERAL        NaN         NaN            NaN
# 358629   EF228471  11/08/2016 GENERAL        NaN         NaN            NaN
# 358630   EF228471  11/04/2014 GENERAL        NaN         NaN            NaN
# 358632   EF228471  05/08/2018 PRIMARY        NaN         NaN            NaN
# 358633   EF228471  05/06/2014 PRIMARY        NaN         NaN            NaN
# 423617   EF217649  11/08/2016 GENERAL        NaN         NaN            NaN
# 475493   EF217647  11/08/2016 GENERAL        NaN         NaN            NaN
# 485063   EF214603  11/08/2016 GENERAL        NaN         NaN            NaN
# 529887   EF234278  11/06/2018 GENERAL        NaN         NaN            NaN
# 634818   EF209750  11/04/2014 GENERAL        NaN         NaN            NaN
# 634821   EF209750  05/06/2014 PRIMARY        NaN         NaN            NaN
# 660700   EF214601  11/08/2016 GENERAL        NaN         NaN            NaN
# 663736   EF214964  11/08/2016 GENERAL        NaN         NaN            NaN
# 686033   EF211172  11/08/2016 GENERAL        NaN         NaN            NaN
# 692215   EF214959  11/08/2016 GENERAL        NaN         NaN            NaN
# 1005266  EF217648  11/08/2016 GENERAL        NaN         NaN            NaN
# 1056148  EF198276  11/06/2012 GENERAL        NaN         NaN            NaN
# 1056149  EF198276  05/08/2012 PRIMARY        NaN         NaN            NaN
# 1056153  EF198276  11/04/2014 GENERAL        NaN         NaN            NaN
# 1056156  EF198276  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1056449  EF214965  11/08/2016 GENERAL        NaN         NaN            NaN
# 1063181  EF217654  11/08/2016 GENERAL        NaN         NaN            NaN
# 1102693  EF216451  11/08/2016 GENERAL        NaN         NaN            NaN
# 1264371  EF211576  11/08/2016 GENERAL        NaN         NaN            NaN
# 1447177  EF201707  11/06/2012 GENERAL        NaN         NaN            NaN
# 1447178  EF201707  05/08/2012 PRIMARY        NaN         NaN            NaN
# 1447182  EF201707  11/04/2014 GENERAL        NaN         NaN            NaN
# 1447185  EF201707  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1487580  EF200020  11/06/2012 GENERAL        NaN         NaN            NaN
# 1487581  EF200020  05/08/2012 PRIMARY        NaN         NaN            NaN
# 1487585  EF200020  11/04/2014 GENERAL        NaN         NaN            NaN
# 1487588  EF200020  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1507736  EF217650  11/08/2016 GENERAL        NaN         NaN            NaN
# 1554706  EF233541  11/06/2018 GENERAL        NaN         NaN            NaN
# 1554710  EF233541  05/08/2018 PRIMARY        NaN         NaN            NaN
# 1648074  EF228472  11/06/2012 GENERAL        NaN         NaN            NaN
# 1648075  EF228472  05/08/2012 PRIMARY        NaN         NaN            NaN
# 1648076  EF228472  03/15/2016 PRIMARY        NaN         NaN            NaN
# 1648077  EF228472  11/06/2018 GENERAL        NaN         NaN            NaN
# 1648078  EF228472  11/08/2016 GENERAL        NaN         NaN            NaN
# 1648079  EF228472  11/04/2014 GENERAL        NaN         NaN            NaN
# 1648081  EF228472  05/08/2018 PRIMARY        NaN         NaN            NaN
# 1648082  EF228472  05/06/2014 PRIMARY        NaN         NaN            NaN
# 1688756  EF217653  11/08/2016 GENERAL        NaN         NaN            NaN
# 1706641  EF234279  11/06/2018 GENERAL        NaN         NaN            NaN
# 1707819  EF214960  11/08/2016 GENERAL        NaN         NaN            NaN
# 1747782  EF214963  11/08/2016 GENERAL        NaN         NaN            NaN
# 1749212  EF214595  11/08/2016 GENERAL        NaN         NaN            NaN
# 1759057  EF217655  11/08/2016 GENERAL        NaN         NaN            NaN
# 1822483  EF214602  11/08/2016 GENERAL        NaN         NaN            NaN
#
#          election_yr election_lbl registr_deadline  registr_in_time  \
# 2776          2018.0   2018-11-06       2018-10-12                1
# 2780          2018.0   2018-05-08       2018-04-13                1
# 15141         2016.0   2016-11-08       2016-10-14                1
# 37599         2012.0   2012-11-06       2012-10-12                1
# 37600         2012.0   2012-05-08       2012-04-13                1
# 37601         2016.0   2016-03-15       2016-02-19                1
# 37602         2018.0   2018-11-06       2018-10-12                1
# 37603         2016.0   2016-11-08       2016-10-14                1
# 37604         2014.0   2014-11-04       2014-10-10                1
# 37606         2018.0   2018-05-08       2018-04-13                1
# 37607         2014.0   2014-05-06       2014-04-11                1
# 45893         2012.0   2012-11-06       2012-10-12                1
# 45894         2012.0   2012-05-08       2012-04-13                1
# 63860         2016.0   2016-11-08       2016-10-14                1
# 70742         2012.0   2012-11-06       2012-10-12                1
# 70743         2012.0   2012-05-08       2012-04-13                1
# 70747         2014.0   2014-11-04       2014-10-10                1
# 70750         2014.0   2014-05-06       2014-04-11                1
# 88885         2016.0   2016-11-08       2016-10-14                1
# 94154         2016.0   2016-11-08       2016-10-14                1
# 118144        2018.0   2018-11-06       2018-10-12                1
# 118148        2018.0   2018-05-08       2018-04-13                1
# 167920        2016.0   2016-11-08       2016-10-14                1
# 209686        2018.0   2018-11-06       2018-10-12                1
# 209690        2018.0   2018-05-08       2018-04-13                1
# 250541        2016.0   2016-11-08       2016-10-14                1
# 324936        2016.0   2016-11-08       2016-10-14                1
# 340292        2016.0   2016-11-08       2016-10-14                1
# 345461        2018.0   2018-11-06       2018-10-12                1
# 345465        2018.0   2018-05-08       2018-04-13                1
# 358625        2012.0   2012-11-06       2012-10-12                1
# 358626        2012.0   2012-05-08       2012-04-13                1
# 358627        2016.0   2016-03-15       2016-02-19                1
# 358628        2018.0   2018-11-06       2018-10-12                1
# 358629        2016.0   2016-11-08       2016-10-14                1
# 358630        2014.0   2014-11-04       2014-10-10                1
# 358632        2018.0   2018-05-08       2018-04-13                1
# 358633        2014.0   2014-05-06       2014-04-11                1
# 423617        2016.0   2016-11-08       2016-10-14                1
# 475493        2016.0   2016-11-08       2016-10-14                1
# 485063        2016.0   2016-11-08       2016-10-14                1
# 529887        2018.0   2018-11-06       2018-10-12                1
# 634818        2014.0   2014-11-04       2014-10-10                1
# 634821        2014.0   2014-05-06       2014-04-11                1
# 660700        2016.0   2016-11-08       2016-10-14                1
# 663736        2016.0   2016-11-08       2016-10-14                1
# 686033        2016.0   2016-11-08       2016-10-14                1
# 692215        2016.0   2016-11-08       2016-10-14                1
# 1005266       2016.0   2016-11-08       2016-10-14                1
# 1056148       2012.0   2012-11-06       2012-10-12                1
# 1056149       2012.0   2012-05-08       2012-04-13                1
# 1056153       2014.0   2014-11-04       2014-10-10                1
# 1056156       2014.0   2014-05-06       2014-04-11                1
# 1056449       2016.0   2016-11-08       2016-10-14                1
# 1063181       2016.0   2016-11-08       2016-10-14                1
# 1102693       2016.0   2016-11-08       2016-10-14                1
# 1264371       2016.0   2016-11-08       2016-10-14                1
# 1447177       2012.0   2012-11-06       2012-10-12                1
# 1447178       2012.0   2012-05-08       2012-04-13                1
# 1447182       2014.0   2014-11-04       2014-10-10                1
# 1447185       2014.0   2014-05-06       2014-04-11                1
# 1487580       2012.0   2012-11-06       2012-10-12                1
# 1487581       2012.0   2012-05-08       2012-04-13                1
# 1487585       2014.0   2014-11-04       2014-10-10                1
# 1487588       2014.0   2014-05-06       2014-04-11                1
# 1507736       2016.0   2016-11-08       2016-10-14                1
# 1554706       2018.0   2018-11-06       2018-10-12                1
# 1554710       2018.0   2018-05-08       2018-04-13                1
# 1648074       2012.0   2012-11-06       2012-10-12                1
# 1648075       2012.0   2012-05-08       2012-04-13                1
# 1648076       2016.0   2016-03-15       2016-02-19                1
# 1648077       2018.0   2018-11-06       2018-10-12                1
# 1648078       2016.0   2016-11-08       2016-10-14                1
# 1648079       2014.0   2014-11-04       2014-10-10                1
# 1648081       2018.0   2018-05-08       2018-04-13                1
# 1648082       2014.0   2014-05-06       2014-04-11                1
# 1688756       2016.0   2016-11-08       2016-10-14                1
# 1706641       2018.0   2018-11-06       2018-10-12                1
# 1707819       2016.0   2016-11-08       2016-10-14                1
# 1747782       2016.0   2016-11-08       2016-10-14                1
# 1749212       2016.0   2016-11-08       2016-10-14                1
# 1759057       2016.0   2016-11-08       2016-10-14                1
# 1822483       2016.0   2016-11-08       2016-10-14                1
#
#          birth_age_adj  presid_elec vote_method_cat  vote_early  vote_by_mail  \
# 2776              17.0          0.0             NaN         0.0           0.0
# 2780              17.0          0.0             NaN         0.0           0.0
# 15141             16.0          1.0             NaN         0.0           0.0
# 37599             11.0          1.0             NaN         0.0           0.0
# 37600             11.0          1.0             NaN         0.0           0.0
# 37601             15.0          1.0             NaN         0.0           0.0
# 37602             17.0          0.0             NaN         0.0           0.0
# 37603             15.0          1.0             NaN         0.0           0.0
# 37604             13.0          0.0             NaN         0.0           0.0
# 37606             17.0          0.0             NaN         0.0           0.0
# 37607             13.0          0.0             NaN         0.0           0.0
# 45893             16.0          1.0           Early         1.0           0.0
# 45894             16.0          1.0             NaN         0.0           0.0
# 63860             17.0          1.0             NaN         0.0           0.0
# 70742             14.0          1.0             NaN         0.0           0.0
# 70743             14.0          1.0             NaN         0.0           0.0
# 70747             16.0          0.0             NaN         0.0           0.0
# 70750             16.0          0.0             NaN         0.0           0.0
# 88885             17.0          1.0             NaN         0.0           0.0
# 94154             16.0          1.0             NaN         0.0           0.0
# 118144            17.0          0.0             NaN         0.0           0.0
# 118148            17.0          0.0             NaN         0.0           0.0
# 167920            17.0          1.0             NaN         0.0           0.0
# 209686            17.0          0.0             NaN         0.0           0.0
# 209690            17.0          0.0             NaN         0.0           0.0
# 250541            17.0          1.0             NaN         0.0           0.0
# 324936            17.0          1.0             NaN         0.0           0.0
# 340292            16.0          1.0             NaN         0.0           0.0
# 345461            17.0          0.0             NaN         0.0           0.0
# 345465            17.0          0.0             NaN         0.0           0.0
# 358625            11.0          1.0             NaN         0.0           0.0
# 358626            11.0          1.0             NaN         0.0           0.0
# 358627            15.0          1.0             NaN         0.0           0.0
# 358628            17.0          0.0             NaN         0.0           0.0
# 358629            15.0          1.0             NaN         0.0           0.0
# 358630            13.0          0.0             NaN         0.0           0.0
# 358632            17.0          0.0             NaN         0.0           0.0
# 358633            13.0          0.0             NaN         0.0           0.0
# 423617            16.0          1.0             NaN         0.0           0.0
# 475493            16.0          1.0             NaN         0.0           0.0
# 485063            17.0          1.0             NaN         0.0           0.0
# 529887            17.0          0.0             NaN         0.0           0.0
# 634818            17.0          0.0             NaN         0.0           0.0
# 634821            17.0          0.0             NaN         0.0           0.0
# 660700            17.0          1.0             NaN         0.0           0.0
# 663736            17.0          1.0             NaN         0.0           0.0
# 686033            17.0          1.0             NaN         0.0           0.0
# 692215            17.0          1.0             NaN         0.0           0.0
# 1005266           16.0          1.0             NaN         0.0           0.0
# 1056148           15.0          1.0             NaN         0.0           0.0
# 1056149           15.0          1.0             NaN         0.0           0.0
# 1056153           17.0          0.0             NaN         0.0           0.0
# 1056156           17.0          0.0             NaN         0.0           0.0
# 1056449           17.0          1.0             NaN         0.0           0.0
# 1063181           16.0          1.0             NaN         0.0           0.0
# 1102693           17.0          1.0             NaN         0.0           0.0
# 1264371           17.0          1.0             NaN         0.0           0.0
# 1447177           14.0          1.0             NaN         0.0           0.0
# 1447178           14.0          1.0             NaN         0.0           0.0
# 1447182           16.0          0.0             NaN         0.0           0.0
# 1447185           16.0          0.0             NaN         0.0           0.0
# 1487580           14.0          1.0             NaN         0.0           0.0
# 1487581           14.0          1.0             NaN         0.0           0.0
# 1487585           16.0          0.0             NaN         0.0           0.0
# 1487588           16.0          0.0             NaN         0.0           0.0
# 1507736           16.0          1.0             NaN         0.0           0.0
# 1554706           17.0          0.0             NaN         0.0           0.0
# 1554710           17.0          0.0             NaN         0.0           0.0
# 1648074           11.0          1.0             NaN         0.0           0.0
# 1648075           11.0          1.0             NaN         0.0           0.0
# 1648076           15.0          1.0             NaN         0.0           0.0
# 1648077           17.0          0.0             NaN         0.0           0.0
# 1648078           15.0          1.0             NaN         0.0           0.0
# 1648079           13.0          0.0             NaN         0.0           0.0
# 1648081           17.0          0.0             NaN         0.0           0.0
# 1648082           13.0          0.0             NaN         0.0           0.0
# 1688756           16.0          1.0             NaN         0.0           0.0
# 1706641           17.0          0.0             NaN         0.0           0.0
# 1707819           17.0          1.0             NaN         0.0           0.0
# 1747782           17.0          1.0             NaN         0.0           0.0
# 1749212           17.0          1.0             NaN         0.0           0.0
# 1759057           16.0          1.0             NaN         0.0           0.0
# 1822483           17.0          1.0             NaN         0.0           0.0
#
#          vote_curbside election_cat     voting_method voted_party_cd  \
# 2776               0.0      GENERAL               NaN            NaN
# 2780               0.0      PRIMARY               NaN            NaN
# 15141              0.0      GENERAL               NaN            NaN
# 37599              0.0      GENERAL               NaN            NaN
# 37600              0.0      PRIMARY               NaN            NaN
# 37601              0.0      PRIMARY               NaN            NaN
# 37602              0.0      GENERAL               NaN            NaN
# 37603              0.0      GENERAL               NaN            NaN
# 37604              0.0      GENERAL               NaN            NaN
# 37606              0.0      PRIMARY               NaN            NaN
# 37607              0.0      PRIMARY               NaN            NaN
# 45893              0.0      GENERAL  ABSENTEE ONESTOP            UNA
# 45894              0.0      PRIMARY               NaN            NaN
# 63860              0.0      GENERAL               NaN            NaN
# 70742              0.0      GENERAL               NaN            NaN
# 70743              0.0      PRIMARY               NaN            NaN
# 70747              0.0      GENERAL               NaN            NaN
# 70750              0.0      PRIMARY               NaN            NaN
# 88885              0.0      GENERAL               NaN            NaN
# 94154              0.0      GENERAL               NaN            NaN
# 118144             0.0      GENERAL               NaN            NaN
# 118148             0.0      PRIMARY               NaN            NaN
# 167920             0.0      GENERAL               NaN            NaN
# 209686             0.0      GENERAL               NaN            NaN
# 209690             0.0      PRIMARY               NaN            NaN
# 250541             0.0      GENERAL               NaN            NaN
# 324936             0.0      GENERAL               NaN            NaN
# 340292             0.0      GENERAL               NaN            NaN
# 345461             0.0      GENERAL               NaN            NaN
# 345465             0.0      PRIMARY               NaN            NaN
# 358625             0.0      GENERAL               NaN            NaN
# 358626             0.0      PRIMARY               NaN            NaN
# 358627             0.0      PRIMARY               NaN            NaN
# 358628             0.0      GENERAL               NaN            NaN
# 358629             0.0      GENERAL               NaN            NaN
# 358630             0.0      GENERAL               NaN            NaN
# 358632             0.0      PRIMARY               NaN            NaN
# 358633             0.0      PRIMARY               NaN            NaN
# 423617             0.0      GENERAL               NaN            NaN
# 475493             0.0      GENERAL               NaN            NaN
# 485063             0.0      GENERAL               NaN            NaN
# 529887             0.0      GENERAL               NaN            NaN
# 634818             0.0      GENERAL               NaN            NaN
# 634821             0.0      PRIMARY               NaN            NaN
# 660700             0.0      GENERAL               NaN            NaN
# 663736             0.0      GENERAL               NaN            NaN
# 686033             0.0      GENERAL               NaN            NaN
# 692215             0.0      GENERAL               NaN            NaN
# 1005266            0.0      GENERAL               NaN            NaN
# 1056148            0.0      GENERAL               NaN            NaN
# 1056149            0.0      PRIMARY               NaN            NaN
# 1056153            0.0      GENERAL               NaN            NaN
# 1056156            0.0      PRIMARY               NaN            NaN
# 1056449            0.0      GENERAL               NaN            NaN
# 1063181            0.0      GENERAL               NaN            NaN
# 1102693            0.0      GENERAL               NaN            NaN
# 1264371            0.0      GENERAL               NaN            NaN
# 1447177            0.0      GENERAL               NaN            NaN
# 1447178            0.0      PRIMARY               NaN            NaN
# 1447182            0.0      GENERAL               NaN            NaN
# 1447185            0.0      PRIMARY               NaN            NaN
# 1487580            0.0      GENERAL               NaN            NaN
# 1487581            0.0      PRIMARY               NaN            NaN
# 1487585            0.0      GENERAL               NaN            NaN
# 1487588            0.0      PRIMARY               NaN            NaN
# 1507736            0.0      GENERAL               NaN            NaN
# 1554706            0.0      GENERAL               NaN            NaN
# 1554710            0.0      PRIMARY               NaN            NaN
# 1648074            0.0      GENERAL               NaN            NaN
# 1648075            0.0      PRIMARY               NaN            NaN
# 1648076            0.0      PRIMARY               NaN            NaN
# 1648077            0.0      GENERAL               NaN            NaN
# 1648078            0.0      GENERAL               NaN            NaN
# 1648079            0.0      GENERAL               NaN            NaN
# 1648081            0.0      PRIMARY               NaN            NaN
# 1648082            0.0      PRIMARY               NaN            NaN
# 1688756            0.0      GENERAL               NaN            NaN
# 1706641            0.0      GENERAL               NaN            NaN
# 1707819            0.0      GENERAL               NaN            NaN
# 1747782            0.0      GENERAL               NaN            NaN
# 1749212            0.0      GENERAL               NaN            NaN
# 1759057            0.0      GENERAL               NaN            NaN
# 1822483            0.0      GENERAL               NaN            NaN
#
#         voted_party_desc pct_label pct_description  voted_county_id  \
# 2776                 NaN       NaN             NaN              NaN
# 2780                 NaN       NaN             NaN              NaN
# 15141                NaN       NaN             NaN              NaN
# 37599                NaN       NaN             NaN              NaN
# 37600                NaN       NaN             NaN              NaN
# 37601                NaN       NaN             NaN              NaN
# 37602                NaN       NaN             NaN              NaN
# 37603                NaN       NaN             NaN              NaN
# 37604                NaN       NaN             NaN              NaN
# 37606                NaN       NaN             NaN              NaN
# 37607                NaN       NaN             NaN              NaN
# 45893       UNAFFILIATED      029A            029A             90.0
# 45894                NaN       NaN             NaN              NaN
# 63860                NaN       NaN             NaN              NaN
# 70742                NaN       NaN             NaN              NaN
# 70743                NaN       NaN             NaN              NaN
# 70747                NaN       NaN             NaN              NaN
# 70750                NaN       NaN             NaN              NaN
# 88885                NaN       NaN             NaN              NaN
# 94154                NaN       NaN             NaN              NaN
# 118144               NaN       NaN             NaN              NaN
# 118148               NaN       NaN             NaN              NaN
# 167920               NaN       NaN             NaN              NaN
# 209686               NaN       NaN             NaN              NaN
# 209690               NaN       NaN             NaN              NaN
# 250541               NaN       NaN             NaN              NaN
# 324936               NaN       NaN             NaN              NaN
# 340292               NaN       NaN             NaN              NaN
# 345461               NaN       NaN             NaN              NaN
# 345465               NaN       NaN             NaN              NaN
# 358625               NaN       NaN             NaN              NaN
# 358626               NaN       NaN             NaN              NaN
# 358627               NaN       NaN             NaN              NaN
# 358628               NaN       NaN             NaN              NaN
# 358629               NaN       NaN             NaN              NaN
# 358630               NaN       NaN             NaN              NaN
# 358632               NaN       NaN             NaN              NaN
# 358633               NaN       NaN             NaN              NaN
# 423617               NaN       NaN             NaN              NaN
# 475493               NaN       NaN             NaN              NaN
# 485063               NaN       NaN             NaN              NaN
# 529887               NaN       NaN             NaN              NaN
# 634818               NaN       NaN             NaN              NaN
# 634821               NaN       NaN             NaN              NaN
# 660700               NaN       NaN             NaN              NaN
# 663736               NaN       NaN             NaN              NaN
# 686033               NaN       NaN             NaN              NaN
# 692215               NaN       NaN             NaN              NaN
# 1005266              NaN       NaN             NaN              NaN
# 1056148              NaN       NaN             NaN              NaN
# 1056149              NaN       NaN             NaN              NaN
# 1056153              NaN       NaN             NaN              NaN
# 1056156              NaN       NaN             NaN              NaN
# 1056449              NaN       NaN             NaN              NaN
# 1063181              NaN       NaN             NaN              NaN
# 1102693              NaN       NaN             NaN              NaN
# 1264371              NaN       NaN             NaN              NaN
# 1447177              NaN       NaN             NaN              NaN
# 1447178              NaN       NaN             NaN              NaN
# 1447182              NaN       NaN             NaN              NaN
# 1447185              NaN       NaN             NaN              NaN
# 1487580              NaN       NaN             NaN              NaN
# 1487581              NaN       NaN             NaN              NaN
# 1487585              NaN       NaN             NaN              NaN
# 1487588              NaN       NaN             NaN              NaN
# 1507736              NaN       NaN             NaN              NaN
# 1554706              NaN       NaN             NaN              NaN
# 1554710              NaN       NaN             NaN              NaN
# 1648074              NaN       NaN             NaN              NaN
# 1648075              NaN       NaN             NaN              NaN
# 1648076              NaN       NaN             NaN              NaN
# 1648077              NaN       NaN             NaN              NaN
# 1648078              NaN       NaN             NaN              NaN
# 1648079              NaN       NaN             NaN              NaN
# 1648081              NaN       NaN             NaN              NaN
# 1648082              NaN       NaN             NaN              NaN
# 1688756              NaN       NaN             NaN              NaN
# 1706641              NaN       NaN             NaN              NaN
# 1707819              NaN       NaN             NaN              NaN
# 1747782              NaN       NaN             NaN              NaN
# 1749212              NaN       NaN             NaN              NaN
# 1759057              NaN       NaN             NaN              NaN
# 1822483              NaN       NaN             NaN              NaN
#
#         voted_county_desc vtd_label vtd_description status_cd  \
# 2776                  NaN       NaN             NaN         A
# 2780                  NaN       NaN             NaN         A
# 15141                 NaN       NaN             NaN         A
# 37599                 NaN       NaN             NaN         A
# 37600                 NaN       NaN             NaN         A
# 37601                 NaN       NaN             NaN         A
# 37602                 NaN       NaN             NaN         A
# 37603                 NaN       NaN             NaN         A
# 37604                 NaN       NaN             NaN         A
# 37606                 NaN       NaN             NaN         A
# 37607                 NaN       NaN             NaN         A
# 45893               UNION      029A            029A         A
# 45894                 NaN       NaN             NaN         A
# 63860                 NaN       NaN             NaN         A
# 70742                 NaN       NaN             NaN         A
# 70743                 NaN       NaN             NaN         A
# 70747                 NaN       NaN             NaN         A
# 70750                 NaN       NaN             NaN         A
# 88885                 NaN       NaN             NaN         A
# 94154                 NaN       NaN             NaN         I
# 118144                NaN       NaN             NaN         A
# 118148                NaN       NaN             NaN         A
# 167920                NaN       NaN             NaN         I
# 209686                NaN       NaN             NaN         A
# 209690                NaN       NaN             NaN         A
# 250541                NaN       NaN             NaN         A
# 324936                NaN       NaN             NaN         A
# 340292                NaN       NaN             NaN         A
# 345461                NaN       NaN             NaN         A
# 345465                NaN       NaN             NaN         A
# 358625                NaN       NaN             NaN         A
# 358626                NaN       NaN             NaN         A
# 358627                NaN       NaN             NaN         A
# 358628                NaN       NaN             NaN         A
# 358629                NaN       NaN             NaN         A
# 358630                NaN       NaN             NaN         A
# 358632                NaN       NaN             NaN         A
# 358633                NaN       NaN             NaN         A
# 423617                NaN       NaN             NaN         A
# 475493                NaN       NaN             NaN         A
# 485063                NaN       NaN             NaN         A
# 529887                NaN       NaN             NaN         A
# 634818                NaN       NaN             NaN         A
# 634821                NaN       NaN             NaN         A
# 660700                NaN       NaN             NaN         I
# 663736                NaN       NaN             NaN         A
# 686033                NaN       NaN             NaN         A
# 692215                NaN       NaN             NaN         A
# 1005266               NaN       NaN             NaN         I
# 1056148               NaN       NaN             NaN         A
# 1056149               NaN       NaN             NaN         A
# 1056153               NaN       NaN             NaN         A
# 1056156               NaN       NaN             NaN         A
# 1056449               NaN       NaN             NaN         A
# 1063181               NaN       NaN             NaN         A
# 1102693               NaN       NaN             NaN         A
# 1264371               NaN       NaN             NaN         A
# 1447177               NaN       NaN             NaN         A
# 1447178               NaN       NaN             NaN         A
# 1447182               NaN       NaN             NaN         A
# 1447185               NaN       NaN             NaN         A
# 1487580               NaN       NaN             NaN         I
# 1487581               NaN       NaN             NaN         I
# 1487585               NaN       NaN             NaN         I
# 1487588               NaN       NaN             NaN         I
# 1507736               NaN       NaN             NaN         A
# 1554706               NaN       NaN             NaN         A
# 1554710               NaN       NaN             NaN         A
# 1648074               NaN       NaN             NaN         A
# 1648075               NaN       NaN             NaN         A
# 1648076               NaN       NaN             NaN         A
# 1648077               NaN       NaN             NaN         A
# 1648078               NaN       NaN             NaN         A
# 1648079               NaN       NaN             NaN         A
# 1648081               NaN       NaN             NaN         A
# 1648082               NaN       NaN             NaN         A
# 1688756               NaN       NaN             NaN         A
# 1706641               NaN       NaN             NaN         A
# 1707819               NaN       NaN             NaN         A
# 1747782               NaN       NaN             NaN         A
# 1749212               NaN       NaN             NaN         A
# 1759057               NaN       NaN             NaN         A
# 1822483               NaN       NaN             NaN         A
#
#         voter_status_desc reason_cd             voter_status_reason_desc  \
# 2776               ACTIVE        AV                             VERIFIED
# 2780               ACTIVE        AV                             VERIFIED
# 15141              ACTIVE        AV                             VERIFIED
# 37599              ACTIVE        AV                             VERIFIED
# 37600              ACTIVE        AV                             VERIFIED
# 37601              ACTIVE        AV                             VERIFIED
# 37602              ACTIVE        AV                             VERIFIED
# 37603              ACTIVE        AV                             VERIFIED
# 37604              ACTIVE        AV                             VERIFIED
# 37606              ACTIVE        AV                             VERIFIED
# 37607              ACTIVE        AV                             VERIFIED
# 45893              ACTIVE        AV                             VERIFIED
# 45894              ACTIVE        AV                             VERIFIED
# 63860              ACTIVE        AV                             VERIFIED
# 70742              ACTIVE        AV                             VERIFIED
# 70743              ACTIVE        AV                             VERIFIED
# 70747              ACTIVE        AV                             VERIFIED
# 70750              ACTIVE        AV                             VERIFIED
# 88885              ACTIVE        AV                             VERIFIED
# 94154            INACTIVE        IN            CONFIRMATION NOT RETURNED
# 118144             ACTIVE        AV                             VERIFIED
# 118148             ACTIVE        AV                             VERIFIED
# 167920           INACTIVE        IN            CONFIRMATION NOT RETURNED
# 209686             ACTIVE        AV                             VERIFIED
# 209690             ACTIVE        AV                             VERIFIED
# 250541             ACTIVE        AV                             VERIFIED
# 324936             ACTIVE        AV                             VERIFIED
# 340292             ACTIVE        AV                             VERIFIED
# 345461             ACTIVE        AV                             VERIFIED
# 345465             ACTIVE        AV                             VERIFIED
# 358625             ACTIVE        AV                             VERIFIED
# 358626             ACTIVE        AV                             VERIFIED
# 358627             ACTIVE        AV                             VERIFIED
# 358628             ACTIVE        AV                             VERIFIED
# 358629             ACTIVE        AV                             VERIFIED
# 358630             ACTIVE        AV                             VERIFIED
# 358632             ACTIVE        AV                             VERIFIED
# 358633             ACTIVE        AV                             VERIFIED
# 423617             ACTIVE        AV                             VERIFIED
# 475493             ACTIVE        AV                             VERIFIED
# 485063             ACTIVE        AV                             VERIFIED
# 529887             ACTIVE        AV                             VERIFIED
# 634818             ACTIVE        AV                             VERIFIED
# 634821             ACTIVE        AV                             VERIFIED
# 660700           INACTIVE        IN            CONFIRMATION NOT RETURNED
# 663736             ACTIVE        AV                             VERIFIED
# 686033             ACTIVE        AV                             VERIFIED
# 692215             ACTIVE        AV                             VERIFIED
# 1005266          INACTIVE        IN            CONFIRMATION NOT RETURNED
# 1056148            ACTIVE        AV                             VERIFIED
# 1056149            ACTIVE        AV                             VERIFIED
# 1056153            ACTIVE        AV                             VERIFIED
# 1056156            ACTIVE        AV                             VERIFIED
# 1056449            ACTIVE        AV                             VERIFIED
# 1063181            ACTIVE        AV                             VERIFIED
# 1102693            ACTIVE        AV                             VERIFIED
# 1264371            ACTIVE        AV                             VERIFIED
# 1447177            ACTIVE        AV                             VERIFIED
# 1447178            ACTIVE        AV                             VERIFIED
# 1447182            ACTIVE        AV                             VERIFIED
# 1447185            ACTIVE        AV                             VERIFIED
# 1487580          INACTIVE        IU  CONFIRMATION RETURNED UNDELIVERABLE
# 1487581          INACTIVE        IU  CONFIRMATION RETURNED UNDELIVERABLE
# 1487585          INACTIVE        IU  CONFIRMATION RETURNED UNDELIVERABLE
# 1487588          INACTIVE        IU  CONFIRMATION RETURNED UNDELIVERABLE
# 1507736            ACTIVE        AV                             VERIFIED
# 1554706            ACTIVE        AV                             VERIFIED
# 1554710            ACTIVE        AV                             VERIFIED
# 1648074            ACTIVE        AV                             VERIFIED
# 1648075            ACTIVE        AV                             VERIFIED
# 1648076            ACTIVE        AV                             VERIFIED
# 1648077            ACTIVE        AV                             VERIFIED
# 1648078            ACTIVE        AV                             VERIFIED
# 1648079            ACTIVE        AV                             VERIFIED
# 1648081            ACTIVE        AV                             VERIFIED
# 1648082            ACTIVE        AV                             VERIFIED
# 1688756            ACTIVE        AV                             VERIFIED
# 1706641            ACTIVE        AV                             VERIFIED
# 1707819            ACTIVE        AV                             VERIFIED
# 1747782            ACTIVE        A1                           UNVERIFIED
# 1749212            ACTIVE        AV                             VERIFIED
# 1759057            ACTIVE        AV                             VERIFIED
# 1822483            ACTIVE        AV                             VERIFIED
#
#                 last_name first_name      middle_name  \
# 2776              ABRAHAM      RISTI           MARTIN
# 2780              ABRAHAM      RISTI           MARTIN
# 15141    ALCOCER CARRILLO     GWENDY              NaN
# 37599            ANDERSON      SARAH           RACHEL
# 37600            ANDERSON      SARAH           RACHEL
# 37601            ANDERSON      SARAH           RACHEL
# 37602            ANDERSON      SARAH           RACHEL
# 37603            ANDERSON      SARAH           RACHEL
# 37604            ANDERSON      SARAH           RACHEL
# 37606            ANDERSON      SARAH           RACHEL
# 37607            ANDERSON      SARAH           RACHEL
# 45893            ARCORACI  FREDERICK             JOHN
# 45894            ARCORACI  FREDERICK             JOHN
# 63860             AYLWARD    MATTHEW      CHRISTOPHER
# 70742               BAKER  ALEXANDER          WILLIAM
# 70743               BAKER  ALEXANDER          WILLIAM
# 70747               BAKER  ALEXANDER          WILLIAM
# 70750               BAKER  ALEXANDER          WILLIAM
# 88885     BARRERA-ESTRADA    MAGDIEL              NaN
# 94154              BARTON    CAMERON          DEWAYNE
# 118144           BENCKERT    JESSICA             LYNN
# 118148           BENCKERT    JESSICA             LYNN
# 167920              BOTTI    ADRIANA             ROSE
# 209686         BROWNFIELD      SCOTT          LINCOLN
# 209690         BROWNFIELD      SCOTT          LINCOLN
# 250541              CANUP    KENNETH             PAUL
# 324936             COLSON   ADESTINE         SHATRECE
# 340292            CORDIER      MILES             KENT
# 345461             COUICK     AUBREY            JACOB
# 345465             COUICK     AUBREY            JACOB
# 358625            CRAWLEY   JONATHON           STUART
# 358626            CRAWLEY   JONATHON           STUART
# 358627            CRAWLEY   JONATHON           STUART
# 358628            CRAWLEY   JONATHON           STUART
# 358629            CRAWLEY   JONATHON           STUART
# 358630            CRAWLEY   JONATHON           STUART
# 358632            CRAWLEY   JONATHON           STUART
# 358633            CRAWLEY   JONATHON           STUART
# 423617           DEVAUGHN      CALEB        D'ANTHONY
# 475493               EGET      EMILY             ROSE
# 485063            ENDSLEY      JONAS             EVAN
# 529887              FLOYD       ABBY           KATLEN
# 634818            GRIFFIN       KARA           REAGAN
# 634821            GRIFFIN       KARA           REAGAN
# 660700               HALE     FOSTER         KRISTIAN
# 663736               HALL      KYLIE          MADISON
# 686033             HARRIS    DONOVAN            OSAZE
# 692215            HARTMAN     THOMAS              KEY
# 1005266              LUNA   SANTONIO           ELIJAH
# 1056148             MAXIM    DEIRDRA            LOREN
# 1056149             MAXIM    DEIRDRA            LOREN
# 1056153             MAXIM    DEIRDRA            LOREN
# 1056156             MAXIM    DEIRDRA            LOREN
# 1056449           MAXWELL       KYLE           JOSEPH
# 1063181            MCCABE      JULIA        JEANNETTE
# 1102693           MEADOWS      ERICA           DENISE
# 1264371          PARLIMAN       KARL          MATTHEW
# 1447177            RUNKEL        JON           CONNOR
# 1447178            RUNKEL        JON           CONNOR
# 1447182            RUNKEL        JON           CONNOR
# 1447185            RUNKEL        JON           CONNOR
# 1487580         SCHWIEGER       ERIC            HENRY
# 1487581         SCHWIEGER       ERIC            HENRY
# 1487585         SCHWIEGER       ERIC            HENRY
# 1487588         SCHWIEGER       ERIC            HENRY
# 1507736              SHAY    WILLIAM          JEFFREY
# 1554706             SMITH       MARK      CHRISTOPHER
# 1554710             SMITH       MARK      CHRISTOPHER
# 1648074            TAYLOR      MASON             PAUL
# 1648075            TAYLOR      MASON             PAUL
# 1648076            TAYLOR      MASON             PAUL
# 1648077            TAYLOR      MASON             PAUL
# 1648078            TAYLOR      MASON             PAUL
# 1648079            TAYLOR      MASON             PAUL
# 1648081            TAYLOR      MASON             PAUL
# 1648082            TAYLOR      MASON             PAUL
# 1688756            TRAVIS    MATTHEW            JACOB
# 1706641              UDOH     INYENE        MAGDALENE
# 1707819         UNDERWOOD      COLBY          MICHAEL
# 1747782           WALLING       DALE        CHRISTIAN
# 1749212             WALSH     HUNTER  CAMERON WILLIAM
# 1759057            WATHEN     HANNAH            GRACE
# ...
# 345465                20B              20C             35.0            55.0
# 358625                20B              20C             35.0            68.0
# 358626                20B              20C             35.0            68.0
# 358627                20B              20C             35.0            68.0
# 358628                20B              20C             35.0            68.0
# 358629                20B              20C             35.0            68.0
# 358630                20B              20C             35.0            68.0
# 358632                20B              20C             35.0            68.0
# 358633                20B              20C             35.0            68.0
# 423617                20B              20C             35.0            69.0
# 475493                20B              20C             35.0            69.0
# 485063                20B              20C             35.0            68.0
# 529887                20B              20C             35.0            55.0
# 634818                20B              20C             35.0            55.0
# 634821                20B              20C             35.0            55.0
# 660700                20B              20C             36.0            69.0
# 663736                20B              20C             35.0            68.0
# 686033                20B              20B             35.0            69.0
# 692215                20B              20C             35.0            68.0
# 1005266               20B              20B             35.0            55.0
# 1056148               20B              20C             35.0            68.0
# 1056149               20B              20C             35.0            68.0
# 1056153               20B              20C             35.0            68.0
# 1056156               20B              20C             35.0            68.0
# 1056449               20B              20C             35.0            68.0
# 1063181               20B              20C             35.0            68.0
# 1102693               20B              20C             35.0            55.0
# 1264371               20B              20C             35.0            69.0
# 1447177               20B              20C             35.0            68.0
# 1447178               20B              20C             35.0            68.0
# 1447182               20B              20C             35.0            68.0
# 1447185               20B              20C             35.0            68.0
# 1487580               20B              20C             35.0            68.0
# 1487581               20B              20C             35.0            68.0
# 1487585               20B              20C             35.0            68.0
# 1487588               20B              20C             35.0            68.0
# 1507736               20B              20C             35.0            68.0
# 1554706               20B              20C             35.0            68.0
# 1554710               20B              20C             35.0            68.0
# 1648074               20B              20B             35.0            55.0
# 1648075               20B              20B             35.0            55.0
# 1648076               20B              20B             35.0            55.0
# 1648077               20B              20B             35.0            55.0
# 1648078               20B              20B             35.0            55.0
# 1648079               20B              20B             35.0            55.0
# 1648081               20B              20B             35.0            55.0
# 1648082               20B              20B             35.0            55.0
# 1688756               20B              20C             35.0            68.0
# 1706641               20B              20C             35.0            68.0
# 1707819               20B              20C             35.0            69.0
# 1747782               20B              20C             35.0            68.0
# 1749212               20B              20C             35.0            68.0
# 1759057               20B              20C             36.0            69.0
# 1822483               20B              20C             35.0            55.0
#
#          school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 2776                   6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 2780                   6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 15141                  1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 37599                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37600                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37601                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37602                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37603                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37604                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37606                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 37607                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 45893                  3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 45894                  3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 63860                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 70742                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 70743                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 70747                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 70750                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 88885                  1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 94154                  6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 118144                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 118148                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 167920                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 209686                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 209690                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 250541                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 324936                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 340292                 5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 345461                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 345465                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 358625                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358626                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358627                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358628                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358629                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358630                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358632                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 358633                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 423617                 5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 475493                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 485063                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 529887                 2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 634818                 1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 634821                 1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 660700                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 663736                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 686033                 1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 692215                 6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1005266                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1056148                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1056149                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1056153                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1056156                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1056449                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1063181                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1102693                3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 1264371                4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 1447177                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1447178                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1447182                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1447185                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1487580                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1487581                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1487585                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1487588                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1507736                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1554706                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1554710                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1648074                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648075                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648076                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648077                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648078                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648079                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648081                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1648082                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 1688756                6.0        SCHOOL #6          30.0  30TH PROSECUTORIAL
# 1706641                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1707819                3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 1747782                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1749212                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 1759057                5.0        SCHOOL #5          30.0  30TH PROSECUTORIAL
# 1822483                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
#
#         confidential_ind  birth_year vtd_abbrv vtd_desc
# 2776                   N        2001       019      019
# 2780                   N        2001       019      019
# 15141                  N        2000       043      043
# 37599                  N        2001       028      028
# 37600                  N        2001       028      028
# 37601                  N        2001       028      028
# 37602                  N        2001       028      028
# 37603                  N        2001       028      028
# 37604                  N        2001       028      028
# 37606                  N        2001       028      028
# 37607                  N        2001       028      028
# 45893                  N        1996      017A     017A
# 45894                  N        1996      017A     017A
# 63860                  N        1999       019      019
# 70742                  N        1998      020B     020B
# 70743                  N        1998      020B     020B
# 70747                  N        1998      020B     020B
# 70750                  N        1998      020B     020B
# 88885                  N        1999       043      043
# 94154                  N        2000      020B     020B
# 118144                 N        2001      038A     038A
# 118148                 N        2001      038A     038A
# 167920                 N        1999      029A     029A
# 209686                 N        2001       028      028
# 209690                 N        2001       028      028
# 250541                 N        1999      017A     017A
# 324936                 N        1999      029A     029A
# 340292                 N        2000       018      018
# 345461                 N        2001       031      031
# 345465                 N        2001       031      031
# 358625                 N        2001       019      019
# 358626                 N        2001       019      019
# 358627                 N        2001       019      019
# 358628                 N        2001       019      019
# 358629                 N        2001       019      019
# 358630                 N        2001       019      019
# 358632                 N        2001       019      019
# 358633                 N        2001       019      019
# 423617                 N        2000      037A     037A
# 475493                 N        2000      038A     038A
# 485063                 N        1999       028      028
# 529887                 N        2001       025      025
# 634818                 N        1997       025      025
# 634821                 N        1997       025      025
# 660700                 N        1999       035      035
# 663736                 N        1999      017A     017A
# 686033                 N        1999       004      004
# 692215                 N        1999       028      028
# 1005266                N        2000       008      008
# 1056148                N        1997       028      028
# 1056149                N        1997       028      028
# 1056153                N        1997       028      028
# 1056156                N        1997       028      028
# 1056449                N        1999      017B     017B
# 1063181                N        2000       028      028
# 1102693                N        1999       031      031
# 1264371                N        1999       039      039
# 1447177                N        1998       028      028
# 1447178                N        1998       028      028
# 1447182                N        1998       028      028
# 1447185                N        1998       028      028
# 1487580                N        1998       040      040
# 1487581                N        1998       040      040
# 1487585                N        1998       040      040
# 1487588                N        1998       040      040
# 1507736                N        2000       028      028
# 1554706                N        2001       028      028
# 1554710                N        2001       028      028
# 1648074                N        2001       009      009
# 1648075                N        2001       009      009
# 1648076                N        2001       009      009
# 1648077                N        2001       009      009
# 1648078                N        2001       009      009
# 1648079                N        2001       009      009
# 1648081                N        2001       009      009
# 1648082                N        2001       009      009
# 1688756                N        2000       028      028
# 1706641                N        2001       041      041
# 1707819                N        1999       030      030
# 1747782                N        1999       018      018
# 1749212                N        1999      020A     020A
# 1759057                N        2000      037B     037B
# 1822483                N        1999       042      042

# %% [markdown]
# ## Create a DataFrame Summarizing Each Voter's History

# %%
## Aggregate individual ncid's to find a way to easily identify individuals
  ## with no recent voting history
ncid_grp_sum = voter_elecs.groupby('ncid').sum().reset_index()
ncid_grp_sum.head(20)
# Out:
#         ncid  county_id  voter_reg_num  election_yr  registr_in_time  \
# 0   AA100547      450.0      1426485.0      20160.0               10
# 1   AA108801       90.0       316902.0      20160.0                6
# 2   AA109481      270.0      1083573.0      20160.0                4
# 3   AA112504      360.0      1089760.0      20160.0               10
# 4   AA114763      810.0      2395116.0      20160.0               10
# 5   AA116927      360.0      1332812.0      20160.0                6
# 6   AA118202      450.0      1027325.0      20160.0               11
# 7   AA120054       90.0       234832.0      20160.0               11
# 8   AA120376      450.0      1447975.0      20160.0                8
# 9   AA122723      360.0      1447388.0      20160.0                5
# 10  AA123939      720.0      2250832.0      20160.0               11
# 11  AA123940      450.0      1406765.0      20160.0               11
# 12  AA124273      360.0      1341068.0      20160.0                6
# 13  AA125831       90.0       319797.0      20160.0                6
# 14  AA125841      450.0      1696390.0      20160.0                7
# 15  AA126939      450.0      1228165.0      20160.0               11
# 16  AA127749      810.0      3296250.0      20160.0               10
# 17  AA127877      360.0       934376.0      20160.0               11
# 18  AA128010        0.0            0.0      20160.0                6
# 19  AA128660      360.0      1094324.0      20160.0               10
#
#     birth_age_adj  presid_elec  vote_early  vote_by_mail  vote_curbside  \
# 0           610.0          6.0         3.0           0.0            0.0
# 1           530.0          6.0         1.0           0.0            0.0
# 2           430.0          6.0         2.0           0.0            0.0
# 3           680.0          6.0         2.0           0.0            0.0
# 4           490.0          6.0         5.0           0.0            0.0
# 5           540.0          6.0         2.0           0.0            0.0
# 6           440.0          6.0         1.0           1.0            0.0
# 7           340.0          6.0         0.0           1.0            0.0
# 8           410.0          6.0         3.0           0.0            0.0
# 9           410.0          6.0         3.0           0.0            0.0
# 10          670.0          6.0         6.0           0.0            0.0
# 11          660.0          6.0         4.0           0.0            0.0
# 12          450.0          6.0         2.0           0.0            0.0
# 13          320.0          6.0         0.0           0.0            0.0
# 14          750.0          6.0         4.0           0.0            0.0
# 15          340.0          6.0         1.0           0.0            0.0
# 16          320.0          6.0         6.0           0.0            0.0
# 17          420.0          6.0         2.0           0.0            0.0
# 18          360.0          6.0         0.0           0.0            0.0
# 19          340.0          6.0         4.0           0.0            0.0
#
#     voted_county_id  zip_code  birth_age  cong_dist_abbrv  nc_senate_abbrv  \
# 0             401.0  308869.0        715             99.0            385.0
# 1              90.0  309903.0        616             99.0            385.0
# 2             270.0  309903.0        517             99.0            385.0
# 3             360.0  309232.0        792             99.0            385.0
# 4             810.0  309144.0        583             99.0            385.0
# 5             182.0  309903.0        638             99.0            385.0
# 6             450.0  308869.0        528             99.0            385.0
# 7              90.0  308869.0        418             99.0            385.0
# 8             450.0  308869.0        495             99.0            385.0
# 9              93.0  309903.0        495             99.0            385.0
# 10            542.0  309210.0        781             99.0            385.0
# 11            272.0  309210.0        770             99.0            385.0
# 12            182.0  309903.0        539             99.0            385.0
# 13              1.0  308869.0        396             99.0            385.0
# 14             94.0  309903.0        869             99.0            385.0
# 15            450.0  308869.0        418             99.0            385.0
# 16            308.0  309144.0        396             99.0            385.0
# 17            360.0  309210.0        506             99.0            385.0
# 18              0.0  308869.0        440             99.0            385.0
# 19            360.0  309903.0        407             99.0            385.0
#
#     nc_house_abbrv  school_dist_abbrv  dist_1_abbrv  birth_year
# 0            759.0               44.0         330.0       21505
# 1            748.0               66.0         330.0       21593
# 2            748.0               22.0         330.0       21703
# 3            605.0               22.0         330.0       21428
# 4            759.0               55.0         330.0       21637
# 5            748.0               66.0         330.0       21582
# 6            759.0               44.0         330.0       21692
# 7            759.0               55.0         330.0       21802
# 8            759.0               44.0         330.0       21725
# 9            748.0               66.0         330.0       21725
# 10           759.0               33.0         330.0       21439
# 11           759.0               33.0         330.0       21450
# 12           748.0               66.0         330.0       21681
# 13           759.0               44.0         330.0       21824
# 14           748.0               66.0         330.0       21351
# 15           759.0               44.0         330.0       21802
# 16           748.0               55.0         330.0       21824
# 17           759.0               33.0         330.0       21714
# 18           748.0               55.0         330.0       21780
# 19           748.0               66.0         330.0       21802

# %%
## Inspect record for an individual with no recent voting history
ncid_grp_sum.loc[ncid_grp_sum['ncid']=='AL261840']
## voter_reg_num shows up as 0 when an individual has no voting history
# Out:
#           ncid  county_id  voter_reg_num  election_yr  registr_in_time  \
# 1117  AL261840        0.0            0.0      20160.0                9
#
#       birth_age_adj  presid_elec  vote_early  vote_by_mail  vote_curbside  \
# 1117          220.0          6.0         0.0           0.0            0.0
#
#       voted_county_id  zip_code  birth_age  cong_dist_abbrv  nc_senate_abbrv  \
# 1117              0.0  308869.0        286             99.0            385.0
#
#       nc_house_abbrv  school_dist_abbrv  dist_1_abbrv  birth_year
# 1117           748.0               33.0         330.0       21934

# %%
## 18,393 voters currently registered in Union County have not voted in a 
## major election so far
never_voted_maj_elec = ncid_grp_sum.loc[ncid_grp_sum['voter_reg_num']==0][['ncid']]
len(never_voted_maj_elec)
# Out:
# 18393

# %%
## Insert a binary column indicating that a voter has no history for voting
  ## in recent major elections (1) or has recently voted at least once (0)
voter_elecs.insert(loc=2, column='no_vote_his',
                 value=np.where(voter_elecs['ncid'].isin(never_voted_maj_elec['ncid']),
                               1,0))

# %%
## Set multiindex for df grouping first by ncid, then election_desc
voter_elecs_mi = voter_elecs.set_index(['ncid','election_desc'])
voter_elecs_mi.head()
# Out:
#                              no_vote_his  county_id county_desc  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL            0       90.0       UNION
#          11/06/2012 GENERAL            0        NaN         NaN
#          05/08/2012 PRIMARY            0        NaN         NaN
#          03/15/2016 PRIMARY            0        NaN         NaN
#          11/06/2018 GENERAL            0        NaN         NaN
#
#                              voter_reg_num  election_yr election_lbl  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL       346446.0       2020.0   2020-11-03
#          11/06/2012 GENERAL            NaN       2012.0   2012-11-06
#          05/08/2012 PRIMARY            NaN       2012.0   2012-05-08
#          03/15/2016 PRIMARY            NaN       2016.0   2016-03-15
#          11/06/2018 GENERAL            NaN       2018.0   2018-11-06
#
#                             registr_deadline  registr_in_time  birth_age_adj  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL       2020-10-09                1           46.0
#          11/06/2012 GENERAL       2012-10-12                0           38.0
#          05/08/2012 PRIMARY       2012-04-13                0           38.0
#          03/15/2016 PRIMARY       2016-02-19                0           42.0
#          11/06/2018 GENERAL       2018-10-12                0           44.0
#
#                              presid_elec vote_method_cat  vote_early  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL          1.0           Early         1.0
#          11/06/2012 GENERAL          1.0             NaN         0.0
#          05/08/2012 PRIMARY          1.0             NaN         0.0
#          03/15/2016 PRIMARY          1.0             NaN         0.0
#          11/06/2018 GENERAL          0.0             NaN         0.0
#
#                              vote_by_mail  vote_curbside election_cat  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL           0.0            0.0      GENERAL
#          11/06/2012 GENERAL           0.0            0.0      GENERAL
#          05/08/2012 PRIMARY           0.0            0.0      PRIMARY
#          03/15/2016 PRIMARY           0.0            0.0      PRIMARY
#          11/06/2018 GENERAL           0.0            0.0      GENERAL
#
#                                 voting_method voted_party_cd voted_party_desc  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL  ABSENTEE ONESTOP            UNA     UNAFFILIATED
#          11/06/2012 GENERAL               NaN            NaN              NaN
#          05/08/2012 PRIMARY               NaN            NaN              NaN
#          03/15/2016 PRIMARY               NaN            NaN              NaN
#          11/06/2018 GENERAL               NaN            NaN              NaN
#
#                             pct_label pct_description  voted_county_id  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL      020A            020A             90.0
#          11/06/2012 GENERAL       NaN             NaN              NaN
#          05/08/2012 PRIMARY       NaN             NaN              NaN
#          03/15/2016 PRIMARY       NaN             NaN              NaN
#          11/06/2018 GENERAL       NaN             NaN              NaN
#
#                             voted_county_desc vtd_label vtd_description  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL             UNION      020A            020A
#          11/06/2012 GENERAL               NaN       NaN             NaN
#          05/08/2012 PRIMARY               NaN       NaN             NaN
#          03/15/2016 PRIMARY               NaN       NaN             NaN
#          11/06/2018 GENERAL               NaN       NaN             NaN
#
#                             status_cd voter_status_desc reason_cd  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL         A            ACTIVE        AV
#          11/06/2012 GENERAL         A            ACTIVE        AV
#          05/08/2012 PRIMARY         A            ACTIVE        AV
#          03/15/2016 PRIMARY         A            ACTIVE        AV
#          11/06/2018 GENERAL         A            ACTIVE        AV
#
#                             voter_status_reason_desc last_name first_name  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL                 VERIFIED    AALAEI       ARIO
#          11/06/2012 GENERAL                 VERIFIED    AALAEI       ARIO
#          05/08/2012 PRIMARY                 VERIFIED    AALAEI       ARIO
#          03/15/2016 PRIMARY                 VERIFIED    AALAEI       ARIO
#          11/06/2018 GENERAL                 VERIFIED    AALAEI       ARIO
#
#                             middle_name        res_street_address  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL         NaN  4009  MILLBRIDGE PKWY
#          11/06/2012 GENERAL         NaN  4009  MILLBRIDGE PKWY
#          05/08/2012 PRIMARY         NaN  4009  MILLBRIDGE PKWY
#          03/15/2016 PRIMARY         NaN  4009  MILLBRIDGE PKWY
#          11/06/2018 GENERAL         NaN  4009  MILLBRIDGE PKWY
#
#                             res_city_desc state_cd  zip_code race_code  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL        WAXHAW       NC   28173.0         W
#          11/06/2012 GENERAL        WAXHAW       NC   28173.0         W
#          05/08/2012 PRIMARY        WAXHAW       NC   28173.0         W
#          03/15/2016 PRIMARY        WAXHAW       NC   28173.0         W
#          11/06/2018 GENERAL        WAXHAW       NC   28173.0         W
#
#                             ethnic_code party_cd gender_code  birth_age  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL          NL      UNA           M         46
#          11/06/2012 GENERAL          NL      UNA           M         46
#          05/08/2012 PRIMARY          NL      UNA           M         46
#          03/15/2016 PRIMARY          NL      UNA           M         46
#          11/06/2018 GENERAL          NL      UNA           M         46
#
#                             birth_state drivers_lic registr_dt precinct_abbrv  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL          OC           Y 2019-04-25           020A
#          11/06/2012 GENERAL          OC           Y 2019-04-25           020A
#          05/08/2012 PRIMARY          OC           Y 2019-04-25           020A
#          03/15/2016 PRIMARY          OC           Y 2019-04-25           020A
#          11/06/2018 GENERAL          OC           Y 2019-04-25           020A
#
#                             precinct_desc  cong_dist_abbrv super_court_abbrv  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL          020A              9.0               20B
#          11/06/2012 GENERAL          020A              9.0               20B
#          05/08/2012 PRIMARY          020A              9.0               20B
#          03/15/2016 PRIMARY          020A              9.0               20B
#          11/06/2018 GENERAL          020A              9.0               20B
#
#                             judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL              20C             35.0            68.0
#          11/06/2012 GENERAL              20C             35.0            68.0
#          05/08/2012 PRIMARY              20C             35.0            68.0
#          03/15/2016 PRIMARY              20C             35.0            68.0
#          11/06/2018 GENERAL              20C             35.0            68.0
#
#                              school_dist_abbrv school_dist_desc  dist_1_abbrv  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL                2.0        SCHOOL #2          30.0
#          11/06/2012 GENERAL                2.0        SCHOOL #2          30.0
#          05/08/2012 PRIMARY                2.0        SCHOOL #2          30.0
#          03/15/2016 PRIMARY                2.0        SCHOOL #2          30.0
#          11/06/2018 GENERAL                2.0        SCHOOL #2          30.0
#
#                                     dist_1_desc confidential_ind  birth_year  \
# ncid     election_desc
# EF230133 11/03/2020 GENERAL  30TH PROSECUTORIAL                N        1974
#          11/06/2012 GENERAL  30TH PROSECUTORIAL                N        1974
#          05/08/2012 PRIMARY  30TH PROSECUTORIAL                N        1974
#          03/15/2016 PRIMARY  30TH PROSECUTORIAL                N        1974
#          11/06/2018 GENERAL  30TH PROSECUTORIAL                N        1974
#
#                             vtd_abbrv vtd_desc
# ncid     election_desc
# EF230133 11/03/2020 GENERAL      020A     020A
#          11/06/2012 GENERAL      020A     020A
#          05/08/2012 PRIMARY      020A     020A
#          03/15/2016 PRIMARY      020A     020A
#          11/06/2018 GENERAL      020A     020A

# %%
## Create a dataframe indexed by ncid that records whether and how a person
  ## voted in each major election
voter_elecs_slice = voter_elecs_mi['vote_method_cat'].copy()
maj_elec_methods = voter_elecs_slice.unstack().drop(columns='None')

# Reorder columns
maj_elec_methods = maj_elec_methods[['11/03/2020 GENERAL', '03/03/2020 PRIMARY', 
                                       '11/06/2018 GENERAL', '05/08/2018 PRIMARY',
                                       '11/08/2016 GENERAL', '03/15/2016 PRIMARY', 
                                       '11/04/2014 GENERAL', '05/06/2014 PRIMARY',
                                       '11/06/2012 GENERAL', '05/08/2012 PRIMARY']]
# Rename columns
maj_elec_methods.columns = ['Gen_2020', 'Pri_2020',
                            'Gen_2018', 'Pri_2018',
                            'Gen_2016', 'Pri_2016',
                            'Gen_2014', 'Pri_2014',
                            'Gen_2012', 'Pri_2012']

# Null values indicate the person did not cast a vote for the election, so
  # make 'No Vote' its own category
maj_elec_methods.fillna('No Vote', inplace=True)

# Inspect df
maj_elec_methods
# Out:
#               Gen_2020      Pri_2020      Gen_2018      Pri_2018  \
# ncid
# AA100547         Early  Election Day         Early       No Vote
# AA108801       No Vote       No Vote       No Vote       No Vote
# AA109481         Early       No Vote       No Vote       No Vote
# AA112504       No Vote       No Vote  Election Day       No Vote
# AA114763         Early  Election Day         Early  Election Day
# ...                ...           ...           ...           ...
# ES20642   Election Day  Election Day  Election Day  Election Day
# ES22412          Early       No Vote  Election Day       No Vote
# ES26874   Election Day       No Vote  Election Day       No Vote
# ES27419   Election Day       No Vote  Election Day       No Vote
# ES6418         No Vote       No Vote       No Vote       No Vote
#
#               Gen_2016      Pri_2016      Gen_2014      Pri_2014  \
# ncid
# AA100547         Early       No Vote       No Vote       No Vote
# AA108801         Early       No Vote       No Vote       No Vote
# AA109481       No Vote       No Vote       No Vote       No Vote
# AA112504         Early       No Vote  Election Day       No Vote
# AA114763         Early  Election Day         Early  Election Day
# ...                ...           ...           ...           ...
# ES20642          Early       No Vote       No Vote       No Vote
# ES22412          Early       No Vote       No Vote       No Vote
# ES26874        No Vote       No Vote       No Vote       No Vote
# ES27419        No Vote       No Vote       No Vote       No Vote
# ES6418    Election Day       No Vote  Election Day  Election Day
#
#               Gen_2012      Pri_2012
# ncid
# AA100547       No Vote  Election Day
# AA108801       No Vote       No Vote
# AA109481         Early  Election Day
# AA112504         Early       No Vote
# AA114763         Early       No Vote
# ...                ...           ...
# ES20642   Election Day       No Vote
# ES22412          Early       No Vote
# ES26874        No Vote       No Vote
# ES27419        No Vote       No Vote
# ES6418    Election Day  Election Day
#
# [169250 rows x 10 columns]

# %%
## Check length of df prior to merging with maj_elec_methods
len(voter_elecs)
# Out:
# 1861750

# %%
## Merge voter_elecs df with maj_elecs_methods according to ncid
voter_elecs = voter_elecs.merge(maj_elec_methods, how='left',
                                   on='ncid')
# Inspect updated df
print(len(voter_elecs)) # length did not change
voter_elecs.head()
# Out:
# 1861750
#        ncid       election_desc  no_vote_his  county_id county_desc  \
# 0  EF230133  11/03/2020 GENERAL            0       90.0       UNION
# 1  EF230133  11/06/2012 GENERAL            0        NaN         NaN
# 2  EF230133  05/08/2012 PRIMARY            0        NaN         NaN
# 3  EF230133  03/15/2016 PRIMARY            0        NaN         NaN
# 4  EF230133  11/06/2018 GENERAL            0        NaN         NaN
#
#    voter_reg_num  election_yr election_lbl registr_deadline  registr_in_time  \
# 0       346446.0       2020.0   2020-11-03       2020-10-09                1
# 1            NaN       2012.0   2012-11-06       2012-10-12                0
# 2            NaN       2012.0   2012-05-08       2012-04-13                0
# 3            NaN       2016.0   2016-03-15       2016-02-19                0
# 4            NaN       2018.0   2018-11-06       2018-10-12                0
#
#    birth_age_adj  presid_elec vote_method_cat  vote_early  vote_by_mail  \
# 0           46.0          1.0           Early         1.0           0.0
# 1           38.0          1.0             NaN         0.0           0.0
# 2           38.0          1.0             NaN         0.0           0.0
# 3           42.0          1.0             NaN         0.0           0.0
# 4           44.0          0.0             NaN         0.0           0.0
#
#    vote_curbside election_cat     voting_method voted_party_cd  \
# 0            0.0      GENERAL  ABSENTEE ONESTOP            UNA
# 1            0.0      GENERAL               NaN            NaN
# 2            0.0      PRIMARY               NaN            NaN
# 3            0.0      PRIMARY               NaN            NaN
# 4            0.0      GENERAL               NaN            NaN
#
#   voted_party_desc pct_label pct_description  voted_county_id  \
# 0     UNAFFILIATED      020A            020A             90.0
# 1              NaN       NaN             NaN              NaN
# 2              NaN       NaN             NaN              NaN
# 3              NaN       NaN             NaN              NaN
# 4              NaN       NaN             NaN              NaN
#
#   voted_county_desc vtd_label vtd_description status_cd voter_status_desc  \
# 0             UNION      020A            020A         A            ACTIVE
# 1               NaN       NaN             NaN         A            ACTIVE
# 2               NaN       NaN             NaN         A            ACTIVE
# 3               NaN       NaN             NaN         A            ACTIVE
# 4               NaN       NaN             NaN         A            ACTIVE
#
#   reason_cd voter_status_reason_desc last_name first_name middle_name  \
# 0        AV                 VERIFIED    AALAEI       ARIO         NaN
# 1        AV                 VERIFIED    AALAEI       ARIO         NaN
# 2        AV                 VERIFIED    AALAEI       ARIO         NaN
# 3        AV                 VERIFIED    AALAEI       ARIO         NaN
# 4        AV                 VERIFIED    AALAEI       ARIO         NaN
#
#          res_street_address res_city_desc state_cd  zip_code race_code  \
# 0  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 1  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 2  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 3  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
# 4  4009  MILLBRIDGE PKWY           WAXHAW       NC   28173.0         W
#
#   ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 0          NL      UNA           M         46          OC           Y
# 1          NL      UNA           M         46          OC           Y
# 2          NL      UNA           M         46          OC           Y
# 3          NL      UNA           M         46          OC           Y
# 4          NL      UNA           M         46          OC           Y
#
#   registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv super_court_abbrv  \
# 0 2019-04-25           020A          020A              9.0               20B
# 1 2019-04-25           020A          020A              9.0               20B
# 2 2019-04-25           020A          020A              9.0               20B
# 3 2019-04-25           020A          020A              9.0               20B
# 4 2019-04-25           020A          020A              9.0               20B
#
#   judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 0              20C             35.0            68.0                2.0
# 1              20C             35.0            68.0                2.0
# 2              20C             35.0            68.0                2.0
# 3              20C             35.0            68.0                2.0
# 4              20C             35.0            68.0                2.0
#
#   school_dist_desc  dist_1_abbrv         dist_1_desc confidential_ind  \
# 0        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 1        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 2        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 3        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
# 4        SCHOOL #2          30.0  30TH PROSECUTORIAL                N
#
#    birth_year vtd_abbrv vtd_desc Gen_2020 Pri_2020 Gen_2018 Pri_2018 Gen_2016  \
# 0        1974      020A     020A    Early  No Vote  No Vote  No Vote  No Vote
# 1        1974      020A     020A    Early  No Vote  No Vote  No Vote  No Vote
# 2        1974      020A     020A    Early  No Vote  No Vote  No Vote  No Vote
# 3        1974      020A     020A    Early  No Vote  No Vote  No Vote  No Vote
# 4        1974      020A     020A    Early  No Vote  No Vote  No Vote  No Vote
#
#   Pri_2016 Gen_2014 Pri_2014 Gen_2012 Pri_2012
# 0  No Vote  No Vote  No Vote  No Vote  No Vote
# 1  No Vote  No Vote  No Vote  No Vote  No Vote
# 2  No Vote  No Vote  No Vote  No Vote  No Vote
# 3  No Vote  No Vote  No Vote  No Vote  No Vote
# 4  No Vote  No Vote  No Vote  No Vote  No Vote

# %%
# voter_elecs.head(35)

# %%
# full_voter_elecs_df = voter_elecs.copy()
# full_voter_elecs_df.to_csv('Data/full_voter_elecs.zip', index=False)

# %%
voter_elecs.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1861750 entries, 0 to 1861749
# Data columns (total 70 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   ncid                      1861750 non-null  object
#  1   election_desc             1861750 non-null  object
#  2   no_vote_his               1861750 non-null  int64
#  3   county_id                 617064 non-null   float64
#  4   county_desc               617064 non-null   object
#  5   voter_reg_num             617064 non-null   float64
#  6   election_yr               1692500 non-null  float64
#  7   election_lbl              1692500 non-null  datetime64[ns]
#  8   registr_deadline          1692500 non-null  datetime64[ns]
#  9   registr_in_time           1861750 non-null  int64
#  10  birth_age_adj             1692500 non-null  float64
#  11  presid_elec               1692500 non-null  float64
#  12  vote_method_cat           617064 non-null   object
#  13  vote_early                1692500 non-null  float64
#  14  vote_by_mail              1692500 non-null  float64
#  15  vote_curbside             1692500 non-null  float64
#  16  election_cat              1692500 non-null  object
#  17  voting_method             617064 non-null   object
#  18  voted_party_cd            617027 non-null   object
#  19  voted_party_desc          617027 non-null   object
#  20  pct_label                 617064 non-null   object
#  21  pct_description           617064 non-null   object
#  22  voted_county_id           617064 non-null   float64
#  23  voted_county_desc         617064 non-null   object
#  24  vtd_label                 616917 non-null   object
#  25  vtd_description           616917 non-null   object
#  26  status_cd                 1861750 non-null  object
#  27  voter_status_desc         1861750 non-null  object
#  28  reason_cd                 1861750 non-null  object
#  29  voter_status_reason_desc  1861750 non-null  object
#  30  last_name                 1861717 non-null  object
#  31  first_name                1861739 non-null  object
#  32  middle_name               1707211 non-null  object
#  33  res_street_address        1861750 non-null  object
#  34  res_city_desc             1861717 non-null  object
#  35  state_cd                  1861717 non-null  object
#  36  zip_code                  1861717 non-null  float64
#  37  race_code                 1861750 non-null  object
#  38  ethnic_code               1861750 non-null  object
#  39  party_cd                  1861750 non-null  object
#  40  gender_code               1861750 non-null  object
#  41  birth_age                 1861750 non-null  int64
#  42  birth_state               1408253 non-null  object
#  43  drivers_lic               1861750 non-null  object
#  44  registr_dt                1861750 non-null  datetime64[ns]
#  45  precinct_abbrv            1861750 non-null  object
#  46  precinct_desc             1861750 non-null  object
#  47  cong_dist_abbrv           1861750 non-null  float64
#  48  super_court_abbrv         1861750 non-null  object
#  49  judic_dist_abbrv          1861750 non-null  object
#  50  nc_senate_abbrv           1861750 non-null  float64
#  51  nc_house_abbrv            1861750 non-null  float64
#  52  school_dist_abbrv         1861750 non-null  float64
#  53  school_dist_desc          1861750 non-null  object
#  54  dist_1_abbrv              1861750 non-null  float64
#  55  dist_1_desc               1861750 non-null  object
#  56  confidential_ind          1861750 non-null  object
#  57  birth_year                1861750 non-null  int64
#  58  vtd_abbrv                 1861750 non-null  object
#  59  vtd_desc                  1861750 non-null  object
#  60  Gen_2020                  1861750 non-null  object
#  61  Pri_2020                  1861750 non-null  object
#  62  Gen_2018                  1861750 non-null  object
#  63  Pri_2018                  1861750 non-null  object
#  64  Gen_2016                  1861750 non-null  object
#  65  Pri_2016                  1861750 non-null  object
#  66  Gen_2014                  1861750 non-null  object
#  67  Pri_2014                  1861750 non-null  object
#  68  Gen_2012                  1861750 non-null  object
#  69  Pri_2012                  1861750 non-null  object
# dtypes: datetime64[ns](3), float64(15), int64(4), object(48)
# memory usage: 1008.5+ MB

# %%
## Create a df that summarizes the information known for each ncid
  ## (one record for each ncid)
ncid_summary = voter_elecs.copy()

# Reorder and only include certain columns
ncid_summary = ncid_summary[['ncid', 'no_vote_his', 'voter_status_desc',
                             'voter_status_reason_desc', 'last_name', 
                             'first_name', 'middle_name','party_cd', 
                             'gender_code', 'birth_age', 'birth_year',
                             'registr_dt', 'race_code','ethnic_code', 
                             'zip_code', 'res_street_address',
                             'res_city_desc', 'birth_state', 'drivers_lic', 
                             'precinct_abbrv', 'vtd_abbrv',
                             'cong_dist_abbrv','super_court_abbrv',
                             'judic_dist_abbrv', 'nc_senate_abbrv', 
                             'nc_house_abbrv', 'school_dist_abbrv',
                             'Gen_2020', 'Pri_2020', 'Gen_2018', 'Pri_2018',
                             'Gen_2016', 'Pri_2016', 'Gen_2014', 'Pri_2014',
                             'Gen_2012', 'Pri_2012'      
                            ]]
# With columns that make a record specific to a single election excluded,
  # each row corresponding to a unique ncid should be identical to the others. 
  # Thus, only one row per unique ncid is needed now, drop duplicates
ncid_summary.drop_duplicates(inplace=True)

# Inspect new df
ncid_summary.head()
# Out:
#         ncid  no_vote_his voter_status_desc voter_status_reason_desc  \
# 0   EF230133            0            ACTIVE                 VERIFIED
# 11  EF231096            0            ACTIVE                 VERIFIED
# 22  AL261840            1            ACTIVE                 VERIFIED
# 33  AL178177            0            ACTIVE                 VERIFIED
# 44  AL193958            0            ACTIVE                 VERIFIED
#
#    last_name first_name   middle_name party_cd gender_code  birth_age  \
# 0     AALAEI       ARIO           NaN      UNA           M         46
# 11    AALAEI    KAVITHA           NaN      DEM           F         46
# 22   AALBORG     ALEXIS         LEANN      UNA           F         26
# 33   AALBORG      BRYAN           LEE      UNA           M         62
# 44   AALBORG     SHARON  SCHLEENBAKER      REP           F         62
#
#     birth_year registr_dt race_code ethnic_code  zip_code  \
# 0         1974 2019-04-25         W          NL   28173.0
# 11        1974 2019-06-24         A          NL   28173.0
# 22        1994 2013-11-04         W          NL   28079.0
# 33        1958 2014-09-17         W          UN   28079.0
# 44        1958 2013-07-24         W          NL   28079.0
#
#            res_street_address res_city_desc birth_state drivers_lic  \
# 0    4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 11   4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 22  1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 33  1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 44  1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
#
#    precinct_abbrv vtd_abbrv  cong_dist_abbrv super_court_abbrv  \
# 0            020A      020A              9.0               20B
# 11           020A      020A              9.0               20B
# 22           029A      029A              9.0               20B
# 33           029A      029A              9.0               20B
# 44           029A      029A              9.0               20B
#
#    judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 0               20C             35.0            68.0                2.0
# 11              20C             35.0            68.0                2.0
# 22              20C             35.0            68.0                3.0
# 33              20C             35.0            68.0                3.0
# 44              20C             35.0            68.0                3.0
#
#    Gen_2020 Pri_2020 Gen_2018 Pri_2018      Gen_2016      Pri_2016  \
# 0     Early  No Vote  No Vote  No Vote       No Vote       No Vote
# 11    Early  No Vote  No Vote  No Vote       No Vote       No Vote
# 22  No Vote  No Vote  No Vote  No Vote       No Vote       No Vote
# 33    Early  No Vote    Early  No Vote  Election Day  Election Day
# 44    Early  No Vote    Early  No Vote  Election Day       No Vote
#
#         Gen_2014 Pri_2014 Gen_2012      Pri_2012
# 0        No Vote  No Vote  No Vote       No Vote
# 11       No Vote  No Vote  No Vote       No Vote
# 22       No Vote  No Vote  No Vote       No Vote
# 33  Election Day  No Vote    Early  Election Day
# 44       No Vote  No Vote    Early       No Vote

# %%
## Check length of new df and number of unique ncid's to ensure each 
  ## appears only once
print(len(ncid_summary))
ncid_summary['ncid'].nunique()
# Out:
# 169250
# 169250

# %%
## Check metadata for new summary df
ncid_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169250 entries, 0 to 1861739
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ncid                      169250 non-null  object
#  1   no_vote_his               169250 non-null  int64
#  2   voter_status_desc         169250 non-null  object
#  3   voter_status_reason_desc  169250 non-null  object
#  4   last_name                 169247 non-null  object
#  5   first_name                169249 non-null  object
#  6   middle_name               155201 non-null  object
#  7   party_cd                  169250 non-null  object
#  8   gender_code               169250 non-null  object
#  9   birth_age                 169250 non-null  int64
#  10  birth_year                169250 non-null  int64
#  11  registr_dt                169250 non-null  datetime64[ns]
#  12  race_code                 169250 non-null  object
#  13  ethnic_code               169250 non-null  object
#  14  zip_code                  169247 non-null  float64
#  15  res_street_address        169250 non-null  object
#  16  res_city_desc             169247 non-null  object
#  17  birth_state               128023 non-null  object
#  18  drivers_lic               169250 non-null  object
#  19  precinct_abbrv            169250 non-null  object
#  20  vtd_abbrv                 169250 non-null  object
#  21  cong_dist_abbrv           169250 non-null  float64
#  22  super_court_abbrv         169250 non-null  object
#  23  judic_dist_abbrv          169250 non-null  object
#  24  nc_senate_abbrv           169250 non-null  float64
#  25  nc_house_abbrv            169250 non-null  float64
#  26  school_dist_abbrv         169250 non-null  float64
#  27  Gen_2020                  169250 non-null  object
#  28  Pri_2020                  169250 non-null  object
#  29  Gen_2018                  169250 non-null  object
#  30  Pri_2018                  169250 non-null  object
#  31  Gen_2016                  169250 non-null  object
#  32  Pri_2016                  169250 non-null  object
#  33  Gen_2014                  169250 non-null  object
#  34  Pri_2014                  169250 non-null  object
#  35  Gen_2012                  169250 non-null  object
#  36  Pri_2012                  169250 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(3), object(28)
# memory usage: 49.1+ MB

# %%
# ncid_summary.to_csv('Data/ncid_summary.zip', index=False)

# %% [markdown]
# ## Create Separate DataFrames for Each Election

# %% [markdown]
# ### No Recent Voting History

# %%
## Make dataframe of registered voters with no history of voting in major elections
no_vote_his = voter_elecs.copy()
no_vote_his = no_vote_his.loc[(no_vote_his['no_vote_his'] == 1)]
no_vote_his.head()
# Out:
#         ncid       election_desc  no_vote_his  county_id county_desc  \
# 22  AL261840  11/03/2020 GENERAL            1        NaN         NaN
# 23  AL261840  11/06/2012 GENERAL            1        NaN         NaN
# 24  AL261840  05/08/2012 PRIMARY            1        NaN         NaN
# 25  AL261840  03/15/2016 PRIMARY            1        NaN         NaN
# 26  AL261840  11/06/2018 GENERAL            1        NaN         NaN
#
#     voter_reg_num  election_yr election_lbl registr_deadline  registr_in_time  \
# 22            NaN       2020.0   2020-11-03       2020-10-09                1
# 23            NaN       2012.0   2012-11-06       2012-10-12                0
# 24            NaN       2012.0   2012-05-08       2012-04-13                0
# 25            NaN       2016.0   2016-03-15       2016-02-19                1
# 26            NaN       2018.0   2018-11-06       2018-10-12                1
#
#     birth_age_adj  presid_elec vote_method_cat  vote_early  vote_by_mail  \
# 22           26.0          1.0             NaN         0.0           0.0
# 23           18.0          1.0             NaN         0.0           0.0
# 24           18.0          1.0             NaN         0.0           0.0
# 25           22.0          1.0             NaN         0.0           0.0
# 26           24.0          0.0             NaN         0.0           0.0
#
#     vote_curbside election_cat voting_method voted_party_cd voted_party_desc  \
# 22            0.0      GENERAL           NaN            NaN              NaN
# 23            0.0      GENERAL           NaN            NaN              NaN
# 24            0.0      PRIMARY           NaN            NaN              NaN
# 25            0.0      PRIMARY           NaN            NaN              NaN
# 26            0.0      GENERAL           NaN            NaN              NaN
#
#    pct_label pct_description  voted_county_id voted_county_desc vtd_label  \
# 22       NaN             NaN              NaN               NaN       NaN
# 23       NaN             NaN              NaN               NaN       NaN
# 24       NaN             NaN              NaN               NaN       NaN
# 25       NaN             NaN              NaN               NaN       NaN
# 26       NaN             NaN              NaN               NaN       NaN
#
#    vtd_description status_cd voter_status_desc reason_cd  \
# 22             NaN         A            ACTIVE        AV
# 23             NaN         A            ACTIVE        AV
# 24             NaN         A            ACTIVE        AV
# 25             NaN         A            ACTIVE        AV
# 26             NaN         A            ACTIVE        AV
#
#    voter_status_reason_desc last_name first_name middle_name  \
# 22                 VERIFIED   AALBORG     ALEXIS       LEANN
# 23                 VERIFIED   AALBORG     ALEXIS       LEANN
# 24                 VERIFIED   AALBORG     ALEXIS       LEANN
# 25                 VERIFIED   AALBORG     ALEXIS       LEANN
# 26                 VERIFIED   AALBORG     ALEXIS       LEANN
#
#            res_street_address res_city_desc state_cd  zip_code race_code  \
# 22  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 23  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 24  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 25  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
# 26  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0         W
#
#    ethnic_code party_cd gender_code  birth_age birth_state drivers_lic  \
# 22          NL      UNA           F         26          IA           Y
# 23          NL      UNA           F         26          IA           Y
# 24          NL      UNA           F         26          IA           Y
# 25          NL      UNA           F         26          IA           Y
# 26          NL      UNA           F         26          IA           Y
#
#    registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv super_court_abbrv  \
# 22 2013-11-04           029A          029A              9.0               20B
# 23 2013-11-04           029A          029A              9.0               20B
# 24 2013-11-04           029A          029A              9.0               20B
# 25 2013-11-04           029A          029A              9.0               20B
# 26 2013-11-04           029A          029A              9.0               20B
#
#    judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  school_dist_abbrv  \
# 22              20C             35.0            68.0                3.0
# 23              20C             35.0            68.0                3.0
# 24              20C             35.0            68.0                3.0
# 25              20C             35.0            68.0                3.0
# 26              20C             35.0            68.0                3.0
#
#    school_dist_desc  dist_1_abbrv         dist_1_desc confidential_ind  \
# 22        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 23        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 24        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 25        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
# 26        SCHOOL #3          30.0  30TH PROSECUTORIAL                N
#
#     birth_year vtd_abbrv vtd_desc Gen_2020 Pri_2020 Gen_2018 Pri_2018  \
# 22        1994      029A     029A  No Vote  No Vote  No Vote  No Vote
# 23        1994      029A     029A  No Vote  No Vote  No Vote  No Vote
# 24        1994      029A     029A  No Vote  No Vote  No Vote  No Vote
# 25        1994      029A     029A  No Vote  No Vote  No Vote  No Vote
# 26        1994      029A     029A  No Vote  No Vote  No Vote  No Vote
#
#    Gen_2016 Pri_2016 Gen_2014 Pri_2014 Gen_2012 Pri_2012
# 22  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 23  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 24  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 25  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 26  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote

# %%
## Double check that these really are people with no history of voting 
## in recent major elections
no_his_methods = [col for col in no_vote_his.columns[-10:]]
for col in no_his_methods:
    display(no_vote_his[col].value_counts().to_frame())
# Out:
#          Gen_2020
# No Vote    202323
#          Pri_2020
# No Vote    202323
#          Gen_2018
# No Vote    202323
#          Pri_2018
# No Vote    202323
#          Gen_2016
# No Vote    202323
#          Pri_2016
# No Vote    202323
#          Gen_2014
# No Vote    202323
#          Pri_2014
# No Vote    202323
#          Gen_2012
# No Vote    202323
#          Pri_2012
# No Vote    202323

# %%
## Only keep the 'None' election rows to cut down on redundant info
no_vote_his = no_vote_his.loc[no_vote_his['election_desc']=='None']
print(len(no_vote_his))
no_vote_his.head()
# Out:
# 18393
#          ncid election_desc  no_vote_his  county_id county_desc  \
# 32   AL261840          None            1        NaN         NaN
# 65   EF186953          None            1        NaN         NaN
# 230  EF187881          None            1        NaN         NaN
# 307  EF225835          None            1        NaN         NaN
# 362  EF244548          None            1        NaN         NaN
#
#      voter_reg_num  election_yr election_lbl registr_deadline  \
# 32             NaN          NaN          NaT              NaT
# 65             NaN          NaN          NaT              NaT
# 230            NaN          NaN          NaT              NaT
# 307            NaN          NaN          NaT              NaT
# 362            NaN          NaN          NaT              NaT
#
#      registr_in_time  birth_age_adj  presid_elec vote_method_cat  vote_early  \
# 32                 1            NaN          NaN             NaN         NaN
# 65                 1            NaN          NaN             NaN         NaN
# 230                1            NaN          NaN             NaN         NaN
# 307                1            NaN          NaN             NaN         NaN
# 362                1            NaN          NaN             NaN         NaN
#
#      vote_by_mail  vote_curbside election_cat voting_method voted_party_cd  \
# 32            NaN            NaN          NaN           NaN            NaN
# 65            NaN            NaN          NaN           NaN            NaN
# 230           NaN            NaN          NaN           NaN            NaN
# 307           NaN            NaN          NaN           NaN            NaN
# 362           NaN            NaN          NaN           NaN            NaN
#
#     voted_party_desc pct_label pct_description  voted_county_id  \
# 32               NaN       NaN             NaN              NaN
# 65               NaN       NaN             NaN              NaN
# 230              NaN       NaN             NaN              NaN
# 307              NaN       NaN             NaN              NaN
# 362              NaN       NaN             NaN              NaN
#
#     voted_county_desc vtd_label vtd_description status_cd voter_status_desc  \
# 32                NaN       NaN             NaN         A            ACTIVE
# 65                NaN       NaN             NaN         A            ACTIVE
# 230               NaN       NaN             NaN         I          INACTIVE
# 307               NaN       NaN             NaN         A            ACTIVE
# 362               NaN       NaN             NaN         A            ACTIVE
#
#     reason_cd   voter_status_reason_desc        last_name first_name  \
# 32         AV                   VERIFIED          AALBORG     ALEXIS
# 65         AV                   VERIFIED         AANENSEN     MATHEW
# 230        IN  CONFIRMATION NOT RETURNED             ABAR    KRISTEN
# 307        AV                   VERIFIED           ABARCA      JENNY
# 362        AV                   VERIFIED  ABARCA-CANTORAN     VICTOR
#
#     middle_name         res_street_address res_city_desc state_cd  zip_code  \
# 32        LEANN  1001  STEVENS PRIDE CT     INDIAN TRAIL       NC   28079.0
# 65       THOMAS           7607  TESH RD           MONROE       NC   28110.0
# 230      ELAINE         5523  CHERAW RD       MARSHVILLE       NC   28103.0
# 307         NaN         1802  STEELE ST           MONROE       NC   28110.0
# 362         NaN        302  MCINTYRE ST           MONROE       NC   28110.0
#
#     race_code ethnic_code party_cd gender_code  birth_age birth_state  \
# 32          W          NL      UNA           F         26          IA
# 65          W          NL      UNA           M         25          NY
# 230         W          NL      DEM           F         24          NC
# 307         O          HL      UNA           F         23          NC
# 362         W          HL      REP           M         19          NC
#
#     drivers_lic registr_dt precinct_abbrv precinct_desc  cong_dist_abbrv  \
# 32            Y 2013-11-04           029A          029A              9.0
# 65            Y 2014-01-21            012           012              9.0
# 230           Y 2014-02-17            026           026              9.0
# 307           Y 2018-11-08            004           004              9.0
# 362           Y 2020-09-17            004           004              9.0
#
#     super_court_abbrv judic_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 32                20B              20C             35.0            68.0
# 65                20B              20C             36.0            69.0
# 230               20B              20C             35.0            55.0
# 307               20B              20B             35.0            69.0
# 362               20B              20B             35.0            69.0
#
#      school_dist_abbrv school_dist_desc  dist_1_abbrv         dist_1_desc  \
# 32                 3.0        SCHOOL #3          30.0  30TH PROSECUTORIAL
# 65                 4.0        SCHOOL #4          30.0  30TH PROSECUTORIAL
# 230                2.0        SCHOOL #2          30.0  30TH PROSECUTORIAL
# 307                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
# 362                1.0        SCHOOL #1          30.0  30TH PROSECUTORIAL
#
#     confidential_ind  birth_year vtd_abbrv vtd_desc Gen_2020 Pri_2020  \
# 32                 N        1994      029A     029A  No Vote  No Vote
# 65                 N        1995       012      012  No Vote  No Vote
# 230                N        1996       026      026  No Vote  No Vote
# 307                N        1997       004      004  No Vote  No Vote
# 362                N        2000       004      004  No Vote  No Vote
#
#     Gen_2018 Pri_2018 Gen_2016 Pri_2016 Gen_2014 Pri_2014 Gen_2012 Pri_2012
# 32   No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 65   No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 230  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 307  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote
# 362  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote  No Vote

# %%
# no_vote_his.to_csv('Data/no_vote_his.zip', index=False)

# %% [markdown]
# ### General 2020

# %%
## Define function to automate assembling election specific dataframes
def get_election_df(yr, cat='GENERAL'):
    
    # Copy original df
    df = voter_elecs.copy()

    # Filter to get only the rows specific to the 2020 general election
    df = df.loc[(df['election_yr']==yr) & 
                (df['election_cat']==cat)]

    # Drop those voters who did not register in time
    df = df.loc[df['registr_in_time']==1]
    
    # Drop those voters who were not old enough to vote in the election
      # (apparently some registration date info is incorrect)
    df = df.loc[df['birth_age_adj']>=18]

    # Reorder and drop certain columns
    df = df[['ncid', 'no_vote_his', 'birth_age_adj', 'voting_method', 
             '{}_{}'.format(cat.title()[:3], yr), 'vote_early', 
             'vote_by_mail', 'vote_curbside', 'Pri_{}'.format(yr), 'party_cd',
             'gender_code', 'birth_year', 'registr_dt', 'race_code', 
             'ethnic_code', 'zip_code', 'res_street_address', 
             'res_city_desc', 'birth_state', 'drivers_lic', 
             'precinct_abbrv', 'vtd_abbrv', 'cong_dist_abbrv', 
             'nc_senate_abbrv', 'nc_house_abbrv', 'school_dist_abbrv'
            ]]
    
    return df

# %%
## Make dataframe specific to 2020 general election
gen_2020 = get_election_df(2020)
print(len(gen_2020))
display(gen_2020.head())
gen_2020.tail()
# Out:
# 168463
#         ncid  no_vote_his  birth_age_adj     voting_method Gen_2020  \
# 0   EF230133            0           46.0  ABSENTEE ONESTOP    Early
# 11  EF231096            0           46.0  ABSENTEE ONESTOP    Early
# 22  AL261840            1           26.0               NaN  No Vote
# 33  AL178177            0           62.0  ABSENTEE ONESTOP    Early
# 44  AL193958            0           62.0  ABSENTEE ONESTOP    Early
#
#     vote_early  vote_by_mail  vote_curbside Pri_2020 party_cd gender_code  \
# 0          1.0           0.0            0.0  No Vote      UNA           M
# 11         1.0           0.0            0.0  No Vote      DEM           F
# 22         0.0           0.0            0.0  No Vote      UNA           F
# 33         1.0           0.0            0.0  No Vote      UNA           M
# 44         1.0           0.0            0.0  No Vote      REP           F
#
#     birth_year registr_dt race_code ethnic_code  zip_code  \
# 0         1974 2019-04-25         W          NL   28173.0
# 11        1974 2019-06-24         A          NL   28173.0
# 22        1994 2013-11-04         W          NL   28079.0
# 33        1958 2014-09-17         W          UN   28079.0
# 44        1958 2013-07-24         W          NL   28079.0
#
#            res_street_address res_city_desc birth_state drivers_lic  \
# 0    4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 11   4009  MILLBRIDGE PKWY           WAXHAW          OC           Y
# 22  1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 33  1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 44  1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
#
#    precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 0            020A      020A              9.0             35.0            68.0
# 11           020A      020A              9.0             35.0            68.0
# 22           029A      029A              9.0             35.0            68.0
# 33           029A      029A              9.0             35.0            68.0
# 44           029A      029A              9.0             35.0            68.0
#
#     school_dist_abbrv
# 0                 2.0
# 11                2.0
# 22                3.0
# 33                3.0
# 44                3.0
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2020  \
# 1861695  BL403374            0           31.0  ABSENTEE ONESTOP         Early
# 1861706  AN145460            0           30.0         IN-PERSON  Election Day
# 1861717  EF199981            0           25.0               NaN       No Vote
# 1861728  EF157599            0           68.0  ABSENTEE ONESTOP         Early
# 1861739  EF219265            1           52.0               NaN       No Vote
#
#          vote_early  vote_by_mail  vote_curbside      Pri_2020 party_cd  \
# 1861695         1.0           0.0            0.0       No Vote      REP
# 1861706         0.0           0.0            0.0  Election Day      REP
# 1861717         0.0           0.0            0.0       No Vote      REP
# 1861728         1.0           0.0            0.0         Early      DEM
# 1861739         0.0           0.0            0.0       No Vote      DEM
#
#         gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 1861695           M        1989 2018-10-04         W          NL   28079.0
# 1861706           U        1990 2019-10-09         U          UN   28112.0
# 1861717           U        1995 2016-02-18         W          UN   28174.0
# 1861728           M        1952 2009-08-28         W          NL   28112.0
# 1861739           F        1968 2018-03-26         W          NL   28104.0
#
#              res_street_address res_city_desc birth_state drivers_lic  \
# 1861695  6525  BRIDGEMOOR DR     INDIAN TRAIL          MA           Y
# 1861706  2017  BRIARBERRY LN           MONROE         NaN           Y
# 1861717      315 E WILSON ST          WINGATE         NaN           N
# 1861728      2905  MEDLIN RD           MONROE          MA           Y
# 1861739   5719  PARKSTONE DR         MATTHEWS          NY           Y
#
#         precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 1861695            016       016              9.0             35.0
# 1861706            007       007              9.0             35.0
# 1861717            008       008              9.0             35.0
# 1861728            025       025              9.0             35.0
# 1861739            040       040              9.0             35.0
#
#          nc_house_abbrv  school_dist_abbrv
# 1861695            69.0                4.0
# 1861706            55.0                1.0
# 1861717            55.0                1.0
# 1861728            55.0                2.0
# 1861739            68.0                5.0

# %%
# gen_2020.to_csv('Data/gen_2020.zip', index=False)

# %% [markdown]
# ### General 2018

# %%
## Make dataframe specific to 2018 general election
gen_2018 = get_election_df(2018)
print(len(gen_2018))
display(gen_2018.head())
gen_2018.tail()
# Out:
# 136686
#         ncid  no_vote_his  birth_age_adj     voting_method Gen_2018  \
# 26  AL261840            1           24.0               NaN  No Vote
# 37  AL178177            0           60.0  ABSENTEE ONESTOP    Early
# 48  AL193958            0           60.0  ABSENTEE ONESTOP    Early
# 59  EF186953            1           23.0               NaN  No Vote
# 70  AN175010            0           24.0               NaN  No Vote
#
#     vote_early  vote_by_mail  vote_curbside Pri_2018 party_cd gender_code  \
# 26         0.0           0.0            0.0  No Vote      UNA           F
# 37         1.0           0.0            0.0  No Vote      UNA           M
# 48         1.0           0.0            0.0  No Vote      REP           F
# 59         0.0           0.0            0.0  No Vote      UNA           M
# 70         0.0           0.0            0.0  No Vote      LIB           M
#
#     birth_year registr_dt race_code ethnic_code  zip_code  \
# 26        1994 2013-11-04         W          NL   28079.0
# 37        1958 2014-09-17         W          UN   28079.0
# 48        1958 2013-07-24         W          NL   28079.0
# 59        1995 2014-01-21         W          NL   28110.0
# 70        1994 2016-08-18         W          NL   28110.0
#
#            res_street_address res_city_desc birth_state drivers_lic  \
# 26  1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 37  1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 48  1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
# 59           7607  TESH RD           MONROE          NY           Y
# 70           7607  TESH RD           MONROE          NY           Y
#
#    precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 26           029A      029A              9.0             35.0            68.0
# 37           029A      029A              9.0             35.0            68.0
# 48           029A      029A              9.0             35.0            68.0
# 59            012       012              9.0             36.0            69.0
# 70            012       012              9.0             36.0            69.0
#
#     school_dist_abbrv
# 26                3.0
# 37                3.0
# 48                3.0
# 59                4.0
# 70                4.0
#              ncid  no_vote_his  birth_age_adj     voting_method Gen_2018  \
# 1861688  EF180541            0           61.0               NaN  No Vote
# 1861699  BL403374            0           29.0               NaN  No Vote
# 1861721  EF199981            0           23.0               NaN  No Vote
# 1861732  EF157599            0           66.0  ABSENTEE ONESTOP    Early
# 1861743  EF219265            1           50.0               NaN  No Vote
#
#          vote_early  vote_by_mail  vote_curbside Pri_2018 party_cd  \
# 1861688         0.0           0.0            0.0  No Vote      REP
# 1861699         0.0           0.0            0.0  No Vote      REP
# 1861721         0.0           0.0            0.0  No Vote      REP
# 1861732         1.0           0.0            0.0    Early      DEM
# 1861743         0.0           0.0            0.0  No Vote      DEM
#
#         gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 1861688           F        1957 2012-10-16         W          NL   28079.0
# 1861699           M        1989 2018-10-04         W          NL   28079.0
# 1861721           U        1995 2016-02-18         W          UN   28174.0
# 1861732           M        1952 2009-08-28         W          NL   28112.0
# 1861743           F        1968 2018-03-26         W          NL   28104.0
#
#                 res_street_address res_city_desc birth_state drivers_lic  \
# 1861688  2110  HUNTERS TRAIL DR     INDIAN TRAIL          OC           Y
# 1861699     6525  BRIDGEMOOR DR     INDIAN TRAIL          MA           Y
# 1861721         315 E WILSON ST          WINGATE         NaN           N
# 1861732         2905  MEDLIN RD           MONROE          MA           Y
# 1861743      5719  PARKSTONE DR         MATTHEWS          NY           Y
#
#         precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 1861688           038A      038A              9.0             35.0
# 1861699            016       016              9.0             35.0
# 1861721            008       008              9.0             35.0
# 1861732            025       025              9.0             35.0
# 1861743            040       040              9.0             35.0
#
#          nc_house_abbrv  school_dist_abbrv
# 1861688            69.0                4.0
# 1861699            69.0                4.0
# 1861721            55.0                1.0
# 1861732            55.0                2.0
# 1861743            68.0                5.0

# %%
# gen_2018.to_csv('Data/gen_2018.zip', index=False)

# %% [markdown]
# ### General 2016

# %%
## Make dataframe specific to 2016 general election
gen_2016 = get_election_df(2016)
print(len(gen_2016))
display(gen_2016.head())
gen_2016.tail()
# Out:
# 123464
#         ncid  no_vote_his  birth_age_adj voting_method      Gen_2016  \
# 27  AL261840            1           22.0           NaN       No Vote
# 38  AL178177            0           58.0     IN-PERSON  Election Day
# 49  AL193958            0           58.0     IN-PERSON  Election Day
# 60  EF186953            1           21.0           NaN       No Vote
# 71  AN175010            0           22.0           NaN       No Vote
#
#     vote_early  vote_by_mail  vote_curbside      Pri_2016 party_cd  \
# 27         0.0           0.0            0.0       No Vote      UNA
# 38         0.0           0.0            0.0  Election Day      UNA
# 49         0.0           0.0            0.0       No Vote      REP
# 60         0.0           0.0            0.0       No Vote      UNA
# 71         0.0           0.0            0.0       No Vote      LIB
#
#    gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 27           F        1994 2013-11-04         W          NL   28079.0
# 38           M        1958 2014-09-17         W          UN   28079.0
# 49           F        1958 2013-07-24         W          NL   28079.0
# 60           M        1995 2014-01-21         W          NL   28110.0
# 71           M        1994 2016-08-18         W          NL   28110.0
#
#            res_street_address res_city_desc birth_state drivers_lic  \
# 27  1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 38  1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 49  1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
# 60           7607  TESH RD           MONROE          NY           Y
# 71           7607  TESH RD           MONROE          NY           Y
#
#    precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  nc_house_abbrv  \
# 27           029A      029A              9.0             35.0            68.0
# 38           029A      029A              9.0             35.0            68.0
# 49           029A      029A              9.0             35.0            68.0
# 60            012       012              9.0             36.0            69.0
# 71            012       012              9.0             36.0            69.0
#
#     school_dist_abbrv
# 27                3.0
# 38                3.0
# 49                3.0
# 60                4.0
# 71                4.0
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2016  \
# 1861656  EF162701            0           24.0         IN-PERSON  Election Day
# 1861667   EF98536            0           57.0  ABSENTEE ONESTOP         Early
# 1861689  EF180541            0           59.0               NaN       No Vote
# 1861722  EF199981            0           21.0               NaN       No Vote
# 1861733  EF157599            0           64.0  ABSENTEE ONESTOP         Early
#
#          vote_early  vote_by_mail  vote_curbside      Pri_2016 party_cd  \
# 1861656         0.0           0.0            0.0         Early      UNA
# 1861667         1.0           0.0            0.0       No Vote      REP
# 1861689         0.0           0.0            0.0       No Vote      REP
# 1861722         0.0           0.0            0.0  Election Day      REP
# 1861733         1.0           0.0            0.0       No Vote      DEM
#
#         gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 1861656           M        1992 2010-09-29         W          UN   28079.0
# 1861667           M        1959 2002-10-07         W          UN   28079.0
# 1861689           F        1957 2012-10-16         W          NL   28079.0
# 1861722           U        1995 2016-02-18         W          UN   28174.0
# 1861733           M        1952 2009-08-28         W          NL   28112.0
#
#                 res_street_address res_city_desc birth_state drivers_lic  \
# 1861656       1004  LAVENHAM PL     INDIAN TRAIL          CA           Y
# 1861667       1004  LAVENHAM PL     INDIAN TRAIL          NY           Y
# 1861689  2110  HUNTERS TRAIL DR     INDIAN TRAIL          OC           Y
# 1861722         315 E WILSON ST          WINGATE         NaN           N
# 1861733         2905  MEDLIN RD           MONROE          MA           Y
#
#         precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 1861656           029B      029B              9.0             35.0
# 1861667           029B      029B              9.0             35.0
# 1861689           038A      038A              9.0             35.0
# 1861722            008       008              9.0             35.0
# 1861733            025       025              9.0             35.0
#
#          nc_house_abbrv  school_dist_abbrv
# 1861656            68.0                5.0
# 1861667            68.0                5.0
# 1861689            69.0                4.0
# 1861722            55.0                1.0
# 1861733            55.0                2.0

# %%
# gen_2016.to_csv('Data/gen_2016.zip', index=False)

# %% [markdown]
# ### General 2014

# %%
## Make dataframe specific to 2014 general election
gen_2014 = get_election_df(2014)
print(len(gen_2014))
display(gen_2014.head())
gen_2014.tail()
# Out:
# 98769
#          ncid  no_vote_his  birth_age_adj voting_method      Gen_2014  \
# 28   AL261840            1           20.0           NaN       No Vote
# 39   AL178177            0           56.0     IN-PERSON  Election Day
# 50   AL193958            0           56.0           NaN       No Vote
# 61   EF186953            1           19.0           NaN       No Vote
# 105  EF143409            0           24.0           NaN       No Vote
#
#      vote_early  vote_by_mail  vote_curbside Pri_2014 party_cd gender_code  \
# 28          0.0           0.0            0.0  No Vote      UNA           F
# 39          0.0           0.0            0.0  No Vote      UNA           M
# 50          0.0           0.0            0.0  No Vote      REP           F
# 61          0.0           0.0            0.0  No Vote      UNA           M
# 105         0.0           0.0            0.0  No Vote      UNA           M
#
#      birth_year registr_dt race_code ethnic_code  zip_code  \
# 28         1994 2013-11-04         W          NL   28079.0
# 39         1958 2014-09-17         W          UN   28079.0
# 50         1958 2013-07-24         W          NL   28079.0
# 61         1995 2014-01-21         W          NL   28110.0
# 105        1990 2008-04-10         M          UN   28079.0
#
#             res_street_address res_city_desc birth_state drivers_lic  \
# 28   1001  STEVENS PRIDE CT     INDIAN TRAIL          IA           Y
# 39   1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 50   1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
# 61            7607  TESH RD           MONROE          NY           Y
# 105    2000  RIDLEY PARK CT     INDIAN TRAIL          CA           Y
#
#     precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 28            029A      029A              9.0             35.0
# 39            029A      029A              9.0             35.0
# 50            029A      029A              9.0             35.0
# 61             012       012              9.0             36.0
# 105           029A      029A              9.0             35.0
#
#      nc_house_abbrv  school_dist_abbrv
# 28             68.0                3.0
# 39             68.0                3.0
# 50             68.0                3.0
# 61             69.0                4.0
# 105            68.0                3.0
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2014  \
# 1861646   EF91123            0           50.0  ABSENTEE ONESTOP         Early
# 1861657  EF162701            0           22.0         IN-PERSON  Election Day
# 1861668   EF98536            0           55.0         IN-PERSON  Election Day
# 1861690  EF180541            0           57.0               NaN       No Vote
# 1861734  EF157599            0           62.0  ABSENTEE ONESTOP         Early
#
#          vote_early  vote_by_mail  vote_curbside Pri_2014 party_cd  \
# 1861646         1.0           0.0            0.0  No Vote      REP
# 1861657         0.0           0.0            0.0  No Vote      UNA
# 1861668         0.0           0.0            0.0  No Vote      REP
# 1861690         0.0           0.0            0.0  No Vote      REP
# 1861734         1.0           0.0            0.0  No Vote      DEM
#
#         gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 1861646           F        1964 2001-08-22         W          NL   28079.0
# 1861657           M        1992 2010-09-29         W          UN   28079.0
# 1861668           M        1959 2002-10-07         W          UN   28079.0
# 1861690           F        1957 2012-10-16         W          NL   28079.0
# 1861734           M        1952 2009-08-28         W          NL   28112.0
#
#                 res_street_address res_city_desc birth_state drivers_lic  \
# 1861646       1004  LAVENHAM PL     INDIAN TRAIL          NJ           Y
# 1861657       1004  LAVENHAM PL     INDIAN TRAIL          CA           Y
# 1861668       1004  LAVENHAM PL     INDIAN TRAIL          NY           Y
# 1861690  2110  HUNTERS TRAIL DR     INDIAN TRAIL          OC           Y
# 1861734         2905  MEDLIN RD           MONROE          MA           Y
#
#         precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 1861646           029B      029B              9.0             35.0
# 1861657           029B      029B              9.0             35.0
# 1861668           029B      029B              9.0             35.0
# 1861690           038A      038A              9.0             35.0
# 1861734            025       025              9.0             35.0
#
#          nc_house_abbrv  school_dist_abbrv
# 1861646            68.0                5.0
# 1861657            68.0                5.0
# 1861668            68.0                5.0
# 1861690            69.0                4.0
# 1861734            55.0                2.0

# %%
# gen_2014.to_csv('Data/gen_2014.zip', index=False)

# %% [markdown]
# ### General 2012

# %%
## Make dataframe specific to 2012 general election
gen_2012 = get_election_df(2012)
print(len(gen_2012))
display(gen_2012.head())
gen_2012.tail()
# Out:
# 96389
#          ncid  no_vote_his  birth_age_adj     voting_method      Gen_2012  \
# 34   AL178177            0           54.0  ABSENTEE ONESTOP         Early
# 45   AL193958            0           54.0  ABSENTEE ONESTOP         Early
# 67   AN175010            0           18.0         IN-PERSON  Election Day
# 78   CW984761            0           31.0         IN-PERSON  Election Day
# 100  EF143409            0           22.0               NaN       No Vote
#
#      vote_early  vote_by_mail  vote_curbside      Pri_2012 party_cd  \
# 34          1.0           0.0            0.0  Election Day      UNA
# 45          1.0           0.0            0.0       No Vote      REP
# 67          0.0           0.0            0.0       No Vote      LIB
# 78          0.0           0.0            0.0       No Vote      REP
# 100         0.0           0.0            0.0       No Vote      UNA
#
#     gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 34            M        1958 2014-09-17         W          UN   28079.0
# 45            F        1958 2013-07-24         W          NL   28079.0
# 67            M        1994 2016-08-18         W          NL   28110.0
# 78            F        1981 2015-01-19         W          UN   28079.0
# 100           M        1990 2008-04-10         M          UN   28079.0
#
#             res_street_address res_city_desc birth_state drivers_lic  \
# 34   1001  STEVENS PRIDE CT     INDIAN TRAIL          OK           Y
# 45   1001  STEVENS PRIDE CT     INDIAN TRAIL          PA           Y
# 67            7607  TESH RD           MONROE          NY           Y
# 78     7007  BLUE STREAM LN     INDIAN TRAIL          NC           Y
# 100    2000  RIDLEY PARK CT     INDIAN TRAIL          CA           Y
#
#     precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 34            029A      029A              9.0             35.0
# 45            029A      029A              9.0             35.0
# 67             012       012              9.0             36.0
# 78             016       016              9.0             35.0
# 100           029A      029A              9.0             35.0
#
#      nc_house_abbrv  school_dist_abbrv
# 34             68.0                3.0
# 45             68.0                3.0
# 67             69.0                4.0
# 78             69.0                4.0
# 100            68.0                3.0
#              ncid  no_vote_his  birth_age_adj     voting_method      Gen_2012  \
# 1861641   EF91123            0           48.0         IN-PERSON  Election Day
# 1861652  EF162701            0           20.0               NaN       No Vote
# 1861663   EF98536            0           53.0         IN-PERSON  Election Day
# 1861707  AN145460            0           22.0         IN-PERSON  Election Day
# 1861729  EF157599            0           60.0  ABSENTEE ONESTOP         Early
#
#          vote_early  vote_by_mail  vote_curbside      Pri_2012 party_cd  \
# 1861641         0.0           0.0            0.0  Election Day      REP
# 1861652         0.0           0.0            0.0       No Vote      UNA
# 1861663         0.0           0.0            0.0  Election Day      REP
# 1861707         0.0           0.0            0.0       No Vote      REP
# 1861729         1.0           0.0            0.0       No Vote      DEM
#
#         gender_code  birth_year registr_dt race_code ethnic_code  zip_code  \
# 1861641           F        1964 2001-08-22         W          NL   28079.0
# 1861652           M        1992 2010-09-29         W          UN   28079.0
# 1861663           M        1959 2002-10-07         W          UN   28079.0
# 1861707           U        1990 2019-10-09         U          UN   28112.0
# 1861729           M        1952 2009-08-28         W          NL   28112.0
#
#              res_street_address res_city_desc birth_state drivers_lic  \
# 1861641    1004  LAVENHAM PL     INDIAN TRAIL          NJ           Y
# 1861652    1004  LAVENHAM PL     INDIAN TRAIL          CA           Y
# 1861663    1004  LAVENHAM PL     INDIAN TRAIL          NY           Y
# 1861707  2017  BRIARBERRY LN           MONROE         NaN           Y
# 1861729      2905  MEDLIN RD           MONROE          MA           Y
#
#         precinct_abbrv vtd_abbrv  cong_dist_abbrv  nc_senate_abbrv  \
# 1861641           029B      029B              9.0             35.0
# 1861652           029B      029B              9.0             35.0
# 1861663           029B      029B              9.0             35.0
# 1861707            007       007              9.0             35.0
# 1861729            025       025              9.0             35.0
#
#          nc_house_abbrv  school_dist_abbrv
# 1861641            68.0                5.0
# 1861652            68.0                5.0
# 1861663            68.0                5.0
# 1861707            55.0                1.0
# 1861729            55.0                2.0

# %%
# gen_2012.to_csv('Data/gen_2012.zip', index=False)
