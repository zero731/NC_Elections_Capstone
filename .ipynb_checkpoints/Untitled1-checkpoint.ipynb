# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.options.display.max_columns = 70

# %%
uc_vhis = pd.read_table('Data/ncvhis90.txt')
uc_vhis.head(15)
# Out:
#     county_id county_desc  voter_reg_num election_lbl  \
# 0          90       UNION         285297   11/06/2018
# 1          90       UNION         285297   11/03/2020
# 2          90       UNION         285297   11/08/2016
# 3          90       UNION         285297   09/10/2019
# 4          90       UNION         285297   03/03/2020
# 5          90       UNION         285297   11/08/2011
# 6          90       UNION         285297   05/08/2012
# 7          90       UNION         228937   11/08/2016
# 8          90       UNION         228937   11/06/2012
# 9          90       UNION         228937   05/08/2012
# 10         90       UNION         228937   11/04/2014
# 11         90       UNION         316902   11/08/2016
# 12         90       UNION         361191   11/06/2012
# 13         90       UNION         361191   05/08/2012
# 14         90       UNION         361191   11/03/2020
#
#                    election_desc     voting_method voted_party_cd  \
# ...

# %%
uc_vhis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806996 entries, 0 to 806995
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   county_id          806996 non-null  int64
#  1   county_desc        806996 non-null  object
#  2   voter_reg_num      806996 non-null  int64
#  3   election_lbl       806996 non-null  object
#  4   election_desc      806996 non-null  object
#  5   voting_method      806996 non-null  object
#  6   voted_party_cd     806932 non-null  object
#  7   voted_party_desc   806932 non-null  object
#  8   pct_label          806996 non-null  object
#  9   pct_description    806996 non-null  object
#  10  ncid               806996 non-null  object
#  11  voted_county_id    806996 non-null  int64
#  12  voted_county_desc  806996 non-null  object
#  13  vtd_label          806828 non-null  object
#  14  vtd_description    806828 non-null  object
# dtypes: int64(3), object(12)
# ...

# %%
uc_vreg = pd.read_table('Data/ncvoter90.txt', encoding='ISO-8859-1')
uc_vreg.head()
# Out:
#    county_id county_desc  voter_reg_num status_cd voter_status_desc reason_cd  \
# 0         90       UNION         346446         A            ACTIVE        AV
# 1         90       UNION         348004         A            ACTIVE        AV
# 2         90       UNION         281016         A            ACTIVE        AV
# 3         90       UNION         288489         A            ACTIVE        AV
# 4         90       UNION         279308         A            ACTIVE        AV
#
#   voter_status_reason_desc absent_ind name_prefx_cd last_name first_name  \
# 0                 VERIFIED                             AALAEI       ARIO
# 1                 VERIFIED                             AALAEI    KAVITHA
# 2                 VERIFIED                            AALBORG     ALEXIS
# 3                 VERIFIED                            AALBORG      BRYAN
# 4                 VERIFIED                            AALBORG     SHARON
#
# ...

# %%
uc_vreg['dist_2_abbrv'].value_counts()
# Out:
#      183969
# Name: dist_2_abbrv, dtype: int64

# %%
uc_vreg['dist_2_abbrv'][0]
# Out:
# ' '

# %%
uc_vreg['dist_2_desc'].value_counts()
# Out:
#      183969
# Name: dist_2_desc, dtype: int64

# %%
uc_vreg['dist_2_desc'][0]
# Out:
# ' '

# %%
uc_vreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183969 entries, 0 to 183968
# Data columns (total 71 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county_id                 183969 non-null  int64
#  1   county_desc               183969 non-null  object
#  2   voter_reg_num             183969 non-null  int64
#  3   status_cd                 183969 non-null  object
#  4   voter_status_desc         183969 non-null  object
#  5   reason_cd                 183969 non-null  object
#  6   voter_status_reason_desc  183969 non-null  object
#  7   absent_ind                183969 non-null  object
#  8   name_prefx_cd             183969 non-null  object
#  9   last_name                 183965 non-null  object
#  10  first_name                183967 non-null  object
#  11  middle_name               168871 non-null  object
#  12  name_suffix_lbl           20984 non-null   object
# ...

# %%
null_cols = [col for col in uc_vreg.columns if uc_vreg[col].isna().mean() == 1]
null_cols = null_cols + ['absent_ind','name_prefx_cd','dist_2_abbrv','dist_2_desc']

# %%
uc_vreg.drop(columns=null_cols, axis=1, inplace=True)

# %%
uc_vreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183969 entries, 0 to 183968
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county_id                 183969 non-null  int64
#  1   county_desc               183969 non-null  object
#  2   voter_reg_num             183969 non-null  int64
#  3   status_cd                 183969 non-null  object
#  4   voter_status_desc         183969 non-null  object
#  5   reason_cd                 183969 non-null  object
#  6   voter_status_reason_desc  183969 non-null  object
#  7   last_name                 183965 non-null  object
#  8   first_name                183967 non-null  object
#  9   middle_name               168871 non-null  object
#  10  name_suffix_lbl           20984 non-null   object
#  11  res_street_address        183969 non-null  object
#  12  res_city_desc             170603 non-null  object
# ...

# %%
for col in uc_vreg.columns:
    print('***'*8)
    print(col,':')
    print('---'*5)
    print(uc_vreg[col].value_counts(dropna=False))
    print('***'*8)
    print()
# Out:
# ************************
# county_id :
# ---------------
# 90    183969
# Name: county_id, dtype: int64
# ************************
#
# ************************
# county_desc :
# ---------------
# UNION    183969
# Name: county_desc, dtype: int64
# ************************
#
# ************************
# voter_reg_num :
# ---------------
# 264191    1
# 298171    1
# 152800    1
# 238814    1
# 232667    1
#          ..
# 350846    1
# 344701    1
# 346748    1
# 356987    1
# 262144    1
# Name: voter_reg_num, Length: 183969, dtype: int64
# ************************
#
# ************************
# status_cd :
# ---------------
# A    154115
# I     15014
# R     13363
# D      1354
# S       123
# Name: status_cd, dtype: int64
# ************************
#
# ************************
# voter_status_desc :
# ---------------
# ACTIVE       154115
# INACTIVE      15014
# REMOVED       13363
# DENIED         1354
# TEMPORARY       123
# Name: voter_status_desc, dtype: int64
# ...

# %%
uc_voters_outer = uc_vhis.merge(uc_vreg, how='outer', on='ncid')
uc_voters_outer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 826425 entries, 0 to 826424
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county_id_x               806996 non-null  float64
#  1   county_desc_x             806996 non-null  object
#  2   voter_reg_num_x           806996 non-null  float64
#  3   election_lbl              806996 non-null  object
#  4   election_desc             806996 non-null  object
#  5   voting_method             806996 non-null  object
#  6   voted_party_cd            806932 non-null  object
#  7   voted_party_desc          806932 non-null  object
#  8   pct_label                 806996 non-null  object
#  9   pct_description           806996 non-null  object
#  10  ncid                      826425 non-null  object
#  11  voted_county_id           806996 non-null  float64
#  12  voted_county_desc         806996 non-null  object
# ...

# %%
print(len(uc_vhis))
uc_vhis['ncid'].nunique()
# Out:
# 806996
# 164783

# %%
print(len(uc_vreg))
uc_vreg['ncid'].nunique()
# Out:
# 183969
# 183969

# %%
uc_voters_outer['ncid'].nunique()
# Out:
# 184212

# %%
uc_voters_outer.head(50)
# Out:
#     county_id_x county_desc_x  voter_reg_num_x election_lbl  \
# 0          90.0         UNION         285297.0   11/06/2018
# 1          90.0         UNION         285297.0   11/03/2020
# 2          90.0         UNION         285297.0   11/08/2016
# 3          90.0         UNION         285297.0   09/10/2019
# 4          90.0         UNION         285297.0   03/03/2020
# 5          90.0         UNION         285297.0   11/08/2011
# 6          90.0         UNION         285297.0   05/08/2012
# 7          90.0         UNION         228937.0   11/08/2016
# 8          90.0         UNION         228937.0   11/06/2012
# 9          90.0         UNION         228937.0   05/08/2012
# 10         90.0         UNION         228937.0   11/04/2014
# 11         90.0         UNION         316902.0   11/08/2016
# 12         90.0         UNION         361191.0   11/06/2012
# 13         90.0         UNION         361191.0   05/08/2012
# 14         90.0         UNION         361191.0   11/03/2020
# ...

# %%
uc_voters_outer.tail(50)
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl election_desc  \
# 826375          NaN           NaN              NaN          NaN           NaN
# 826376          NaN           NaN              NaN          NaN           NaN
# 826377          NaN           NaN              NaN          NaN           NaN
# 826378          NaN           NaN              NaN          NaN           NaN
# 826379          NaN           NaN              NaN          NaN           NaN
# 826380          NaN           NaN              NaN          NaN           NaN
# 826381          NaN           NaN              NaN          NaN           NaN
# 826382          NaN           NaN              NaN          NaN           NaN
# 826383          NaN           NaN              NaN          NaN           NaN
# 826384          NaN           NaN              NaN          NaN           NaN
# 826385          NaN           NaN              NaN          NaN           NaN
# ...

# %%
uc_voters_outer.loc[uc_voters['ncid']=='EF160001']
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl election_desc  \
# 826396          NaN           NaN              NaN          NaN           NaN
#
#        voting_method voted_party_cd voted_party_desc pct_label  \
# 826396           NaN            NaN              NaN       NaN
#
#        pct_description      ncid  voted_county_id voted_county_desc vtd_label  \
# 826396             NaN  EF160001              NaN               NaN       NaN
#
#        vtd_description  county_id_y county_desc_y  voter_reg_num_y status_cd  \
# 826396             NaN         90.0         UNION         246590.0         A
#
#        voter_status_desc reason_cd voter_status_reason_desc last_name  \
# 826396            ACTIVE        AV                 VERIFIED  ZHUPIKOV
#
#        first_name   middle_name name_suffix_lbl res_street_address  \
# 826396      ALINA  VLADIMIROVNA             NaN  614  BUFORD ST
#
#        res_city_desc state_cd  zip_code  mail_addr1 mail_addr2 mail_addr3  \
# ...

# %%
not_uc = uc_voters.loc[uc_voters['county_id_x'] != 90]
not_uc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42341 entries, 675416 to 717756
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   county_id_x               0 non-null      float64
#  1   county_desc_x             0 non-null      object
#  2   voter_reg_num_x           0 non-null      float64
#  3   election_lbl              0 non-null      object
#  4   election_desc             0 non-null      object
#  5   voting_method             0 non-null      object
#  6   voted_party_cd            0 non-null      object
#  7   voted_party_desc          0 non-null      object
#  8   pct_label                 0 non-null      object
#  9   pct_description           0 non-null      object
#  10  ncid                      42341 non-null  object
#  11  voted_county_id           0 non-null      float64
#  12  voted_county_desc         0 non-null      object
# ...

# %%
not_uc.head(50)
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl election_desc  \
# 675416          NaN           NaN              NaN          NaN           NaN
# 675417          NaN           NaN              NaN          NaN           NaN
# 675418          NaN           NaN              NaN          NaN           NaN
# 675419          NaN           NaN              NaN          NaN           NaN
# 675420          NaN           NaN              NaN          NaN           NaN
# 675421          NaN           NaN              NaN          NaN           NaN
# 675422          NaN           NaN              NaN          NaN           NaN
# 675423          NaN           NaN              NaN          NaN           NaN
# 675424          NaN           NaN              NaN          NaN           NaN
# 675425          NaN           NaN              NaN          NaN           NaN
# 675426          NaN           NaN              NaN          NaN           NaN
# ...

# %%
mism_reg_nums = uc_voters.loc[uc_voters['voter_reg_num_x'] != uc_voters['voter_reg_num_y']]
mism_reg_nums.head(50)
# Out:
#       county_id_x county_desc_x  voter_reg_num_x election_lbl  \
# 123          90.0         UNION         320824.0   11/06/2012
# 124          90.0         UNION         320824.0   05/08/2012
# 125          90.0         UNION         320824.0   11/08/2016
# 394          90.0         UNION         360071.0   11/08/2016
# 395          90.0         UNION         360071.0   11/06/2012
# 997          90.0         UNION         341427.0   11/06/2012
# 998          90.0         UNION         341427.0   05/08/2012
# 1699         90.0         UNION         327849.0   11/06/2012
# 1825         90.0         UNION         321607.0   11/08/2016
# 1826         90.0         UNION         321607.0   11/06/2012
# 1885         90.0         UNION         295412.0   07/15/2014
# 1886         90.0         UNION         295412.0   11/06/2012
# 2057         90.0         UNION         277090.0   05/08/2012
# 2191         90.0         UNION         298317.0   11/06/2012
# ...

# %%
mism_reg_nums.tail(50)
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl election_desc  \
# 717707          NaN           NaN              NaN          NaN           NaN
# 717708          NaN           NaN              NaN          NaN           NaN
# 717709          NaN           NaN              NaN          NaN           NaN
# 717710          NaN           NaN              NaN          NaN           NaN
# 717711          NaN           NaN              NaN          NaN           NaN
# 717712          NaN           NaN              NaN          NaN           NaN
# 717713          NaN           NaN              NaN          NaN           NaN
# 717714          NaN           NaN              NaN          NaN           NaN
# 717715          NaN           NaN              NaN          NaN           NaN
# 717716          NaN           NaN              NaN          NaN           NaN
# 717717          NaN           NaN              NaN          NaN           NaN
# ...

# %%
uc_voters.loc[uc_voters['birth_year'] == 1753]
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl election_desc  \
# 692764          NaN           NaN              NaN          NaN           NaN
#
#        voting_method voted_party_cd voted_party_desc pct_label  \
# 692764           NaN            NaN              NaN       NaN
#
#        pct_description      ncid  voted_county_id voted_county_desc vtd_label  \
# 692764             NaN  EF155672              NaN               NaN       NaN
#
#        vtd_description  county_id_y county_desc_y  voter_reg_num_y status_cd  \
# 692764             NaN         90.0         UNION         376011.0         A
#
#        voter_status_desc reason_cd voter_status_reason_desc last_name  \
# 692764            ACTIVE        AP     VERIFICATION PENDING  HOLLIDAY
#
#        first_name middle_name name_suffix_lbl     res_street_address  \
# 692764    TIFFANY       JEWEL             NaN  2315  COATSDALE LN
#
#        res_city_desc state_cd  zip_code         mail_addr1 mail_addr2  \
# ...

# %%
uc_voters.loc[uc_voters['first_name'] == 'KRISTY'].loc[uc_voters['last_name'] == 'CONFER']
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl  \
# 435314         90.0         UNION         333619.0   09/10/2019
# 435315         90.0         UNION         333619.0   11/06/2018
# 435316         90.0         UNION         333619.0   03/03/2020
#
#              election_desc     voting_method voted_party_cd voted_party_desc  \
# 435314  09/10/2019 GENERAL         IN-PERSON            DEM       DEMOCRATIC
# 435315  11/06/2018 GENERAL  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 435316  03/03/2020 PRIMARY         IN-PERSON            DEM       DEMOCRATIC
#
#        pct_label pct_description      ncid  voted_county_id voted_county_desc  \
# 435314      029A            029A  EF221606             90.0             UNION
# 435315      029C            029C  EF221606             90.0             UNION
# 435316      029A            029A  EF221606             90.0             UNION
#
#        vtd_label vtd_description  county_id_y county_desc_y  voter_reg_num_y  \
# ...

# %%
uc_voters.loc[uc_voters['first_name'] == 'MAX'].loc[uc_voters['last_name'] == 'STEELE']
# Out:
#         county_id_x county_desc_x  voter_reg_num_x election_lbl  \
# 305581         90.0         UNION         246238.0   03/03/2020
# 305582         90.0         UNION         246238.0   11/06/2012
# 305583         90.0         UNION         246238.0   05/08/2012
# 305584         90.0         UNION         246238.0   09/10/2019
#
#              election_desc     voting_method voted_party_cd voted_party_desc  \
# 305581  03/03/2020 PRIMARY         IN-PERSON            DEM       DEMOCRATIC
# 305582  11/06/2012 GENERAL  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 305583  05/08/2012 PRIMARY  ABSENTEE ONESTOP            DEM       DEMOCRATIC
# 305584  09/10/2019 GENERAL         IN-PERSON            DEM       DEMOCRATIC
#
#        pct_label pct_description      ncid  voted_county_id voted_county_desc  \
# 305581       023             023  EF159734             90.0             UNION
# 305582       010             010  EF159734             90.0             UNION
# ...

# %%
uc_voters['election_desc'].value_counts()
# Out:
# 11/08/2016 GENERAL                   107393
# 11/06/2012 GENERAL                    97635
# 11/06/2018 GENERAL                    88066
# 09/10/2019 GENERAL                    59807
# 11/04/2014 GENERAL                    59707
#                                       ...
# 09/10/2013 PRIMARY                        1
# 11/08/2011 GENERAL MUNICIPAL              1
# 09/15/2015 ALB PRIMARY                    1
# 06/23/2020 SECOND PRIMARY                 1
# 11/05/2013 MUNI AND SANI DISTRICT         1
# Name: election_desc, Length: 107, dtype: int64

# %%
pd.options.display.max_rows = 110
elec_counts_df = uc_voters['election_desc'].value_counts().to_frame().head(20)
elec_counts_df.head(20)
# Out:
#                                                     election_desc
# 11/08/2016 GENERAL                                         107393
# 11/06/2012 GENERAL                                          97635
# 11/06/2018 GENERAL                                          88066
# 09/10/2019 GENERAL                                          59807
# 11/04/2014 GENERAL                                          59707
# 03/15/2016 PRIMARY                                          46766
# 03/03/2020 PRIMARY                                          43473
# 05/08/2012 PRIMARY                                          41394
# 05/08/2018 PRIMARY                                          18118
# 05/06/2014 PRIMARY                                          15673
# 05/14/2019 PRIMARY                                          12705
# 11/05/2019 MUNICIPAL                                        12533
# 06/07/2016 CONGRESSIONAL PRIMARY                            12394
# ...

# %%
major_elections = elec_counts_df.loc[elec_counts_df['election_desc'] > 12700].index.to_list()
major_elections
# Out:
# ['11/08/2016 GENERAL',
#  '11/06/2012 GENERAL',
#  '11/06/2018 GENERAL',
#  '09/10/2019 GENERAL',
#  '11/04/2014 GENERAL',
#  '03/15/2016 PRIMARY',
#  '03/03/2020 PRIMARY',
#  '05/08/2012 PRIMARY',
#  '05/08/2018 PRIMARY',
#  '05/06/2014 PRIMARY',
#  '05/14/2019 PRIMARY']

# %%
uc_major_elec_df = uc_voters.loc[uc_voters['election_desc'].isin(major_elections)]
uc_major_elec_df.head(20)
# Out:
#     county_id_x county_desc_x  voter_reg_num_x election_lbl  \
# 0          90.0         UNION         285297.0   11/08/2016
# 1          90.0         UNION         285297.0   09/10/2019
# 2          90.0         UNION         285297.0   03/03/2020
# 3          90.0         UNION         285297.0   11/06/2018
# 5          90.0         UNION         285297.0   05/08/2012
# 6          90.0         UNION         228937.0   11/04/2014
# 7          90.0         UNION         228937.0   11/06/2012
# 8          90.0         UNION         228937.0   05/08/2012
# 9          90.0         UNION         228937.0   11/08/2016
# 10         90.0         UNION         316902.0   11/08/2016
# 11         90.0         UNION         361191.0   11/06/2012
# 12         90.0         UNION         361191.0   05/08/2012
# 13         90.0         UNION         272440.0   11/06/2012
# 14         90.0         UNION         272440.0   11/08/2016
# 15         90.0         UNION         272440.0   11/04/2014
# ...

# %%
uc_voters['election_desc'][0].split()[1:]
# Out:
# ['GENERAL']

# %%
uc_voters['election_desc'][23].split()[1:]
# Out:
# ['CONGRESSIONAL', 'PRIMARY']

# %%
uc_voters['election_type'] =
